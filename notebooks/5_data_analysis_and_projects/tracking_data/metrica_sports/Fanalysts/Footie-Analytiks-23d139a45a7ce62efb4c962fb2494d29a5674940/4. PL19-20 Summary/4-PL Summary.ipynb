# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
PL_players = pd.read_csv('D:/Football/Data/FBref/PL/Player_name.csv')

# %%
PL_players.head()
# Out:
#    ID               Player    Name
# 0   0  Patrick van Aanholt     PVA
# 1   1           Max Aarons  Aarons
# 2   2        Tammy Abraham   Tammy
# 3   3            Che Adams   Adams
# 4   4               Adrián  Adrián

# %% [markdown]
# <h1>SOME OBSERVATIONS:</h1>
#
# Some interesting facts from EPL:
#
# <ul>
#     <li><strong>Liverpool</strong> have the least number of <strong>yellow cards</strong> (26)</li>
#     <li><strong>Southampton</strong> are the one of the 5 teams to have more than 5 away wins this season(6), others being Liverpool,City,Leicester, Chelsea. </li>
#     <li>Penalty Data</li>
# </ul>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

fixg,ax = plt.subplots(figsize=(10,8))
p1 = plt.bar(ind, menMeans, width, yerr=menStd,color='r')
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd,color='b')

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
league_table = pd.read_csv('D:\Football\Data\FBref\PL\League-Table.csv')
league_table.head()
# Out:
#    Rk             Team  Home-MP  Home-W  Home-D  Home-L  Home-GF  Home-GA  \
# 0   1        Liverpool       15      15       0       0       40       12
# 1   2  Manchester City       13       9       2       2       33       12
# 2   3   Leicester City       15       9       3       3       30       15
# 3   4          Chelsea       15       7       3       5       22       15
# 4   5   Manchester Utd       15       8       5       2       29       12
#
#    Home-GDiff  Home-Pts  ...  Away-L  Away-GF  Away-GA  Away-GDiff  Away-Pts  \
# 0          28        45  ...       1       26        9          17        37
# 1          21        29  ...       5       35       19          16        28
# 2          15        30  ...       5       28       13          15        23
# 3           7        24  ...       4       29       24           5        24
# 4          17        29  ...       6       15       18          -3        16
#
# ...

# %%
league_table.columns[2:17]
# Out:
# Index(['Home-MP', 'Home-W', 'Home-D', 'Home-L', 'Home-GF', 'Home-GA',
#        'Home-GDiff', 'Home-Pts', 'Home-Pts/G', 'Home-xG', 'Home-xGA',
#        'Home-xGDiff', 'Home-xGDiff/90', 'Away-MP', 'Away-W'],
#       dtype='object')

# %%
std_stats = pd.read_csv('D:\Football\Data\FBref\PL\Standard-stats.csv',header=[0,1])
std_stats.head()
# Out:
#                                Playing Time              Performance         \
#           Team # Players  Poss           MP Starts   Min         Gls Ast PK
# 0      Arsenal        27  55.7           28    308  2520          40  27  2
# 1  Aston Villa        28  45.7           28    308  2520          33  27  1
# 2  Bournemouth        25  44.7           29    319  2610          28  18  1
# 3     Brighton        24  55.8           29    319  2610          28  19  1
# 4      Burnley        21  40.2           29    319  2610          33  23  2
#
#          ... Per 90 Minutes        Expected             Per 90 Minutes        \
#   PKatt  ...           G-PK G+A-PK       xG  npxG    xA             xG    xA
# 0     2  ...           1.36   2.32     36.3  34.8  36.3           1.30  1.30
# 1     3  ...           1.14   2.11     31.1  28.7  31.1           1.11  1.11
# 2     1  ...           0.93   1.55     32.6  31.8  32.6           1.12  1.12
# ...

# %%
std_stats.columns = [f'{i}{j}' for i, j in std_stats.columns]

# %%
std_stats.columns
# Out:
# Index([' Team', ' # Players', ' Poss', 'Playing TimeMP', 'Playing TimeStarts',
#        'Playing TimeMin', 'PerformanceGls', 'PerformanceAst', 'PerformancePK',
#        'PerformancePKatt', 'PerformanceCrdY', 'PerformanceCrdR',
#        'Per 90 MinutesGls', 'Per 90 MinutesAst', 'Per 90 MinutesG+A',
#        'Per 90 MinutesG-PK', 'Per 90 MinutesG+A-PK', 'ExpectedxG',
#        'ExpectednpxG', 'ExpectedxA', 'Per 90 MinutesxG', 'Per 90 MinutesxA',
#        'Per 90 MinutesxG+xA', 'Per 90 MinutesnpxG', 'Per 90 MinutesnpxG+xA'],
#       dtype='object')

# %%
yellow_card_data = std_stats.sort_values(by='PerformanceCrdY')[[' Team','PerformanceCrdY','PerformanceCrdR']]

# %%
penalty_data = std_stats.sort_values(by=['PerformancePK','PerformancePKatt'],ascending=False)[[' Team','PerformancePK','PerformancePKatt']]

# %%
penalty_data['PKMissed'] = penalty_data['PerformancePKatt'] - penalty_data['PerformancePK']
penalty_data
# Out:
#                Team  PerformancePK  PerformancePKatt  PKMissed
# 11   Manchester Utd              6                10         4
# 8    Leicester City              5                 7         2
# 9         Liverpool              5                 5         0
# 17          Watford              4                 5         1
# 5           Chelsea              4                 4         0
# 10  Manchester City              3                 7         4
# 16        Tottenham              3                 4         1
# 6    Crystal Palace              3                 3         0
# 18         West Ham              3                 3         0
# 19           Wolves              3                 3         0
# 0           Arsenal              2                 2         0
# 4           Burnley              2                 2         0
# 13     Norwich City              2                 2         0
# 1       Aston Villa              1                 3         2
# ...

# %%
csfont = {'fontname':'serif'}

fig,ax = plt.subplots(figsize=(8,9))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# ax.spines['bottom'].set_visible(False)

p1 = plt.barh(np.arange(20),penalty_data['PerformancePK'],height=0.7,color="#00aa00",edgecolor="#000000")
p2 = plt.barh(np.arange(20),penalty_data['PKMissed'],left=penalty_data['PerformancePK'],height=0.7,color="#ff0000",edgecolor="#000000")


plt.xlabel('Goals',fontsize=16,labelpad=10,**csfont)
plt.title('Penalty Kicks',fontsize=22,**csfont)

plt.xticks(np.arange(11),**csfont,fontsize=14)
plt.yticks(np.arange(20), penalty_data[' Team'],**csfont,fontsize=14)

plt.legend((p1[0], p2[0]), ('Scored', 'Missed'),fontsize=15)
# plt.grid(linestyle='-',color='white',alpha=0.5)

plt.annotate('Viz by @gkgokul10', xy=(0.7,-0.08), xycoords='axes fraction',fontsize='14')

plt.savefig('D:/Pen-kics.png',dpi=1000,bbox_inches = "tight")
plt.show()

# %%
yellow_card_data
# Out:
#                Team  PerformanceCrdY  PerformanceCrdR
# 9         Liverpool               26                1
# 8    Leicester City               33                1
# 15      Southampton               44                3
# 3          Brighton               47                2
# 6    Crystal Palace               48                1
# 19           Wolves               49                2
# 14    Sheffield Utd               51                1
# 12    Newcastle Utd               52                3
# 13     Norwich City               53                1
# 5           Chelsea               53                0
# 18         West Ham               55                1
# 10  Manchester City               55                3
# 1       Aston Villa               55                1
# 11   Manchester Utd               56                0
# 4           Burnley               58                0
# 7           Everton               59                3
# ...

# %%
import matplotlib.colors as mcolors

csfont = {'fontname':'serif'}

fig,ax = plt.subplots(figsize=(10,10))

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

clist = [(0, "#bbbb00"),(1, "#eeee00")]

rvb = mcolors.LinearSegmentedColormap.from_list("", clist)

plt.xlim([20,70])
plt.xlabel('No. of Cards',fontsize=16,labelpad=10,**csfont)

plt.xticks(np.arange(20,70,2),fontsize=12)
plt.yticks(np.arange(20), yellow_card_data[' Team'],**csfont,fontsize=14)
p1 = plt.barh(np.arange(20),yellow_card_data['PerformanceCrdY'],height=0.7,color=rvb(np.arange(20)/20.0),edgecolor="#000000")
p2 = plt.barh(np.arange(20),yellow_card_data['PerformanceCrdR'],left=yellow_card_data['PerformanceCrdY'],height=0.7,color='red',edgecolor="#000000",alpha=0.9)

plt.title('Bookings',fontsize=22,**csfont)
plt.legend((p1[len(p1)-1], p2[0]), ('Yellow', 'Red'),fontsize=15)
plt.grid(linestyle='-',color='white',alpha=0.2)

plt.annotate('Viz by @gkgokul10', xy=(0.7,-0.08), xycoords='axes fraction',fontsize='14')

plt.savefig('D:/Bookings.png',dpi=800,bbox_inches = "tight")
plt.show()

# %%
SCA_GCA_stats= pd.read_csv('D:\Football\Data\FBref\PL\SCA-GCA.csv',header=[0,1])
SCA_GCA_stats.head()
# Out:
#                      SCA        SCA Types                       GCA        \
#           Team # Pl  SCA  SCA90  PassLive PassDead Drib  Sh Fld GCA GCA90
# 0      Arsenal   27  486  17.36       351       44   36  30  25  58  2.07
# 1  Aston Villa   28  557  19.89       414       52   33  20  37  58  2.07
# 2  Bournemouth   25  436  15.03       309       49   24  22  31  44  1.52
# 3     Brighton   24  578  19.93       432       57   32  27  26  53  1.83
# 4      Burnley   21  414  14.28       286       52   19  29  27  47  1.62
#
#   GCA Types
#    PassLive PassDead Drib Sh Fld OG
# 0        42        3    2  8   3  0
# 1        42        4    5  3   3  1
# 2        26        3    3  6   5  1
# 3        31        7    4  2   5  4
# 4        32        5    3  5   1  1

# %%
SCA_GCA_stats.columns = [f'{i}{j}' for i, j in SCA_GCA_stats.columns]
SCA_GCA_stats.columns
# Out:
# Index([' Team', ' # Pl', 'SCASCA', 'SCASCA90', 'SCA TypesPassLive',
#        'SCA TypesPassDead', 'SCA TypesDrib', 'SCA TypesSh', 'SCA TypesFld',
#        'GCAGCA', 'GCAGCA90', 'GCA TypesPassLive', 'GCA TypesPassDead',
#        'GCA TypesDrib', 'GCA TypesSh', 'GCA TypesFld', 'GCA TypesOG'],
#       dtype='object')

# %%
SCA_GCA = SCA_GCA_stats[[' Team','SCASCA90','GCAGCA90']]
SCA_GCA
# Out:
#                Team  SCASCA90  GCAGCA90
# 0           Arsenal     17.36      2.07
# 1       Aston Villa     19.89      2.07
# 2       Bournemouth     15.03      1.52
# 3          Brighton     19.93      1.83
# 4           Burnley     14.28      1.62
# 5           Chelsea     26.24      2.62
# 6    Crystal Palace     13.79      1.52
# 7           Everton     19.14      1.79
# 8    Leicester City     22.21      3.34
# 9         Liverpool     23.62      3.62
# 10  Manchester City     31.11      4.11
# 11   Manchester Utd     24.00      2.24
# 12    Newcastle Utd     15.07      1.28
# 13     Norwich City     17.76      1.17
# 14    Sheffield Utd     15.61      1.57
# 15      Southampton     18.38      1.55
# 16        Tottenham     19.21      2.41
# 17          Watford     16.93      1.24
# 18         West Ham     16.31      2.03
# 19           Wolves     18.76      2.24

# %%
np.median(SCA_GCA['SCASCA90'])
# Out:
# 18.57

# %%
csfont = {'fontname':'serif'}

fig,ax = plt.subplots(figsize=(12,12))

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.yticks(np.arange(0,4.5,0.25))
plt.xticks(np.arange(10,34,1))

plt.scatter(SCA_GCA['SCASCA90'],SCA_GCA['GCAGCA90'],color='red')

for ind,data in SCA_GCA.iterrows():
    if(data[' Team']=='Bournemouth' or data[' Team']=='Norwich City' or data[' Team']=='Watford'or data[' Team']=='West Ham'or data[' Team']=='Everton'):
        plt.annotate(data[' Team'], xy=(data['SCASCA90']-0.8,data['GCAGCA90']-0.07), xycoords='data',fontsize=12,**csfont)
    else:
        plt.annotate(data[' Team'], xy=(data['SCASCA90']-1,data['GCAGCA90']+0.03), xycoords='data',fontsize=12,**csfont)

        
        
plt.xlabel('Shot-Creating Actions per 90',fontsize=16, labelpad=10,**csfont)
plt.ylabel('Goal-Creating Actions per 90',fontsize=16, labelpad=10,**csfont)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title('Attacking Actions per 90',fontsize=22,**csfont)
plt.grid(linestyle='-',color='white',alpha=0.25)

plt.annotate('Viz by @gkgokul10', xy=(0.8,-0.07), xycoords='axes fraction',fontsize='14')

plt.savefig('D:/Attacking-Actions-per90.png',dpi=700,bbox_inches = "tight")
plt.show()

# %%
Sqd_def_stats= pd.read_csv('D:\Football\Data\FBref\PL\Squad-def-actions.csv',header=[0,1])
Sqd_def_stats.head()
# Out:
#                     Tackles                              Vs Dribbles       \
#           Team # Pl     Tkl TklW Def 3rd Mid 3rd Att 3rd         Tkl  Att
# 0      Arsenal   27     469  292     255     157      57         161  463
# 1  Aston Villa   28     485  311     271     157      57         157  483
# 2  Bournemouth   25     428  260     219     168      41         142  446
# 3     Brighton   24     519  326     254     195      70         167  497
# 4      Burnley   21     454  269     201     190      63         171  485
#
#          ... Pressures                 Blocks
#    Tkl%  ...   Def 3rd Mid 3rd Att 3rd Blocks   Sh ShSv Pass  Int  Clr Err
# 0  34.8  ...      1770    2037     938    455  117    2  338  242  724   6
# 1  32.5  ...      1709    1903     971    566  181    4  385  312  757  23
# 2  31.8  ...      1759    2289    1176    552  146    3  406  387  983  10
# 3  33.6  ...      1531    1918    1086    457  109    3  348  308  707  11
# ...

# %%
Sqd_def_stats.columns = [f'{i}{j}' for i, j in Sqd_def_stats.columns]
Sqd_def_stats.columns
# Out:
# Index([' Team', ' # Pl', 'TacklesTkl', 'TacklesTklW', 'TacklesDef 3rd',
#        'TacklesMid 3rd', 'TacklesAtt 3rd', 'Vs DribblesTkl', 'Vs DribblesAtt',
#        'Vs DribblesTkl%', 'Vs DribblesPast', 'PressuresPress', 'PressuresSucc',
#        'Pressures%', 'PressuresDef 3rd', 'PressuresMid 3rd',
#        'PressuresAtt 3rd', 'BlocksBlocks', 'BlocksSh', 'BlocksShSv',
#        'BlocksPass', ' Int', ' Clr', ' Err'],
#       dtype='object')

# %%
att3_press = Sqd_def_stats[[' Team','PressuresPress','Pressures%','PressuresDef 3rd', 'PressuresMid 3rd',
       'PressuresAtt 3rd']]

# df['Discounted_Price'] = df.apply(lambda row: row.Cost - 
#                                   (row.Cost * 0.1), axis = 1) 

# att3_press['%inAtt3rd'] = att3_press.apply(lambda row: row['PressuresAtt 3rd']/row['PressuresPress'], axis=1) 

att3_press['%inDef3rd'] = att3_press['PressuresDef 3rd']*100/att3_press['PressuresPress']
att3_press['%inMid3rd'] = att3_press['PressuresMid 3rd']*100/att3_press['PressuresPress']
att3_press['%inAtt3rd'] = att3_press['PressuresAtt 3rd']*100/att3_press['PressuresPress']

att3_press['%inAtt3rd'] = att3_press['%inAtt3rd'].astype(float).round(1)
att3_press['%inMid3rd'] = att3_press['%inMid3rd'].astype(float).round(1)
att3_press['%inDef3rd'] = att3_press['%inDef3rd'].astype(float).round(1)

att3_press.sort_values(by='%inAtt3rd')
att3_press
# Out:
# C:\Users\gkgok\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\gkgok\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\gkgok\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
press_stats = att3_press.sort_values(by='PressuresPress')
press_stats
# Out:
#                Team  PressuresPress  Pressures%  PressuresDef 3rd  \
# 10  Manchester City            3949        30.3               934
# 3          Brighton            4535        31.0              1531
# 1       Aston Villa            4583        27.8              1709
# 9         Liverpool            4608        31.7              1264
# 4           Burnley            4707        25.0              1394
# 0           Arsenal            4745        26.6              1770
# 7           Everton            4853        27.3              1561
# 11   Manchester Utd            4892        28.5              1546
# 14    Sheffield Utd            4899        28.0              1633
# 6    Crystal Palace            4947        26.7              1972
# 5           Chelsea            4949        30.4              1403
# 12    Newcastle Utd            4985        24.4              2157
# 16        Tottenham            5054        28.2              1817
# ...

# %%
import matplotlib.colors as mcolors

csfont = {'fontname':'serif'}

fig,ax = plt.subplots(figsize=(14,7))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

clist = [(0, "#cccc00"),(1, "#ffff00")]
rvb1 = mcolors.LinearSegmentedColormap.from_list("", clist)

plt.xlabel('No. of Pressing action',fontsize=16,labelpad=10,**csfont)

plt.xticks(np.arange(0,6000,250),fontsize=10)
plt.yticks(np.arange(20), press_stats[' Team'],**csfont,fontsize=14)

p1 = plt.barh(np.arange(20),press_stats['PressuresAtt 3rd'],height=0.7,color='#cccc00',edgecolor="#000000")
p2 = plt.barh(np.arange(20),press_stats['PressuresMid 3rd'],left=press_stats['PressuresAtt 3rd'],height=0.7,color='#ff8800',edgecolor="#000000",alpha=0.9)
p3 = plt.barh(np.arange(20),press_stats['PressuresDef 3rd'],left=press_stats['PressuresAtt 3rd']+press_stats['PressuresMid 3rd'],height=0.7,color='red',edgecolor="#000000",alpha=0.9)

plt.title('Pressing Actions',fontsize=22,**csfont)
plt.legend((p1[len(p1)-1], p2[len(p2)-1],p3[len(p3)-1]), ('Att 3rd', 'Mid 3rd','Def 3rd'),fontsize=15)
plt.grid(linestyle='-',color='white',alpha=0.3)

plt.annotate('Viz by @gkgokul10', xy=(0.8,-0.1), xycoords='axes fraction',fontsize='14')


plt.savefig('D:/Press%OVR.png',dpi=800,bbox_inches = "tight")
plt.show()

# %%
csfont = {'fontname':'serif'}

fig,ax = plt.subplots(figsize=(12,12))

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.yticks(np.arange(0,45,1))
plt.xticks(np.arange(16,34,1))
# plt.plot([0,0.333],[0.333,0])    

plt.scatter(att3_press['%inAtt3rd'],att3_press['%inDef3rd'],color='red')

# for ind,data in SCA_GCA.iterrows():
#     if(data[' Team']=='Bournemouth' or data[' Team']=='Norwich City' or data[' Team']=='Watford'):
#         plt.annotate(data[' Team'], xy=(data['SCASCA90']-0.8,data['GCAGCA90']-0.07), xycoords='data',fontsize=12,**csfont)
#     else:
#         plt.annotate(data[' Team'], xy=(data['SCASCA90']-1,data['GCAGCA90']+0.03), xycoords='data',fontsize=12,**csfont)

for ind,data in att3_press.iterrows():
    if(data[' Team']=='Crystal Palace' or data[' Team']=='West Ham' or data[' Team']=='Manchester Utd'or data[' Team']=='Leicester City' or data[' Team']=='Bournemouth' or data[' Team']=='Tottenham'):
        plt.annotate(data[' Team'], xy=(data['%inAtt3rd']-1,data['%inDef3rd']-0.5), xycoords='data',fontsize=12,**csfont)
    elif(data[' Team']=='Sheffield Utd' or data[' Team']=='Southampton' or data[' Team']=='Everton'or data[' Team']=='Brighton'or data[' Team']=='Aston Villa' or data[' Team']=='Norwich City'):
        plt.annotate(data[' Team'], xy=(data['%inAtt3rd']+0.1,data['%inDef3rd']), xycoords='data',fontsize=12,**csfont)

    else:
        plt.annotate(data[' Team'], xy=(data['%inAtt3rd']-0.4,data['%inDef3rd']+0.2), xycoords='data',fontsize=12,**csfont)

        
        
plt.xlabel('Pressing % in Attacking 3rd ',fontsize=16, labelpad=10)
plt.ylabel('Pressing % in Defensive 3rd',fontsize=16, labelpad=10)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title('Pressing Percentages',fontsize=22)
plt.grid(linestyle='-',color='white',alpha=0.25)

plt.annotate('Viz by @gkgokul10', xy=(0.8,-0.07), xycoords='axes fraction',fontsize='14')

plt.savefig('D:/Pressing%.png',dpi=700,bbox_inches = "tight")
plt.show()
