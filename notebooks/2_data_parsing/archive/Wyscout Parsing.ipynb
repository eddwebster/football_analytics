# %% [markdown]
# <a id='top'></a>

# %% [markdown]
# # Wyscout Parsing
# ##### Notebook to parse JSON Event data from [Wyscout](https://wyscout.com/).
#
# ### By [Edd Webster](https://www.twitter.com/eddwebster)
# Last updated: 03/09/2020

# %% [markdown]
# ![title](../../img/wyscout_logo.png)

# %% [markdown]
# Click [here](#section5) to jump straight to the Exploratory Data Analysis section and skip the [Task Brief](#section2), [Data Sources](#section3), and [Data Engineering](#section4) sections. Or click [here](#section6) to jump straight to the Conclusion.

# %% [markdown]
# ___
#
# <a id='sectionintro'></a>

# %% [markdown]
# ## <a id='import_libraries'>Introduction</a>
# This notebook parses pubicly available [Wyscout](https://wyscout.com/) football match data for the Big 5 European leagues for the 17/18 season, using [pandas](http://pandas.pydata.org/) for data manipulation through DataFrames.
#
# For more information about this notebook and the author, I'm available through all the following channels:
# *    [eddwebster.com](https://www.eddwebster.com/),
# *    edd.j.webster@gmail.com,
# *    [@eddwebster](https://www.twitter.com/eddwebster),
# *    [LinkedIn.com/in/eddwebster](https://www.linkedin.com/in/eddwebster/),
# *    [GitHub/eddwebster](https://github.com/eddwebster/),
# *    [Kaggle.com/eddwebster](https://www.kaggle.com/eddwebster), and
# *    [HackerRank.com/eddwebster](https://www.hackerrank.com/eddwebster).

# %% [markdown]
# The accompanying GitHub repository for this notebook can be found [here](https://github.com/eddwebster/fifa-league) and a static version of this notebook can be found [here](https://nbviewer.jupyter.org/github/eddwebster/fifa-league/blob/master/FIFA%2020%20Fantasy%20Football%20League%20using%20TransferMarkt%20Player%20Valuations.ipynb).

# %% [markdown]
# ___
#
# <a id='sectioncontents'></a>

# %% [markdown]
# ## <a id='notebook_contents'>Notebook Contents</a>
# 1.    [Notebook Dependencies](#section1)<br>
# 2.    [Project Brief](#section2)<br>
# 3.    [Data Sources](#section3)<br>
#       1.    [Introduction](#section3.1)<br>
#       2.    [Competitions](#section3.2)<br>
#       3.    [Events](#section3.3)<br>
#       4.    [Matches](#section3.4)<br>
#       5.    [Players](#section3.5)<br>
#       6.    [Teams](#section3.6)<br>
# 4.    [Data Engineering](#section4)<br>
#       1.    [Join Datasets](#section4.1)<br>
#       5.    [Export DataFrame](#section4.5)<br>
# 5.    [Exploratory Data Analysis (EDA)](#section5)<br>
#       1.    [...](#section5.1)<br>
#       2.    [...](#section5.2)<br>
#       3.    [...](#section5.3)<br>
# 6.    [Summary](#section6)<br>
# 7.    [Next Steps](#section7)<br>
# 8.    [Bibliography](#section8)<br>

# %% [markdown]
# ___
#
# <a id='section1'></a>

# %% [markdown]
# ## <a id='#section1'>1. Notebook Dependencies</a>

# %% [markdown]
# This notebook was written using [Python 3](https://docs.python.org/3.7/) and requires the following libraries:
# *    [`Jupyter notebooks`](https://jupyter.org/) for this notebook environment with which this project is presented;
# *    [`NumPy`](http://www.numpy.org/) for multidimensional array computing;
# *    [`pandas`](http://pandas.pydata.org/) for data analysis and manipulation; and
# *    [`matplotlib`](https://matplotlib.org/contents.html?v=20200411155018) for data visualisations;
#
# All packages used for this notebook except for BeautifulSoup can be obtained by downloading and installing the [Conda](https://anaconda.org/anaconda/conda) distribution, available on all platforms (Windows, Linux and Mac OSX). Step-by-step guides on how to install Anaconda can be found for Windows [here](https://medium.com/@GalarnykMichael/install-python-on-windows-anaconda-c63c7c3d1444) and Mac [here](https://medium.com/@GalarnykMichael/install-python-on-mac-anaconda-ccd9f2014072), as well as in the Anaconda documentation itself [here](https://docs.anaconda.com/anaconda/install/).

# %% [markdown]
# ### Import Libraries and Modules

# %%
# Python ≥3.5 (ideally)
import platform
import sys, getopt
assert sys.version_info >= (3, 5)
import csv

# Import Dependencies
# %matplotlib inline

# Math Operations
import numpy as np
from math import pi

# Datetime
import datetime
from datetime import date
import time

# Data Preprocessing
import pandas as pd    # version 1.0.3
import os    #  used to read the csv filenames
import re
import random
from io import BytesIO
from pathlib import Path

# Reading directories
import glob
import os

# Working with JSON
import json
from pandas.io.json import json_normalize
from ast import literal_eval

# Fuzzy Matching - Record Linkage
import recordlinkage
import jellyfish
import numexpr as ne

# Data Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno as msno    # visually display missing data

# Display in Jupyter
from IPython.display import Image, YouTubeVideo
from IPython.core.display import HTML

# Ignore Warnings
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

print('Setup Complete')
# Out:
# Setup Complete

# %%
# Python / module versions used here for reference
print('Python: {}'.format(platform.python_version()))
print('NumPy: {}'.format(np.__version__))
print('pandas: {}'.format(pd.__version__))
print('matplotlib: {}'.format(mpl.__version__))
print('Seaborn: {}'.format(sns.__version__))
# Out:
# Python: 3.7.6
# NumPy: 1.18.1
# pandas: 1.0.1
# matplotlib: 3.1.3
# Seaborn: 0.10.0

# %% [markdown]
# ### Defined Filepaths

# %%
# Set up initial paths to subfolders
base_dir = os.path.join('..', '..', )
data_dir = os.path.join(base_dir, 'data')
data_dir_fbref = os.path.join(base_dir, 'data', 'fbref')
data_dir_tm = os.path.join(base_dir, 'data', 'tm')
data_dir_wyscout = os.path.join(base_dir, 'data', 'wyscout')
img_dir = os.path.join(base_dir, 'img')
fig_dir = os.path.join(base_dir, 'img', 'fig')
video_dir = os.path.join(base_dir, 'video')

# %% [markdown]
# ---
#
# <a id='section2'></a>

# %% [markdown]
# ## <a id='#section2'>2. Project Brief</a>
# This Jupyter notebook explores how to parse pubicly available [Wyscout](https://wyscout.com/) JSON data of football matches for the Big 5 European leagues for the 17/18 season using [pandas](http://pandas.pydata.org/) for data manipulation through DataFrames.
#
# The resulting five engineered DataFrames for each of the Big 5 European league are exported to CSV files. This data can be further analysed in Python, joined to other datasets, or explored using Tableau, PowerBI, Microsoft Excel.

# %% [markdown]
# ---
#
# <a id='section3'></a>

# %% [markdown]
# ## <a id='#section3'>3. Data Sources</a>

# %% [markdown]
# ### <a id='#section3.1'>3.1. Introduction</a>
# [Wyscout](https://wyscout.com/) is an Italian company that supports football scouting, match analysis and transfer dynamics. The company was founded in Genoa, Italy in 2004 and provides video analysis tools and digital databases regarding performances and matches for coaches, teams and players dealing with football business.
#
# The purpose is to allow them have a detailed sight of a large number of athletes about individual performances, patterns of play and tactical strategy.
#
# This notebook explores a complete dataset of event data for the Big 5 European leagues during the 17/18 season.
#
# A detailed description of the data can be found in the following paper:
# - Pappalardo, L., Cintia, P., Rossi, A. et al. **A public data set of spatio-temporal match events in soccer competitions**. Scientific Data 6, 236 (2019) doi:10.1038/s41597-019-0247-7, https://www.nature.com/articles/s41597-019-0247-7
#
# It is from this paper import the *matches*, *events*, *players*, *playerank*, *referees*, *coaches*, and *competition* data sets from the <a href="https://doi.org/10.6084/m9.figshare.c.4415000.v5">figshare repository</a>. Data are stored in `.json` format.
#
# The complete data set contains:
# - 1,941 matches
# - 3,251,294 events
# - 4,299 players.
#
# The datasets we will be using are:
# - competitions;
# - events;
# - matches;
# - players; and
# - teams
#
# Before conducting our EDA, the data needs to be imported as a DataFrame in the Data Sources section [Section 3](#section3) and cleaned in the Data Engineering section [Section 4](#section4).
#
# We'll be using the [pandas](http://pandas.pydata.org/) library to import our data to this workbook as a DataFrame.

# %% [markdown]
# ### <a id='#section3.2'>3.2. Competitions</a>
# This data provides the details of the competitions in the dataset

# %% [markdown]
# #### <a id='#section3.2.1.'>3.2.1. Data Dictionary</a>
# ...

# %% [markdown]
# #### <a id='#section3.2.2.'>3.2.2. Import Data</a>

# %% [markdown]
# ##### Import data

# %%
# Import the Wyscout JSON Competitions for the Big 5 European leagues for the 17/18 season
with open(data_dir_wyscout + '/raw/json/competitions.json') as f:
    json_wyscout_competitions_data = json.load(f)

# %%
# Display the Competitions JSON
json_wyscout_competitions_data
# Out:
# [{'name': 'Italian first division',
#   'wyId': 524,
#   'format': 'Domestic league',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'name': 'English first division',
#   'wyId': 364,
#   'format': 'Domestic league',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'name': 'Spanish first division',
#   'wyId': 795,
#   'format': 'Domestic league',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'name': 'French first division',
#   'wyId': 412,
#   'format': 'Domestic league',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'name': 'German first division',
#   'wyId': 426,
#   'format': 'Domestic league',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'name': 'European Championship',
#   'wyId': 102,
#   'format': 'International cup',
#   'area': {'name': '', 'id': 0, 'alpha3code': 'XEU', 'alpha2code': ''},
#   'type': 'international'},
#  {'name': 'World Cup',
#   'wyId': 28,
#   'format': 'International cup',
#   'area': {'name': '', 'id': 0, 'alpha3code': 'XWO', 'alpha2code': ''},
#   'type': 'international'}]

# %% [markdown]
# ##### Flatten Competitions data

# %%
# Flatten the Wyscout JSON Competition data and export the DataFrame as a CSV file
df_wyscout_competitions_data_flat = json_normalize(json_wyscout_competitions_data)
df_wyscout_competitions_data_flat.to_csv(data_dir_wyscout + '/raw/csv/competitions.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
df_wyscout_competitions_data_flat
# Out:
#                      name  wyId             format           type area.name  \
# 0  Italian first division   524    Domestic league           club     Italy
# 1  English first division   364    Domestic league           club   England
# 2  Spanish first division   795    Domestic league           club     Spain
# 3   French first division   412    Domestic league           club    France
# 4   German first division   426    Domestic league           club   Germany
# 5   European Championship   102  International cup  international
# 6               World Cup    28  International cup  international
#
#   area.id area.alpha3code area.alpha2code
# 0     380             ITA              IT
# 1       0             XEN
# 2     724             ESP              ES
# 3     250             FRA              FR
# 4     276             DEU              DE
# 5       0             XEU
# 6       0             XWO

# %% [markdown]
# ##### Rename columns

# %%
df_wyscout_competitions_data_flat = df_wyscout_competitions_data_flat.rename(columns={'name': 'competition_name_generic',
                                                                                      'wyId': 'wyId',
                                                                                      'format': 'competition_format',
                                                                                      'type': 'competition_type',
                                                                                      'area.name': 'country',
                                                                                      'area.id': 'country_id',
                                                                                      'area.alpha3code': 'country_alpha3code',
                                                                                      'area.alpha2code': 'country_alpha2code'
                                                                                     }
                                                                            )

# %% [markdown]
# ##### Create `league_name` column derived from the `competition_name_generic` column

# %%
dict_league_name_wyscout = {
    'Italy first division': 'Seria A',
    'English first division': 'Premier League',
    'Spanish first division': 'La Liga',
    'French first division': 'Ligue 1',
    'German first division': 'Bundesliga',
    'European Championship': 'UEFA EURO',
    'World Cup': 'FIFA World Cup'
}

# %%
df_wyscout_competitions_data_flat['league_name'] = df_wyscout_competitions_data_flat['competition_name_generic'].map(dict_league_name_wyscout)

# %% [markdown]
# ##### Streamline the DataFrame

# %%
df_wyscout_competitions_data_flat.columns
# Out:
# Index(['competition_name_generic', 'wyId', 'competition_format',
#        'competition_type', 'country', 'country_id', 'country_alpha3code',
#        'country_alpha2code', 'league_name'],
#       dtype='object')

# %%
# Select columns of interest
cols_competitions = ['league_name', 'wyId', 'country']

# Create more concise DataFrame using only columns of interest
df_wyscout_competitions_data_flat_select = df_wyscout_competitions_data_flat[cols_competitions]

# Export DataFrame
df_wyscout_competitions_data_flat_select.to_csv(data_dir_wyscout + '/raw/csv/competitions_select.csv', index=None, header=True)

# %%
df_wyscout_competitions_data_flat_select
# Out:
#       league_name  wyId  country
# 0             NaN   524    Italy
# 1  Premier League   364  England
# 2         La Liga   795    Spain
# 3         Ligue 1   412   France
# 4      Bundesliga   426  Germany
# 5       UEFA EURO   102
# 6  FIFA World Cup    28

# %% [markdown]
# For our analysis, we want just the Big 5 European leagues which are the following competition IDs:
# *    Seria A - 380
# *    Premier League - 364
# *    La Liga - 724
# *    Ligue 1 - 250
# *    Bundesliga - 276

# %% [markdown]
# ### <a id='#section3.3.'>3.3. Events</a>

# %% [markdown]
# #### <a id='#section3.3.1.'>3.3.1. Data Dictionary</a>
# The [WyScout](https://www.transfermarkt.co.uk/) Events dataset has twelve features (columns) with the following definitions and data types:
#
# | Feature     | Data type    |
# |------|-----|
# | `eventId`    | int64     |
# | `subEventName`    | object     |
# | `tags`    | object     |
# | `playerId`    | int64     |
# | `positions`    | object     |
# | `matchId`    | int64     |
# | `eventName`    | object     |
# | `teamId`    | int64     |
# | `matchPeriod`    | object     |
# | `eventSec`    | float64     |
# | `subEventId`    | object     |
# | `id`    | int64     |
#
# Refer to the Wyscout [API docs](https://apidocs.wyscout.com/) and [Events Manual](https://footballdata.wyscout.com/wp-content/uploads/2018/03/Wyscout-Events-Manual.pdf) for further information about event and subevents.

# %% [markdown]
# #### <a id='#section3.3.2.'>3.3.2. Import Data</a>

# %% [markdown]
# ##### Read in Event Data

# %%
# Import all Wyscout JSON Events data for the Big 5 European leagues for the 17/18 season

## Premier League - England
with open(data_dir_wyscout + '/raw/json/events/events_England.json') as f:
    json_wyscout_event_data_england = json.load(f)
    
## Ligue 1 - France
with open(data_dir_wyscout + '/raw/json/events/events_France.json') as f:
    json_wyscout_event_data_france  = json.load(f)

## Bundesliga - Germany
with open(data_dir_wyscout + '/raw/json/events/events_Germany.json') as f:
    json_wyscout_event_data_germany = json.load(f)

## Seria A - Italy
with open(data_dir_wyscout + '/raw/json/events/events_Italy.json') as f:
    json_wyscout_event_data_italy = json.load(f)

## La Liga - Spain
with open(data_dir_wyscout + '/raw/json/events/events_Spain.json') as f:
    json_wyscout_event_data_spain = json.load(f)

# %%
json_wyscout_event_data_england
# Out:
# [{'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 25413,
#   'positions': [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 2.7586489999999912,
#   'subEventId': 85,
#   'id': 177959171},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 370224,
#   'positions': [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 4.946850000000012,
#   'subEventId': 83,
#   'id': 177959172},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 6.54218800000001,
#   'subEventId': 82,
#   'id': 177959173},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 8.143394999999998,
#   'subEventId': 82,
#   'id': 177959174},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 10.302366000000006,
#   'subEventId': 85,
#   'id': 177959175},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1802}],
#   'playerId': 3319,
#   'positions': [{'y': 88, 'x': 72}, {'y': 75, 'x': 77}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 12.548934000000003,
#   'subEventId': 85,
#   'id': 177959177},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 25, 'x': 23}, {'y': 15, 'x': 39}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 13.961228000000006,
#   'subEventId': 82,
#   'id': 177959186},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 8013,
#   'positions': [{'y': 15, 'x': 39}, {'y': 20, 'x': 33}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 14.765321,
#   'subEventId': 10,
#   'id': 177959189},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 85, 'x': 61}, {'y': 80, 'x': 67}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 14.765321,
#   'subEventId': 10,
#   'id': 177961218},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1401}, {'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 80, 'x': 67}, {'y': 61, 'x': 59}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 15.320341000000013,
#   'subEventId': 82,
#   'id': 177959178},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 61, 'x': 59}, {'y': 45, 'x': 45}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 18.051874999999995,
#   'subEventId': 82,
#   'id': 177959179},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 45, 'x': 45}, {'y': 54, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 20.426526999999993,
#   'subEventId': 83,
#   'id': 177959180},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 46, 'x': 29}, {'y': 41, 'x': 50}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 21.878309,
#   'subEventId': 10,
#   'id': 177959191},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 25413,
#   'positions': [{'y': 54, 'x': 71}, {'y': 59, 'x': 50}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 22.551816000000002,
#   'subEventId': 10,
#   'id': 177959181},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1802}],
#   'playerId': 3560,
#   'positions': [{'y': 59, 'x': 50}, {'y': 69, 'x': 76}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 24.588310000000007,
#   'subEventId': 83,
#   'id': 177959182},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 31, 'x': 24}, {'y': 15, 'x': 42}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 25.904248999999993,
#   'subEventId': 82,
#   'id': 177959194},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 15, 'x': 42}, {'y': 26, 'x': 29}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 27.52769599999999,
#   'subEventId': 82,
#   'id': 177959195},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 265366,
#   'positions': [{'y': 26, 'x': 29}, {'y': 8, 'x': 37}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 29.980897999999996,
#   'subEventId': 85,
#   'id': 177959196},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 8, 'x': 37}, {'y': 5, 'x': 23}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 31.163870000000003,
#   'subEventId': 85,
#   'id': 177959197},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1802}],
#   'playerId': 14853,
#   'positions': [{'y': 5, 'x': 23}, {'y': 19, 'x': 63}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 32.80561800000001,
#   'subEventId': 83,
#   'id': 177959202},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1802}],
#   'playerId': 370224,
#   'positions': [{'y': 81, 'x': 37}, {'y': 95, 'x': 45}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 35.685081999999994,
#   'subEventId': 82,
#   'id': 177959184},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 5, 'x': 55}, {'y': 22, 'x': 67}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 36.66126399999999,
#   'subEventId': 82,
#   'id': 177959204},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 12829,
#   'positions': [{'y': 22, 'x': 67}, {'y': 15, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 38.19187400000001,
#   'subEventId': 13,
#   'id': 177959205},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 0,
#   'positions': [{'y': 78, 'x': 33}, {'y': 85, 'x': 29}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 38.19187400000001,
#   'subEventId': 13,
#   'id': 177961219},
#  {'eventId': 8,
#   'subEventName': 'Smart pass',
#   'tags': [{'id': 901}, {'id': 1802}],
#   'playerId': 14763,
#   'positions': [{'y': 15, 'x': 71}, {'y': 26, 'x': 81}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 39.94010900000001,
#   'subEventId': 86,
#   'id': 177959206},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 74, 'x': 19}, {'y': 53, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 43.04583099999999,
#   'subEventId': 85,
#   'id': 177959185},
#  {'eventId': 8,
#   'subEventName': 'Launch',
#   'tags': [{'id': 1801}],
#   'playerId': 7882,
#   'positions': [{'y': 53, 'x': 4}, {'y': 44, 'x': 40}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 44.425679,
#   'subEventId': 84,
#   'id': 177959187},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 192748,
#   'positions': [{'y': 56, 'x': 60}, {'y': 49, 'x': 56}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 47.71750800000001,
#   'subEventId': 10,
#   'id': 177959210},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 7945,
#   'positions': [{'y': 44, 'x': 40}, {'y': 51, 'x': 44}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 48.265872,
#   'subEventId': 10,
#   'id': 177959188},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 504}, {'id': 701}, {'id': 1802}],
#   'playerId': 149019,
#   'positions': [{'y': 49, 'x': 56}, {'y': 54, 'x': 45}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 49.18256600000001,
#   'subEventId': 12,
#   'id': 177959213},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 503}, {'id': 703}, {'id': 1801}],
#   'playerId': 7945,
#   'positions': [{'y': 51, 'x': 44}, {'y': 46, 'x': 55}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 50.33752100000001,
#   'subEventId': 11,
#   'id': 177959190},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 7945,
#   'positions': [{'y': 46, 'x': 55}, {'y': 44, 'x': 64}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 51.66581099999999,
#   'subEventId': 11,
#   'id': 177959192},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 192748,
#   'positions': [{'y': 54, 'x': 45}, {'y': 56, 'x': 36}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 52.00954300000001,
#   'subEventId': 12,
#   'id': 177959215},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 1601}, {'id': 701}, {'id': 1802}],
#   'playerId': 8488,
#   'positions': [{'y': 56, 'x': 36}, {'y': 48, 'x': 36}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 52.66353599999999,
#   'subEventId': 12,
#   'id': 177959217},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 7945,
#   'positions': [{'y': 44, 'x': 64}, {'y': 52, 'x': 64}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 53.25379799999999,
#   'subEventId': 11,
#   'id': 177959193},
#  {'eventId': 2,
#   'subEventName': 'Foul',
#   'tags': [],
#   'playerId': 8488,
#   'positions': [{'y': 48, 'x': 36}, {'y': 56, 'x': 36}],
#   'matchId': 2499719,
#   'eventName': 'Foul',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 54.36619999999999,
#   'subEventId': 20,
#   'id': 177959219},
#  {'eventId': 3,
#   'subEventName': 'Free Kick',
#   'tags': [{'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 44, 'x': 65}, {'y': 31, 'x': 65}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 74.73714100000001,
#   'subEventId': 31,
#   'id': 177959198},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 31, 'x': 65}, {'y': 13, 'x': 90}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 76.625696,
#   'subEventId': 85,
#   'id': 177959199},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 502}, {'id': 703}, {'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 13, 'x': 90}, {'y': 14, 'x': 96}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 83.67514599999998,
#   'subEventId': 11,
#   'id': 177959200},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 501}, {'id': 701}, {'id': 1802}],
#   'playerId': 149019,
#   'positions': [{'y': 87, 'x': 10}, {'y': 86, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 83.706077,
#   'subEventId': 12,
#   'id': 177959222},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 14, 'x': 96}, {'y': 3, 'x': 90}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 85.07404300000002,
#   'subEventId': 11,
#   'id': 177959201},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 0,
#   'positions': [{'y': 86, 'x': 4}, {'y': 97, 'x': 10}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 85.07404300000002,
#   'subEventId': 12,
#   'id': 177961220},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 3, 'x': 90}, {'y': 13, 'x': 72}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 86.77345700000001,
#   'subEventId': 85,
#   'id': 177959203},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 13, 'x': 72}, {'y': 86, 'x': 86}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 89.24938700000001,
#   'subEventId': 83,
#   'id': 177959207},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 86, 'x': 86}, {'y': 71, 'x': 73}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 93.11554799999999,
#   'subEventId': 85,
#   'id': 177959208},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 301}, {'id': 402}, {'id': 801}, {'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 71, 'x': 73}, {'y': 41, 'x': 88}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 93.96123499999999,
#   'subEventId': 80,
#   'id': 177959211},
#  {'eventId': 10,
#   'subEventName': 'Shot',
#   'tags': [{'id': 101}, {'id': 402}, {'id': 201}, {'id': 1205}, {'id': 1801}],
#   'playerId': 25413,
#   'positions': [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}],
#   'matchId': 2499719,
#   'eventName': 'Shot',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 94.59578800000003,
#   'subEventId': 100,
#   'id': 177959212},
#  {'eventId': 9,
#   'subEventName': 'Reflexes',
#   'tags': [{'id': 101}, {'id': 1205}, {'id': 1802}],
#   'playerId': 8480,
#   'positions': [{'y': 100, 'x': 100}, {'y': 59, 'x': 12}],
#   'matchId': 2499719,
#   'eventName': 'Save attempt',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 96.97061400000001,
#   'subEventId': 90,
#   'id': 177959226},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 8013,
#   'positions': [{'y': 6, 'x': 75}, {'y': 6, 'x': 82}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 147.157528,
#   'subEventId': 13,
#   'id': 177959231},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 94, 'x': 25}, {'y': 94, 'x': 18}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 147.63374,
#   'subEventId': 13,
#   'id': 177959218},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1802}],
#   'playerId': 3319,
#   'positions': [{'y': 94, 'x': 18}, {'y': 92, 'x': 20}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 148.97274700000003,
#   'subEventId': 85,
#   'id': 177959220},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [{'id': 1401}],
#   'playerId': 8013,
#   'positions': [{'y': 8, 'x': 80}, {'y': 28, 'x': 92}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 149.68212999999997,
#   'subEventId': 72,
#   'id': 177959233},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [],
#   'playerId': 12829,
#   'positions': [{'y': 28, 'x': 92}, {'y': 27, 'x': 89}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 151.86729000000003,
#   'subEventId': 72,
#   'id': 177959238},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 370224,
#   'positions': [{'y': 73, 'x': 11}, {'y': 73, 'x': 5}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 152.127886,
#   'subEventId': 12,
#   'id': 177959221},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 0,
#   'positions': [{'y': 27, 'x': 89}, {'y': 27, 'x': 95}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 152.127886,
#   'subEventId': 11,
#   'id': 177961221},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 12829,
#   'positions': [{'y': 27, 'x': 95}, {'y': 28, 'x': 94}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 153.404026,
#   'subEventId': 12,
#   'id': 177959236},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 73, 'x': 5}, {'y': 72, 'x': 6}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 153.404026,
#   'subEventId': 11,
#   'id': 177961222},
#  {'eventId': 7,
#   'subEventName': 'Clearance',
#   'tags': [{'id': 1802}],
#   'playerId': 370224,
#   'positions': [{'y': 72, 'x': 6}, {'y': 100, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 154.63865900000002,
#   'subEventId': 71,
#   'id': 177959223},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 0, 'x': 96}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 157.045503,
#   'subEventId': 50,
#   'id': 177959242},
#  {'eventId': 3,
#   'subEventName': 'Throw in',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 0, 'x': 94}, {'y': 41, 'x': 93}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 175.308128,
#   'subEventId': 36,
#   'id': 177959244},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 8488,
#   'positions': [{'y': 41, 'x': 93}, {'y': 52, 'x': 85}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 178.23953899999998,
#   'subEventId': 10,
#   'id': 177959246},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 59, 'x': 7}, {'y': 48, 'x': 15}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 178.317724,
#   'subEventId': 10,
#   'id': 177959224},
#  {'eventId': 10,
#   'subEventName': 'Shot',
#   'tags': [{'id': 401}, {'id': 201}, {'id': 1211}, {'id': 1802}],
#   'playerId': 26150,
#   'positions': [{'y': 52, 'x': 85}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Shot',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 179.854785,
#   'subEventId': 100,
#   'id': 177959247},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 38, 'x': 100}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 184.10022300000003,
#   'subEventId': 50,
#   'id': 177959251},
#  {'eventId': 3,
#   'subEventName': 'Goal kick',
#   'tags': [],
#   'playerId': 7882,
#   'positions': [{'y': 0, 'x': 0}, {'y': 44, 'x': 28}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 196.06685900000002,
#   'subEventId': 34,
#   'id': 177959227},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 44, 'x': 28}, {'y': 47, 'x': 43}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 198.85002100000003,
#   'subEventId': 85,
#   'id': 177959228},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 501}, {'id': 701}, {'id': 1802}],
#   'playerId': 8488,
#   'positions': [{'y': 53, 'x': 57}, {'y': 55, 'x': 55}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 200.55237599999998,
#   'subEventId': 12,
#   'id': 177959252},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 502}, {'id': 703}, {'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 47, 'x': 43}, {'y': 45, 'x': 45}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 200.862749,
#   'subEventId': 11,
#   'id': 177959229},
#  {'eventId': 2,
#   'subEventName': 'Foul',
#   'tags': [],
#   'playerId': 8488,
#   'positions': [{'y': 55, 'x': 55}, {'y': 53, 'x': 57}],
#   'matchId': 2499719,
#   'eventName': 'Foul',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 202.040527,
#   'subEventId': 20,
#   'id': 177959253},
#  {'eventId': 3,
#   'subEventName': 'Free Kick',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 31, 'x': 39}, {'y': 61, 'x': 50}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 214.312946,
#   'subEventId': 31,
#   'id': 177959230},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 61, 'x': 50}, {'y': 43, 'x': 45}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 215.98235899999997,
#   'subEventId': 85,
#   'id': 177959232},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1802}],
#   'playerId': 49876,
#   'positions': [{'y': 43, 'x': 45}, {'y': 86, 'x': 47}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 217.803357,
#   'subEventId': 83,
#   'id': 177959234},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1901}, {'id': 1401}, {'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 14, 'x': 53}, {'y': 7, 'x': 85}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 220.782446,
#   'subEventId': 85,
#   'id': 177959254},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 501}, {'id': 701}, {'id': 1802}],
#   'playerId': 3560,
#   'positions': [{'y': 93, 'x': 15}, {'y': 90, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 226.31321400000002,
#   'subEventId': 12,
#   'id': 177959237},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 1901}, {'id': 502}, {'id': 703}, {'id': 1801}],
#   'playerId': 12829,
#   'positions': [{'y': 7, 'x': 85}, {'y': 10, 'x': 96}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 227.006908,
#   'subEventId': 11,
#   'id': 177959257},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 1901}, {'id': 401}, {'id': 2101}, {'id': 1802}],
#   'playerId': 12829,
#   'positions': [{'y': 10, 'x': 96}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 228.76425799999998,
#   'subEventId': 80,
#   'id': 177959258},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [{'id': 1401}],
#   'playerId': 3560,
#   'positions': [{'y': 77, 'x': 3}, {'y': 84, 'x': 18}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 230.80848600000002,
#   'subEventId': 72,
#   'id': 177959239},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 84, 'x': 18}, {'y': 95, 'x': 23}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 232.53819900000002,
#   'subEventId': 85,
#   'id': 177959240},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 2001}, {'id': 701}, {'id': 1802}],
#   'playerId': 3319,
#   'positions': [{'y': 95, 'x': 23}, {'y': 90, 'x': 8}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 233.70948900000002,
#   'subEventId': 11,
#   'id': 177959243},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 5, 'x': 77}, {'y': 10, 'x': 92}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 233.74561,
#   'subEventId': 12,
#   'id': 177959262},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 401}, {'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 10, 'x': 92}, {'y': 37, 'x': 93}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 235.809436,
#   'subEventId': 80,
#   'id': 177959264},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 702}, {'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 37, 'x': 93}, {'y': 0, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 236.935247,
#   'subEventId': 13,
#   'id': 177959266},
#  {'eventId': 1,
#   'subEventName': 'Ground loose ball duel',
#   'tags': [{'id': 702}, {'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 63, 'x': 7}, {'y': 100, 'x': 0}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 237.110293,
#   'subEventId': 13,
#   'id': 177959245},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 29, 'x': 100}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 239.67726199999998,
#   'subEventId': 50,
#   'id': 177959267},
#  {'eventId': 3,
#   'subEventName': 'Corner',
#   'tags': [{'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 0, 'x': 100}, {'y': 6, 'x': 91}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 247.13447000000002,
#   'subEventId': 30,
#   'id': 177959268},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 6, 'x': 91}, {'y': 15, 'x': 77}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 249.17341599999997,
#   'subEventId': 85,
#   'id': 177959271},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 402}, {'id': 801}, {'id': 1802}],
#   'playerId': 8013,
#   'positions': [{'y': 15, 'x': 77}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 251.06831899999997,
#   'subEventId': 80,
#   'id': 177959273},
#  {'eventId': 4,
#   'subEventName': 'Goalkeeper leaving line',
#   'tags': [],
#   'playerId': 7882,
#   'positions': [{'y': 0, 'x': 0}, {'y': 85, 'x': 23}],
#   'matchId': 2499719,
#   'eventName': 'Goalkeeper leaving line',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 252.848204,
#   'subEventId': 40,
#   'id': 177959250},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 301}, {'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 66, 'x': 97}, {'y': 52, 'x': 96}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 252.93102399999998,
#   'subEventId': 82,
#   'id': 177959277},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 49876,
#   'positions': [{'y': 48, 'x': 4}, {'y': 48, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 253.89308599999998,
#   'subEventId': 10,
#   'id': 177959248},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 52, 'x': 96}, {'y': 52, 'x': 96}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 254.03630800000002,
#   'subEventId': 10,
#   'id': 177959279},
#  {'eventId': 10,
#   'subEventName': 'Shot',
#   'tags': [{'id': 101}, {'id': 403}, {'id': 201}, {'id': 1207}, {'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 52, 'x': 96}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Shot',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 254.745027,
#   'subEventId': 100,
#   'id': 177959280},
#  {'eventId': 9,
#   'subEventName': 'Reflexes',
#   'tags': [{'id': 101}, {'id': 1207}, {'id': 1802}],
#   'playerId': 7882,
#   'positions': [{'y': 0, 'x': 0}, {'y': 48, 'x': 4}],
#   'matchId': 2499719,
#   'eventName': 'Save attempt',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 256.547834,
#   'subEventId': 90,
#   'id': 177959249},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1802}],
#   'playerId': 370224,
#   'positions': [{'y': 85, 'x': 35}, {'y': 70, 'x': 86}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 320.235462,
#   'subEventId': 83,
#   'id': 177959256},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [{'id': 1302}],
#   'playerId': 14853,
#   'positions': [{'y': 30, 'x': 14}, {'y': 31, 'x': 6}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 322.227608,
#   'subEventId': 72,
#   'id': 177959290},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [],
#   'playerId': 8480,
#   'positions': [{'y': 31, 'x': 6}, {'y': 41, 'x': 16}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 324.62300700000003,
#   'subEventId': 72,
#   'id': 177959291},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8480,
#   'positions': [{'y': 41, 'x': 16}, {'y': 9, 'x': 62}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 340.684982,
#   'subEventId': 83,
#   'id': 177959295},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 9, 'x': 62}, {'y': 33, 'x': 72}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 342.852928,
#   'subEventId': 82,
#   'id': 177959296},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 370224,
#   'positions': [{'y': 67, 'x': 28}, {'y': 50, 'x': 47}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 344.968625,
#   'subEventId': 10,
#   'id': 177959259},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 12829,
#   'positions': [{'y': 33, 'x': 72}, {'y': 50, 'x': 53}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 344.97733300000004,
#   'subEventId': 10,
#   'id': 177959297},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 7945,
#   'positions': [{'y': 50, 'x': 47}, {'y': 47, 'x': 53}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 346.556014,
#   'subEventId': 11,
#   'id': 177959261},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 50, 'x': 53}, {'y': 53, 'x': 47}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 346.556014,
#   'subEventId': 12,
#   'id': 177961224},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8488,
#   'positions': [{'y': 53, 'x': 47}, {'y': 51, 'x': 57}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 348.28910399999995,
#   'subEventId': 85,
#   'id': 177959298},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 26150,
#   'positions': [{'y': 51, 'x': 57}, {'y': 53, 'x': 55}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 349.19831,
#   'subEventId': 85,
#   'id': 177959299},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 901}, {'id': 1802}],
#   'playerId': 192748,
#   'positions': [{'y': 53, 'x': 55}, {'y': 54, 'x': 87}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 349.80626199999995,
#   'subEventId': 83,
#   'id': 177959300},
#  {'eventId': 8,
#   'subEventName': 'Hand pass',
#   'tags': [{'id': 1801}],
#   'playerId': 7882,
#   'positions': [{'y': 46, 'x': 13}, {'y': 20, 'x': 33}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 355.197401,
#   'subEventId': 81,
#   'id': 177959263},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 20, 'x': 33}, {'y': 23, 'x': 40}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 358.32967299999996,
#   'subEventId': 85,
#   'id': 177959265},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 23, 'x': 40}, {'y': 14, 'x': 40}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 360.99043099999994,
#   'subEventId': 85,
#   'id': 177959269},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1802}],
#   'playerId': 7868,
#   'positions': [{'y': 14, 'x': 40}, {'y': 100, 'x': 67}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 364.98598000000004,
#   'subEventId': 83,
#   'id': 177959270},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 0, 'x': 33}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 369.60858399999995,
#   'subEventId': 50,
#   'id': 177959302},
#  {'eventId': 3,
#   'subEventName': 'Throw in',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 0, 'x': 32}, {'y': 6, 'x': 47}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 392.39299000000005,
#   'subEventId': 36,
#   'id': 177959304},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1802}],
#   'playerId': 265366,
#   'positions': [{'y': 6, 'x': 47}, {'y': 10, 'x': 67}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 393.678768,
#   'subEventId': 82,
#   'id': 177959305},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 370224,
#   'positions': [{'y': 90, 'x': 33}, {'y': 70, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 395.56156999999996,
#   'subEventId': 83,
#   'id': 177959275},
#  {'eventId': 8,
#   'subEventName': 'Head pass',
#   'tags': [{'id': 1802}],
#   'playerId': 25413,
#   'positions': [{'y': 70, 'x': 71}, {'y': 63, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 397.881307,
#   'subEventId': 82,
#   'id': 177959276},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1401}, {'id': 1801}],
#   'playerId': 149019,
#   'positions': [{'y': 37, 'x': 29}, {'y': 3, 'x': 26}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 398.57293000000004,
#   'subEventId': 85,
#   'id': 177959308},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 3, 'x': 26}, {'y': 8, 'x': 44}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 400.97083399999997,
#   'subEventId': 85,
#   'id': 177959310},
#  {'eventId': 8,
#   'subEventName': 'Smart pass',
#   'tags': [{'id': 901}, {'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 8, 'x': 44}, {'y': 17, 'x': 83}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 402.998466,
#   'subEventId': 86,
#   'id': 177959312},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 12829,
#   'positions': [{'y': 17, 'x': 83}, {'y': 30, 'x': 83}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 408.42680199999995,
#   'subEventId': 85,
#   'id': 177959317},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 14763,
#   'positions': [{'y': 30, 'x': 83}, {'y': 27, 'x': 89}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 410.001179,
#   'subEventId': 11,
#   'id': 177959322},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 70, 'x': 17}, {'y': 73, 'x': 11}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 410.001179,
#   'subEventId': 12,
#   'id': 177961225},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 702}, {'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 27, 'x': 89}, {'y': 28, 'x': 91}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 411.42878399999995,
#   'subEventId': 12,
#   'id': 177959326},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 702}, {'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 73, 'x': 11}, {'y': 72, 'x': 9}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 411.936148,
#   'subEventId': 11,
#   'id': 177959281},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 72, 'x': 9}, {'y': 61, 'x': 14}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 412.85655799999995,
#   'subEventId': 85,
#   'id': 177959282},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 61, 'x': 14}, {'y': 39, 'x': 34}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 414.341812,
#   'subEventId': 85,
#   'id': 177959283},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 39, 'x': 34}, {'y': 10, 'x': 53}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 418.028087,
#   'subEventId': 85,
#   'id': 177959284},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 504}, {'id': 701}, {'id': 1802}],
#   'playerId': 14853,
#   'positions': [{'y': 90, 'x': 47}, {'y': 82, 'x': 41}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 421.06571499999995,
#   'subEventId': 12,
#   'id': 177959331},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 503}, {'id': 703}, {'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 10, 'x': 53}, {'y': 18, 'x': 59}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 421.29478200000005,
#   'subEventId': 11,
#   'id': 177959287},
#  {'eventId': 7,
#   'subEventName': 'Acceleration',
#   'tags': [{'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 18, 'x': 59}, {'y': 33, 'x': 81}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 423.759467,
#   'subEventId': 70,
#   'id': 177959288},
#  {'eventId': 10,
#   'subEventName': 'Shot',
#   'tags': [{'id': 401}, {'id': 201}, {'id': 1215}, {'id': 1802}],
#   'playerId': 7868,
#   'positions': [{'y': 33, 'x': 81}, {'y': 0, 'x': 0}],
#   'matchId': 2499719,
#   'eventName': 'Shot',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 425.824035,
#   'subEventId': 100,
#   'id': 177959289},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 53, 'x': 2}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 427.39092600000004,
#   'subEventId': 50,
#   'id': 177959337},
#  {'eventId': 3,
#   'subEventName': 'Goal kick',
#   'tags': [],
#   'playerId': 8480,
#   'positions': [{'y': 100, 'x': 100}, {'y': 47, 'x': 65}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 458.974297,
#   'subEventId': 34,
#   'id': 177959339},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 47, 'x': 65}, {'y': 52, 'x': 83}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 462.26596900000004,
#   'subEventId': 10,
#   'id': 177959340},
#  {'eventId': 1,
#   'subEventName': 'Air duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 3560,
#   'positions': [{'y': 53, 'x': 35}, {'y': 48, 'x': 17}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 462.764499,
#   'subEventId': 10,
#   'id': 177959292},
#  {'eventId': 7,
#   'subEventName': 'Clearance',
#   'tags': [{'id': 1802}],
#   'playerId': 370224,
#   'positions': [{'y': 48, 'x': 17}, {'y': 100, 'x': 12}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 466.102129,
#   'subEventId': 71,
#   'id': 177959294},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 0, 'x': 88}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 468.918533,
#   'subEventId': 50,
#   'id': 177959343},
#  {'eventId': 3,
#   'subEventName': 'Throw in',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 0, 'x': 73}, {'y': 7, 'x': 92}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 483.340689,
#   'subEventId': 36,
#   'id': 177959344},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 7, 'x': 92}, {'y': 6, 'x': 85}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 485.09508300000005,
#   'subEventId': 85,
#   'id': 177959346},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 401}, {'id': 1802}],
#   'playerId': 14853,
#   'positions': [{'y': 6, 'x': 85}, {'y': 38, 'x': 92}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 486.18351700000005,
#   'subEventId': 80,
#   'id': 177959347},
#  {'eventId': 7,
#   'subEventName': 'Clearance',
#   'tags': [{'id': 1401}, {'id': 1802}],
#   'playerId': 370224,
#   'positions': [{'y': 62, 'x': 8}, {'y': 85, 'x': 50}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 488.01946799999996,
#   'subEventId': 71,
#   'id': 177959301},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 15, 'x': 50}, {'y': 36, 'x': 39}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 491.98057300000005,
#   'subEventId': 85,
#   'id': 177959349},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 504}, {'id': 703}, {'id': 1801}],
#   'playerId': 8488,
#   'positions': [{'y': 36, 'x': 39}, {'y': 13, 'x': 49}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 493.929879,
#   'subEventId': 11,
#   'id': 177959350},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 503}, {'id': 701}, {'id': 1802}],
#   'playerId': 25413,
#   'positions': [{'y': 64, 'x': 61}, {'y': 87, 'x': 51}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 494.461238,
#   'subEventId': 12,
#   'id': 177959303},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8488,
#   'positions': [{'y': 13, 'x': 49}, {'y': 4, 'x': 63}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 496.18985,
#   'subEventId': 85,
#   'id': 177959353},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 901}, {'id': 1802}],
#   'playerId': 14853,
#   'positions': [{'y': 4, 'x': 63}, {'y': 96, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 498.38919699999997,
#   'subEventId': 83,
#   'id': 177959354},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 96, 'x': 100}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '1H',
#   'eventSec': 506.70697500000006,
#   'subEventId': 50,
#   'id': 177959359},
#  {'eventId': 3,
#   'subEventName': 'Goal kick',
#   'tags': [],
#   'playerId': 7882,
#   'positions': [{'y': 0, 'x': 0}, {'y': 47, 'x': 24}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 517.797223,
#   'subEventId': 34,
#   'id': 177959306},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 47, 'x': 24}, {'y': 57, 'x': 34}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 519.222798,
#   'subEventId': 85,
#   'id': 177959307},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 57, 'x': 34}, {'y': 80, 'x': 25}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 520.828507,
#   'subEventId': 85,
#   'id': 177959309},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 370224,
#   'positions': [{'y': 80, 'x': 25}, {'y': 25, 'x': 33}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
#   'eventSec': 525.366124,
#   'subEventId': 85,
#   'id': 177959311},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 25, 'x': 33}, {'y': 33, 'x': 52}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '1H',
# ...
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 164.05490999999984,
#   'subEventId': 85,
#   'id': 177960165},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 68, 'x': 57}, {'y': 54, 'x': 29}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 165.29245600000013,
#   'subEventId': 85,
#   'id': 177960166},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 54, 'x': 29}, {'y': 23, 'x': 30}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 167.885902,
#   'subEventId': 85,
#   'id': 177960167},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 23, 'x': 30}, {'y': 47, 'x': 44}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 168.85408000000007,
#   'subEventId': 85,
#   'id': 177960169},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 47, 'x': 44}, {'y': 27, 'x': 44}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 170.35161100000005,
#   'subEventId': 85,
#   'id': 177960171},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 27, 'x': 44}, {'y': 46, 'x': 37}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 174.00739599999997,
#   'subEventId': 85,
#   'id': 177960172},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 46, 'x': 37}, {'y': 74, 'x': 60}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 175.6039179999998,
#   'subEventId': 85,
#   'id': 177960174},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 120339,
#   'positions': [{'y': 74, 'x': 60}, {'y': 49, 'x': 60}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 182.03423599999996,
#   'subEventId': 85,
#   'id': 177960176},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 49, 'x': 60}, {'y': 81, 'x': 63}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 183.24235899999985,
#   'subEventId': 85,
#   'id': 177960177},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 81, 'x': 63}, {'y': 65, 'x': 63}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 185.24922800000013,
#   'subEventId': 85,
#   'id': 177960178},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 65, 'x': 63}, {'y': 72, 'x': 62}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 186.1367009999999,
#   'subEventId': 85,
#   'id': 177960179},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 72, 'x': 62}, {'y': 18, 'x': 57}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 189.68460800000003,
#   'subEventId': 85,
#   'id': 177960181},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 18, 'x': 57}, {'y': 50, 'x': 46}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 194.10971699999982,
#   'subEventId': 85,
#   'id': 177960183},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 50, 'x': 46}, {'y': 68, 'x': 62}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 197.43899899999997,
#   'subEventId': 85,
#   'id': 177960185},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 49876,
#   'positions': [{'y': 68, 'x': 62}, {'y': 90, 'x': 72}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 200.35452699999996,
#   'subEventId': 85,
#   'id': 177960186},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 90, 'x': 72}, {'y': 83, 'x': 63}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 202.7087700000002,
#   'subEventId': 85,
#   'id': 177960187},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 83, 'x': 63}, {'y': 65, 'x': 65}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 204.90293100000008,
#   'subEventId': 85,
#   'id': 177960188},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 25413,
#   'positions': [{'y': 65, 'x': 65}, {'y': 82, 'x': 67}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 205.7661039999998,
#   'subEventId': 85,
#   'id': 177960189},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 82, 'x': 67}, {'y': 68, 'x': 62}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 207.51314899999988,
#   'subEventId': 85,
#   'id': 177960191},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1802}],
#   'playerId': 49876,
#   'positions': [{'y': 68, 'x': 62}, {'y': 81, 'x': 73}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 208.912237,
#   'subEventId': 85,
#   'id': 177960193},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1401}, {'id': 1802}],
#   'playerId': 265366,
#   'positions': [{'y': 19, 'x': 27}, {'y': 19, 'x': 41}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 209.33612099999982,
#   'subEventId': 85,
#   'id': 177960218},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 81, 'x': 59}, {'y': 44, 'x': 52}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 211.99095399999987,
#   'subEventId': 85,
#   'id': 177960194},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3560,
#   'positions': [{'y': 44, 'x': 52}, {'y': 16, 'x': 56}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 215.43078500000001,
#   'subEventId': 85,
#   'id': 177960195},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14869,
#   'positions': [{'y': 16, 'x': 56}, {'y': 9, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 218.08489700000018,
#   'subEventId': 85,
#   'id': 177960197},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 26150,
#   'positions': [{'y': 91, 'x': 29}, {'y': 70, 'x': 29}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 220.79419800000005,
#   'subEventId': 12,
#   'id': 177960221},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 9, 'x': 71}, {'y': 30, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 220.83575400000018,
#   'subEventId': 11,
#   'id': 177960198},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 7868,
#   'positions': [{'y': 30, 'x': 71}, {'y': 32, 'x': 70}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 222.6034239999999,
#   'subEventId': 85,
#   'id': 177960201},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 25413,
#   'positions': [{'y': 32, 'x': 70}, {'y': 59, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 223.8708200000001,
#   'subEventId': 85,
#   'id': 177960202},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 3319,
#   'positions': [{'y': 59, 'x': 71}, {'y': 85, 'x': 78}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 226.30891500000007,
#   'subEventId': 85,
#   'id': 177960203},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 167145,
#   'positions': [{'y': 85, 'x': 78}, {'y': 64, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 229.245187,
#   'subEventId': 85,
#   'id': 177960204},
#  {'eventId': 10,
#   'subEventName': 'Shot',
#   'tags': [{'id': 401}, {'id': 201}, {'id': 1210}, {'id': 1802}],
#   'playerId': 3319,
#   'positions': [{'y': 64, 'x': 71}, {'y': 0, 'x': 0}],
#   'matchId': 2499719,
#   'eventName': 'Shot',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 231.5146890000001,
#   'subEventId': 100,
#   'id': 177960206},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 41, 'x': 3}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 233.94576599999982,
#   'subEventId': 50,
#   'id': 177960223},
#  {'eventId': 3,
#   'subEventName': 'Goal kick',
#   'tags': [],
#   'playerId': 8480,
#   'positions': [{'y': 100, 'x': 100}, {'y': 90, 'x': 59}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 257.22024899999997,
#   'subEventId': 34,
#   'id': 177960228},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [],
#   'playerId': 26150,
#   'positions': [{'y': 90, 'x': 59}, {'y': 91, 'x': 52}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 259.6467269999998,
#   'subEventId': 72,
#   'id': 177960229},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 26150,
#   'positions': [{'y': 91, 'x': 52}, {'y': 93, 'x': 69}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 262.5783160000001,
#   'subEventId': 11,
#   'id': 177960231},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 7868,
#   'positions': [{'y': 9, 'x': 48}, {'y': 7, 'x': 31}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 263.25244999999995,
#   'subEventId': 12,
#   'id': 177960213},
#  {'eventId': 2,
#   'subEventName': 'Foul',
#   'tags': [],
#   'playerId': 7868,
#   'positions': [{'y': 7, 'x': 31}, {'y': 9, 'x': 48}],
#   'matchId': 2499719,
#   'eventName': 'Foul',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 266.75271900000007,
#   'subEventId': 20,
#   'id': 177960215},
#  {'eventId': 3,
#   'subEventName': 'Free Kick',
#   'tags': [{'id': 1801}],
#   'playerId': 149019,
#   'positions': [{'y': 94, 'x': 60}, {'y': 96, 'x': 59}],
#   'matchId': 2499719,
#   'eventName': 'Free Kick',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 282.76789800000006,
#   'subEventId': 31,
#   'id': 177960235},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 26150,
#   'positions': [{'y': 96, 'x': 59}, {'y': 25, 'x': 39}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 284.14239899999984,
#   'subEventId': 83,
#   'id': 177960236},
#  {'eventId': 7,
#   'subEventName': 'Touch',
#   'tags': [],
#   'playerId': 8653,
#   'positions': [{'y': 25, 'x': 39}, {'y': 27, 'x': 61}],
#   'matchId': 2499719,
#   'eventName': 'Others on the ball',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 288.9895270000002,
#   'subEventId': 72,
#   'id': 177960237},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 703}, {'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 27, 'x': 61}, {'y': 12, 'x': 68}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 292.1812180000002,
#   'subEventId': 11,
#   'id': 177960239},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 701}, {'id': 1802}],
#   'playerId': 25413,
#   'positions': [{'y': 73, 'x': 39}, {'y': 88, 'x': 32}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 292.799266,
#   'subEventId': 12,
#   'id': 177960217},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 12, 'x': 68}, {'y': 4, 'x': 59}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 294.15222300000005,
#   'subEventId': 85,
#   'id': 177960240},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8013,
#   'positions': [{'y': 4, 'x': 59}, {'y': 11, 'x': 71}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 295.89178600000014,
#   'subEventId': 85,
#   'id': 177960241},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14763,
#   'positions': [{'y': 11, 'x': 71}, {'y': 12, 'x': 90}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 298.74366899999995,
#   'subEventId': 85,
#   'id': 177960246},
#  {'eventId': 1,
#   'subEventName': 'Ground defending duel',
#   'tags': [{'id': 502}, {'id': 701}, {'id': 1802}],
#   'playerId': 167145,
#   'positions': [{'y': 88, 'x': 10}, {'y': 84, 'x': 12}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1609,
#   'matchPeriod': '2H',
#   'eventSec': 304.05688999999984,
#   'subEventId': 12,
#   'id': 177960219},
#  {'eventId': 1,
#   'subEventName': 'Ground attacking duel',
#   'tags': [{'id': 501}, {'id': 703}, {'id': 1801}],
#   'playerId': 0,
#   'positions': [{'y': 12, 'x': 90}, {'y': 16, 'x': 88}],
#   'matchId': 2499719,
#   'eventName': 'Duel',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 304.05688999999984,
#   'subEventId': 11,
#   'id': 177961256},
#  {'eventId': 8,
#   'subEventName': 'Simple pass',
#   'tags': [{'id': 1801}],
#   'playerId': 8653,
#   'positions': [{'y': 16, 'x': 88}, {'y': 23, 'x': 70}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 306.370089,
#   'subEventId': 85,
#   'id': 177960255},
#  {'eventId': 8,
#   'subEventName': 'High pass',
#   'tags': [{'id': 1801}],
#   'playerId': 14853,
#   'positions': [{'y': 23, 'x': 70}, {'y': 77, 'x': 97}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 307.8467780000001,
#   'subEventId': 83,
#   'id': 177960263},
#  {'eventId': 8,
#   'subEventName': 'Cross',
#   'tags': [{'id': 401}, {'id': 801}, {'id': 1802}],
#   'playerId': 26150,
#   'positions': [{'y': 77, 'x': 97}, {'y': 0, 'x': 96}],
#   'matchId': 2499719,
#   'eventName': 'Pass',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 312.5272420000001,
#   'subEventId': 80,
#   'id': 177960264},
#  {'eventId': 5,
#   'subEventName': 'Ball out of the field',
#   'tags': [],
#   'playerId': 0,
#   'positions': [{'y': 0, 'x': 96}, {'y': 100, 'x': 100}],
#   'matchId': 2499719,
#   'eventName': 'Interruption',
#   'teamId': 1631,
#   'matchPeriod': '2H',
#   'eventSec': 316.37825900000007,
#   'subEventId': 50,
#   'id': 177960266},
#  ...]

# %% [markdown]
# ##### Flatten Events data

# %%
# Flatten the JSON Events data for each of the Big 5 European leagues and export each DataFrame as a CSV file

## Premier League - England
df_wyscout_event_data_england_flat = json_normalize(json_wyscout_event_data_england)
df_wyscout_event_data_england_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_England.csv', index=None, header=True)
    
## Ligue 1 - France
df_wyscout_event_data_france_flat = json_normalize(json_wyscout_event_data_france)
df_wyscout_event_data_france_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_France.csv', index=None, header=True)

## Bundesliga - Germany
df_wyscout_event_data_germany_flat = json_normalize(json_wyscout_event_data_germany)
df_wyscout_event_data_germany_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_Germany.csv', index=None, header=True)

## Seria A - Italy
df_wyscout_event_data_italy_flat = json_normalize(json_wyscout_event_data_italy)
df_wyscout_event_data_italy_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_Italy.csv', index=None, header=True)

## La Liga - Spain
df_wyscout_event_data_spain_flat = json_normalize(json_wyscout_event_data_spain)
df_wyscout_event_data_spain_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_Spain.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
df_wyscout_event_data_england_flat.shape
# Out:
# (643150, 12)

# %% [markdown]
# ##### Concatenate the flattened Events data for the Big 5 European leagues

# %%
# Concatenate the flattened events data for the Big 5 European leagues

## List of the Big 5 DataFrames
lst_events_dataframes_big5 = [df_wyscout_event_data_england_flat, df_wyscout_event_data_france_flat, df_wyscout_event_data_germany_flat, df_wyscout_event_data_italy_flat, df_wyscout_event_data_spain_flat]

## Concatenate the individual Big 5 DataFrames to one unified DataFrame
df_wyscout_event_data_big5_flat = pd.concat(lst_events_dataframes_big5)

## Export unified DataFrame
df_wyscout_event_data_big5_flat.to_csv(data_dir_wyscout + '/raw/csv/events/events_big5.csv', index=None, header=True)

# %%
df_wyscout_event_data_big5_flat.shape
# Out:
# (3071395, 12)

# %% [markdown]
# ### <a id='#section3.4.'>3.4. Matches</a>

# %% [markdown]
# ##### Read in Matches Data

# %%
# Import all Wyscout JSON matches data from the Big 5 European leagues for the 17/18 season

## Premier League - England
with open(data_dir_wyscout + '/raw/json/matches/matches_England.json') as f:
    json_wyscout_matches_data_england = json.load(f)
    
## Ligue 1 - France
with open(data_dir_wyscout + '/raw/json/matches/matches_France.json') as f:
    json_wyscout_matches_data_france  = json.load(f)

## Bundesliga - Germany
with open(data_dir_wyscout + '/raw/json/matches/matches_Germany.json') as f:
    json_wyscout_matches_data_germany = json.load(f)

## Seria A - Italy
with open(data_dir_wyscout + '/raw/json/matches/matches_Italy.json') as f:
    json_wyscout_matches_data_italy = json.load(f)

## La Liga - Spain
with open(data_dir_wyscout + '/raw/json/matches/matches_Spain.json') as f:
    json_wyscout_matches_data_spain = json.load(f)

# %% [markdown]
# ##### Flatten Matches data

# %%
# Flatten the JSON Matches data for each of the Big 5 European leagues and export each DataFrame as a CSV file

## Premier League - England
df_wyscout_matches_data_england_flat = json_normalize(json_wyscout_matches_data_england)
df_wyscout_matches_data_england_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_England.csv', index=None, header=True)
    
## Ligue 1 - France
df_wyscout_matches_data_france_flat = json_normalize(json_wyscout_matches_data_france)
df_wyscout_matches_data_france_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_France.csv', index=None, header=True)

## Bundesliga - Germany
df_wyscout_matches_data_germany_flat = json_normalize(json_wyscout_matches_data_germany)
df_wyscout_matches_data_germany_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_Germany.csv', index=None, header=True)

## Seria A - Italy
df_wyscout_matches_data_italy_flat = json_normalize(json_wyscout_matches_data_italy)
df_wyscout_matches_data_italy_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_Italy.csv', index=None, header=True)

## La Liga - Spain
df_wyscout_matches_data_spain_flat = json_normalize(json_wyscout_matches_data_spain)
df_wyscout_matches_data_spain_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_Spain.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# ##### Concatenate the flattened Matches data for the Big 5 European leagues

# %%
# Concatenate the flattened events data for the Big 5 European leagues

## List of the Big 5 DataFrames
lst_matches_dataframes_big5 = [df_wyscout_matches_data_england_flat, df_wyscout_matches_data_france_flat, df_wyscout_matches_data_germany_flat, df_wyscout_matches_data_italy_flat, df_wyscout_matches_data_spain_flat]

## Concatenate the individual Big 5 DataFrames to one unified DataFrame
df_wyscout_matches_data_big5_flat = pd.concat(lst_matches_dataframes_big5)

## Export unified DataFrame
df_wyscout_matches_data_big5_flat.to_csv(data_dir_wyscout + '/raw/csv/matches/matches_big5.csv', index=None, header=True)

# %%
df_wyscout_matches_data_big5_flat
# Out:
#      status  roundId  gameweek  seasonId              dateutc  winner  \
# 0    Played  4405654        38    181150  2018-05-13 14:00:00    1659
# 1    Played  4405654        38    181150  2018-05-13 14:00:00    1628
# 2    Played  4405654        38    181150  2018-05-13 14:00:00    1609
# 3    Played  4405654        38    181150  2018-05-13 14:00:00    1612
# 4    Played  4405654        38    181150  2018-05-13 14:00:00    1611
# ..      ...      ...       ...       ...                  ...     ...
# 375  Played  4406122         1    181144  2017-08-19 20:15:00       0
# 376  Played  4406122         1    181144  2017-08-19 18:15:00       0
# 377  Played  4406122         1    181144  2017-08-19 16:15:00     687
# 378  Played  4406122         1    181144  2017-08-18 20:15:00     674
# 379  Played  4406122         1    181144  2017-08-18 18:15:00     712
#
#                                             venue     wyId  \
# 0                                       Turf Moor  2500089
# 1                                   Selhurst Park  2500090
# 2                        The John Smith's Stadium  2500091
# 3                                         Anfield  2500092
# 4                                    Old Trafford  2500093
# ..                                            ...      ...
# 375  Estadio Ram\u00f3n S\u00e1nchez Pizju\u00e1n  2565552
# 376                 Estadi Municipal de Montilivi  2565551
# 377                      Estadio de Bala\u00eddos  2565549
# 378                           Estadio de Mestalla  2565556
# 379                 Estadio Municipal de Butarque  2565557
#
#                                             label  \
# 0                Burnley - AFC Bournemouth, 1 - 2
# 1    Crystal Palace - West Bromwich Albion, 2 - 0
# 2              Huddersfield Town - Arsenal, 0 - 1
# 3       Liverpool - Brighton & Hove Albion, 4 - 0
# 4              Manchester United - Watford, 1 - 0
# ..                                            ...
# 375                     Sevilla - Espanyol, 1 - 1
# 376          Girona - Atl\u00e9tico Madrid, 2 - 2
# 377          Celta de Vigo - Real Sociedad, 2 - 3
# 378                  Valencia - Las Palmas, 1 - 0
# 379   Legan\u00e9s - Deportivo Alav\u00e9s, 1 - 0
#
#                                      date  ... teamsData.695.coachId  \
# 0        May 13, 2018 at 4:00:00 PM GMT+2  ...                   NaN
# 1        May 13, 2018 at 4:00:00 PM GMT+2  ...                   NaN
# 2        May 13, 2018 at 4:00:00 PM GMT+2  ...                   NaN
# 3        May 13, 2018 at 4:00:00 PM GMT+2  ...                   NaN
# 4        May 13, 2018 at 4:00:00 PM GMT+2  ...                   NaN
# ..                                    ...  ...                   ...
# 375  August 19, 2017 at 10:15:00 PM GMT+2  ...                   NaN
# 376   August 19, 2017 at 8:15:00 PM GMT+2  ...                   NaN
# 377   August 19, 2017 at 6:15:00 PM GMT+2  ...                   NaN
# 378  August 18, 2017 at 10:15:00 PM GMT+2  ...                   NaN
# 379   August 18, 2017 at 8:15:00 PM GMT+2  ...                   NaN
#
#     teamsData.695.side  teamsData.695.teamId  teamsData.695.score  \
# 0                  NaN                   NaN                  NaN
# 1                  NaN                   NaN                  NaN
# 2                  NaN                   NaN                  NaN
# 3                  NaN                   NaN                  NaN
# 4                  NaN                   NaN                  NaN
# ..                 ...                   ...                  ...
# 375                NaN                   NaN                  NaN
# 376                NaN                   NaN                  NaN
# 377                NaN                   NaN                  NaN
# 378                NaN                   NaN                  NaN
# 379                NaN                   NaN                  NaN
#
#      teamsData.695.scoreP teamsData.695.hasFormation  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
# ..                    ...                        ...
# 375                   NaN                        NaN
# 376                   NaN                        NaN
# 377                   NaN                        NaN
# 378                   NaN                        NaN
# 379                   NaN                        NaN
#
#      teamsData.695.formation.bench  teamsData.695.formation.lineup  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ..                             ...                             ...
# 375                            NaN                             NaN
# 376                            NaN                             NaN
# 377                            NaN                             NaN
# 378                            NaN                             NaN
# 379                            NaN                             NaN
#
#      teamsData.695.formation.substitutions  teamsData.695.scoreHT
# 0                                      NaN                    NaN
# 1                                      NaN                    NaN
# 2                                      NaN                    NaN
# 3                                      NaN                    NaN
# 4                                      NaN                    NaN
# ..                                     ...                    ...
# 375                                    NaN                    NaN
# 376                                    NaN                    NaN
# 377                                    NaN                    NaN
# 378                                    NaN                    NaN
# 379                                    NaN                    NaN
#
# [1826 rows x 1091 columns]

# %%
# Displays all columns
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_wyscout_matches_data_big5_flat.dtypes)
# Out:
# status                                      object
# roundId                                      int64
# gameweek                                     int64
# seasonId                                     int64
# dateutc                                     object
# winner                                       int64
# venue                                       object
# wyId                                         int64
# label                                       object
# date                                        object
# referees                                    object
# duration                                    object
# competitionId                                int64
# teamsData.1646.scoreET                     float64
# teamsData.1646.coachId                     float64
# teamsData.1646.side                         object
# teamsData.1646.teamId                      float64
# teamsData.1646.score                       float64
# teamsData.1646.scoreP                      float64
# teamsData.1646.hasFormation                float64
# teamsData.1646.formation.bench              object
# teamsData.1646.formation.lineup             object
# teamsData.1646.formation.substitutions      object
# teamsData.1646.scoreHT                     float64
# teamsData.1659.scoreET                     float64
# teamsData.1659.coachId                     float64
# teamsData.1659.side                         object
# teamsData.1659.teamId                      float64
# teamsData.1659.score                       float64
# teamsData.1659.scoreP                      float64
# teamsData.1659.hasFormation                float64
# teamsData.1659.formation.bench              object
# teamsData.1659.formation.lineup             object
# teamsData.1659.formation.substitutions      object
# teamsData.1659.scoreHT                     float64
# teamsData.1628.scoreET                     float64
# teamsData.1628.coachId                     float64
# teamsData.1628.side                         object
# teamsData.1628.teamId                      float64
# teamsData.1628.score                       float64
# teamsData.1628.scoreP                      float64
# teamsData.1628.hasFormation                float64
# teamsData.1628.formation.bench              object
# teamsData.1628.formation.lineup             object
# teamsData.1628.formation.substitutions      object
# teamsData.1628.scoreHT                     float64
# teamsData.1627.scoreET                     float64
# teamsData.1627.coachId                     float64
# teamsData.1627.side                         object
# teamsData.1627.teamId                      float64
# teamsData.1627.score                       float64
# teamsData.1627.scoreP                      float64
# teamsData.1627.hasFormation                float64
# teamsData.1627.formation.bench              object
# teamsData.1627.formation.lineup             object
# teamsData.1627.formation.substitutions      object
# teamsData.1627.scoreHT                     float64
# teamsData.1609.scoreET                     float64
# teamsData.1609.coachId                     float64
# teamsData.1609.side                         object
# teamsData.1609.teamId                      float64
# teamsData.1609.score                       float64
# teamsData.1609.scoreP                      float64
# teamsData.1609.hasFormation                float64
# teamsData.1609.formation.bench              object
# teamsData.1609.formation.lineup             object
# teamsData.1609.formation.substitutions      object
# teamsData.1609.scoreHT                     float64
# teamsData.1673.scoreET                     float64
# teamsData.1673.coachId                     float64
# teamsData.1673.side                         object
# teamsData.1673.teamId                      float64
# teamsData.1673.score                       float64
# teamsData.1673.scoreP                      float64
# teamsData.1673.hasFormation                float64
# teamsData.1673.formation.bench              object
# teamsData.1673.formation.lineup             object
# teamsData.1673.formation.substitutions      object
# teamsData.1673.scoreHT                     float64
# teamsData.1651.scoreET                     float64
# teamsData.1651.coachId                     float64
# teamsData.1651.side                         object
# teamsData.1651.teamId                      float64
# teamsData.1651.score                       float64
# teamsData.1651.scoreP                      float64
# teamsData.1651.hasFormation                float64
# teamsData.1651.formation.bench              object
# teamsData.1651.formation.lineup             object
# teamsData.1651.formation.substitutions      object
# teamsData.1651.scoreHT                     float64
# teamsData.1612.scoreET                     float64
# teamsData.1612.coachId                     float64
# teamsData.1612.side                         object
# teamsData.1612.teamId                      float64
# teamsData.1612.score                       float64
# teamsData.1612.scoreP                      float64
# teamsData.1612.hasFormation                float64
# teamsData.1612.formation.bench              object
# teamsData.1612.formation.lineup             object
# teamsData.1612.formation.substitutions      object
# teamsData.1612.scoreHT                     float64
# teamsData.1644.scoreET                     float64
# teamsData.1644.coachId                     float64
# teamsData.1644.side                         object
# teamsData.1644.teamId                      float64
# teamsData.1644.score                       float64
# teamsData.1644.scoreP                      float64
# teamsData.1644.hasFormation                float64
# teamsData.1644.formation.bench              object
# teamsData.1644.formation.lineup             object
# teamsData.1644.formation.substitutions      object
# teamsData.1644.scoreHT                     float64
# teamsData.1611.scoreET                     float64
# teamsData.1611.coachId                     float64
# teamsData.1611.side                         object
# teamsData.1611.teamId                      float64
# teamsData.1611.score                       float64
# teamsData.1611.scoreP                      float64
# teamsData.1611.hasFormation                float64
# teamsData.1611.formation.bench              object
# teamsData.1611.formation.lineup             object
# teamsData.1611.formation.substitutions      object
# teamsData.1611.scoreHT                     float64
# teamsData.1613.scoreET                     float64
# teamsData.1613.coachId                     float64
# teamsData.1613.side                         object
# teamsData.1613.teamId                      float64
# teamsData.1613.score                       float64
# teamsData.1613.scoreP                      float64
# teamsData.1613.hasFormation                float64
# teamsData.1613.formation.bench              object
# teamsData.1613.formation.lineup             object
# teamsData.1613.formation.substitutions      object
# teamsData.1613.scoreHT                     float64
# teamsData.1610.scoreET                     float64
# teamsData.1610.coachId                     float64
# teamsData.1610.side                         object
# teamsData.1610.teamId                      float64
# teamsData.1610.score                       float64
# teamsData.1610.scoreP                      float64
# teamsData.1610.hasFormation                float64
# teamsData.1610.formation.bench              object
# teamsData.1610.formation.lineup             object
# teamsData.1610.formation.substitutions      object
# teamsData.1610.scoreHT                     float64
# teamsData.1625.scoreET                     float64
# teamsData.1625.coachId                     float64
# teamsData.1625.side                         object
# teamsData.1625.teamId                      float64
# teamsData.1625.score                       float64
# teamsData.1625.scoreP                      float64
# teamsData.1625.hasFormation                float64
# teamsData.1625.formation.bench              object
# teamsData.1625.formation.lineup             object
# teamsData.1625.formation.substitutions      object
# teamsData.1625.scoreHT                     float64
# teamsData.1619.scoreET                     float64
# teamsData.1619.coachId                     float64
# teamsData.1619.side                         object
# teamsData.1619.teamId                      float64
# teamsData.1619.score                       float64
# teamsData.1619.scoreP                      float64
# teamsData.1619.hasFormation                float64
# teamsData.1619.formation.bench              object
# teamsData.1619.formation.lineup             object
# teamsData.1619.formation.substitutions      object
# teamsData.1619.scoreHT                     float64
# teamsData.10531.scoreET                    float64
# teamsData.10531.coachId                    float64
# teamsData.10531.side                        object
# teamsData.10531.teamId                     float64
# teamsData.10531.score                      float64
# teamsData.10531.scoreP                     float64
# teamsData.10531.hasFormation               float64
# teamsData.10531.formation.bench             object
# teamsData.10531.formation.lineup            object
# teamsData.10531.formation.substitutions     object
# teamsData.10531.scoreHT                    float64
# teamsData.1639.scoreET                     float64
# teamsData.1639.coachId                     float64
# teamsData.1639.side                         object
# teamsData.1639.teamId                      float64
# teamsData.1639.score                       float64
# teamsData.1639.scoreP                      float64
# teamsData.1639.hasFormation                float64
# teamsData.1639.formation.bench              object
# teamsData.1639.formation.lineup             object
# teamsData.1639.formation.substitutions      object
# teamsData.1639.scoreHT                     float64
# teamsData.1631.scoreET                     float64
# teamsData.1631.coachId                     float64
# teamsData.1631.side                         object
# teamsData.1631.teamId                      float64
# teamsData.1631.score                       float64
# teamsData.1631.scoreP                      float64
# teamsData.1631.hasFormation                float64
# teamsData.1631.formation.bench              object
# teamsData.1631.formation.lineup             object
# teamsData.1631.formation.substitutions      object
# teamsData.1631.scoreHT                     float64
# teamsData.1624.scoreET                     float64
# teamsData.1624.coachId                     float64
# teamsData.1624.side                         object
# teamsData.1624.teamId                      float64
# teamsData.1624.score                       float64
# teamsData.1624.scoreP                      float64
# teamsData.1624.hasFormation                float64
# teamsData.1624.formation.bench              object
# teamsData.1624.formation.lineup             object
# teamsData.1624.formation.substitutions      object
# teamsData.1624.scoreHT                     float64
# teamsData.1623.scoreET                     float64
# teamsData.1623.coachId                     float64
# teamsData.1623.side                         object
# teamsData.1623.teamId                      float64
# teamsData.1623.score                       float64
# teamsData.1623.scoreP                      float64
# teamsData.1623.hasFormation                float64
# teamsData.1623.formation.bench              object
# teamsData.1623.formation.lineup             object
# teamsData.1623.formation.substitutions      object
# teamsData.1623.scoreHT                     float64
# teamsData.1633.scoreET                     float64
# teamsData.1633.coachId                     float64
# teamsData.1633.side                         object
# teamsData.1633.teamId                      float64
# teamsData.1633.score                       float64
# teamsData.1633.scoreP                      float64
# teamsData.1633.hasFormation                float64
# teamsData.1633.formation.bench              object
# teamsData.1633.formation.lineup             object
# teamsData.1633.formation.substitutions      object
# teamsData.1633.scoreHT                     float64
# teamsData.3783.scoreET                     float64
# teamsData.3783.coachId                     float64
# teamsData.3783.side                         object
# teamsData.3783.teamId                      float64
# teamsData.3783.score                       float64
# teamsData.3783.scoreP                      float64
# teamsData.3783.hasFormation                float64
# teamsData.3783.formation.bench              object
# teamsData.3783.formation.lineup             object
# teamsData.3783.formation.substitutions      object
# teamsData.3783.scoreHT                     float64
# teamsData.3767.scoreET                     float64
# teamsData.3767.coachId                     float64
# teamsData.3767.side                         object
# teamsData.3767.teamId                      float64
# teamsData.3767.score                       float64
# teamsData.3767.scoreP                      float64
# teamsData.3767.hasFormation                float64
# teamsData.3767.formation.bench              object
# teamsData.3767.formation.lineup             object
# teamsData.3767.formation.substitutions      object
# teamsData.3767.scoreHT                     float64
# teamsData.3804.scoreET                     float64
# teamsData.3804.coachId                     float64
# teamsData.3804.side                         object
# teamsData.3804.teamId                      float64
# teamsData.3804.score                       float64
# teamsData.3804.scoreP                      float64
# teamsData.3804.hasFormation                float64
# teamsData.3804.formation.bench              object
# teamsData.3804.formation.lineup             object
# teamsData.3804.formation.substitutions      object
# teamsData.3804.scoreHT                     float64
# teamsData.3799.scoreET                     float64
# teamsData.3799.coachId                     float64
# teamsData.3799.side                         object
# teamsData.3799.teamId                      float64
# teamsData.3799.score                       float64
# teamsData.3799.scoreP                      float64
# teamsData.3799.hasFormation                float64
# teamsData.3799.formation.bench              object
# teamsData.3799.formation.lineup             object
# teamsData.3799.formation.substitutions      object
# teamsData.3799.scoreHT                     float64
# teamsData.3766.scoreET                     float64
# teamsData.3766.coachId                     float64
# teamsData.3766.side                         object
# teamsData.3766.teamId                      float64
# teamsData.3766.score                       float64
# teamsData.3766.scoreP                      float64
# teamsData.3766.hasFormation                float64
# teamsData.3766.formation.bench              object
# teamsData.3766.formation.lineup             object
# teamsData.3766.formation.substitutions      object
# teamsData.3766.scoreHT                     float64
# teamsData.3775.scoreET                     float64
# teamsData.3775.coachId                     float64
# teamsData.3775.side                         object
# teamsData.3775.teamId                      float64
# teamsData.3775.score                       float64
# teamsData.3775.scoreP                      float64
# teamsData.3775.hasFormation                float64
# teamsData.3775.formation.bench              object
# teamsData.3775.formation.lineup             object
# teamsData.3775.formation.substitutions      object
# teamsData.3775.scoreHT                     float64
# teamsData.3771.scoreET                     float64
# teamsData.3771.coachId                     float64
# teamsData.3771.side                         object
# teamsData.3771.teamId                      float64
# teamsData.3771.score                       float64
# teamsData.3771.scoreP                      float64
# teamsData.3771.hasFormation                float64
# teamsData.3771.formation.bench              object
# teamsData.3771.formation.lineup             object
# teamsData.3771.formation.substitutions      object
# teamsData.3771.scoreHT                     float64
# teamsData.3789.scoreET                     float64
# teamsData.3789.coachId                     float64
# teamsData.3789.side                         object
# teamsData.3789.teamId                      float64
# teamsData.3789.score                       float64
# teamsData.3789.scoreP                      float64
# teamsData.3789.hasFormation                float64
# teamsData.3789.formation.bench              object
# teamsData.3789.formation.lineup             object
# teamsData.3789.formation.substitutions      object
# teamsData.3789.scoreHT                     float64
# teamsData.3772.scoreET                     float64
# teamsData.3772.coachId                     float64
# teamsData.3772.side                         object
# teamsData.3772.teamId                      float64
# teamsData.3772.score                       float64
# teamsData.3772.scoreP                      float64
# teamsData.3772.hasFormation                float64
# teamsData.3772.formation.bench              object
# teamsData.3772.formation.lineup             object
# teamsData.3772.formation.substitutions      object
# teamsData.3772.scoreHT                     float64
# teamsData.3777.scoreET                     float64
# teamsData.3777.coachId                     float64
# teamsData.3777.side                         object
# teamsData.3777.teamId                      float64
# teamsData.3777.score                       float64
# teamsData.3777.scoreP                      float64
# teamsData.3777.hasFormation                float64
# teamsData.3777.formation.bench              object
# teamsData.3777.formation.lineup             object
# teamsData.3777.formation.substitutions      object
# teamsData.3777.scoreHT                     float64
# teamsData.3779.scoreET                     float64
# teamsData.3779.coachId                     float64
# teamsData.3779.side                         object
# teamsData.3779.teamId                      float64
# teamsData.3779.score                       float64
# teamsData.3779.scoreP                      float64
# teamsData.3779.hasFormation                float64
# teamsData.3779.formation.bench              object
# teamsData.3779.formation.lineup             object
# teamsData.3779.formation.substitutions      object
# teamsData.3779.scoreHT                     float64
# teamsData.3770.scoreET                     float64
# teamsData.3770.coachId                     float64
# teamsData.3770.side                         object
# teamsData.3770.teamId                      float64
# teamsData.3770.score                       float64
# teamsData.3770.scoreP                      float64
# teamsData.3770.hasFormation                float64
# teamsData.3770.formation.bench              object
# teamsData.3770.formation.lineup             object
# teamsData.3770.formation.substitutions      object
# teamsData.3770.scoreHT                     float64
# teamsData.3787.scoreET                     float64
# teamsData.3787.coachId                     float64
# teamsData.3787.side                         object
# teamsData.3787.teamId                      float64
# teamsData.3787.score                       float64
# teamsData.3787.scoreP                      float64
# teamsData.3787.hasFormation                float64
# teamsData.3787.formation.bench              object
# teamsData.3787.formation.lineup             object
# teamsData.3787.formation.substitutions      object
# teamsData.3787.scoreHT                     float64
# teamsData.3774.scoreET                     float64
# teamsData.3774.coachId                     float64
# teamsData.3774.side                         object
# teamsData.3774.teamId                      float64
# teamsData.3774.score                       float64
# teamsData.3774.scoreP                      float64
# teamsData.3774.hasFormation                float64
# teamsData.3774.formation.bench              object
# teamsData.3774.formation.lineup             object
# teamsData.3774.formation.substitutions      object
# teamsData.3774.scoreHT                     float64
# teamsData.3782.scoreET                     float64
# teamsData.3782.coachId                     float64
# teamsData.3782.side                         object
# teamsData.3782.teamId                      float64
# teamsData.3782.score                       float64
# teamsData.3782.scoreP                      float64
# teamsData.3782.hasFormation                float64
# teamsData.3782.formation.bench              object
# teamsData.3782.formation.lineup             object
# teamsData.3782.formation.substitutions      object
# teamsData.3782.scoreHT                     float64
# teamsData.3776.scoreET                     float64
# teamsData.3776.coachId                     float64
# teamsData.3776.side                         object
# teamsData.3776.teamId                      float64
# teamsData.3776.score                       float64
# teamsData.3776.scoreP                      float64
# teamsData.3776.hasFormation                float64
# teamsData.3776.formation.bench              object
# teamsData.3776.formation.lineup             object
# teamsData.3776.formation.substitutions      object
# teamsData.3776.scoreHT                     float64
# teamsData.3780.scoreET                     float64
# teamsData.3780.coachId                     float64
# teamsData.3780.side                         object
# teamsData.3780.teamId                      float64
# teamsData.3780.score                       float64
# teamsData.3780.scoreP                      float64
# teamsData.3780.hasFormation                float64
# teamsData.3780.formation.bench              object
# teamsData.3780.formation.lineup             object
# teamsData.3780.formation.substitutions      object
# teamsData.3780.scoreHT                     float64
# teamsData.3785.scoreET                     float64
# teamsData.3785.coachId                     float64
# teamsData.3785.side                         object
# teamsData.3785.teamId                      float64
# teamsData.3785.score                       float64
# teamsData.3785.scoreP                      float64
# teamsData.3785.hasFormation                float64
# teamsData.3785.formation.bench              object
# teamsData.3785.formation.lineup             object
# teamsData.3785.formation.substitutions      object
# teamsData.3785.scoreHT                     float64
# teamsData.3795.scoreET                     float64
# teamsData.3795.coachId                     float64
# teamsData.3795.side                         object
# teamsData.3795.teamId                      float64
# teamsData.3795.score                       float64
# teamsData.3795.scoreP                      float64
# teamsData.3795.hasFormation                float64
# teamsData.3795.formation.bench              object
# teamsData.3795.formation.lineup             object
# teamsData.3795.formation.substitutions      object
# teamsData.3795.scoreHT                     float64
# teamsData.19830.scoreET                    float64
# teamsData.19830.coachId                    float64
# teamsData.19830.side                        object
# teamsData.19830.teamId                     float64
# teamsData.19830.score                      float64
# teamsData.19830.scoreP                     float64
# teamsData.19830.hasFormation               float64
# teamsData.19830.formation.bench             object
# teamsData.19830.formation.lineup            object
# teamsData.19830.formation.substitutions     object
# teamsData.19830.scoreHT                    float64
# teamsData.2444.scoreET                     float64
# teamsData.2444.coachId                     float64
# teamsData.2444.side                         object
# teamsData.2444.teamId                      float64
# teamsData.2444.score                       float64
# teamsData.2444.scoreP                      float64
# teamsData.2444.hasFormation                float64
# teamsData.2444.formation.bench              object
# teamsData.2444.formation.lineup             object
# teamsData.2444.formation.substitutions      object
# teamsData.2444.scoreHT                     float64
# teamsData.2445.scoreET                     float64
# teamsData.2445.coachId                     float64
# teamsData.2445.side                         object
# teamsData.2445.teamId                      float64
# teamsData.2445.score                       float64
# teamsData.2445.scoreP                      float64
# teamsData.2445.hasFormation                float64
# teamsData.2445.formation.bench              object
# teamsData.2445.formation.lineup             object
# teamsData.2445.formation.substitutions      object
# teamsData.2445.scoreHT                     float64
# teamsData.2482.scoreET                     float64
# teamsData.2482.coachId                     float64
# teamsData.2482.side                         object
# teamsData.2482.teamId                      float64
# teamsData.2482.score                       float64
# teamsData.2482.scoreP                      float64
# teamsData.2482.hasFormation                float64
# teamsData.2482.formation.bench              object
# teamsData.2482.formation.lineup             object
# teamsData.2482.formation.substitutions      object
# teamsData.2482.scoreHT                     float64
# teamsData.2447.scoreET                     float64
# teamsData.2447.coachId                     float64
# teamsData.2447.side                         object
# teamsData.2447.teamId                      float64
# teamsData.2447.score                       float64
# teamsData.2447.scoreP                      float64
# teamsData.2447.hasFormation                float64
# teamsData.2447.formation.bench              object
# teamsData.2447.formation.lineup             object
# teamsData.2447.formation.substitutions      object
# teamsData.2447.scoreHT                     float64
# teamsData.2457.scoreET                     float64
# teamsData.2457.coachId                     float64
# teamsData.2457.side                         object
# teamsData.2457.teamId                      float64
# teamsData.2457.score                       float64
# teamsData.2457.scoreP                      float64
# teamsData.2457.hasFormation                float64
# teamsData.2457.formation.bench              object
# teamsData.2457.formation.lineup             object
# teamsData.2457.formation.substitutions      object
# teamsData.2457.scoreHT                     float64
# teamsData.2975.scoreET                     float64
# teamsData.2975.coachId                     float64
# teamsData.2975.side                         object
# teamsData.2975.teamId                      float64
# teamsData.2975.score                       float64
# teamsData.2975.scoreP                      float64
# teamsData.2975.hasFormation                float64
# teamsData.2975.formation.bench              object
# teamsData.2975.formation.lineup             object
# teamsData.2975.formation.substitutions      object
# teamsData.2975.scoreHT                     float64
# teamsData.2453.scoreET                     float64
# teamsData.2453.coachId                     float64
# teamsData.2453.side                         object
# teamsData.2453.teamId                      float64
# teamsData.2453.score                       float64
# teamsData.2453.scoreP                      float64
# teamsData.2453.hasFormation                float64
# teamsData.2453.formation.bench              object
# teamsData.2453.formation.lineup             object
# teamsData.2453.formation.substitutions      object
# teamsData.2453.scoreHT                     float64
# teamsData.2481.scoreET                     float64
# teamsData.2481.coachId                     float64
# teamsData.2481.side                         object
# teamsData.2481.teamId                      float64
# teamsData.2481.score                       float64
# teamsData.2481.scoreP                      float64
# teamsData.2481.hasFormation                float64
# teamsData.2481.formation.bench              object
# teamsData.2481.formation.lineup             object
# teamsData.2481.formation.substitutions      object
# teamsData.2481.scoreHT                     float64
# teamsData.2449.scoreET                     float64
# teamsData.2449.coachId                     float64
# teamsData.2449.side                         object
# teamsData.2449.teamId                      float64
# teamsData.2449.score                       float64
# teamsData.2449.scoreP                      float64
# teamsData.2449.hasFormation                float64
# teamsData.2449.formation.bench              object
# teamsData.2449.formation.lineup             object
# teamsData.2449.formation.substitutions      object
# teamsData.2449.scoreHT                     float64
# teamsData.2462.scoreET                     float64
# teamsData.2462.coachId                     float64
# teamsData.2462.side                         object
# teamsData.2462.teamId                      float64
# teamsData.2462.score                       float64
# teamsData.2462.scoreP                      float64
# teamsData.2462.hasFormation                float64
# teamsData.2462.formation.bench              object
# teamsData.2462.formation.lineup             object
# teamsData.2462.formation.substitutions      object
# teamsData.2462.scoreHT                     float64
# teamsData.2455.scoreET                     float64
# teamsData.2455.coachId                     float64
# teamsData.2455.side                         object
# teamsData.2455.teamId                      float64
# teamsData.2455.score                       float64
# teamsData.2455.scoreP                      float64
# teamsData.2455.hasFormation                float64
# teamsData.2455.formation.bench              object
# teamsData.2455.formation.lineup             object
# teamsData.2455.formation.substitutions      object
# teamsData.2455.scoreHT                     float64
# teamsData.2446.scoreET                     float64
# teamsData.2446.coachId                     float64
# teamsData.2446.side                         object
# teamsData.2446.teamId                      float64
# teamsData.2446.score                       float64
# teamsData.2446.scoreP                      float64
# teamsData.2446.hasFormation                float64
# teamsData.2446.formation.bench              object
# teamsData.2446.formation.lineup             object
# teamsData.2446.formation.substitutions      object
# teamsData.2446.scoreHT                     float64
# teamsData.2454.scoreET                     float64
# teamsData.2454.coachId                     float64
# teamsData.2454.side                         object
# teamsData.2454.teamId                      float64
# teamsData.2454.score                       float64
# teamsData.2454.scoreP                      float64
# teamsData.2454.hasFormation                float64
# teamsData.2454.formation.bench              object
# teamsData.2454.formation.lineup             object
# teamsData.2454.formation.substitutions      object
# teamsData.2454.scoreHT                     float64
# teamsData.2450.scoreET                     float64
# teamsData.2450.coachId                     float64
# teamsData.2450.side                         object
# teamsData.2450.teamId                      float64
# teamsData.2450.score                       float64
# teamsData.2450.scoreP                      float64
# teamsData.2450.hasFormation                float64
# teamsData.2450.formation.bench              object
# teamsData.2450.formation.lineup             object
# teamsData.2450.formation.substitutions      object
# teamsData.2450.scoreHT                     float64
# teamsData.2443.scoreET                     float64
# teamsData.2443.coachId                     float64
# teamsData.2443.side                         object
# teamsData.2443.teamId                      float64
# teamsData.2443.score                       float64
# teamsData.2443.scoreP                      float64
# teamsData.2443.hasFormation                float64
# teamsData.2443.formation.bench              object
# teamsData.2443.formation.lineup             object
# teamsData.2443.formation.substitutions      object
# teamsData.2443.scoreHT                     float64
# teamsData.2460.scoreET                     float64
# teamsData.2460.coachId                     float64
# teamsData.2460.side                         object
# teamsData.2460.teamId                      float64
# teamsData.2460.score                       float64
# teamsData.2460.scoreP                      float64
# teamsData.2460.hasFormation                float64
# teamsData.2460.formation.bench              object
# teamsData.2460.formation.lineup             object
# teamsData.2460.formation.substitutions      object
# teamsData.2460.scoreHT                     float64
# teamsData.2451.scoreET                     float64
# teamsData.2451.coachId                     float64
# teamsData.2451.side                         object
# teamsData.2451.teamId                      float64
# teamsData.2451.score                       float64
# teamsData.2451.scoreP                      float64
# teamsData.2451.hasFormation                float64
# teamsData.2451.formation.bench              object
# teamsData.2451.formation.lineup             object
# teamsData.2451.formation.substitutions      object
# teamsData.2451.scoreHT                     float64
# teamsData.2463.scoreET                     float64
# teamsData.2463.coachId                     float64
# teamsData.2463.side                         object
# teamsData.2463.teamId                      float64
# teamsData.2463.score                       float64
# teamsData.2463.scoreP                      float64
# teamsData.2463.hasFormation                float64
# teamsData.2463.formation.bench              object
# teamsData.2463.formation.lineup             object
# teamsData.2463.formation.substitutions      object
# teamsData.2463.scoreHT                     float64
# teamsData.3162.scoreET                     float64
# teamsData.3162.coachId                     float64
# teamsData.3162.side                         object
# teamsData.3162.teamId                      float64
# teamsData.3162.score                       float64
# teamsData.3162.scoreP                      float64
# teamsData.3162.hasFormation                float64
# teamsData.3162.formation.bench              object
# teamsData.3162.formation.lineup             object
# teamsData.3162.formation.substitutions      object
# teamsData.3162.scoreHT                     float64
# teamsData.3161.scoreET                     float64
# teamsData.3161.coachId                     float64
# teamsData.3161.side                         object
# teamsData.3161.teamId                      float64
# teamsData.3161.score                       float64
# teamsData.3161.scoreP                      float64
# teamsData.3161.hasFormation                float64
# teamsData.3161.formation.bench              object
# teamsData.3161.formation.lineup             object
# teamsData.3161.formation.substitutions      object
# teamsData.3161.scoreHT                     float64
# teamsData.3158.scoreET                     float64
# teamsData.3158.coachId                     float64
# teamsData.3158.side                         object
# teamsData.3158.teamId                      float64
# teamsData.3158.score                       float64
# teamsData.3158.scoreP                      float64
# teamsData.3158.hasFormation                float64
# teamsData.3158.formation.bench              object
# teamsData.3158.formation.lineup             object
# teamsData.3158.formation.substitutions      object
# teamsData.3158.scoreHT                     float64
# teamsData.3315.scoreET                     float64
# teamsData.3315.coachId                     float64
# teamsData.3315.side                         object
# teamsData.3315.teamId                      float64
# teamsData.3315.score                       float64
# teamsData.3315.scoreP                      float64
# teamsData.3315.hasFormation                float64
# teamsData.3315.formation.bench              object
# teamsData.3315.formation.lineup             object
# teamsData.3315.formation.substitutions      object
# teamsData.3315.scoreHT                     float64
# teamsData.3173.scoreET                     float64
# teamsData.3173.coachId                     float64
# teamsData.3173.side                         object
# teamsData.3173.teamId                      float64
# teamsData.3173.score                       float64
# teamsData.3173.scoreP                      float64
# teamsData.3173.hasFormation                float64
# teamsData.3173.formation.bench              object
# teamsData.3173.formation.lineup             object
# teamsData.3173.formation.substitutions      object
# teamsData.3173.scoreHT                     float64
# teamsData.3172.scoreET                     float64
# teamsData.3172.coachId                     float64
# teamsData.3172.side                         object
# teamsData.3172.teamId                      float64
# teamsData.3172.score                       float64
# teamsData.3172.scoreP                      float64
# teamsData.3172.hasFormation                float64
# teamsData.3172.formation.bench              object
# teamsData.3172.formation.lineup             object
# teamsData.3172.formation.substitutions      object
# teamsData.3172.scoreHT                     float64
# teamsData.3165.scoreET                     float64
# teamsData.3165.coachId                     float64
# teamsData.3165.side                         object
# teamsData.3165.teamId                      float64
# teamsData.3165.score                       float64
# teamsData.3165.scoreP                      float64
# teamsData.3165.hasFormation                float64
# teamsData.3165.formation.bench              object
# teamsData.3165.formation.lineup             object
# teamsData.3165.formation.substitutions      object
# teamsData.3165.scoreHT                     float64
# teamsData.3219.scoreET                     float64
# teamsData.3219.coachId                     float64
# teamsData.3219.side                         object
# teamsData.3219.teamId                      float64
# teamsData.3219.score                       float64
# teamsData.3219.scoreP                      float64
# teamsData.3219.hasFormation                float64
# teamsData.3219.formation.bench              object
# teamsData.3219.formation.lineup             object
# teamsData.3219.formation.substitutions      object
# teamsData.3219.scoreHT                     float64
# teamsData.3166.scoreET                     float64
# teamsData.3166.coachId                     float64
# teamsData.3166.side                         object
# teamsData.3166.teamId                      float64
# teamsData.3166.score                       float64
# teamsData.3166.scoreP                      float64
# teamsData.3166.hasFormation                float64
# teamsData.3166.formation.bench              object
# teamsData.3166.formation.lineup             object
# teamsData.3166.formation.substitutions      object
# teamsData.3166.scoreHT                     float64
# teamsData.3163.scoreET                     float64
# teamsData.3163.coachId                     float64
# teamsData.3163.side                         object
# teamsData.3163.teamId                      float64
# teamsData.3163.score                       float64
# teamsData.3163.scoreP                      float64
# teamsData.3163.hasFormation                float64
# teamsData.3163.formation.bench              object
# teamsData.3163.formation.lineup             object
# teamsData.3163.formation.substitutions      object
# teamsData.3163.scoreHT                     float64
# teamsData.3197.scoreET                     float64
# teamsData.3197.coachId                     float64
# teamsData.3197.side                         object
# teamsData.3197.teamId                      float64
# teamsData.3197.score                       float64
# teamsData.3197.scoreP                      float64
# teamsData.3197.hasFormation                float64
# teamsData.3197.formation.bench              object
# teamsData.3197.formation.lineup             object
# teamsData.3197.formation.substitutions      object
# teamsData.3197.scoreHT                     float64
# teamsData.3187.scoreET                     float64
# teamsData.3187.coachId                     float64
# teamsData.3187.side                         object
# teamsData.3187.teamId                      float64
# teamsData.3187.score                       float64
# teamsData.3187.scoreP                      float64
# teamsData.3187.hasFormation                float64
# teamsData.3187.formation.bench              object
# teamsData.3187.formation.lineup             object
# teamsData.3187.formation.substitutions      object
# teamsData.3187.scoreHT                     float64
# teamsData.3157.scoreET                     float64
# teamsData.3157.coachId                     float64
# teamsData.3157.side                         object
# teamsData.3157.teamId                      float64
# teamsData.3157.score                       float64
# teamsData.3157.scoreP                      float64
# teamsData.3157.hasFormation                float64
# teamsData.3157.formation.bench              object
# teamsData.3157.formation.lineup             object
# teamsData.3157.formation.substitutions      object
# teamsData.3157.scoreHT                     float64
# teamsData.3176.scoreET                     float64
# teamsData.3176.coachId                     float64
# teamsData.3176.side                         object
# teamsData.3176.teamId                      float64
# teamsData.3176.score                       float64
# teamsData.3176.scoreP                      float64
# teamsData.3176.hasFormation                float64
# teamsData.3176.formation.bench              object
# teamsData.3176.formation.lineup             object
# teamsData.3176.formation.substitutions      object
# teamsData.3176.scoreHT                     float64
# teamsData.3164.scoreET                     float64
# teamsData.3164.coachId                     float64
# teamsData.3164.side                         object
# teamsData.3164.teamId                      float64
# teamsData.3164.score                       float64
# teamsData.3164.scoreP                      float64
# teamsData.3164.hasFormation                float64
# teamsData.3164.formation.bench              object
# teamsData.3164.formation.lineup             object
# teamsData.3164.formation.substitutions      object
# teamsData.3164.scoreHT                     float64
# teamsData.3204.scoreET                     float64
# teamsData.3204.coachId                     float64
# teamsData.3204.side                         object
# teamsData.3204.teamId                      float64
# teamsData.3204.score                       float64
# teamsData.3204.scoreP                      float64
# teamsData.3204.hasFormation                float64
# teamsData.3204.formation.bench              object
# teamsData.3204.formation.lineup             object
# teamsData.3204.formation.substitutions      object
# teamsData.3204.scoreHT                     float64
# teamsData.3185.scoreET                     float64
# teamsData.3185.coachId                     float64
# teamsData.3185.side                         object
# teamsData.3185.teamId                      float64
# teamsData.3185.score                       float64
# teamsData.3185.scoreP                      float64
# teamsData.3185.hasFormation                float64
# teamsData.3185.formation.bench              object
# teamsData.3185.formation.lineup             object
# teamsData.3185.formation.substitutions      object
# teamsData.3185.scoreHT                     float64
# teamsData.3193.scoreET                     float64
# teamsData.3193.coachId                     float64
# teamsData.3193.side                         object
# teamsData.3193.teamId                      float64
# teamsData.3193.score                       float64
# teamsData.3193.scoreP                      float64
# teamsData.3193.hasFormation                float64
# teamsData.3193.formation.bench              object
# teamsData.3193.formation.lineup             object
# teamsData.3193.formation.substitutions      object
# teamsData.3193.scoreHT                     float64
# teamsData.3159.scoreET                     float64
# teamsData.3159.coachId                     float64
# teamsData.3159.side                         object
# teamsData.3159.teamId                      float64
# teamsData.3159.score                       float64
# teamsData.3159.scoreP                      float64
# teamsData.3159.hasFormation                float64
# teamsData.3159.formation.bench              object
# teamsData.3159.formation.lineup             object
# teamsData.3159.formation.substitutions      object
# teamsData.3159.scoreHT                     float64
# teamsData.3194.scoreET                     float64
# teamsData.3194.coachId                     float64
# teamsData.3194.side                         object
# teamsData.3194.teamId                      float64
# teamsData.3194.score                       float64
# teamsData.3194.scoreP                      float64
# teamsData.3194.hasFormation                float64
# teamsData.3194.formation.bench              object
# teamsData.3194.formation.lineup             object
# teamsData.3194.formation.substitutions      object
# teamsData.3194.scoreHT                     float64
# teamsData.676.scoreET                      float64
# teamsData.676.coachId                      float64
# teamsData.676.side                          object
# teamsData.676.teamId                       float64
# teamsData.676.score                        float64
# teamsData.676.scoreP                       float64
# teamsData.676.hasFormation                 float64
# teamsData.676.formation.bench               object
# teamsData.676.formation.lineup              object
# teamsData.676.formation.substitutions       object
# teamsData.676.scoreHT                      float64
# teamsData.687.scoreET                      float64
# teamsData.687.coachId                      float64
# teamsData.687.side                          object
# teamsData.687.teamId                       float64
# teamsData.687.score                        float64
# teamsData.687.scoreP                       float64
# teamsData.687.hasFormation                 float64
# teamsData.687.formation.bench               object
# teamsData.687.formation.lineup              object
# teamsData.687.formation.substitutions       object
# teamsData.687.scoreHT                      float64
# teamsData.679.scoreET                      float64
# teamsData.679.coachId                      float64
# teamsData.679.side                          object
# teamsData.679.teamId                       float64
# teamsData.679.score                        float64
# teamsData.679.scoreP                       float64
# teamsData.679.hasFormation                 float64
# teamsData.679.formation.bench               object
# teamsData.679.formation.lineup              object
# teamsData.679.formation.substitutions       object
# teamsData.679.scoreHT                      float64
# teamsData.701.scoreET                      float64
# teamsData.701.coachId                      float64
# teamsData.701.side                          object
# teamsData.701.teamId                       float64
# teamsData.701.score                        float64
# teamsData.701.scoreP                       float64
# teamsData.701.hasFormation                 float64
# teamsData.701.formation.bench               object
# teamsData.701.formation.lineup              object
# teamsData.701.formation.substitutions       object
# teamsData.701.scoreHT                      float64
# teamsData.691.scoreET                      float64
# teamsData.691.coachId                      float64
# teamsData.691.side                          object
# teamsData.691.teamId                       float64
# teamsData.691.score                        float64
# teamsData.691.scoreP                       float64
# teamsData.691.hasFormation                 float64
# teamsData.691.formation.bench               object
# teamsData.691.formation.lineup              object
# teamsData.691.formation.substitutions       object
# teamsData.691.scoreHT                      float64
# teamsData.678.scoreET                      float64
# teamsData.678.coachId                      float64
# teamsData.678.side                          object
# teamsData.678.teamId                       float64
# teamsData.678.score                        float64
# teamsData.678.scoreP                       float64
# teamsData.678.hasFormation                 float64
# teamsData.678.formation.bench               object
# teamsData.678.formation.lineup              object
# teamsData.678.formation.substitutions       object
# teamsData.678.scoreHT                      float64
# teamsData.674.scoreET                      float64
# teamsData.674.coachId                      float64
# teamsData.674.side                          object
# teamsData.674.teamId                       float64
# teamsData.674.score                        float64
# teamsData.674.scoreP                       float64
# teamsData.674.hasFormation                 float64
# teamsData.674.formation.bench               object
# teamsData.674.formation.lineup              object
# teamsData.674.formation.substitutions       object
# teamsData.674.scoreHT                      float64
# teamsData.677.scoreET                      float64
# teamsData.677.coachId                      float64
# teamsData.677.side                          object
# teamsData.677.teamId                       float64
# teamsData.677.score                        float64
# teamsData.677.scoreP                       float64
# teamsData.677.hasFormation                 float64
# teamsData.677.formation.bench               object
# teamsData.677.formation.lineup              object
# teamsData.677.formation.substitutions       object
# teamsData.677.scoreHT                      float64
# teamsData.675.scoreET                      float64
# teamsData.675.coachId                      float64
# teamsData.675.side                          object
# teamsData.675.teamId                       float64
# teamsData.675.score                        float64
# teamsData.675.scoreP                       float64
# teamsData.675.hasFormation                 float64
# teamsData.675.formation.bench               object
# teamsData.675.formation.lineup              object
# teamsData.675.formation.substitutions       object
# teamsData.675.scoreHT                      float64
# teamsData.682.scoreET                      float64
# teamsData.682.coachId                      float64
# teamsData.682.side                          object
# teamsData.682.teamId                       float64
# teamsData.682.score                        float64
# teamsData.682.scoreP                       float64
# teamsData.682.hasFormation                 float64
# teamsData.682.formation.bench               object
# teamsData.682.formation.lineup              object
# teamsData.682.formation.substitutions       object
# teamsData.682.scoreHT                      float64
# teamsData.696.scoreET                      float64
# teamsData.696.coachId                      float64
# teamsData.696.side                          object
# teamsData.696.teamId                       float64
# teamsData.696.score                        float64
# teamsData.696.scoreP                       float64
# teamsData.696.hasFormation                 float64
# teamsData.696.formation.bench               object
# teamsData.696.formation.lineup              object
# teamsData.696.formation.substitutions       object
# teamsData.696.scoreHT                      float64
# teamsData.680.scoreET                      float64
# teamsData.680.coachId                      float64
# teamsData.680.side                          object
# teamsData.680.teamId                       float64
# teamsData.680.score                        float64
# teamsData.680.scoreP                       float64
# teamsData.680.hasFormation                 float64
# teamsData.680.formation.bench               object
# teamsData.680.formation.lineup              object
# teamsData.680.formation.substitutions       object
# teamsData.680.scoreHT                      float64
# teamsData.698.scoreET                      float64
# teamsData.698.coachId                      float64
# teamsData.698.side                          object
# teamsData.698.teamId                       float64
# teamsData.698.score                        float64
# teamsData.698.scoreP                       float64
# teamsData.698.hasFormation                 float64
# teamsData.698.formation.bench               object
# teamsData.698.formation.lineup              object
# teamsData.698.formation.substitutions       object
# teamsData.698.scoreHT                      float64
# teamsData.683.scoreET                      float64
# teamsData.683.coachId                      float64
# teamsData.683.side                          object
# teamsData.683.teamId                       float64
# teamsData.683.score                        float64
# teamsData.683.scoreP                       float64
# teamsData.683.hasFormation                 float64
# teamsData.683.formation.bench               object
# teamsData.683.formation.lineup              object
# teamsData.683.formation.substitutions       object
# teamsData.683.scoreHT                      float64
# teamsData.714.scoreET                      float64
# teamsData.714.coachId                      float64
# teamsData.714.side                          object
# teamsData.714.teamId                       float64
# teamsData.714.score                        float64
# teamsData.714.scoreP                       float64
# teamsData.714.hasFormation                 float64
# teamsData.714.formation.bench               object
# teamsData.714.formation.lineup              object
# teamsData.714.formation.substitutions       object
# teamsData.714.scoreHT                      float64
# teamsData.756.scoreET                      float64
# teamsData.756.coachId                      float64
# teamsData.756.side                          object
# teamsData.756.teamId                       float64
# teamsData.756.score                        float64
# teamsData.756.scoreP                       float64
# teamsData.756.hasFormation                 float64
# teamsData.756.formation.bench               object
# teamsData.756.formation.lineup              object
# teamsData.756.formation.substitutions       object
# teamsData.756.scoreHT                      float64
# teamsData.684.scoreET                      float64
# teamsData.684.coachId                      float64
# teamsData.684.side                          object
# teamsData.684.teamId                       float64
# teamsData.684.score                        float64
# teamsData.684.scoreP                       float64
# teamsData.684.hasFormation                 float64
# teamsData.684.formation.bench               object
# teamsData.684.formation.lineup              object
# teamsData.684.formation.substitutions       object
# teamsData.684.scoreHT                      float64
# teamsData.712.scoreET                      float64
# teamsData.712.coachId                      float64
# teamsData.712.side                          object
# teamsData.712.teamId                       float64
# teamsData.712.score                        float64
# teamsData.712.scoreP                       float64
# teamsData.712.hasFormation                 float64
# teamsData.712.formation.bench               object
# teamsData.712.formation.lineup              object
# teamsData.712.formation.substitutions       object
# teamsData.712.scoreHT                      float64
# teamsData.692.scoreET                      float64
# teamsData.692.coachId                      float64
# teamsData.692.side                          object
# teamsData.692.teamId                       float64
# teamsData.692.score                        float64
# teamsData.692.scoreP                       float64
# teamsData.692.hasFormation                 float64
# teamsData.692.formation.bench               object
# teamsData.692.formation.lineup              object
# teamsData.692.formation.substitutions       object
# teamsData.692.scoreHT                      float64
# teamsData.695.scoreET                      float64
# teamsData.695.coachId                      float64
# teamsData.695.side                          object
# teamsData.695.teamId                       float64
# teamsData.695.score                        float64
# teamsData.695.scoreP                       float64
# teamsData.695.hasFormation                 float64
# teamsData.695.formation.bench               object
# teamsData.695.formation.lineup              object
# teamsData.695.formation.substitutions       object
# teamsData.695.scoreHT                      float64
# dtype: object

# %% [markdown]
# ##### Streamline the DataFrame
# The `Matches` data includes a lot of `teamsData` columns that we don't require at this stage. We will streamline this DataFrame to only include the columns of interest.

# %%
# Select columns of interest
cols_matches = ['status', 'roundId', 'gameweek', 'seasonId', 'dateutc', 'winner', 'venue', 'wyId', 'label', 'date', 'referees', 'duration', 'competitionId']

# Create more concise DataFrame using only columns of interest
df_wyscout_matches_data_big5_flat_select = df_wyscout_matches_data_big5_flat[cols_matches]

# %% [markdown]
# ### <a id='#section3.5.'>3.5. Players</a>

# %% [markdown]
# ##### Read in the Players data

# %%
# Import the Wyscout JSON Players data from the Big 5 European leagues for the 17/18 season
with open(data_dir_wyscout + '/raw/json/players.json') as f:
    json_wyscout_players_data = json.load(f)

# %%
json_wyscout_players_data
# Out:
# [{'passportArea': {'name': 'Turkey',
#    'id': '792',
#    'alpha3code': 'TUR',
#    'alpha2code': 'TR'},
#   'weight': 78,
#   'firstName': 'Harun',
#   'middleName': '',
#   'lastName': 'Tekin',
#   'currentTeamId': 4502,
#   'birthDate': '1989-06-17',
#   'height': 187,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Turkey',
#    'id': '792',
#    'alpha3code': 'TUR',
#    'alpha2code': 'TR'},
#   'wyId': 32777,
#   'foot': 'right',
#   'shortName': 'H. Tekin',
#   'currentNationalTeamId': 4687},
#  {'passportArea': {'name': 'Senegal',
#    'id': '686',
#    'alpha3code': 'SEN',
#    'alpha2code': 'SN'},
#   'weight': 73,
#   'firstName': 'Malang',
#   'middleName': '',
#   'lastName': 'Sarr',
#   'currentTeamId': 3775,
#   'birthDate': '1999-01-23',
#   'height': 182,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 393228,
#   'foot': 'left',
#   'shortName': 'M. Sarr',
#   'currentNationalTeamId': 4423},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 72,
#   'firstName': 'Over',
#   'middleName': '',
#   'lastName': 'Mandanda',
#   'currentTeamId': 3772,
#   'birthDate': '1998-10-26',
#   'height': 176,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 393230,
#   'foot': '',
#   'shortName': 'O. Mandanda',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Senegal',
#    'id': '686',
#    'alpha3code': 'SEN',
#    'alpha2code': 'SN'},
#   'weight': 82,
#   'firstName': 'Alfred John Momar',
#   'middleName': '',
#   'lastName': "N'Diaye",
#   'currentTeamId': 683,
#   'birthDate': '1990-03-06',
#   'height': 187,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 32793,
#   'foot': 'right',
#   'shortName': "A. N'Diaye",
#   'currentNationalTeamId': 19314},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 84,
#   'firstName': 'Ibrahima',
#   'middleName': '',
#   'lastName': 'Konat\\u00e9',
#   'currentTeamId': 2975,
#   'birthDate': '1999-05-25',
#   'height': 192,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 393247,
#   'foot': 'right',
#   'shortName': 'I. Konat\\u00e9',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 83,
#   'firstName': 'Jasper',
#   'middleName': '',
#   'lastName': 'Cillessen',
#   'currentTeamId': 676,
#   'birthDate': '1989-04-22',
#   'height': 185,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 33,
#   'foot': 'right',
#   'shortName': 'J. Cillessen',
#   'currentNationalTeamId': 664},
#  {'passportArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'weight': 91,
#   'firstName': 'Toby',
#   'middleName': '',
#   'lastName': 'Alderweireld',
#   'currentTeamId': 1624,
#   'birthDate': '1989-03-02',
#   'height': 187,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'wyId': 36,
#   'foot': 'right',
#   'shortName': 'T. Alderweireld',
#   'currentNationalTeamId': 5629},
#  {'passportArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'weight': 88,
#   'firstName': 'Jan',
#   'middleName': '',
#   'lastName': 'Vertonghen',
#   'currentTeamId': 1624,
#   'birthDate': '1987-04-24',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'wyId': 48,
#   'foot': 'left',
#   'shortName': 'J. Vertonghen',
#   'currentNationalTeamId': 5629},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 74,
#   'firstName': 'Alexander',
#   'middleName': '',
#   'lastName': 'Djiku',
#   'currentTeamId': 3783,
#   'birthDate': '1994-08-09',
#   'height': 182,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 229427,
#   'foot': 'right',
#   'shortName': 'A. Djiku',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Denmark',
#    'id': '208',
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'weight': 76,
#   'firstName': 'Christian ',
#   'middleName': '',
#   'lastName': 'Dannemann Eriksen',
#   'currentTeamId': 1624,
#   'birthDate': '1992-02-14',
#   'height': 180,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Denmark',
#    'id': '208',
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'wyId': 54,
#   'foot': 'right',
#   'shortName': 'C. Eriksen',
#   'currentNationalTeamId': 7712},
#  {'passportArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'weight': 74,
#   'firstName': 'Marcel',
#   'middleName': '',
#   'lastName': 'Sabitzer',
#   'currentTeamId': 2975,
#   'birthDate': '1994-03-17',
#   'height': 177,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'wyId': 65596,
#   'foot': 'right',
#   'shortName': 'M. Sabitzer',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Iceland',
#    'id': '352',
#    'alpha3code': 'ISL',
#    'alpha2code': 'IS'},
#   'weight': 84,
#   'firstName': 'Kolbeinn',
#   'middleName': '',
#   'lastName': 'Sig\\u00fe\\u00f3rsson',
#   'currentTeamId': 3770,
#   'birthDate': '1990-03-14',
#   'height': 186,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Iceland',
#    'id': '352',
#    'alpha3code': 'ISL',
#    'alpha2code': 'IS'},
#   'wyId': 66,
#   'foot': 'right',
#   'shortName': 'K. Sig\\u00fe\\u00f3rsson',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 74,
#   'firstName': 'Charles',
#   'middleName': '',
#   'lastName': 'Traor\\u00e9',
#   'currentTeamId': 3795,
#   'birthDate': '1992-01-01',
#   'height': 180,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Mali',
#    'id': '466',
#    'alpha3code': 'MLI',
#    'alpha2code': 'ML'},
#   'wyId': 393284,
#   'foot': 'left',
#   'shortName': 'C. Traor\\u00e9',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Finland',
#    'id': '246',
#    'alpha3code': 'FIN',
#    'alpha2code': 'FI'},
#   'weight': 75,
#   'firstName': 'Niklas',
#   'middleName': '',
#   'lastName': 'Moisander',
#   'currentTeamId': 2443,
#   'birthDate': '1985-09-29',
#   'height': 183,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Finland',
#    'id': '246',
#    'alpha3code': 'FIN',
#    'alpha2code': 'FI'},
#   'wyId': 77,
#   'foot': 'left',
#   'shortName': 'N. Moisander',
#   'currentNationalTeamId': 4849},
#  {'passportArea': {'name': 'Cura\\u00e7ao',
#    'id': '531',
#    'alpha3code': 'CUW',
#    'alpha2code': 'CW'},
#   'weight': 91,
#   'firstName': 'Charlison',
#   'middleName': '',
#   'lastName': 'Benschop',
#   'currentTeamId': 2455,
#   'birthDate': '1989-08-21',
#   'height': 191,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Cura\\u00e7ao',
#    'id': '531',
#    'alpha3code': 'CUW',
#    'alpha2code': 'CW'},
#   'wyId': 91,
#   'foot': 'right',
#   'shortName': 'C. Benschop',
#   'currentNationalTeamId': 18138},
#  {'passportArea': {'name': 'Iceland',
#    'id': '352',
#    'alpha3code': 'ISL',
#    'alpha2code': 'IS'},
#   'weight': 77,
#   'firstName': 'Johann ',
#   'middleName': '',
#   'lastName': 'Berg Gu\\u00f0munds\\u00adson',
#   'currentTeamId': 1646,
#   'birthDate': '1990-10-27',
#   'height': 186,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Iceland',
#    'id': '352',
#    'alpha3code': 'ISL',
#    'alpha2code': 'IS'},
#   'wyId': 93,
#   'foot': 'left',
#   'shortName': 'J. Gu\\u00f0munds\\u00adson',
#   'currentNationalTeamId': 7839},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 83,
#   'firstName': 'Przemys\\u0142aw',
#   'middleName': '',
#   'lastName': 'Tyto\\u0144',
#   'currentTeamId': 677,
#   'birthDate': '1987-01-04',
#   'height': 194,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99,
#   'foot': 'right',
#   'shortName': 'P. Tyto\\u0144',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'weight': 85,
#   'firstName': 'Marcelo Ant\\u00f4nio',
#   'middleName': '',
#   'lastName': 'Guedes Filho',
#   'currentTeamId': 3766,
#   'birthDate': '1987-05-20',
#   'height': 191,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 102,
#   'foot': 'right',
#   'shortName': 'Marcelo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Cura\\u00e7ao',
#    'id': '531',
#    'alpha3code': 'CUW',
#    'alpha2code': 'CW'},
#   'weight': 65,
#   'firstName': 'Jetro',
#   'middleName': '',
#   'lastName': 'Willems',
#   'currentTeamId': 2462,
#   'birthDate': '1994-03-30',
#   'height': 169,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 110,
#   'foot': 'left',
#   'shortName': 'J. Willems',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Iraq',
#    'id': '368',
#    'alpha3code': 'IRQ',
#    'alpha2code': 'IQ'},
#   'weight': 78,
#   'firstName': 'Ali Adnan Kadhim',
#   'middleName': '',
#   'lastName': 'Al Tameemi',
#   'currentTeamId': 3163,
#   'birthDate': '1993-12-19',
#   'height': 186,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Iraq',
#    'id': '368',
#    'alpha3code': 'IRQ',
#    'alpha2code': 'IQ'},
#   'wyId': 131184,
#   'foot': 'left',
#   'shortName': 'Ali Adnan',
#   'currentNationalTeamId': 17759},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 78,
#   'firstName': 'Kevin',
#   'middleName': '',
#   'lastName': 'Strootman',
#   'currentTeamId': 3158,
#   'birthDate': '1990-02-13',
#   'height': 186,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 114,
#   'foot': 'left',
#   'shortName': 'K. Strootman',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Ghana',
#    'id': '288',
#    'alpha3code': 'GHA',
#    'alpha2code': 'GH'},
#   'weight': 78,
#   'firstName': 'Memphis',
#   'middleName': '',
#   'lastName': 'Depay',
#   'currentTeamId': 3766,
#   'birthDate': '1994-02-13',
#   'height': 176,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 118,
#   'foot': 'right',
#   'shortName': 'M. Depay',
#   'currentNationalTeamId': 664},
#  {'passportArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'weight': 61,
#   'firstName': 'Dries',
#   'middleName': '',
#   'lastName': 'Mertens',
#   'currentTeamId': 3187,
#   'birthDate': '1987-05-06',
#   'height': 169,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'wyId': 122,
#   'foot': 'right',
#   'shortName': 'D. Mertens',
#   'currentNationalTeamId': 5629},
#  {'passportArea': {'name': 'Sweden',
#    'id': '752',
#    'alpha3code': 'SWE',
#    'alpha2code': 'SE'},
#   'weight': 78,
#   'firstName': 'Ola',
#   'middleName': '',
#   'lastName': 'Toivonen',
#   'currentTeamId': 3780,
#   'birthDate': '1986-07-03',
#   'height': 192,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Sweden',
#    'id': '752',
#    'alpha3code': 'SWE',
#    'alpha2code': 'SE'},
#   'wyId': 123,
#   'foot': 'right',
#   'shortName': 'O. Toivonen',
#   'currentNationalTeamId': 7047},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 78,
#   'firstName': 'Stefan',
#   'middleName': '',
#   'lastName': 'de Vrij',
#   'currentTeamId': 3162,
#   'birthDate': '1992-02-05',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 130,
#   'foot': 'right',
#   'shortName': 'S. de Vrij',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Morocco',
#    'id': '504',
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'weight': 78,
#   'firstName': 'Karim',
#   'middleName': '',
#   'lastName': 'El Ahmadi Al Aroos',
#   'currentTeamId': 16469,
#   'birthDate': '1985-01-27',
#   'height': 179,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 142,
#   'foot': 'right',
#   'shortName': 'K. El Ahmadi',
#   'currentNationalTeamId': 16216},
#  {'passportArea': {'name': 'Sweden',
#    'id': '752',
#    'alpha3code': 'SWE',
#    'alpha2code': 'SE'},
#   'weight': 79,
#   'firstName': 'John',
#   'middleName': '',
#   'lastName': 'Guidetti',
#   'currentTeamId': 696,
#   'birthDate': '1992-04-15',
#   'height': 185,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Sweden',
#    'id': '752',
#    'alpha3code': 'SWE',
#    'alpha2code': 'SE'},
#   'wyId': 151,
#   'foot': 'right',
#   'shortName': 'J. Guidetti',
#   'currentNationalTeamId': 7047},
#  {'passportArea': {'name': 'Turkey',
#    'id': '792',
#    'alpha3code': 'TUR',
#    'alpha2code': 'TR'},
#   'weight': 86,
#   'firstName': 'Volkan',
#   'middleName': '',
#   'lastName': 'Babacan',
#   'currentTeamId': 4535,
#   'birthDate': '1988-08-11',
#   'height': 192,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Turkey',
#    'id': '792',
#    'alpha3code': 'TUR',
#    'alpha2code': 'TR'},
#   'wyId': 32923,
#   'foot': 'right',
#   'shortName': 'V. Babacan',
#   'currentNationalTeamId': 4687},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 78,
#   'firstName': 'Jeffrey',
#   'middleName': '',
#   'lastName': 'Gouweleeuw',
#   'currentTeamId': 2481,
#   'birthDate': '1991-07-10',
#   'height': 188,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 159,
#   'foot': 'right',
#   'shortName': 'J. Gouweleeuw',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 72,
#   'firstName': 'Filip',
#   'middleName': '',
#   'lastName': '\\u0110uri\\u010di\\u0107',
#   'currentTeamId': 3219,
#   'birthDate': '1992-01-30',
#   'height': 181,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 174,
#   'foot': 'right',
#   'shortName': 'F. \\u0110uri\\u010di\\u0107',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Slovakia',
#    'id': '703',
#    'alpha3code': 'SVK',
#    'alpha2code': 'SK'},
#   'weight': 70,
#   'firstName': 'Peter',
#   'middleName': '',
#   'lastName': 'Pekar\\u00edk',
#   'currentTeamId': 2457,
#   'birthDate': '1986-10-30',
#   'height': 176,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Slovakia',
#    'id': '703',
#    'alpha3code': 'SVK',
#    'alpha2code': 'SK'},
#   'wyId': 32959,
#   'foot': 'right',
#   'shortName': 'P. Pekar\\u00edk',
#   'currentNationalTeamId': 14496},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 93,
#   'firstName': 'Jago\\u0161',
#   'middleName': '',
#   'lastName': 'Vukovi\\u0107',
#   'currentTeamId': 3194,
#   'birthDate': '1988-06-10',
#   'height': 195,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 192,
#   'foot': 'left',
#   'shortName': 'J. Vukovi\\u0107',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Morocco',
#    'id': '504',
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'weight': 77,
#   'firstName': 'Nordin',
#   'middleName': '',
#   'lastName': 'Amrabat',
#   'currentTeamId': 16470,
#   'birthDate': '1987-03-31',
#   'height': 178,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 32968,
#   'foot': 'right',
#   'shortName': 'N. Amrabat',
#   'currentNationalTeamId': 16216},
#  {'passportArea': {'name': "C\\u00f4te d'Ivoire",
#    'id': '384',
#    'alpha3code': 'CIV',
#    'alpha2code': 'CI'},
#   'weight': 72,
#   'firstName': 'Christian',
#   'middleName': '',
#   'lastName': 'Kouakou Yao',
#   'currentTeamId': 3783,
#   'birthDate': '1991-03-01',
#   'height': 182,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': "C\\u00f4te d'Ivoire",
#    'id': '384',
#    'alpha3code': 'CIV',
#    'alpha2code': 'CI'},
#   'wyId': 131321,
#   'foot': 'right',
#   'shortName': 'C. Kouakou',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Venezuela',
#    'id': '862',
#    'alpha3code': 'VEN',
#    'alpha2code': 'VE'},
#   'weight': 71,
#   'firstName': 'Roberto Jos\\u00e9',
#   'middleName': '',
#   'lastName': 'Rosales Altuve',
#   'currentTeamId': 683,
#   'birthDate': '1988-11-20',
#   'height': 175,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Venezuela',
#    'id': '862',
#    'alpha3code': 'VEN',
#    'alpha2code': 'VE'},
#   'wyId': 254,
#   'foot': 'right',
#   'shortName': 'R. Rosales',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Morocco',
#    'id': '504',
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'weight': 80,
#   'firstName': 'Nacer',
#   'middleName': '',
#   'lastName': 'Chadli',
#   'currentTeamId': 1627,
#   'birthDate': '1989-08-02',
#   'height': 187,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Belgium',
#    'id': '56',
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'wyId': 261,
#   'foot': 'right',
#   'shortName': 'N. Chadli',
#   'currentNationalTeamId': 5629},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 76,
#   'firstName': 'Robin',
#   'middleName': '',
#   'lastName': 'Gosens',
#   'currentTeamId': 3172,
#   'birthDate': '1994-06-05',
#   'height': 183,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 295176,
#   'foot': 'left',
#   'shortName': 'R. Gosens',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Morocco',
#    'id': '504',
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'weight': 78,
#   'firstName': 'Yacine',
#   'middleName': '',
#   'lastName': 'Bammou',
#   'currentTeamId': 3770,
#   'birthDate': '1991-09-11',
#   'height': 188,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 229697,
#   'foot': 'right',
#   'shortName': 'Y. Bammou',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 86,
#   'firstName': 'Florian',
#   'middleName': '',
#   'lastName': 'Le Joncour',
#   'currentTeamId': 3783,
#   'birthDate': '1995-02-03',
#   'height': 193,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 328021,
#   'foot': 'left',
#   'shortName': 'F. Le Joncour',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'weight': 78,
#   'firstName': 'Andr\\u00e9',
#   'middleName': '',
#   'lastName': 'Ramalho Silva',
#   'currentTeamId': 8743,
#   'birthDate': '1992-02-16',
#   'height': 182,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 65880,
#   'foot': 'right',
#   'shortName': 'Andr\\u00e9 Ramalho',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 69,
#   'firstName': 'Davide',
#   'middleName': '',
#   'lastName': 'Borsellini',
#   'currentTeamId': 3163,
#   'birthDate': '1999-01-04',
#   'height': 180,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 393566,
#   'foot': 'left',
#   'shortName': 'D. Borsellini',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Nigeria',
#    'id': '566',
#    'alpha3code': 'NGA',
#    'alpha2code': 'NG'},
#   'weight': 81,
#   'firstName': 'Leon-Aderemi',
#   'middleName': '',
#   'lastName': 'Balogun',
#   'currentTeamId': 1651,
#   'birthDate': '1988-06-28',
#   'height': 190,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 16443,
#   'foot': 'right',
#   'shortName': 'L. Balogun',
#   'currentNationalTeamId': 16823},
#  {'passportArea': {'name': 'Ghana',
#    'id': '288',
#    'alpha3code': 'GHA',
#    'alpha2code': 'GH'},
#   'weight': 70,
#   'firstName': 'Godfred',
#   'middleName': '',
#   'lastName': 'Donsah',
#   'currentTeamId': 3166,
#   'birthDate': '1996-06-07',
#   'height': 175,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Ghana',
#    'id': '288',
#    'alpha3code': 'GHA',
#    'alpha2code': 'GH'},
#   'wyId': 295273,
#   'foot': 'right',
#   'shortName': 'G. Donsah',
#   'currentNationalTeamId': 17527},
#  {'passportArea': {'name': 'Korea Republic',
#    'id': '410',
#    'alpha3code': 'KOR',
#    'alpha2code': 'KR'},
#   'weight': 82,
#   'firstName': 'Hyun-Jun',
#   'middleName': '',
#   'lastName': 'Suk',
#   'currentTeamId': 3795,
#   'birthDate': '1991-06-29',
#   'height': 190,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Korea Republic',
#    'id': '410',
#    'alpha3code': 'KOR',
#    'alpha2code': 'KR'},
#   'wyId': 382,
#   'foot': 'right',
#   'shortName': 'Suk Hyun-Jun',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 76,
#   'firstName': 'Du\\u0161an',
#   'middleName': '',
#   'lastName': 'Tadi\\u0107',
#   'currentTeamId': 9,
#   'birthDate': '1988-11-20',
#   'height': 181,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 383,
#   'foot': 'left',
#   'shortName': 'D. Tadi\\u0107',
#   'currentNationalTeamId': 17322},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 80,
#   'firstName': 'Bram',
#   'middleName': '',
#   'lastName': 'Nuytinck',
#   'currentTeamId': 3163,
#   'birthDate': '1990-05-04',
#   'height': 190,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 394,
#   'foot': 'left',
#   'shortName': 'B. Nuytinck',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Denmark',
#    'id': '208',
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'weight': 78,
#   'firstName': 'Lasse',
#   'middleName': '',
#   'lastName': 'Sch\\u00f6ne',
#   'currentTeamId': 9,
#   'birthDate': '1986-05-27',
#   'height': 177,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Denmark',
#    'id': '208',
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'wyId': 405,
#   'foot': 'right',
#   'shortName': 'L. Sch\\u00f6ne',
#   'currentNationalTeamId': 7712},
#  {'passportArea': {'name': 'Gambia',
#    'id': '270',
#    'alpha3code': 'GMB',
#    'alpha2code': 'GM'},
#   'weight': 56,
#   'firstName': 'Ablie',
#   'middleName': '',
#   'lastName': 'Jallow',
#   'currentTeamId': 3777,
#   'birthDate': '1998-11-14',
#   'height': 166,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Gambia',
#    'id': '270',
#    'alpha3code': 'GMB',
#    'alpha2code': 'GM'},
#   'wyId': 376908,
#   'foot': 'left',
#   'shortName': 'A. Jallow',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Romania',
#    'id': '642',
#    'alpha3code': 'ROU',
#    'alpha2code': 'RO'},
#   'weight': 75,
#   'firstName': 'Bogdan Sorin',
#   'middleName': '',
#   'lastName': 'Stancu',
#   'currentTeamId': 4502,
#   'birthDate': '1987-06-28',
#   'height': 183,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Romania',
#    'id': '642',
#    'alpha3code': 'ROU',
#    'alpha2code': 'RO'},
#   'wyId': 33235,
#   'foot': 'right',
#   'shortName': 'B. Stancu',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Switzerland',
#    'id': '756',
#    'alpha3code': 'CHE',
#    'alpha2code': 'CH'},
#   'weight': 90,
#   'firstName': 'Gregor',
#   'middleName': '',
#   'lastName': 'Kobel',
#   'currentTeamId': 2482,
#   'birthDate': '1997-12-06',
#   'height': 194,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Switzerland',
#    'id': '756',
#    'alpha3code': 'CHE',
#    'alpha2code': 'CH'},
#   'wyId': 328190,
#   'foot': 'right',
#   'shortName': 'G. Kobel',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Congo DR',
#    'id': '180',
#    'alpha3code': 'COD',
#    'alpha2code': 'CD'},
#   'weight': 80,
#   'firstName': 'Denis Lemi',
#   'middleName': '',
#   'lastName': 'Zakaria Lako Lado',
#   'currentTeamId': 2454,
#   'birthDate': '1996-11-20',
#   'height': 191,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Switzerland',
#    'id': '756',
#    'alpha3code': 'CHE',
#    'alpha2code': 'CH'},
#   'wyId': 360992,
#   'foot': 'right',
#   'shortName': 'D. Zakaria',
#   'currentNationalTeamId': 6697},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 76,
#   'firstName': 'Marten',
#   'middleName': '',
#   'lastName': 'de Roon',
#   'currentTeamId': 3172,
#   'birthDate': '1991-03-29',
#   'height': 185,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 625,
#   'foot': 'right',
#   'shortName': 'M. de Roon',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'weight': 75,
#   'firstName': 'Alex',
#   'middleName': '',
#   'lastName': 'Iwobi',
#   'currentTeamId': 1609,
#   'birthDate': '1996-05-03',
#   'height': 180,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Nigeria',
#    'id': '566',
#    'alpha3code': 'NGA',
#    'alpha2code': 'NG'},
#   'wyId': 230020,
#   'foot': 'right',
#   'shortName': 'A. Iwobi',
#   'currentNationalTeamId': 16823},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 77,
#   'firstName': 'Lorenzo',
#   'middleName': '',
#   'lastName': 'Pellegrini',
#   'currentTeamId': 3158,
#   'birthDate': '1996-06-19',
#   'height': 186,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 328333,
#   'foot': 'right',
#   'shortName': 'L. Pellegrini',
#   'currentNationalTeamId': 3757},
#  {'passportArea': {'name': 'Algeria',
#    'id': '12',
#    'alpha3code': 'DZA',
#    'alpha2code': 'DZ'},
#   'weight': 75,
#   'firstName': 'Mohamed Salim',
#   'middleName': '',
#   'lastName': 'Fares',
#   'currentTeamId': 3194,
#   'birthDate': '1996-02-15',
#   'height': 183,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 328336,
#   'foot': 'left',
#   'shortName': 'M. Fares',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'weight': 73,
#   'firstName': 'Ot\\u00e1vio Henrique',
#   'middleName': '',
#   'lastName': 'Passos Santos',
#   'currentTeamId': 3772,
#   'birthDate': '1994-05-04',
#   'height': 176,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 295569,
#   'foot': 'right',
#   'shortName': 'Ot\\u00e1vio',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Argentina',
#    'id': '32',
#    'alpha3code': 'ARG',
#    'alpha2code': 'AR'},
#   'weight': 72,
#   'firstName': 'Hern\\u00e1n Dar\\u00edo',
#   'middleName': '',
#   'lastName': 'Toledo',
#   'currentTeamId': 714,
#   'birthDate': '1996-01-17',
#   'height': 180,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Argentina',
#    'id': '32',
#    'alpha3code': 'ARG',
#    'alpha2code': 'AR'},
#   'wyId': 393881,
#   'foot': 'right',
#   'shortName': 'H. Toledo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Japan',
#    'id': '392',
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'weight': 78,
#   'firstName': 'Maya',
#   'middleName': '',
#   'lastName': 'Yoshida',
#   'currentTeamId': 1619,
#   'birthDate': '1988-08-24',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Japan',
#    'id': '392',
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'wyId': 703,
#   'foot': 'right',
#   'shortName': 'M. Yoshida',
#   'currentNationalTeamId': 12913},
#  {'passportArea': {'name': 'Congo',
#    'id': '178',
#    'alpha3code': 'COG',
#    'alpha2code': 'CG'},
#   'weight': 78,
#   'firstName': 'Bryan',
#   'middleName': '',
#   'lastName': 'Passi',
#   'currentTeamId': 3787,
#   'birthDate': '1997-08-05',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 426692,
#   'foot': 'right',
#   'shortName': 'B. Passi',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': "C\\u00f4te d'Ivoire",
#    'id': '384',
#    'alpha3code': 'CIV',
#    'alpha2code': 'CI'},
#   'weight': 73,
#   'firstName': 'Hamza',
#   'middleName': '',
#   'lastName': 'Mendyl',
#   'currentTeamId': 2449,
#   'birthDate': '1997-10-21',
#   'height': 179,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Morocco',
#    'id': '504',
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'wyId': 426702,
#   'foot': 'left',
#   'shortName': 'H. Mendyl',
#   'currentNationalTeamId': 16216},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 70,
#   'firstName': 'Anthony',
#   'middleName': '',
#   'lastName': 'Caci',
#   'currentTeamId': 3779,
#   'birthDate': '1997-07-01',
#   'height': 184,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 426714,
#   'foot': 'right',
#   'shortName': 'A. Caci',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'weight': 77,
#   'firstName': 'Miguel \\u00c1ngel',
#   'middleName': '',
#   'lastName': 'Guerrero Mart\\u00edn',
#   'currentTeamId': 712,
#   'birthDate': '1990-07-12',
#   'height': 182,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'wyId': 5481,
#   'foot': 'right',
#   'shortName': 'Guerrero',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Slovakia',
#    'id': '703',
#    'alpha3code': 'SVK',
#    'alpha2code': 'SK'},
#   'weight': 75,
#   'firstName': 'R\\u00f3bert',
#   'middleName': '',
#   'lastName': 'Maz\\u00e1\\u0148',
#   'currentTeamId': 692,
#   'birthDate': '1994-02-09',
#   'height': 180,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Slovakia',
#    'id': '703',
#    'alpha3code': 'SVK',
#    'alpha2code': 'SK'},
#   'wyId': 786,
#   'foot': 'left',
#   'shortName': 'R. Maz\\u00e1\\u0148',
#   'currentNationalTeamId': 14496},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 71,
#   'firstName': 'Martin',
#   'middleName': '',
#   'lastName': 'Terrier',
#   'currentTeamId': 3779,
#   'birthDate': '1997-03-04',
#   'height': 183,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 394006,
#   'foot': 'right',
#   'shortName': 'M. Terrier',
#   'currentNationalTeamId': 4425},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 75,
#   'firstName': 'Th\\u00e9odore',
#   'middleName': '',
#   'lastName': 'Efouba Ayissi',
#   'currentTeamId': None,
#   'birthDate': '1997-05-05',
#   'height': 184,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Cameroon',
#    'id': '120',
#    'alpha3code': 'CMR',
#    'alpha2code': 'CM'},
#   'wyId': 394008,
#   'foot': 'right',
#   'shortName': 'T. Efouba Ayissi',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Nigeria',
#    'id': '566',
#    'alpha3code': 'NGA',
#    'alpha2code': 'NG'},
#   'weight': 72,
#   'firstName': 'Tyronne',
#   'middleName': '',
#   'lastName': 'Ebuehi',
#   'currentTeamId': 9607,
#   'birthDate': '1995-12-16',
#   'height': 187,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 332821,
#   'foot': 'right',
#   'shortName': 'T. Ebuehi',
#   'currentNationalTeamId': 16823},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 65,
#   'firstName': 'Patrick',
#   'middleName': '',
#   'lastName': 'Burner',
#   'currentTeamId': 3775,
#   'birthDate': '1996-04-11',
#   'height': 170,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Martinique',
#    'id': '474',
#    'alpha3code': 'MTQ',
#    'alpha2code': 'MQ'},
#   'wyId': 328488,
#   'foot': 'right',
#   'shortName': 'P. Burner',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 64,
#   'firstName': 'Samuel',
#   'middleName': '',
#   'lastName': 'Grandsir',
#   'currentTeamId': 3795,
#   'birthDate': '1996-08-14',
#   'height': 168,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 295761,
#   'foot': 'right',
#   'shortName': 'S. Grandsir',
#   'currentNationalTeamId': 4425},
#  {'passportArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'weight': 0,
#   'firstName': 'V\\u00edctor',
#   'middleName': '',
#   'lastName': 'L\\u00f3pez Ib\\u00e1\\u00f1ez',
#   'currentTeamId': 696,
#   'birthDate': '1997-05-12',
#   'height': 0,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'wyId': 404285,
#   'foot': 'right',
#   'shortName': 'V\\u00edctor L\\u00f3pez',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': "C\\u00f4te d'Ivoire",
#    'id': '384',
#    'alpha3code': 'CIV',
#    'alpha2code': 'CI'},
#   'weight': 65,
#   'firstName': 'Jean Micha\\u00ebl',
#   'middleName': '',
#   'lastName': 'Seri',
#   'currentTeamId': 3775,
#   'birthDate': '1991-07-19',
#   'height': 168,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': "C\\u00f4te d'Ivoire",
#    'id': '384',
#    'alpha3code': 'CIV',
#    'alpha2code': 'CI'},
#   'wyId': 131959,
#   'foot': 'right',
#   'shortName': 'J. Seri',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'weight': 77,
#   'firstName': 'Gerard',
#   'middleName': '',
#   'lastName': 'Gumbau Garriga',
#   'currentTeamId': 712,
#   'birthDate': '1994-12-18',
#   'height': 187,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'wyId': 263091,
#   'foot': 'left',
#   'shortName': 'Gumbau',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'weight': 68,
#   'firstName': 'Pablo',
#   'middleName': '',
#   'lastName': 'Maffeo Becerra',
#   'currentTeamId': 756,
#   'birthDate': '1997-07-12',
#   'height': 173,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'wyId': 263105,
#   'foot': 'right',
#   'shortName': 'Pablo Maffeo',
#   'currentNationalTeamId': 1604},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 78,
#   'firstName': 'Artur',
#   'middleName': '',
#   'lastName': 'J\\u0119drzejczyk',
#   'currentTeamId': 13505,
#   'birthDate': '1987-11-04',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99381,
#   'foot': 'right',
#   'shortName': 'A. J\\u0119drzejczyk',
#   'currentNationalTeamId': 13869},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 75,
#   'firstName': 'Maciej',
#   'middleName': '',
#   'lastName': 'Rybus',
#   'currentTeamId': 13887,
#   'birthDate': '1989-08-19',
#   'height': 173,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99391,
#   'foot': 'left',
#   'shortName': 'M. Rybus',
#   'currentNationalTeamId': 13869},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 82,
#   'firstName': 'Marcin',
#   'middleName': '',
#   'lastName': 'Kami\\u0144ski',
#   'currentTeamId': 2445,
#   'birthDate': '1992-01-15',
#   'height': 192,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99410,
#   'foot': 'left',
#   'shortName': 'M. Kami\\u0144ski',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'weight': 76,
#   'firstName': 'Karim',
#   'middleName': '',
#   'lastName': 'Onisiwo',
#   'currentTeamId': 2460,
#   'birthDate': '1992-03-17',
#   'height': 188,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'wyId': 66654,
#   'foot': 'right',
#   'shortName': 'K. Onisiwo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Russia',
#    'id': '643',
#    'alpha3code': 'RUS',
#    'alpha2code': 'RU'},
#   'weight': 81,
#   'firstName': 'Artjoms',
#   'middleName': '',
#   'lastName': 'Rud\\u0146evs',
#   'currentTeamId': None,
#   'birthDate': '1988-01-13',
#   'height': 183,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Latvia',
#    'id': '428',
#    'alpha3code': 'LVA',
#    'alpha2code': 'LV'},
#   'wyId': 99425,
#   'foot': 'left',
#   'shortName': 'A. Rud\\u0146evs',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 83,
#   'firstName': '\\u0141ukasz',
#   'middleName': '',
#   'lastName': 'Skorupski',
#   'currentTeamId': 3158,
#   'birthDate': '1991-05-05',
#   'height': 190,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99430,
#   'foot': 'right',
#   'shortName': '\\u0141. Skorupski',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 76,
#   'firstName': 'Pawe\\u0142',
#   'middleName': '',
#   'lastName': 'Olkowski',
#   'currentTeamId': 2463,
#   'birthDate': '1990-02-13',
#   'height': 184,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99437,
#   'foot': 'right',
#   'shortName': 'P. Olkowski',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 78,
#   'firstName': 'Arkadiusz',
#   'middleName': '',
#   'lastName': 'Milik',
#   'currentTeamId': 3187,
#   'birthDate': '1994-02-28',
#   'height': 186,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99452,
#   'foot': 'left',
#   'shortName': 'A. Milik',
#   'currentNationalTeamId': 13869},
#  {'passportArea': {'name': 'Burkina Faso',
#    'id': '854',
#    'alpha3code': 'BFA',
#    'alpha2code': 'BF'},
#   'weight': 72,
#   'firstName': 'Pr\\u00e9juce Niguimb\\u00e9',
#   'middleName': '',
#   'lastName': 'Nakoulma',
#   'currentTeamId': None,
#   'birthDate': '1987-04-21',
#   'height': 178,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Burkina Faso',
#    'id': '854',
#    'alpha3code': 'BFA',
#    'alpha2code': 'BF'},
#   'wyId': 99453,
#   'foot': 'right',
#   'shortName': 'P. Nakoulma',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 76,
#   'firstName': 'Gianluca',
#   'middleName': '',
#   'lastName': 'Pegolo',
#   'currentTeamId': 3315,
#   'birthDate': '1981-03-25',
#   'height': 183,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 20771,
#   'foot': 'left',
#   'shortName': 'G. Pegolo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 72,
#   'firstName': 'Mariusz',
#   'middleName': '',
#   'lastName': 'St\\u0119pi\\u0144ski',
#   'currentTeamId': 3165,
#   'birthDate': '1995-05-12',
#   'height': 183,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'wyId': 99511,
#   'foot': 'right',
#   'shortName': 'M. St\\u0119pi\\u0144ski',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Croatia',
#    'id': '191',
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'weight': 89,
#   'firstName': 'Duje',
#   'middleName': '',
#   'lastName': '\\u0106aleta-Car',
#   'currentTeamId': 3771,
#   'birthDate': '1996-09-17',
#   'height': 192,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Croatia',
#    'id': '191',
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'wyId': 230626,
#   'foot': 'right',
#   'shortName': 'D. \\u0106aleta-Car',
#   'currentNationalTeamId': 9598},
#  {'passportArea': {'name': 'Lithuania',
#    'id': '440',
#    'alpha3code': 'LTU',
#    'alpha2code': 'LT'},
#   'weight': 92,
#   'firstName': 'Edvinas',
#   'middleName': '',
#   'lastName': 'Gertmonas',
#   'currentTeamId': 3774,
#   'birthDate': '1996-06-01',
#   'height': 192,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Lithuania',
#    'id': '440',
#    'alpha3code': 'LTU',
#    'alpha2code': 'LT'},
#   'wyId': 240507,
#   'foot': 'right',
#   'shortName': 'E. Gertmonas',
#   'currentNationalTeamId': 13503},
#  {'passportArea': {'name': 'Croatia',
#    'id': '191',
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'weight': 74,
#   'firstName': 'Hrvoje',
#   'middleName': '',
#   'lastName': 'Mili\\u0107',
#   'currentTeamId': None,
#   'birthDate': '1989-05-10',
#   'height': 183,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Croatia',
#    'id': '191',
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'wyId': 69874,
#   'foot': 'left',
#   'shortName': 'H. Mili\\u0107',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 70,
#   'firstName': 'Jonathan',
#   'middleName': '',
#   'lastName': 'Klinsmann',
#   'currentTeamId': 2457,
#   'birthDate': '1997-04-08',
#   'height': 194,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'United States',
#    'id': '840',
#    'alpha3code': 'USA',
#    'alpha2code': 'US'},
#   'wyId': 492782,
#   'foot': 'right',
#   'shortName': 'J. Klinsmann',
#   'currentNationalTeamId': 8140},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 80,
#   'firstName': 'Francesco',
#   'middleName': '',
#   'lastName': 'Vicari',
#   'currentTeamId': 3204,
#   'birthDate': '1994-08-03',
#   'height': 190,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 263432,
#   'foot': 'right',
#   'shortName': 'F. Vicari',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 70,
#   'firstName': 'Alex',
#   'middleName': '',
#   'lastName': 'Ferrari',
#   'currentTeamId': 3194,
#   'birthDate': '1994-07-01',
#   'height': 183,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 263433,
#   'foot': 'right',
#   'shortName': 'A. Ferrari',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Croatia',
#    'id': '191',
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'weight': 88,
#   'firstName': 'Emil',
#   'middleName': '',
#   'lastName': 'Berggreen',
#   'currentTeamId': 2460,
#   'birthDate': '1993-05-10',
#   'height': 194,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Denmark',
#    'id': '208',
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'wyId': 230687,
#   'foot': 'right',
#   'shortName': 'E. Berggreen',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Poland',
#    'id': '616',
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'weight': 88,
#   'firstName': 'Igor',
#   'middleName': '',
#   'lastName': 'Lewczuk',
#   'currentTeamId': 3772,
#   'birthDate': '1985-05-30',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Poland',
#    'id': '616',
# ...
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'wyId': 473326,
#   'foot': 'right',
#   'shortName': 'Moha Ramos',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 91,
#   'firstName': 'Branislav',
#   'middleName': '',
#   'lastName': 'Ivanovi\\u0107',
#   'currentTeamId': 13885,
#   'birthDate': '1984-02-22',
#   'height': 185,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 7891,
#   'foot': 'right',
#   'shortName': 'B. Ivanovi\\u0107',
#   'currentNationalTeamId': 17322},
#  {'passportArea': {'name': 'Egypt',
#    'id': '818',
#    'alpha3code': 'EGY',
#    'alpha2code': 'EG'},
#   'weight': 70,
#   'firstName': 'Amr Medhat',
#   'middleName': '',
#   'lastName': 'Warda',
#   'currentTeamId': 12510,
#   'birthDate': '1993-09-17',
#   'height': 176,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Egypt',
#    'id': '818',
#    'alpha3code': 'EGY',
#    'alpha2code': 'EG'},
#   'wyId': 388928,
#   'foot': 'right',
#   'shortName': 'Amr Warda',
#   'currentNationalTeamId': 16129},
#  {'passportArea': {'name': 'Greece',
#    'id': '300',
#    'alpha3code': 'GRC',
#    'alpha2code': 'GR'},
#   'weight': 85,
#   'firstName': 'Sokratis',
#   'middleName': '',
#   'lastName': 'Papastathopoulos',
#   'currentTeamId': 2447,
#   'birthDate': '1988-06-09',
#   'height': 186,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Greece',
#    'id': '300',
#    'alpha3code': 'GRC',
#    'alpha2code': 'GR'},
#   'wyId': 14687,
#   'foot': 'right',
#   'shortName': 'S. Papastathopoulos',
#   'currentNationalTeamId': 12678},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 91,
#   'firstName': 'Ronaldo ',
#   'middleName': '',
#   'lastName': 'Aparecido Rodrigues',
#   'currentTeamId': 2449,
#   'birthDate': '1982-09-10',
#   'height': 198,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 14689,
#   'foot': 'right',
#   'shortName': 'Naldo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 71,
#   'firstName': 'Philipp',
#   'middleName': '',
#   'lastName': 'Bargfrede',
#   'currentTeamId': 2443,
#   'birthDate': '1989-03-03',
#   'height': 174,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14692,
#   'foot': 'right',
#   'shortName': 'P. Bargfrede',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 71,
#   'firstName': 'Aleksandar',
#   'middleName': '',
#   'lastName': 'Ignjovski',
#   'currentTeamId': 2453,
#   'birthDate': '1991-01-27',
#   'height': 175,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 14695,
#   'foot': 'right',
#   'shortName': 'A. Ignjovski',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'weight': 69,
#   'firstName': 'Zlatko',
#   'middleName': '',
#   'lastName': 'Junuzovi\\u0107',
#   'currentTeamId': 2443,
#   'birthDate': '1987-09-26',
#   'height': 172,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'wyId': 14696,
#   'foot': 'right',
#   'shortName': 'Z. Junuzovi\\u0107',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 83,
#   'firstName': 'Niclas',
#   'middleName': '',
#   'lastName': 'F\\u00fcllkrug',
#   'currentTeamId': 2455,
#   'birthDate': '1993-02-09',
#   'height': 189,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14705,
#   'foot': 'right',
#   'shortName': 'N. F\\u00fcllkrug',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'weight': 73,
#   'firstName': 'Aaron',
#   'middleName': '',
#   'lastName': 'Hunt',
#   'currentTeamId': 2450,
#   'birthDate': '1986-09-04',
#   'height': 183,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14706,
#   'foot': 'left',
#   'shortName': 'A. Hunt',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 84,
#   'firstName': 'Claudio Miguel',
#   'middleName': '',
#   'lastName': 'Pizarro Bossio',
#   'currentTeamId': 2463,
#   'birthDate': '1978-10-03',
#   'height': 184,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Peru',
#    'id': '604',
#    'alpha3code': 'PER',
#    'alpha2code': 'PE'},
#   'wyId': 14707,
#   'foot': 'right',
#   'shortName': 'C. Pizarro',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 92,
#   'firstName': 'Manuel',
#   'middleName': '',
#   'lastName': 'Neuer',
#   'currentTeamId': 2444,
#   'birthDate': '1986-03-27',
#   'height': 193,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14712,
#   'foot': 'right',
#   'shortName': 'M. Neuer',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 83,
#   'firstName': 'Holger',
#   'middleName': '',
#   'lastName': 'Badstuber',
#   'currentTeamId': 2445,
#   'birthDate': '1989-03-13',
#   'height': 189,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14715,
#   'foot': 'left',
#   'shortName': 'H. Badstuber',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 90,
#   'firstName': 'J\\u00e9r\\u00f4me',
#   'middleName': '',
#   'lastName': 'Boateng',
#   'currentTeamId': 2444,
#   'birthDate': '1988-09-03',
#   'height': 192,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14716,
#   'foot': 'right',
#   'shortName': 'J. Boateng',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 75,
#   'firstName': 'Diego',
#   'middleName': '',
#   'lastName': 'Contento',
#   'currentTeamId': 3772,
#   'birthDate': '1990-05-01',
#   'height': 177,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14717,
#   'foot': 'left',
#   'shortName': 'D. Contento',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'weight': 68,
#   'firstName': 'M\\u00e1rcio Rafael',
#   'middleName': '',
#   'lastName': 'Ferreira de Souza',
#   'currentTeamId': 2444,
#   'birthDate': '1985-09-07',
#   'height': 172,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 14718,
#   'foot': 'right',
#   'shortName': 'Rafinha',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'weight': 78,
#   'firstName': 'Luiz Gustavo',
#   'middleName': '',
#   'lastName': 'Dias',
#   'currentTeamId': 3771,
#   'birthDate': '1987-07-23',
#   'height': 187,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Brazil',
#    'id': '76',
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'wyId': 14722,
#   'foot': 'left',
#   'shortName': 'Luiz Gustavo',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 76,
#   'firstName': 'Toni',
#   'middleName': '',
#   'lastName': 'Kroos',
#   'currentTeamId': 675,
#   'birthDate': '1990-01-04',
#   'height': 183,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14723,
#   'foot': 'right',
#   'shortName': 'T. Kroos',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'weight': 76,
#   'firstName': 'David',
#   'middleName': '',
#   'lastName': 'Olatukunbo Alaba',
#   'currentTeamId': 2444,
#   'birthDate': '1992-06-24',
#   'height': 180,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Austria',
#    'id': '40',
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'wyId': 14724,
#   'foot': 'left',
#   'shortName': 'D. Alaba',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'weight': 72,
#   'firstName': 'Franck Bilal',
#   'middleName': '',
#   'lastName': 'Rib\\u00e9ry',
#   'currentTeamId': 2444,
#   'birthDate': '1983-04-07',
#   'height': 170,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'wyId': 14726,
#   'foot': 'right',
#   'shortName': 'F. Rib\\u00e9ry',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'weight': 80,
#   'firstName': 'Arjen',
#   'middleName': '',
#   'lastName': 'Robben',
#   'currentTeamId': 2444,
#   'birthDate': '1984-01-23',
#   'height': 180,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Netherlands',
#    'id': '528',
#    'alpha3code': 'NLD',
#    'alpha2code': 'NL'},
#   'wyId': 14727,
#   'foot': 'left',
#   'shortName': 'A. Robben',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Japan',
#    'id': '392',
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'weight': 77,
#   'firstName': 'Takashi',
#   'middleName': '',
#   'lastName': 'Usami',
#   'currentTeamId': 2502,
#   'birthDate': '1992-05-06',
#   'height': 180,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Japan',
#    'id': '392',
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'wyId': 14730,
#   'foot': 'right',
#   'shortName': 'T. Usami',
#   'currentNationalTeamId': 12913},
#  {'passportArea': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'weight': 88,
#   'firstName': 'Mario',
#   'middleName': '',
#   'lastName': 'G\\u00f3mez Garc\\u00eda',
#   'currentTeamId': 2445,
#   'birthDate': '1985-07-10',
#   'height': 189,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14731,
#   'foot': 'right',
#   'shortName': 'M. G\\u00f3mez',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 75,
#   'firstName': 'Thomas',
#   'middleName': '',
#   'lastName': 'M\\u00fcller',
#   'currentTeamId': 2444,
#   'birthDate': '1989-09-13',
#   'height': 186,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14732,
#   'foot': 'right',
#   'shortName': 'T. M\\u00fcller',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 85,
#   'firstName': 'Nils',
#   'middleName': '',
#   'lastName': 'Petersen',
#   'currentTeamId': 2453,
#   'birthDate': '1988-12-06',
#   'height': 188,
#   'role': {'code2': 'FW', 'code3': 'FWD', 'name': 'Forward'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14734,
#   'foot': 'right',
#   'shortName': 'N. Petersen',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 84,
#   'firstName': 'Sven',
#   'middleName': '',
#   'lastName': 'Ulreich',
#   'currentTeamId': 2444,
#   'birthDate': '1988-08-03',
#   'height': 192,
#   'role': {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalkeeper'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14736,
#   'foot': 'right',
#   'shortName': 'S. Ulreich',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'weight': 82,
#   'firstName': 'Cristian',
#   'middleName': '',
#   'lastName': 'Molinaro',
#   'currentTeamId': 3185,
#   'birthDate': '1983-07-30',
#   'height': 182,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'wyId': 14745,
#   'foot': 'left',
#   'shortName': 'C. Molinaro',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Sierra Leone',
#    'id': '694',
#    'alpha3code': 'SLE',
#    'alpha2code': 'SL'},
#   'weight': 85,
#   'firstName': 'Antonio',
#   'middleName': '',
#   'lastName': 'R\\u00fcdiger',
#   'currentTeamId': 1610,
#   'birthDate': '1993-03-03',
#   'height': 191,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14748,
#   'foot': 'right',
#   'shortName': 'A. R\\u00fcdiger',
#   'currentNationalTeamId': 3148},
#  {'passportArea': {'name': 'Japan',
#    'id': '392',
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'weight': 74,
#   'firstName': 'Gotoku',
#   'middleName': '',
#   'lastName': 'Sakai',
#   'currentTeamId': 2450,
#   'birthDate': '1991-03-14',
#   'height': 176,
#   'role': {'code2': 'DF', 'code3': 'DEF', 'name': 'Defender'},
#   'birthArea': {'name': 'United States',
#    'id': '840',
#    'alpha3code': 'USA',
#    'alpha2code': 'US'},
#   'wyId': 14749,
#   'foot': 'right',
#   'shortName': 'G. Sakai',
#   'currentNationalTeamId': 12913},
#  {'passportArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'weight': 81,
#   'firstName': 'Christian',
#   'middleName': '',
#   'lastName': 'Gentner',
#   'currentTeamId': 2445,
#   'birthDate': '1985-08-14',
#   'height': 189,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'wyId': 14754,
#   'foot': 'right',
#   'shortName': 'C. Gentner',
#   'currentNationalTeamId': 'null'},
#  {'passportArea': {'name': 'Serbia',
#    'id': '688',
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'weight': 81,
#   'firstName': 'Zdravko',
#   'middleName': '',
#   'lastName': 'Kuzmanovi\\u0107',
#   'currentTeamId': 683,
#   'birthDate': '1987-09-22',
#   'height': 185,
#   'role': {'code2': 'MD', 'code3': 'MID', 'name': 'Midfielder'},
#   'birthArea': {'name': 'Switzerland',
#    'id': '756',
#    'alpha3code': 'CHE',
#    'alpha2code': 'CH'},
#   'wyId': 14757,
#   'foot': 'right',
#   'shortName': 'Z. Kuzmanovi\\u0107',
#   'currentNationalTeamId': 'null'},
#  ...]

# %% [markdown]
# ##### Flatten Players data

# %%
# Flatten the JSON Players for the Big 5 European leagues and export DataFrame as a CSV file
df_wyscout_players_data_flat = json_normalize(json_wyscout_players_data)
df_wyscout_players_data_flat.to_csv(data_dir_wyscout + '/raw/csv/players.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
df_wyscout_players_data_flat.head()
# Out:
#    weight          firstName middleName     lastName currentTeamId  \
# 0      78              Harun                   Tekin          4502
# 1      73             Malang                    Sarr          3775
# 2      72               Over                Mandanda          3772
# 3      82  Alfred John Momar                 N'Diaye           683
# 4      84           Ibrahima             Konat\u00e9          2975
#
#     birthDate  height    wyId   foot       shortName  ... passportArea.id  \
# 0  1989-06-17     187   32777  right        H. Tekin  ...             792
# 1  1999-01-23     182  393228   left         M. Sarr  ...             686
# 2  1998-10-26     176  393230            O. Mandanda  ...             250
# 3  1990-03-06     187   32793  right      A. N'Diaye  ...             686
# 4  1999-05-25     192  393247  right  I. Konat\u00e9  ...             250
#
#   passportArea.alpha3code passportArea.alpha2code role.code2 role.code3  \
# 0                     TUR                      TR         GK        GKP
# 1                     SEN                      SN         DF        DEF
# 2                     FRA                      FR         GK        GKP
# 3                     SEN                      SN         MD        MID
# 4                     FRA                      FR         DF        DEF
#
#     role.name birthArea.name birthArea.id birthArea.alpha3code  \
# 0  Goalkeeper         Turkey          792                  TUR
# 1    Defender         France          250                  FRA
# 2  Goalkeeper         France          250                  FRA
# 3  Midfielder         France          250                  FRA
# 4    Defender         France          250                  FRA
#
#   birthArea.alpha2code
# 0                   TR
# 1                   FR
# 2                   FR
# 3                   FR
# 4                   FR
#
# [5 rows x 22 columns]

# %%
# Displays all columns
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_wyscout_players_data_flat.dtypes)
# Out:
# weight                      int64
# firstName                  object
# middleName                 object
# lastName                   object
# currentTeamId              object
# birthDate                  object
# height                      int64
# wyId                        int64
# foot                       object
# shortName                  object
# currentNationalTeamId      object
# passportArea.name          object
# passportArea.id            object
# passportArea.alpha3code    object
# passportArea.alpha2code    object
# role.code2                 object
# role.code3                 object
# role.name                  object
# birthArea.name             object
# birthArea.id               object
# birthArea.alpha3code       object
# birthArea.alpha2code       object
# dtype: object

# %% [markdown]
# ##### Streamline the DataFrame
# Include only the columns of interest

# %%
# Select columns of interest
cols_players = ['weight', 'firstName', 'middleName', 'lastName', 'birthDate', 'height', 'wyId', 'foot', 'shortName', 'passportArea.name', 'role.name', 'birthArea.name']

# Create more concise DataFrame using only columns of interest
df_wyscout_players_data_flat_select = df_wyscout_players_data_flat[cols_players]

# %% [markdown]
# ##### Create `fullName` attribute
# Join together the `firstName` and `lastName` attribute to create a `fullName` attribute.

# %%
df_wyscout_players_data_flat_select['fullName'] = df_wyscout_players_data_flat_select['firstName'].astype(str) + ' ' + df_wyscout_players_data_flat_select['lastName'].astype(str)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_wyscout_players_data_flat_select
# Out:
#       weight          firstName middleName             lastName   birthDate  \
# 0         78              Harun                           Tekin  1989-06-17
# 1         73             Malang                            Sarr  1999-01-23
# 2         72               Over                        Mandanda  1998-10-26
# 3         82  Alfred John Momar                         N'Diaye  1990-03-06
# 4         84           Ibrahima                     Konat\u00e9  1999-05-25
# ...      ...                ...        ...                  ...         ...
# 3598      72                Ali                    Ma\u00e2loul  1990-01-01
# 3599      76     Carlos Alberto             C\u00e1ceda Oyaguez  1991-09-27
# 3600      78  Miguel Gianpierre                   Araujo Blanco  1994-10-24
# 3601      70         Ahmed Reda                       Tagnaouti  1996-04-05
# 3602       0            Ricardo                   Guardia Avila  1997-02-04
#
#       height    wyId   foot        shortName passportArea.name   role.name  \
# 0        187   32777  right         H. Tekin            Turkey  Goalkeeper
# 1        182  393228   left          M. Sarr           Senegal    Defender
# 2        176  393230             O. Mandanda            France  Goalkeeper
# 3        187   32793  right       A. N'Diaye           Senegal  Midfielder
# 4        192  393247  right   I. Konat\u00e9            France    Defender
# ...      ...     ...    ...              ...               ...         ...
# 3598     175  120839   left  A. Ma\u00e2loul           Tunisia    Defender
# 3599     183  114736  right   C. C\u00e1ceda              Peru  Goalkeeper
# 3600     179  114908  right        M. Araujo              Peru    Defender
# 3601     182  285583  right     A. Tagnaouti           Morocco  Goalkeeper
# 3602       0  361536   left         R. Avila            Panama  Midfielder
#
#      birthArea.name                            fullName
# 0            Turkey                         Harun Tekin
# 1            France                         Malang Sarr
# 2            France                       Over Mandanda
# 3            France           Alfred John Momar N'Diaye
# 4            France                Ibrahima Konat\u00e9
# ...             ...                                 ...
# 3598        Tunisia                    Ali Ma\u00e2loul
# 3599           Peru  Carlos Alberto C\u00e1ceda Oyaguez
# 3600           Peru     Miguel Gianpierre Araujo Blanco
# 3601        Morocco                Ahmed Reda Tagnaouti
# 3602         Panama               Ricardo Guardia Avila
#
# [3603 rows x 13 columns]

# %% [markdown]
# ##### Export DataFrame

# %%
df_wyscout_players_data_flat_select.to_csv(data_dir_wyscout + '/raw/csv/players_select.csv', index=None, header=True)

# %% [markdown]
# ##### Investigate problem with player names

# %%
lst_players = list(df_wyscout_players_data_flat_select['fullName'].unique())

# %% [markdown]
# Player names with characters need cleaning e.g. 'Giovani dos Santos Ram\\u00edrez' is 'Giovani dos Santos Ramírez'.

# %% [markdown]
# ### <a id='#section3.6'>3.6. Teams</a>

# %% [markdown]
# ##### Read in the Teams data

# %%
# Import the Wyscout JSON Teams data from the Big 5 European leagues for the 17/18 season
with open(data_dir_wyscout + '/raw/json/teams.json') as f:
    json_wyscout_teams_data = json.load(f)

# %%
json_wyscout_teams_data
# Out:
# [{'city': 'Newcastle upon Tyne',
#   'name': 'Newcastle United',
#   'wyId': 1613,
#   'officialName': 'Newcastle United FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Vigo',
#   'name': 'Celta de Vigo',
#   'wyId': 692,
#   'officialName': 'Real Club Celta de Vigo',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Barcelona',
#   'name': 'Espanyol',
#   'wyId': 691,
#   'officialName': 'Reial Club Deportiu Espanyol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Vitoria-Gasteiz',
#   'name': 'Deportivo Alav\\u00e9s',
#   'wyId': 696,
#   'officialName': 'Deportivo Alav\\u00e9s',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Valencia',
#   'name': 'Levante',
#   'wyId': 695,
#   'officialName': 'Levante UD',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Troyes',
#   'name': 'Troyes',
#   'wyId': 3795,
#   'officialName': 'Esp\\u00e9rance Sportive Troyes Aube Champagne',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Getafe (Madrid)',
#   'name': 'Getafe',
#   'wyId': 698,
#   'officialName': 'Getafe Club de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'M\\u00f6nchengladbach',
#   'name': "Borussia M'gladbach",
#   'wyId': 2454,
#   'officialName': 'Borussia VfL M\\u00f6nchengladbach',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Huddersfield, West Yorkshire',
#   'name': 'Huddersfield Town',
#   'wyId': 1673,
#   'officialName': 'Huddersfield Town FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Bilbao',
#   'name': 'Athletic Club',
#   'wyId': 678,
#   'officialName': 'Athletic Club Bilbao',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Madrid',
#   'name': 'Atl\\u00e9tico Madrid',
#   'wyId': 679,
#   'officialName': 'Club Atl\\u00e9tico de Madrid',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Lyon',
#   'name': 'Olympique Lyonnais',
#   'wyId': 3766,
#   'officialName': 'Olympique Lyonnais',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Paris',
#   'name': 'PSG',
#   'wyId': 3767,
#   'officialName': 'Paris Saint-Germain FC',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Valencia',
#   'name': 'Valencia',
#   'wyId': 674,
#   'officialName': 'Valencia Club de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Madrid',
#   'name': 'Real Madrid',
#   'wyId': 675,
#   'officialName': 'Real Madrid Club de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Barcelona',
#   'name': 'Barcelona',
#   'wyId': 676,
#   'officialName': 'FC Barcelona',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Las Palmas de Gran Canaria',
#   'name': 'Las Palmas',
#   'wyId': 714,
#   'officialName': 'UD Las Palmas',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Legan\\u00e9s',
#   'name': 'Legan\\u00e9s',
#   'wyId': 712,
#   'officialName': 'CD Legan\\u00e9s',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Ferrara',
#   'name': 'SPAL',
#   'wyId': 3204,
#   'officialName': 'Societ\\u00e0 Polisportiva Ars et Labor 2013',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Swansea',
#   'name': 'Swansea City',
#   'wyId': 10531,
#   'officialName': 'Swansea City AFC',
#   'area': {'name': 'Wales', 'id': '0', 'alpha3code': 'XWA', 'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Marseille',
#   'name': 'Olympique Marseille',
#   'wyId': 3771,
#   'officialName': 'Olympique de Marseille',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'La Chapelle-sur-Erdre',
#   'name': 'Nantes',
#   'wyId': 3770,
#   'officialName': 'FC Nantes',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Nice',
#   'name': 'Nice',
#   'wyId': 3775,
#   'officialName': "O.G.C. Nice C\\u00f4te d'Azur",
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Rennes',
#   'name': 'Rennes',
#   'wyId': 3774,
#   'officialName': 'Stade Rennais FC',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Strasbourg',
#   'name': 'Strasbourg',
#   'wyId': 3779,
#   'officialName': 'RC Strasbourg Alsace',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Eibar',
#   'name': 'Eibar',
#   'wyId': 701,
#   'officialName': 'SD Eibar',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Bournemouth, Dorset',
#   'name': 'AFC Bournemouth',
#   'wyId': 1659,
#   'officialName': 'AFC Bournemouth',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Brighton, East Sussex',
#   'name': 'Brighton & Hove Albion',
#   'wyId': 1651,
#   'officialName': 'Brighton & Hove Albion FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Bremen',
#   'name': 'Werder Bremen',
#   'wyId': 2443,
#   'officialName': 'SV Werder Bremen',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Leverkusen',
#   'name': 'Bayer Leverkusen',
#   'wyId': 2446,
#   'officialName': 'TSV Bayer 04 Leverkusen',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Dortmund',
#   'name': 'Borussia Dortmund',
#   'wyId': 2447,
#   'officialName': 'BV Borussia 09 Dortmund',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'M\\u00fcnchen',
#   'name': 'Bayern M\\u00fcnchen',
#   'wyId': 2444,
#   'officialName': 'FC Bayern M\\u00fcnchen',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Stuttgart',
#   'name': 'Stuttgart',
#   'wyId': 2445,
#   'officialName': 'VfB Stuttgart 1893',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Gelsenkirchen',
#   'name': 'Schalke 04',
#   'wyId': 2449,
#   'officialName': 'FC Schalke 04',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Milano',
#   'name': 'Milan',
#   'wyId': 3157,
#   'officialName': 'AC Milan',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Angers',
#   'name': 'Angers',
#   'wyId': 3799,
#   'officialName': 'Angers SCO',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Torino',
#   'name': 'Juventus',
#   'wyId': 3159,
#   'officialName': 'Juventus FC',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Roma',
#   'name': 'Roma',
#   'wyId': 3158,
#   'officialName': 'AS Roma',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Sassuolo',
#   'name': 'Sassuolo',
#   'wyId': 3315,
#   'officialName': 'US Sassuolo Calcio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Burnley, Lancashire',
#   'name': 'Burnley',
#   'wyId': 1646,
#   'officialName': 'Burnley FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Le Haillan',
#   'name': 'Bordeaux',
#   'wyId': 3772,
#   'officialName': 'FC Girondins de Bordeaux',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Hannover',
#   'name': 'Hannover 96',
#   'wyId': 2455,
#   'officialName': 'Hannover 96',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Dijon',
#   'name': 'Dijon',
#   'wyId': 3804,
#   'officialName': 'Dijon FCO',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Berlin',
#   'name': 'Hertha BSC',
#   'wyId': 2457,
#   'officialName': 'Hertha BSC',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Wolfsburg',
#   'name': 'Wolfsburg',
#   'wyId': 2451,
#   'officialName': 'VfL Wolfsburg',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Hamburg',
#   'name': 'Hamburger SV',
#   'wyId': 2450,
#   'officialName': 'Hamburger SV',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Freiburg im Breisgau',
#   'name': 'Freiburg',
#   'wyId': 2453,
#   'officialName': 'SC Freiburg',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Bologna',
#   'name': 'Bologna',
#   'wyId': 3166,
#   'officialName': 'Bologna FC 1909',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Metz',
#   'name': 'Metz',
#   'wyId': 3777,
#   'officialName': 'FC Metz',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Genova',
#   'name': 'Sampdoria',
#   'wyId': 3164,
#   'officialName': 'UC Sampdoria',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Verona',
#   'name': 'Chievo',
#   'wyId': 3165,
#   'officialName': 'AC Chievo Verona',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Formello',
#   'name': 'Lazio',
#   'wyId': 3162,
#   'officialName': 'SS Lazio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Udine',
#   'name': 'Udinese',
#   'wyId': 3163,
#   'officialName': 'Udinese Calcio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Milano',
#   'name': 'Internazionale',
#   'wyId': 3161,
#   'officialName': 'FC Internazionale Milano',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Leicester',
#   'name': 'Leicester City',
#   'wyId': 1631,
#   'officialName': 'Leicester City FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'London',
#   'name': 'West Ham United',
#   'wyId': 1633,
#   'officialName': 'West Ham United FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Stoke-on-Trent',
#   'name': 'Stoke City',
#   'wyId': 1639,
#   'officialName': 'Stoke City FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Benevento',
#   'name': 'Benevento',
#   'wyId': 3219,
#   'officialName': 'Benevento Calcio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Saint-\\u00c9tienne',
#   'name': 'Saint-\\u00c9tienne',
#   'wyId': 3782,
#   'officialName': 'AS Saint-\\u00c9tienne',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Girona',
#   'name': 'Girona',
#   'wyId': 756,
#   'officialName': 'Girona FC',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Watford',
#   'name': 'Watford',
#   'wyId': 1644,
#   'officialName': 'Watford FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Sinsheim',
#   'name': 'Hoffenheim',
#   'wyId': 2482,
#   'officialName': 'TSG 1899 Hoffenheim',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Cagliari',
#   'name': 'Cagliari',
#   'wyId': 3173,
#   'officialName': 'Cagliari Calcio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Ciserano',
#   'name': 'Atalanta',
#   'wyId': 3172,
#   'officialName': 'Atalanta Bergamasca Calcio',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Firenze',
#   'name': 'Fiorentina',
#   'wyId': 3176,
#   'officialName': 'ACF Fiorentina',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Liverpool',
#   'name': 'Everton',
#   'wyId': 1623,
#   'officialName': 'Everton FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'West Bromwich',
#   'name': 'West Bromwich Albion',
#   'wyId': 1627,
#   'officialName': 'West Bromwich Albion FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Manchester',
#   'name': 'Manchester City',
#   'wyId': 1625,
#   'officialName': 'Manchester City FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'London',
#   'name': 'Tottenham Hotspur',
#   'wyId': 1624,
#   'officialName': 'Tottenham Hotspur FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Augsburg',
#   'name': 'Augsburg',
#   'wyId': 2481,
#   'officialName': 'FC Augsburg',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'London',
#   'name': 'Crystal Palace',
#   'wyId': 1628,
#   'officialName': 'Crystal Palace FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Monaco',
#   'name': 'Monaco',
#   'wyId': 19830,
#   'officialName': 'AS Monaco FC',
#   'area': {'name': 'Monaco',
#    'id': '492',
#    'alpha3code': 'MCO',
#    'alpha2code': 'MC'},
#   'type': 'club'},
#  {'city': 'Mainz',
#   'name': 'Mainz 05',
#   'wyId': 2460,
#   'officialName': '1. FSV Mainz 05',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': "Villeneuve-d'Ascq",
#   'name': 'Lille',
#   'wyId': 3776,
#   'officialName': 'Lille OSC M\\u00e9tropole',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Frankfurt am Main',
#   'name': 'Eintracht Frankfurt',
#   'wyId': 2462,
#   'officialName': 'Eintracht Frankfurt',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Southampton, Hampshire',
#   'name': 'Southampton',
#   'wyId': 1619,
#   'officialName': 'Southampton FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'K\\u00f6ln',
#   'name': 'K\\u00f6ln',
#   'wyId': 2463,
#   'officialName': '1. FC K\\u00f6ln',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'Liverpool',
#   'name': 'Liverpool',
#   'wyId': 1612,
#   'officialName': 'Liverpool FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'London',
#   'name': 'Chelsea',
#   'wyId': 1610,
#   'officialName': 'Chelsea FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Manchester',
#   'name': 'Manchester United',
#   'wyId': 1611,
#   'officialName': 'Manchester United FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Torino',
#   'name': 'Torino',
#   'wyId': 3185,
#   'officialName': 'Torino FC',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Castel Volturno',
#   'name': 'Napoli',
#   'wyId': 3187,
#   'officialName': 'SSC Napoli',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'A Coru\\u00f1a',
#   'name': 'Deportivo La Coru\\u00f1a',
#   'wyId': 677,
#   'officialName': 'Real Club Deportivo de La Coru\\u00f1a',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Leipzig',
#   'name': 'RB Leipzig',
#   'wyId': 2975,
#   'officialName': 'Rasen Ballsport Leipzig',
#   'area': {'name': 'Germany',
#    'id': '276',
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'club'},
#  {'city': 'London',
#   'name': 'Arsenal',
#   'wyId': 1609,
#   'officialName': 'Arsenal FC',
#   'area': {'name': 'England',
#    'id': '0',
#    'alpha3code': 'XEN',
#    'alpha2code': ''},
#   'type': 'club'},
#  {'city': 'Caen',
#   'name': 'Caen',
#   'wyId': 3783,
#   'officialName': 'Stade Malherbe Caen',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Toulouse',
#   'name': 'Toulouse',
#   'wyId': 3780,
#   'officialName': 'Toulouse FC',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Montpellier',
#   'name': 'Montpellier',
#   'wyId': 3787,
#   'officialName': 'Montpellier HSC',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Guingamp',
#   'name': 'Guingamp',
#   'wyId': 3785,
#   'officialName': 'En Avant Guingamp',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Amiens',
#   'name': 'Amiens SC',
#   'wyId': 3789,
#   'officialName': 'Amiens SC',
#   'area': {'name': 'France',
#    'id': '250',
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'club'},
#  {'city': 'Crotone',
#   'name': 'Crotone',
#   'wyId': 3197,
#   'officialName': 'FC Crotone',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Verona',
#   'name': 'Hellas Verona',
#   'wyId': 3194,
#   'officialName': 'Hellas Verona FC',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Genova',
#   'name': 'Genoa',
#   'wyId': 3193,
#   'officialName': 'Genoa CFC',
#   'area': {'name': 'Italy',
#    'id': '380',
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'club'},
#  {'city': 'Sevilla',
#   'name': 'Real Betis',
#   'wyId': 684,
#   'officialName': 'Real Betis Balompi\\u00e9',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Donostia-San Sebasti\\u00e1n',
#   'name': 'Real Sociedad',
#   'wyId': 687,
#   'officialName': 'Real Sociedad de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Sevilla',
#   'name': 'Sevilla',
#   'wyId': 680,
#   'officialName': 'Sevilla FC',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Malaga',
#   'name': 'M\\u00e1laga',
#   'wyId': 683,
#   'officialName': 'M\\u00e1laga Club de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Villarreal',
#   'name': 'Villarreal',
#   'wyId': 682,
#   'officialName': 'Villarreal Club de F\\u00fatbol',
#   'area': {'name': 'Spain',
#    'id': '724',
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'club'},
#  {'city': 'Seoul',
#   'name': 'Korea Republic',
#   'wyId': 14855,
#   'officialName': 'Korea Republic',
#   'area': {'name': 'Korea Republic',
#    'id': 410,
#    'alpha3code': 'KOR',
#    'alpha2code': 'KR'},
#   'type': 'national'},
#  {'city': 'Budapest',
#   'name': 'Hungary',
#   'wyId': 10451,
#   'officialName': 'Hungary',
#   'area': {'name': 'Hungary',
#    'id': 348,
#    'alpha3code': 'HUN',
#    'alpha2code': 'HU'},
#   'type': 'national'},
#  {'city': 'Istanbul',
#   'name': 'Turkey',
#   'wyId': 4687,
#   'officialName': 'Turkey',
#   'area': {'name': 'Turkey',
#    'id': 792,
#    'alpha3code': 'TUR',
#    'alpha2code': 'TR'},
#   'type': 'national'},
#  {'city': 'Moskva',
#   'name': 'Russia',
#   'wyId': 14358,
#   'officialName': 'Russia',
#   'area': {'name': 'Russia',
#    'id': 643,
#    'alpha3code': 'RUS',
#    'alpha2code': 'RU'},
#   'type': 'national'},
#  {'city': 'Solna',
#   'name': 'Sweden',
#   'wyId': 7047,
#   'officialName': 'Sweden',
#   'area': {'name': 'Sweden',
#    'id': 752,
#    'alpha3code': 'SWE',
#    'alpha2code': 'SE'},
#   'type': 'national'},
#  {'city': 'El Menzah',
#   'name': 'Tunisia',
#   'wyId': 16276,
#   'officialName': 'Tunisia',
#   'area': {'name': 'Tunisia',
#    'id': 788,
#    'alpha3code': 'TUN',
#    'alpha2code': 'TN'},
#   'type': 'national'},
#  {'city': 'Rio de Janeiro, Rio de Janeiro',
#   'name': 'Brazil',
#   'wyId': 6380,
#   'officialName': 'Brazil',
#   'area': {'name': 'Brazil',
#    'id': 76,
#    'alpha3code': 'BRA',
#    'alpha2code': 'BR'},
#   'type': 'national'},
#  {'city': 'Frankfurt am Main',
#   'name': 'Germany',
#   'wyId': 3148,
#   'officialName': 'Germany',
#   'area': {'name': 'Germany',
#    'id': 276,
#    'alpha3code': 'DEU',
#    'alpha2code': 'DE'},
#   'type': 'national'},
#  {'city': 'Tiran\\u00eb (Tirana)',
#   'name': 'Albania',
#   'wyId': 8731,
#   'officialName': 'Albania',
#   'area': {'name': 'Albania',
#    'id': 8,
#    'alpha3code': 'ALB',
#    'alpha2code': 'AL'},
#   'type': 'national'},
#  {'city': 'Bucure\\u015fti',
#   'name': 'Romania',
#   'wyId': 11944,
#   'officialName': 'Romania',
#   'area': {'name': 'Romania',
#    'id': 642,
#    'alpha3code': 'ROU',
#    'alpha2code': 'RO'},
#   'type': 'national'},
#  {'city': 'Kyiv (Kiev)',
#   'name': 'Ukraine',
#   'wyId': 14622,
#   'officialName': 'Ukraine',
#   'area': {'name': 'Ukraine',
#    'id': 804,
#    'alpha3code': 'UKR',
#    'alpha2code': 'UA'},
#   'type': 'national'},
#  {'city': 'Rabat',
#   'name': 'Morocco',
#   'wyId': 16216,
#   'officialName': 'Morocco',
#   'area': {'name': 'Morocco',
#    'id': 504,
#    'alpha3code': 'MAR',
#    'alpha2code': 'MA'},
#   'type': 'national'},
#  {'city': 'Bratislava',
#   'name': 'Slovakia',
#   'wyId': 14496,
#   'officialName': 'Slovakia',
#   'area': {'name': 'Slovakia',
#    'id': 703,
#    'alpha3code': 'SVK',
#    'alpha2code': 'SK'},
#   'type': 'national'},
#  {'city': 'Bogot\\u00e1 D.C.',
#   'name': 'Colombia',
#   'wyId': 12430,
#   'officialName': 'Colombia',
#   'area': {'name': 'Colombia',
#    'id': 170,
#    'alpha3code': 'COL',
#    'alpha2code': 'CO'},
#   'type': 'national'},
#  {'city': 'Ciudad de Panam\\u00e1',
#   'name': 'Panama',
#   'wyId': 17929,
#   'officialName': 'Panama',
#   'area': {'name': 'Panama',
#    'id': 591,
#    'alpha3code': 'PAN',
#    'alpha2code': 'PA'},
#   'type': 'national'},
#  {'city': 'Sydney',
#   'name': 'Australia',
#   'wyId': 8493,
#   'officialName': 'Australia',
#   'area': {'name': 'Australia',
#    'id': 36,
#    'alpha3code': 'AUS',
#    'alpha2code': 'AU'},
#   'type': 'national'},
#  {'city': 'Buenos Aires, Ciudad de Buenos Aires',
#   'name': 'Argentina',
#   'wyId': 12274,
#   'officialName': 'Argentina',
#   'area': {'name': 'Argentina',
#    'id': 32,
#    'alpha3code': 'ARG',
#    'alpha2code': 'AR'},
#   'type': 'national'},
#  {'city': 'Belfast',
#   'name': 'Northern Ireland',
#   'wyId': 10962,
#   'officialName': 'Northern Ireland',
#   'area': {'name': 'Northern Ireland',
#    'id': 0,
#    'alpha3code': 'XNI',
#    'alpha2code': ''},
#   'type': 'national'},
#  {'city': 'Lisboa',
#   'name': 'Portugal',
#   'wyId': 9905,
#   'officialName': 'Portugal',
#   'area': {'name': 'Portugal',
#    'id': 620,
#    'alpha3code': 'PRT',
#    'alpha2code': 'PT'},
#   'type': 'national'},
#  {'city': 'Bruxelles (Brussel)',
#   'name': 'Belgium',
#   'wyId': 5629,
#   'officialName': 'Belgium',
#   'area': {'name': 'Belgium',
#    'id': 56,
#    'alpha3code': 'BEL',
#    'alpha2code': 'BE'},
#   'type': 'national'},
#  {'city': 'Br\\u00f8ndby',
#   'name': 'Denmark',
#   'wyId': 7712,
#   'officialName': 'Denmark',
#   'area': {'name': 'Denmark',
#    'id': 208,
#    'alpha3code': 'DNK',
#    'alpha2code': 'DK'},
#   'type': 'national'},
#  {'city': 'Montevideo',
#   'name': 'Uruguay',
#   'wyId': 15670,
#   'officialName': 'Uruguay',
#   'area': {'name': 'Uruguay',
#    'id': 858,
#    'alpha3code': 'URY',
#    'alpha2code': 'UY'},
#   'type': 'national'},
#  {'city': 'Cardiff',
#   'name': 'Wales',
#   'wyId': 10682,
#   'officialName': 'Wales',
#   'area': {'name': 'Wales', 'id': 0, 'alpha3code': 'XWA', 'alpha2code': ''},
#   'type': 'national'},
#  {'city': 'San Jos\\u00e9',
#   'name': 'Costa Rica',
#   'wyId': 16871,
#   'officialName': 'Costa Rica',
#   'area': {'name': 'Costa Rica',
#    'id': 188,
#    'alpha3code': 'CRI',
#    'alpha2code': 'CR'},
#   'type': 'national'},
#  {'city': 'London',
#   'name': 'England',
#   'wyId': 2413,
#   'officialName': 'England',
#   'area': {'name': 'England', 'id': 0, 'alpha3code': 'XEN', 'alpha2code': ''},
#   'type': 'national'},
#  {'city': 'Cairo',
#   'name': 'Egypt',
#   'wyId': 16129,
#   'officialName': 'Egypt',
#   'area': {'name': 'Egypt',
#    'id': 818,
#    'alpha3code': 'EGY',
#    'alpha2code': 'EG'},
#   'type': 'national'},
#  {'city': 'T\\u014dky\\u014d (Tokyo)',
#   'name': 'Japan',
#   'wyId': 12913,
#   'officialName': 'Japan',
#   'area': {'name': 'Japan',
#    'id': 392,
#    'alpha3code': 'JPN',
#    'alpha2code': 'JP'},
#   'type': 'national'},
#  {'city': 'Tehr\\u0101n (Teheran)',
#   'name': 'Iran',
#   'wyId': 10840,
#   'officialName': 'Iran',
#   'area': {'name': 'Iran', 'id': 364, 'alpha3code': 'IRN', 'alpha2code': 'IR'},
#   'type': 'national'},
#  {'city': 'Wien',
#   'name': 'Austria',
#   'wyId': 9109,
#   'officialName': 'Austria',
#   'area': {'name': 'Austria',
#    'id': 40,
#    'alpha3code': 'AUT',
#    'alpha2code': 'AT'},
#   'type': 'national'},
#  {'city': 'Reykjav\\u00edk',
#   'name': 'Iceland',
#   'wyId': 7839,
#   'officialName': 'Iceland',
#   'area': {'name': 'Iceland',
#    'id': 352,
#    'alpha3code': 'ISL',
#    'alpha2code': 'IS'},
#   'type': 'national'},
#  {'city': 'Zagreb',
#   'name': 'Croatia',
#   'wyId': 9598,
#   'officialName': 'Croatia',
#   'area': {'name': 'Croatia',
#    'id': 191,
#    'alpha3code': 'HRV',
#    'alpha2code': 'HR'},
#   'type': 'national'},
#  {'city': 'Coyoac\\u00e1n, Ciudad de M\\u00e9xico (D.F.)',
#   'name': 'Mexico',
#   'wyId': 15473,
#   'officialName': 'Mexico',
#   'area': {'name': 'Mexico',
#    'id': 484,
#    'alpha3code': 'MEX',
#    'alpha2code': 'MX'},
#   'type': 'national'},
#  {'city': 'Dublin',
#   'name': 'Republic of Ireland',
#   'wyId': 8274,
#   'officialName': 'Republic of Ireland',
#   'area': {'name': 'Ireland Republic',
#    'id': 372,
#    'alpha3code': 'IRL',
#    'alpha2code': 'IE'},
#   'type': 'national'},
#  {'city': 'Praha',
#   'name': 'Czech Republic',
#   'wyId': 11555,
#   'officialName': 'Czech Republic',
#   'area': {'name': 'Czech Republic',
#    'id': 203,
#    'alpha3code': 'CZE',
#    'alpha2code': 'CZ'},
#   'type': 'national'},
#  {'city': 'Dakar',
#   'name': 'Senegal',
#   'wyId': 19314,
#   'officialName': 'Senegal',
#   'area': {'name': 'Senegal',
#    'id': 686,
#    'alpha3code': 'SEN',
#    'alpha2code': 'SN'},
#   'type': 'national'},
#  {'city': 'Roma',
#   'name': 'Italy',
#   'wyId': 3757,
#   'officialName': 'Italy',
#   'area': {'name': 'Italy',
#    'id': 380,
#    'alpha3code': 'ITA',
#    'alpha2code': 'IT'},
#   'type': 'national'},
#  {'city': 'Lima',
#   'name': 'Peru',
#   'wyId': 15594,
#   'officialName': 'Peru',
#   'area': {'name': 'Peru', 'id': 604, 'alpha3code': 'PER', 'alpha2code': 'PE'},
#   'type': 'national'},
#  {'city': 'Paris',
#   'name': 'France',
#   'wyId': 4418,
#   'officialName': 'France',
#   'area': {'name': 'France',
#    'id': 250,
#    'alpha3code': 'FRA',
#    'alpha2code': 'FR'},
#   'type': 'national'},
#  {'city': 'Ar-Riy\\u0101\\u1e0d (Riyadh)',
#   'name': 'Saudi Arabia',
#   'wyId': 16521,
#   'officialName': 'Saudi Arabia',
#   'area': {'name': 'Saudi Arabia',
#    'id': 682,
#    'alpha3code': 'SAU',
#    'alpha2code': 'SA'},
#   'type': 'national'},
#  {'city': 'Las Rozas',
#   'name': 'Spain',
#   'wyId': 1598,
#   'officialName': 'Spain',
#   'area': {'name': 'Spain',
#    'id': 724,
#    'alpha3code': 'ESP',
#    'alpha2code': 'ES'},
#   'type': 'national'},
#  {'city': 'Beograd',
#   'name': 'Serbia',
#   'wyId': 17322,
#   'officialName': 'Serbia',
#   'area': {'name': 'Serbia',
#    'id': 688,
#    'alpha3code': 'SRB',
#    'alpha2code': 'RS'},
#   'type': 'national'},
#  {'city': 'Bern',
#   'name': 'Switzerland',
#   'wyId': 6697,
#   'officialName': 'Switzerland',
#   'area': {'name': 'Switzerland',
#    'id': 756,
#    'alpha3code': 'CHE',
#    'alpha2code': 'CH'},
#   'type': 'national'},
#  {'city': 'Warszawa',
#   'name': 'Poland',
#   'wyId': 13869,
#   'officialName': 'Poland',
#   'area': {'name': 'Poland',
#    'id': 616,
#    'alpha3code': 'POL',
#    'alpha2code': 'PL'},
#   'type': 'national'},
#  {'city': 'Abuja',
#   'name': 'Nigeria',
#   'wyId': 16823,
#   'officialName': 'Nigeria',
#   'area': {'name': 'Nigeria',
#    'id': 566,
#    'alpha3code': 'NGA',
#    'alpha2code': 'NG'},
#   'type': 'national'}]

# %% [markdown]
# ##### Flatten Teams data

# %%
# Flatten the JSON Teams data for the Big 5 European leagues and export DataFrame as a CSV file
df_wyscout_teams_data_flat = json_normalize(json_wyscout_teams_data)
df_wyscout_teams_data_flat.to_csv(data_dir_wyscout + '/raw/csv/players.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
df_wyscout_teams_data_flat.head()
# Out:
#                   city                   name  wyId  \
# 0  Newcastle upon Tyne       Newcastle United  1613
# 1                 Vigo          Celta de Vigo   692
# 2            Barcelona               Espanyol   691
# 3      Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4             Valencia                Levante   695
#
#                    officialName  type area.name area.id area.alpha3code  \
# 0           Newcastle United FC  club   England       0             XEN
# 1       Real Club Celta de Vigo  club     Spain     724             ESP
# 2  Reial Club Deportiu Espanyol  club     Spain     724             ESP
# 3         Deportivo Alav\u00e9s  club     Spain     724             ESP
# 4                    Levante UD  club     Spain     724             ESP
#
#   area.alpha2code
# 0
# 1              ES
# 2              ES
# 3              ES
# 4              ES

# %% [markdown]
# ##### Streamline the DataFrame
# Include only the columns of interest

# %%
df_wyscout_teams_data_flat.columns
# Out:
# Index(['city', 'name', 'wyId', 'officialName', 'type', 'area.name', 'area.id',
#        'area.alpha3code', 'area.alpha2code'],
#       dtype='object')

# %% [markdown]
# ##### Rename columns

# %%
# Select columns of interest
cols_teams = ['name', 'wyId']

# Create more concise DataFrame using only columns of interest
df_wyscout_teams_data_flat_select = df_wyscout_teams_data_flat[cols_teams]

# %%
df_wyscout_teams_data_flat_select = df_wyscout_teams_data_flat_select.rename(columns={'name': 'teamName'})

# %% [markdown]
# ##### Export DataFrame

# %%
df_wyscout_teams_data_flat_select.to_csv(data_dir_wyscout + '/raw/csv/teams_select.csv', index=None, header=True)

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section4'>4. Data Engineering</a>

# %% [markdown]
# ### <a id='#section4.1'>4.1. Join Datasets</a>
# Next, we're required to join the `Matches` DataFrame and the `Players` DataFrame to the `Events` DatFrame. The `Events` data is the base DataFrame in which we join the other tables via `wyId`, `matchId`, `competitionId`, `playerId`, and `teamId`.

# %% [markdown]
# ##### Join Matches DataFrame to Events DataFrame

# %%
# Join the Events DataFrame to the Matches DataFrame
df_wyscout_merge = pd.merge(df_wyscout_event_data_big5_flat, df_wyscout_matches_data_big5_flat_select, left_on='matchId', right_on='wyId')

# %% [markdown]
# ##### Join Competitions DataFrame to Merged DataFrame via Events DataFrame

# %%
# Join the Players DataFrame to the Events-Matches DataFrame
df_wyscout_merge = pd.merge(df_wyscout_merge, df_wyscout_competitions_data_flat_select, left_on='competitionId', right_on='wyId')

# %% [markdown]
# ##### Join Player DataFrame to Merged DataFrame via Events DataFrame

# %%
# Join the Players DataFrame to the Events-Matches DataFrame
df_wyscout_merge = pd.merge(df_wyscout_merge, df_wyscout_players_data_flat_select, left_on='playerId', right_on='wyId')

# %% [markdown]
# ##### Join Teams DataFrame to Merged DataFrame via Events DataFrame

# %%
# Join the Players DataFrame to the Events-Matches DataFrame
df_wyscout_merge = pd.merge(df_wyscout_merge, df_wyscout_teams_data_flat_select, left_on='teamId', right_on='wyId')

# %%
df_wyscout_merge.shape
# Out:
# (2845357, 43)

# %% [markdown]
# ### <a id='#section4.2'>4.2. Export DataFrame</a>

# %%
df_wyscout_merge.to_csv(data_dir_wyscout + '/raw/csv/combined/wyscout_big5_combined.csv', index=None, header=True)

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section5'>5. Exploratory Data Analysis</a>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section6'>6. Summary</a>
# This notebook parses Wyscout data using [pandas](http://pandas.pydata.org/) for data maniuplation through DataFrames.

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section7'>7. Next Steps</a>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section8'>8. References</a>

# %% [markdown]
# ### <a id='#section9.1'>8.1. Bibliography</a>
#
# #### Wyscout
# *    WyScout: https://wyscout.com/
# *    WyScout Events data manual: https://footballdata.wyscout.com/events-manual/
# *    Pappalardo, Luca; Massucco, Emanuele (2019): Soccer match event dataset. figshare. Collection. https://doi.org/10.6084/m9.figshare.c.4415000.v5
# *    Pappalardo, L., Cintia, P., Rossi, A. et al. **A public data set of spatio-temporal match events in soccer competitions**. Scientific Data 6, 236 (2019) doi:10.1038/s41597-019-0247-7, https://www.nature.com/articles/s41597-019-0247-7

# %% [markdown]
# ### <a id='#section9.2'>8.2. Python Techniques Observed</a>
# To conduct our analysis, we have used the following libraries and modules for the following tasks:
# *    [NumPy](http://www.numpy.org/) for multidimensional array computing,
# *    [pandas](http://pandas.pydata.org/) for data manipulation and ingestion
#
# We have also demonstrated an array of techniques in Python using the following methods and functions:
# *    pandas EDA methods:
#      +    [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html),
#      +    [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html),
#      +    [shape](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html),
#      +    [columns](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html),
#      +    [dtypes](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html),
#      +    [info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html), and
#      +    [describe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html).
# *    The [missingno](https://pypi.org/project/missingno/) library to visualise how many missing values we have in the dataset, and
# *    The pandas [.to_csv()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html) method to export the DataFrames as csv files.

# %% [markdown]
# ---
#
# ***Visit my website [EddWebster.com](https://www.eddwebster.com) or my [GitHub Repository](https://github.com/eddwebster) for more projects. If you'd like to get in contact, my Twitter handle is [@eddwebster](http://www.twitter.com/eddwebster) and my email is: edd.j.webster@gmail.com.***

# %% [markdown]
# [Back to the top](#top)
