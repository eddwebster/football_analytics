# %% [markdown]
# <a id='top'></a>

# %% [markdown]
# # Data Parsing of StatsBomb Data
# ##### Notebook to parse JSON data available from the [StatsBomb Open Data GitHub repository](https://github.com/statsbomb/open-data)
#
# ### By [Edd Webster](https://www.twitter.com/eddwebster)
# Last updated: 10/11/2020

# %% [markdown]
# ![title](../../img/stats-bomb-logo.png)

# %% [markdown]
# Click [here](#section5) to jump straight to the Exploratory Data Analysis section and skip the [Task Brief](#section2), [Data Sources](#section3), and [Data Engineering](#section4) sections. Or click [here](#section6) to jump straight to the Conclusion.

# %% [markdown]
# ___
#
# <a id='sectionintro'></a>

# %% [markdown]
# ## <a id='import_libraries'>Introduction</a>
# This notebook parses JSON data from [StatsBomb](https://statsbomb.com/) using [pandas](http://pandas.pydata.org/) for data manipulation through DataFrames.
#
# For more information about this notebook and the author, I'm available through all the following channels:
# *    [eddwebster.com](https://www.eddwebster.com/),
# *    edd.j.webster@gmail.com,
# *    [@eddwebster](https://www.twitter.com/eddwebster),
# *    [LinkedIn.com/in/eddwebster](https://www.linkedin.com/in/eddwebster/),
# *    [GitHub/eddwebster](https://github.com/eddwebster/),
# *    [Kaggle.com/eddwebster](https://www.kaggle.com/eddwebster), and
# *    [HackerRank.com/eddwebster](https://www.hackerrank.com/eddwebster).

# %% [markdown]
# The accompanying GitHub repository for this notebook can be found [here](https://github.com/eddwebster/fifa-league) and a static version of this notebook can be found [here](https://nbviewer.jupyter.org/github/eddwebster/fifa-league/blob/master/FIFA%2020%20Fantasy%20Football%20League%20using%20TransferMarkt%20Player%20Valuations.ipynb).

# %% [markdown]
# ___
#
# <a id='sectioncontents'></a>

# %% [markdown]
# ## <a id='notebook_contents'>Notebook Contents</a>
# 1.    [Notebook Dependencies](#section1)<br>
# 2.    [Project Brief](#section2)<br>
# 3.    [Data Sources](#section3)<br>
#       1.    [Introduction](#section3.1)<br>
#       2.    [Data Dictionary](#section3.2)<br>
#       3.    [Creating the DataFrame](#section3.3)<br>
#       4.    [Initial Data Handling](#section3.4)<br>
#       5.    [Export the Raw DataFrame](#section3.5)<br>
# 4.    [Data Engineering](#section4)<br>
#       1.    [Introduction](#section4.1)<br>
#       2.    [Columns of Interest](#section4.2)<br>
#       3.    [String Cleaning](#section4.3)<br>
#       4.    [Converting Data Types](#section4.4)<br>
#       5.    [Export the Engineered DataFrame](#section4.5)<br>
# 5.    [Exploratory Data Analysis (EDA)](#section5)<br>
#       1.    [...](#section5.1)<br>
#       2.    [...](#section5.2)<br>
#       3.    [...](#section5.3)<br>
# 6.    [Summary](#section6)<br>
# 7.    [Next Steps](#section7)<br>
# 8.    [Bibliography](#section8)<br>

# %% [markdown]
# ___
#
# <a id='section1'></a>

# %% [markdown]
# ## <a id='#section1'>1. Notebook Dependencies</a>

# %% [markdown]
# This notebook was written using [Python 3](https://docs.python.org/3.7/) and requires the following libraries:
# *    [`Jupyter notebooks`](https://jupyter.org/) for this notebook environment with which this project is presented;
# *    [`NumPy`](http://www.numpy.org/) for multidimensional array computing;
# *    [`pandas`](http://pandas.pydata.org/) for data analysis and manipulation;
# *    `tqdm` for a clean progress bar;
# *    [`matplotlib`](https://matplotlib.org/contents.html?v=20200411155018) for data visualisations;
#
# All packages used for this notebook except for BeautifulSoup can be obtained by downloading and installing the [Conda](https://anaconda.org/anaconda/conda) distribution, available on all platforms (Windows, Linux and Mac OSX). Step-by-step guides on how to install Anaconda can be found for Windows [here](https://medium.com/@GalarnykMichael/install-python-on-windows-anaconda-c63c7c3d1444) and Mac [here](https://medium.com/@GalarnykMichael/install-python-on-mac-anaconda-ccd9f2014072), as well as in the Anaconda documentation itself [here](https://docs.anaconda.com/anaconda/install/).

# %% [markdown]
# ### Import Libraries and Modules

# %%
# Python ≥3.5 (ideally)
import platform
import sys, getopt
assert sys.version_info >= (3, 5)
import csv

# Import Dependencies
# %matplotlib inline

# Math Operations
import numpy as np
from math import pi

# Datetime
import datetime
from datetime import date
import time

# Data Preprocessing
import pandas as pd    # version 1.0.3
import os    #  used to read the csv filenames
import re
import random
from io import BytesIO
from pathlib import Path

# Reading directories
import glob
import os

# Working with JSON
import json
import codecs
from pandas.io.json import json_normalize

# Football Libraries
from FCPython import createPitch

# Data Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno as msno    # visually display missing data

# Progress Bar
from tqdm import tqdm    # a clean progress bar library

# Display in Jupyter
from IPython.display import Image, Video, YouTubeVideo
from IPython.core.display import HTML

# Ignore Warnings
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

print('Setup Complete')
# Out:
# Setup Complete

# %%
# Python / module versions used here for reference
print('Python: {}'.format(platform.python_version()))
print('NumPy: {}'.format(np.__version__))
print('pandas: {}'.format(pd.__version__))
print('matplotlib: {}'.format(mpl.__version__))
print('Seaborn: {}'.format(sns.__version__))
# Out:
# Python: 3.7.6
# NumPy: 1.18.1
# pandas: 1.0.1
# matplotlib: 3.1.3
# Seaborn: 0.10.0

# %% [markdown]
# ### Defined Variables

# %%
# Define today's date
today = datetime.datetime.now().strftime('%d/%m/%Y').replace('/', '')

# %% [markdown]
# ### Defined Filepaths

# %%
# Set up initial paths to subfolders
base_dir = os.path.join('..', '..', )
data_dir = os.path.join(base_dir, 'data')
data_dir_fbref = os.path.join(base_dir, 'data', 'fbref')
data_dir_tm = os.path.join(base_dir, 'data', 'tm')
data_dir_sb = os.path.join(base_dir, 'data', 'sb')
data_dir_understat = os.path.join(base_dir, 'data', 'understat')
img_dir = os.path.join(base_dir, 'img')
fig_dir = os.path.join(base_dir, 'img', 'fig')
video_dir = os.path.join(base_dir, 'video')

# %% [markdown]
# ### Notebook Settings

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
#
# <a id='section2'></a>

# %% [markdown]
# ## <a id='#section2'>2. Project Brief</a>
# This Jupyter notebook explores how to parse publicly available Event data from [StatsBomb](https://statsbomb.com/) using [pandas](http://pandas.pydata.org/) for data maniuplation through DataFrames.
#
# In this analysis, we're looking specifically at [FA WSL](https://womenscompetitions.thefa.com/) for the 18/19 and 19/20 seasons.
#
# The combined event data roduced in this notebook is exported to CSV. This data can be further analysed in Python, joined to other datasets, or explored using Tableau, PowerBI, Microsoft Excel.

# %% [markdown]
# ---
#
# <a id='section3'></a>

# %% [markdown]
# ## <a id='#section3'>3. Data Sources</a>

# %% [markdown]
# ### <a id='#section3.1'>3.1. Introduction</a>
# [StatsBomb](https://statsbomb.com/) are a football analytics and data company.
#
# Before conducting our EDA, the data needs to be imported as a DataFrame in the Data Sources section [Section 3](#section3) and Cleaned in the Data Engineering section [Section 4](#section4).
#
# We'll be using the [pandas](http://pandas.pydata.org/) library to import our data to this workbook as a DataFrame.

# %% [markdown]
# ### <a id='#section3.2'>3.2. Read in JSON files</a>

# %% [markdown]
# #### <a id='#section3.3.1.'>3.3.1. Competitions</a>

# %% [markdown]
# ##### Data Dictionary

# %% [markdown]
# ##### Import data

# %%
# Load the StatsBomb Competition JSON file
with open(data_dir_sb + '/competitions/raw/json/competitions.json') as f:
    json_sb_competitions_data = json.load(f)

# %%
# Display the StatsBomb Competition JSON file
json_sb_competitions_data
# Out:
# [{'competition_id': 16,
#   'season_id': 4,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2018/2019',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 1,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2017/2018',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 2,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2016/2017',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 27,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2015/2016',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 26,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2014/2015',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 25,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2013/2014',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 24,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2012/2013',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 23,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2011/2012',
#   'match_updated': '2020-08-26T12:33:15.869622',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 22,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2010/2011',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 21,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2009/2010',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 41,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2008/2009',
#   'match_updated': '2020-08-30T10:18:39.435424',
#   'match_available': '2020-08-30T10:18:39.435424'},
#  {'competition_id': 16,
#   'season_id': 39,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2006/2007',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 37,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2004/2005',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 16,
#   'season_id': 44,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '2003/2004',
#   'match_updated': '2020-08-30T10:18:39.435424',
#   'match_available': '2020-08-30T10:18:39.435424'},
#  {'competition_id': 16,
#   'season_id': 76,
#   'country_name': 'Europe',
#   'competition_name': 'Champions League',
#   'competition_gender': 'male',
#   'season_name': '1999/2000',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 37,
#   'season_id': 42,
#   'country_name': 'England',
#   'competition_name': "FA Women's Super League",
#   'competition_gender': 'female',
#   'season_name': '2019/2020',
#   'match_updated': '2020-09-30T14:59:21.257704',
#   'match_available': '2020-09-30T14:59:21.257704'},
#  {'competition_id': 37,
#   'season_id': 4,
#   'country_name': 'England',
#   'competition_name': "FA Women's Super League",
#   'competition_gender': 'female',
#   'season_name': '2018/2019',
#   'match_updated': '2020-08-24T14:34:34.401523',
#   'match_available': '2020-08-24T14:34:34.401523'},
#  {'competition_id': 43,
#   'season_id': 3,
#   'country_name': 'International',
#   'competition_name': 'FIFA World Cup',
#   'competition_gender': 'male',
#   'season_name': '2018',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 42,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2019/2020',
#   'match_updated': '2020-10-11T20:05:57.703730',
#   'match_available': '2020-10-11T20:05:57.703730'},
#  {'competition_id': 11,
#   'season_id': 4,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2018/2019',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 1,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2017/2018',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 2,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2016/2017',
#   'match_updated': '2020-10-09T04:20:42.205355',
#   'match_available': '2020-10-09T04:20:42.205355'},
#  {'competition_id': 11,
#   'season_id': 27,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2015/2016',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 26,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2014/2015',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 25,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2013/2014',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 24,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2012/2013',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 23,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2011/2012',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 22,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2010/2011',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 21,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2009/2010',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 41,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2008/2009',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 40,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2007/2008',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 39,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2006/2007',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 38,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2005/2006',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 11,
#   'season_id': 37,
#   'country_name': 'Spain',
#   'competition_name': 'La Liga',
#   'competition_gender': 'male',
#   'season_name': '2004/2005',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 49,
#   'season_id': 3,
#   'country_name': 'United States of America',
#   'competition_name': 'NWSL',
#   'competition_gender': 'female',
#   'season_name': '2018',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'},
#  {'competition_id': 2,
#   'season_id': 44,
#   'country_name': 'England',
#   'competition_name': 'Premier League',
#   'competition_gender': 'male',
#   'season_name': '2003/2004',
#   'match_updated': '2020-08-31T20:40:28.969635',
#   'match_available': '2020-08-31T20:40:28.969635'},
#  {'competition_id': 72,
#   'season_id': 30,
#   'country_name': 'International',
#   'competition_name': "Women's World Cup",
#   'competition_gender': 'female',
#   'season_name': '2019',
#   'match_updated': '2020-07-29T05:00',
#   'match_available': '2020-07-29T05:00'}]

# %% [markdown]
# ##### Flatten Competitions data

# %%
# Flatten the Wyscout JSON Competition data and export the DataFrame as a CSV file
df_sb_competitions_data_flat = json_normalize(json_sb_competitions_data)
df_sb_competitions_data_flat.to_csv(data_dir_sb + '/competitions/raw/csv/competitions.json', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
df_sb_competitions_data_flat
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         42                   England
# 16              37          4                   England
# 17              43          3             International
# 18              11         42                     Spain
# 19              11          4                     Spain
# 20              11          1                     Spain
# 21              11          2                     Spain
# 22              11         27                     Spain
# 23              11         26                     Spain
# 24              11         25                     Spain
# 25              11         24                     Spain
# 26              11         23                     Spain
# 27              11         22                     Spain
# 28              11         21                     Spain
# 29              11         41                     Spain
# 30              11         40                     Spain
# 31              11         39                     Spain
# 32              11         38                     Spain
# 33              11         37                     Spain
# 34              49          3  United States of America
# 35               2         44                   England
# 36              72         30             International
#
#            competition_name competition_gender season_name  \
# 0          Champions League               male   2018/2019
# 1          Champions League               male   2017/2018
# 2          Champions League               male   2016/2017
# 3          Champions League               male   2015/2016
# 4          Champions League               male   2014/2015
# 5          Champions League               male   2013/2014
# 6          Champions League               male   2012/2013
# 7          Champions League               male   2011/2012
# 8          Champions League               male   2010/2011
# 9          Champions League               male   2009/2010
# 10         Champions League               male   2008/2009
# 11         Champions League               male   2006/2007
# 12         Champions League               male   2004/2005
# 13         Champions League               male   2003/2004
# 14         Champions League               male   1999/2000
# 15  FA Women's Super League             female   2019/2020
# 16  FA Women's Super League             female   2018/2019
# 17           FIFA World Cup               male        2018
# 18                  La Liga               male   2019/2020
# 19                  La Liga               male   2018/2019
# 20                  La Liga               male   2017/2018
# 21                  La Liga               male   2016/2017
# 22                  La Liga               male   2015/2016
# 23                  La Liga               male   2014/2015
# 24                  La Liga               male   2013/2014
# 25                  La Liga               male   2012/2013
# 26                  La Liga               male   2011/2012
# 27                  La Liga               male   2010/2011
# 28                  La Liga               male   2009/2010
# 29                  La Liga               male   2008/2009
# 30                  La Liga               male   2007/2008
# 31                  La Liga               male   2006/2007
# 32                  La Liga               male   2005/2006
# 33                  La Liga               male   2004/2005
# 34                     NWSL             female        2018
# 35           Premier League               male   2003/2004
# 36        Women's World Cup             female        2019
#
#                  match_updated             match_available
# 0             2020-07-29T05:00            2020-07-29T05:00
# 1             2020-07-29T05:00            2020-07-29T05:00
# 2   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 3   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 4   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 5   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 6   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 7   2020-08-26T12:33:15.869622            2020-07-29T05:00
# 8             2020-07-29T05:00            2020-07-29T05:00
# 9             2020-07-29T05:00            2020-07-29T05:00
# 10  2020-08-30T10:18:39.435424  2020-08-30T10:18:39.435424
# 11            2020-07-29T05:00            2020-07-29T05:00
# 12            2020-07-29T05:00            2020-07-29T05:00
# 13  2020-08-30T10:18:39.435424  2020-08-30T10:18:39.435424
# 14            2020-07-29T05:00            2020-07-29T05:00
# 15  2020-09-30T14:59:21.257704  2020-09-30T14:59:21.257704
# 16  2020-08-24T14:34:34.401523  2020-08-24T14:34:34.401523
# 17            2020-07-29T05:00            2020-07-29T05:00
# 18  2020-10-11T20:05:57.703730  2020-10-11T20:05:57.703730
# 19            2020-07-29T05:00            2020-07-29T05:00
# 20            2020-07-29T05:00            2020-07-29T05:00
# 21  2020-10-09T04:20:42.205355  2020-10-09T04:20:42.205355
# 22            2020-07-29T05:00            2020-07-29T05:00
# 23            2020-07-29T05:00            2020-07-29T05:00
# 24            2020-07-29T05:00            2020-07-29T05:00
# 25            2020-07-29T05:00            2020-07-29T05:00
# 26            2020-07-29T05:00            2020-07-29T05:00
# 27            2020-07-29T05:00            2020-07-29T05:00
# 28            2020-07-29T05:00            2020-07-29T05:00
# 29            2020-07-29T05:00            2020-07-29T05:00
# 30            2020-07-29T05:00            2020-07-29T05:00
# 31            2020-07-29T05:00            2020-07-29T05:00
# 32            2020-07-29T05:00            2020-07-29T05:00
# 33            2020-07-29T05:00            2020-07-29T05:00
# 34            2020-07-29T05:00            2020-07-29T05:00
# 35  2020-08-31T20:40:28.969635  2020-08-31T20:40:28.969635
# 36            2020-07-29T05:00            2020-07-29T05:00

# %% [markdown]
# ##### Streamline the DataFrame

# %%
df_sb_competitions_data_flat.columns
# Out:
# Index(['competition_id', 'season_id', 'country_name', 'competition_name',
#        'competition_gender', 'season_name', 'match_updated',
#        'match_available'],
#       dtype='object')

# %%
# Select columns of interest
cols_competitions = ['competition_id', 'season_id', 'country_name', 'competition_name', 'competition_gender', 'season_name']
                     
# Create more concise DataFrame using only columns of interest
df_sb_competitions_data_flat_select = df_sb_competitions_data_flat[cols_competitions]

# Export DataFrame
df_sb_competitions_data_flat_select.to_csv(data_dir_sb + '/competitions/raw/csv/competitions_select.csv', index=None, header=True)

# %%
df_sb_competitions_data_flat_select
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         42                   England
# 16              37          4                   England
# 17              43          3             International
# 18              11         42                     Spain
# 19              11          4                     Spain
# 20              11          1                     Spain
# 21              11          2                     Spain
# 22              11         27                     Spain
# 23              11         26                     Spain
# 24              11         25                     Spain
# 25              11         24                     Spain
# 26              11         23                     Spain
# 27              11         22                     Spain
# 28              11         21                     Spain
# 29              11         41                     Spain
# 30              11         40                     Spain
# 31              11         39                     Spain
# 32              11         38                     Spain
# 33              11         37                     Spain
# 34              49          3  United States of America
# 35               2         44                   England
# 36              72         30             International
#
#            competition_name competition_gender season_name
# 0          Champions League               male   2018/2019
# 1          Champions League               male   2017/2018
# 2          Champions League               male   2016/2017
# 3          Champions League               male   2015/2016
# 4          Champions League               male   2014/2015
# 5          Champions League               male   2013/2014
# 6          Champions League               male   2012/2013
# 7          Champions League               male   2011/2012
# 8          Champions League               male   2010/2011
# 9          Champions League               male   2009/2010
# 10         Champions League               male   2008/2009
# 11         Champions League               male   2006/2007
# 12         Champions League               male   2004/2005
# 13         Champions League               male   2003/2004
# 14         Champions League               male   1999/2000
# 15  FA Women's Super League             female   2019/2020
# 16  FA Women's Super League             female   2018/2019
# 17           FIFA World Cup               male        2018
# 18                  La Liga               male   2019/2020
# 19                  La Liga               male   2018/2019
# 20                  La Liga               male   2017/2018
# 21                  La Liga               male   2016/2017
# 22                  La Liga               male   2015/2016
# 23                  La Liga               male   2014/2015
# 24                  La Liga               male   2013/2014
# 25                  La Liga               male   2012/2013
# 26                  La Liga               male   2011/2012
# 27                  La Liga               male   2010/2011
# 28                  La Liga               male   2009/2010
# 29                  La Liga               male   2008/2009
# 30                  La Liga               male   2007/2008
# 31                  La Liga               male   2006/2007
# 32                  La Liga               male   2005/2006
# 33                  La Liga               male   2004/2005
# 34                     NWSL             female        2018
# 35           Premier League               male   2003/2004
# 36        Women's World Cup             female        2019

# %% [markdown]
# ##### Identify FA Women's Super League Competitions

# %%
df_sb_competitions_data_flat_wsl = df_sb_competitions_data_flat_select.loc[df_sb_competitions_data_flat['competition_name'] == 'FA Women\'s Super League']

# %%
df_sb_competitions_data_flat_wsl
# Out:
#     competition_id  season_id country_name         competition_name  \
# 15              37         42      England  FA Women's Super League
# 16              37          4      England  FA Women's Super League
#
#    competition_gender season_name
# 15             female   2019/2020
# 16             female   2018/2019

# %% [markdown]
# ##### Identify Competitions of Interest by ID

# %%
# FA Women's Super League has competition ID 37
competition_id = 37

# %% [markdown]
# For our analysis, we want just the Women's Super League which are the following competition IDs:
# *    2018/2019 - `season_id`: 4
# *    2019/2020 - `season_id`: 42

# %% [markdown]
# #### <a id='#section3.3.2.'>3.3.2. Matches</a>

# %% [markdown]
# ##### Data Dictionary

# %% [markdown]
# ##### Import Data

# %%
# Show files in directory
print(glob.glob(data_dir_sb + '/matches/raw/json/' + str(competition_id) + '/*json'))
# Out:
# ['../../data/sb/matches/raw/json/37/90.json', '../../data/sb/matches/raw/json/37/4.json', '../../data/sb/matches/raw/json/37/42.json']

# %%
# REWRITE THE STEP BELOW TO APPEND ALL JSON FILES TO ONE PANDAS DATAFRAME

# %%
# Import all StatsBomb JSON Match data for the WSL

## WSL - 18/19
with open(data_dir_sb + '/matches/raw/json/' + str(competition_id) + '/4.json') as f:
    json_sb_match_data_wsl_1819 = json.load(f)
          
## WSL - 19/20
with open(data_dir_sb + '/matches/raw/json/' + str(competition_id) + '/42.json') as f:
    json_sb_match_data_wsl_1920 = json.load(f)
    
## WSL - 20/21
with open(data_dir_sb + '/matches/raw/json/' + str(competition_id) + '/90.json') as f:
    json_sb_match_data_wsl_2021 = json.load(f)

# %% [markdown]
# ##### Inspect 19/20 season JSON

# %%
json_sb_match_data_wsl_1819
# Out:
# [{'match_id': 19743,
#   'match_date': '2018-10-21',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 898, 'name': 'A. Fearn'}},
#  {'match_id': 19740,
#   'match_date': '2018-10-21',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 153,
#      'name': 'Chris Kirkland',
#      'nickname': None,
#      'dob': '1981-05-02',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 568,
#    'name': 'J. Packman',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 19716,
#   'match_date': '2018-09-09',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 970,
#    'away_team_name': 'Yeovil Town LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 4,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 1,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 19800,
#   'match_date': '2019-03-14',
#   'kick_off': '20:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 4,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-08-24T14:34:34.401523',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 18,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 915, 'name': 'R. Whitton'}},
#  {'match_id': 19739,
#   'match_date': '2018-10-21',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 6,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 19734,
#   'match_date': '2018-10-14',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 146,
#      'name': 'Andy Spence',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 5,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 906, 'name': 'S. Copeland'}},
#  {'match_id': 19748,
#   'match_date': '2018-10-28',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 19822,
#   'match_date': '2019-05-11',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 22,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 19766,
#   'match_date': '2018-11-25',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 4,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 915, 'name': 'R. Whitton'}},
#  {'match_id': 19785,
#   'match_date': '2019-01-13',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 977, 'name': 'R. Welch '}},
#  {'match_id': 19749,
#   'match_date': '2018-11-04',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 977, 'name': 'R. Welch '}},
#  {'match_id': 19751,
#   'match_date': '2018-11-04',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 897, 'name': 'P. Howard'}},
#  {'match_id': 19764,
#   'match_date': '2018-11-25',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 917, 'name': 'L. Sandoe'}},
#  {'match_id': 19773,
#   'match_date': '2018-12-02',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 919, 'name': 'S. Mather'}},
#  {'match_id': 19783,
#   'match_date': '2019-01-06',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 3,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 13,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 925, 'name': 'L. Brennan'}},
#  {'match_id': 19736,
#   'match_date': '2018-10-14',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 5,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 5,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 905, 'name': 'S. Purkiss'}},
#  {'match_id': 19747,
#   'match_date': '2018-10-26',
#   'kick_off': '20:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 902, 'name': 'D. McNamara'}},
#  {'match_id': 19787,
#   'match_date': '2019-01-13',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 928, 'name': 'L. Benn'}},
#  {'match_id': 19771,
#   'match_date': '2018-12-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 970,
#    'away_team_name': 'Yeovil Town LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 918, 'name': 'J. Simms'}},
#  {'match_id': 19769,
#   'match_date': '2018-12-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4494,
#    'name': "The People's Pension Stadium",
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 19770,
#   'match_date': '2018-12-02',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 895, 'name': 'A. Marriott'}},
#  {'match_id': 19765,
#   'match_date': '2018-11-25',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 916, 'name': 'S. Mulhall'}},
#  {'match_id': 19757,
#   'match_date': '2019-02-10',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 973,
#    'home_team_name': 'Bristol City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 16,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4055,
#    'name': 'Stoke Gifford Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 831, 'name': 'S. Garratt'}},
#  {'match_id': 19742,
#   'match_date': '2018-10-21',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 1,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 896, 'name': 'S. Jackson'}},
#  {'match_id': 19777,
#   'match_date': '2018-12-09',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 5,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 922, 'name': 'M. Russell'}},
#  {'match_id': 19758,
#   'match_date': '2019-04-17',
#   'kick_off': '20:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 5,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 16,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 896, 'name': 'S. Jackson'}},
#  {'match_id': 19802,
#   'match_date': '2019-03-13',
#   'kick_off': '20:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 970,
#    'home_team_name': 'Yeovil Town LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 18,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4847,
#    'name': 'Clayson Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 924, 'name': 'J. Durkin'}},
#  {'match_id': 19803,
#   'match_date': '2019-03-13',
#   'kick_off': '20:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 18,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 935, 'name': 'D. Skipper'}},
#  {'match_id': 19746,
#   'match_date': '2018-10-28',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 146,
#      'name': 'Andy Spence',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 908, 'name': 'A. Jackson'}},
#  {'match_id': 19733,
#   'match_date': '2018-09-30',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 901, 'name': 'W. Cartmel'}},
#  {'match_id': 19811,
#   'match_date': '2019-04-21',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 20,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 19805,
#   'match_date': '2019-03-31',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 19,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 19745,
#   'match_date': '2018-10-28',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 970,
#    'away_team_name': 'Yeovil Town LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 19752,
#   'match_date': '2018-11-04',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 909, 'name': 'T. Parsons'}},
#  {'match_id': 19772,
#   'match_date': '2018-12-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 894, 'name': 'L. Oliver'}},
#  {'match_id': 19775,
#   'match_date': '2018-12-09',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 921, 'name': 'J. Smith'}},
#  {'match_id': 19760,
#   'match_date': '2018-11-18',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 970,
#    'away_team_name': 'Yeovil Town LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
# ...
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 21,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 203,
#    'name': 'The American Express Community Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 894, 'name': 'L. Oliver'}},
#  {'match_id': 19817,
#   'match_date': '2019-04-28',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 21,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 19818,
#   'match_date': '2019-04-28',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 970,
#    'away_team_name': 'Yeovil Town LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 147,
#      'name': 'Lee Burch',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 21,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 19819,
#   'match_date': '2019-05-11',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 22,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 19821,
#   'match_date': '2019-05-11',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 22,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 19801,
#   'match_date': '2019-03-13',
#   'kick_off': '20:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 18,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 934, 'name': 'T. Reeves'}},
#  {'match_id': 19741,
#   'match_date': '2018-10-21',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 6,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 895, 'name': 'A. Marriott'}},
#  {'match_id': 19778,
#   'match_date': '2018-12-09',
#   'kick_off': '13:15:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 128,
#      'name': 'Marc Skinner',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 977, 'name': 'R. Welch '}},
#  {'match_id': 19756,
#   'match_date': '2019-04-17',
#   'kick_off': '20:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 16,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 978, 'name': 'P. Clarke'}},
#  {'match_id': 19754,
#   'match_date': '2019-03-24',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 1,
#   'away_score': 5,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 16,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 19724,
#   'match_date': '2018-09-23',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 4,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.0.3'},
#   'match_week': 3,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 897, 'name': 'P. Howard'}},
#  {'match_id': 19814,
#   'match_date': '2019-04-28',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 973,
#    'home_team_name': 'Bristol City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2'},
#   'match_week': 21,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4055,
#    'name': 'Stoke Gifford Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 842, 'name': 'R. Hulme'}},
#  {'match_id': 19729,
#   'match_date': '2019-03-24',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 4, 'season_name': '2018/2019'},
#   'home_team': {'home_team_id': 973,
#    'home_team_name': 'Bristol City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4055,
#    'name': 'Stoke Gifford Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}}]

# %%
json_sb_match_data_wsl_1920
# Out:
# [{'match_id': 2275054,
#   'match_date': '2020-01-05',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 2275072,
#   'match_date': '2020-01-05',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 2275085,
#   'match_date': '2020-01-05',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 749,
#    'home_team_name': 'Tottenham Hotspur Women',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 122,
#    'name': 'The Hive Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 2275113,
#   'match_date': '2020-01-19',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 13,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 912, 'name': 'Ryan Atkin'}},
#  {'match_id': 2275142,
#   'match_date': '2020-01-05',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 1475,
#    'home_team_name': 'Manchester United',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 2926,
#      'name': 'Casey Stoney',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4979,
#    'name': 'Leigh Sports Village Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 894, 'name': 'L. Oliver'}},
#  {'match_id': 2275099,
#   'match_date': '2019-09-08',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1274, 'name': 'S. Barrott'}},
#  {'match_id': 2275057,
#   'match_date': '2020-02-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 8,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 898, 'name': 'A. Fearn'}},
#  {'match_id': 2275075,
#   'match_date': '2019-12-15',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 749,
#    'away_team_name': 'Tottenham Hotspur Women',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 2275092,
#   'match_date': '2020-01-19',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 13,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 2275077,
#   'match_date': '2020-01-12',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 749,
#    'home_team_name': 'Tottenham Hotspur Women',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 122,
#    'name': 'The Hive Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 894, 'name': 'L. Oliver'}},
#  {'match_id': 2275036,
#   'match_date': '2020-01-19',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-08-17T00:16:15.196468',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 13,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4054,
#    'name': 'Select Security Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1720, 'name': 'P. Shacklady'}},
#  {'match_id': 2275117,
#   'match_date': '2019-12-15',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1624, 'name': 'B. Speedie'}},
#  {'match_id': 2275040,
#   'match_date': '2019-10-13',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 972,
#    'away_team_name': 'West Ham United LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4494,
#    'name': "The People's Pension Stadium",
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 928, 'name': 'L. Benn'}},
#  {'match_id': 2275045,
#   'match_date': '2019-12-15',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1710, 'name': 'L. Saunders'}},
#  {'match_id': 2275093,
#   'match_date': '2019-11-24',
#   'kick_off': '15:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 6,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 2275153,
#   'match_date': '2020-02-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 1475,
#    'away_team_name': 'Manchester United',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 2926,
#      'name': 'Casey Stoney',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 2275097,
#   'match_date': '2019-12-15',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 5,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 10,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 894, 'name': 'L. Oliver'}},
#  {'match_id': 2275122,
#   'match_date': '2019-11-17',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 3,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 223,
#    'name': 'Madejski Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 2275084,
#   'match_date': '2019-10-27',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 5,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 915, 'name': 'R. Whitton'}},
#  {'match_id': 2275089,
#   'match_date': '2020-01-05',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 11,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 926, 'name': 'E. Simms'}},
#  {'match_id': 2275116,
#   'match_date': '2019-12-01',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 2275127,
#   'match_date': '2019-10-13',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 3,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1509, 'name': 'A. Dale'}},
#  {'match_id': 2275104,
#   'match_date': '2019-12-01',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 968,
#    'home_team_name': 'Arsenal WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 11,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 456,
#    'name': 'Meadow Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 2275052,
#   'match_date': '2019-09-15',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 971,
#    'away_team_name': 'Chelsea FCW',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4494,
#    'name': "The People's Pension Stadium",
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 34,
#    'name': 'L. Collins',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 2275037,
#   'match_date': '2020-02-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 2,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 2275027,
#   'match_date': '2020-02-02',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 14,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'referee': {'id': 937, 'name': 'A. Bryne'}},
#  {'match_id': 2275078,
#   'match_date': '2020-01-11',
#   'kick_off': '18:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 898, 'name': 'A. Fearn'}},
#  {'match_id': 2275080,
#   'match_date': '2020-01-12',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 6,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1711, 'name': 'E. Heaslip'}},
#  {'match_id': 2275098,
#   'match_date': '2020-01-12',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'home_score': 0,
#   'away_score': 4,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 12,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'}},
#  {'match_id': 2275156,
#   'match_date': '2019-09-16',
#   'kick_off': '20:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 1475,
#    'home_team_name': 'Manchester United',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 2926,
#      'name': 'Casey Stoney',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 2,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4979,
#    'name': 'Leigh Sports Village Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 937, 'name': 'A. Bryne'}},
#  {'match_id': 2275028,
#   'match_date': '2019-10-12',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 746,
#    'home_team_name': 'Manchester City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 30,
#      'name': 'Nick Cushing',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 3,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 99,
#    'name': 'Academy Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 567,
#    'name': 'H. Conley',
#    'country': {'id': 68, 'name': 'England'}}},
#  {'match_id': 2275120,
#   'match_date': '2019-09-08',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 1275, 'name': 'E. Swallow'}},
#  {'match_id': 2275150,
#   'match_date': '2019-12-01',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'away_team': {'away_team_id': 1475,
#    'away_team_name': 'Manchester United',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'home_score': 3,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 898, 'name': 'A. Fearn'}},
#  {'match_id': 2275139,
#   'match_date': '2019-10-13',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 749,
#    'home_team_name': 'Tottenham Hotspur Women',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 1475,
#    'away_team_name': 'Manchester United',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 2926,
#      'name': 'Casey Stoney',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 122,
#    'name': 'The Hive Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 914, 'name': 'K. Dowle'}},
#  {'match_id': 2275070,
#   'match_date': '2019-10-13',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 4,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 579,
#    'name': 'Prenton Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1512, 'name': 'M. Woods'}},
#  {'match_id': 2275051,
#   'match_date': '2019-10-27',
#   'kick_off': '13:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 967,
#    'home_team_name': 'Everton LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
# ...
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'away_team': {'away_team_id': 749,
#    'away_team_name': 'Tottenham Hotspur Women',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 7,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 111,
#    'name': 'Haig Avenue',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1689, 'name': 'M. Barlow'}},
#  {'match_id': 2275102,
#   'match_date': '2019-11-29',
#   'kick_off': '20:45:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 974,
#    'away_team_name': 'Reading WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 2,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4494,
#    'name': "The People's Pension Stadium",
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 922, 'name': 'M. Russell'}},
#  {'match_id': 2275109,
#   'match_date': '2019-12-04',
#   'kick_off': '20:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'away_team': {'away_team_id': 749,
#    'away_team_name': 'Tottenham Hotspur Women',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 8,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 918, 'name': 'J. Simms'}},
#  {'match_id': 2275088,
#   'match_date': '2019-12-08',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 973,
#    'home_team_name': 'Bristol City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 9,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4055,
#    'name': 'Stoke Gifford Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 904, 'name': 'S. Allison'}},
#  {'match_id': 2275091,
#   'match_date': '2019-12-08',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 749,
#    'home_team_name': 'Tottenham Hotspur Women',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 965,
#    'away_team_name': 'Brighton & Hove Albion WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 1,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 9,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 122,
#    'name': 'The Hive Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 1711, 'name': 'E. Heaslip'}},
#  {'match_id': 2275030,
#   'match_date': '2020-02-23',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 965,
#    'home_team_name': 'Brighton & Hove Albion WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 149,
#      'name': 'Hope Patricia Powell',
#      'nickname': 'Hope Powell',
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 749,
#    'away_team_name': 'Tottenham Hotspur Women',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 17,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'referee': {'id': 1710, 'name': 'L. Saunders'}},
#  {'match_id': 2275133,
#   'match_date': '2020-02-23',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 972,
#    'home_team_name': 'West Ham United LFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 139,
#      'name': 'Matt Beard',
#      'nickname': None,
#      'dob': '1978-01-09',
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 966,
#    'away_team_name': 'Liverpool WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 4,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 17,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4062,
#    'name': 'The Rush Green Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 922, 'name': 'M. Russell'}},
#  {'match_id': 2275083,
#   'match_date': '2020-02-23',
#   'kick_off': '15:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 969,
#    'home_team_name': 'Birmingham City WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'away_team': {'away_team_id': 973,
#    'away_team_name': 'Bristol City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 143,
#      'name': 'Tanya Oxtoby',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 17,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 5332,
#    'name': 'SportNation.bet Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 893, 'name': 'S. Pearson'}},
#  {'match_id': 2275086,
#   'match_date': '2019-12-08',
#   'kick_off': '15:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 974,
#    'home_team_name': 'Reading WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 144,
#      'name': 'Kelly Chambers',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 968,
#    'away_team_name': 'Arsenal WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 31,
#      'name': 'Joseph Montemurro',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 14, 'name': 'Australia'}}]},
#   'home_score': 0,
#   'away_score': 3,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 9,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 577,
#    'name': 'Adams Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 842, 'name': 'R. Hulme'}},
#  {'match_id': 2275137,
#   'match_date': '2020-01-19',
#   'kick_off': '13:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 1475,
#    'home_team_name': 'Manchester United',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 2926,
#      'name': 'Casey Stoney',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 749,
#    'away_team_name': 'Tottenham Hotspur Women',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 791,
#      'name': 'Karen Hills',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'home_score': 3,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 13,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4979,
#    'name': 'Leigh Sports Village Stadium',
#    'country': {'id': 255, 'name': 'International'}},
#   'referee': {'id': 1721, 'name': 'E. Duckworth'}},
#  {'match_id': 2275056,
#   'match_date': '2019-11-17',
#   'kick_off': '16:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 966,
#    'home_team_name': 'Liverpool WFC',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 623,
#      'name': 'Victoria Jepson',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 967,
#    'away_team_name': 'Everton LFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 639,
#      'name': 'Willie Kirk',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 201, 'name': 'Scotland'}}]},
#   'home_score': 0,
#   'away_score': 1,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 6,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 6,
#    'name': 'Anfield',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 898, 'name': 'A. Fearn'}},
#  {'match_id': 2275074,
#   'match_date': '2020-02-12',
#   'kick_off': '20:00:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 42, 'season_name': '2019/2020'},
#   'home_team': {'home_team_id': 971,
#    'home_team_name': 'Chelsea FCW',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 152,
#      'name': 'Emma Hayes',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 68, 'name': 'England'}}]},
#   'away_team': {'away_team_id': 969,
#    'away_team_name': 'Birmingham City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'},
#    'managers': [{'id': 1817,
#      'name': 'Marta Tejedor',
#      'nickname': None,
#      'dob': None,
#      'country': {'id': 45, 'name': 'Chile'}}]},
#   'home_score': 2,
#   'away_score': 0,
#   'match_status': 'available',
#   'last_updated': '2020-07-29T05:00',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 16,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 4279,
#    'name': 'The Cherry Red Records Stadium',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 915, 'name': 'R. Whitton'}}]

# %%
json_sb_match_data_wsl_2021
# Out:
# [{'match_id': 3764234,
#   'match_date': '2020-09-05',
#   'kick_off': '15:30:00.000',
#   'competition': {'competition_id': 37,
#    'country_name': 'England',
#    'competition_name': "FA Women's Super League"},
#   'season': {'season_id': 90, 'season_name': '2020/2021'},
#   'home_team': {'home_team_id': 2647,
#    'home_team_name': 'Aston Villa',
#    'home_team_gender': 'female',
#    'home_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'away_team': {'away_team_id': 746,
#    'away_team_name': 'Manchester City WFC',
#    'away_team_gender': 'female',
#    'away_team_group': None,
#    'country': {'id': 68, 'name': 'England'}},
#   'home_score': 0,
#   'away_score': 2,
#   'match_status': 'available',
#   'last_updated': '2020-09-06T19:03:37.632953',
#   'metadata': {'data_version': '1.1.0',
#    'shot_fidelity_version': '2',
#    'xy_fidelity_version': '2'},
#   'match_week': 1,
#   'competition_stage': {'id': 1, 'name': 'Regular Season'},
#   'stadium': {'id': 211,
#    'name': 'Villa Park',
#    'country': {'id': 68, 'name': 'England'}},
#   'referee': {'id': 937, 'name': 'A. Bryne'}}]

# %% [markdown]
# Inspect matches

# %%
# See the first match in the dataset
json_sb_match_data_wsl_1920[0]
# Out:
# {'match_id': 2275054,
#  'match_date': '2020-01-05',
#  'kick_off': '15:00:00.000',
#  'competition': {'competition_id': 37,
#   'country_name': 'England',
#   'competition_name': "FA Women's Super League"},
#  'season': {'season_id': 42, 'season_name': '2019/2020'},
#  'home_team': {'home_team_id': 965,
#   'home_team_name': 'Brighton & Hove Albion WFC',
#   'home_team_gender': 'female',
#   'home_team_group': None,
#   'country': {'id': 68, 'name': 'England'}},
#  'away_team': {'away_team_id': 966,
#   'away_team_name': 'Liverpool WFC',
#   'away_team_gender': 'female',
#   'away_team_group': None,
#   'country': {'id': 68, 'name': 'England'}},
#  'home_score': 1,
#  'away_score': 0,
#  'match_status': 'available',
#  'last_updated': '2020-07-29T05:00',
#  'metadata': {'data_version': '1.1.0',
#   'shot_fidelity_version': '2',
#   'xy_fidelity_version': '2'},
#  'match_week': 11,
#  'competition_stage': {'id': 1, 'name': 'Regular Season'}}

# %%
# See the away team for the first match in the dataset
json_sb_match_data_wsl_1920[0]['away_team']
# Out:
# {'away_team_id': 966,
#  'away_team_name': 'Liverpool WFC',
#  'away_team_gender': 'female',
#  'away_team_group': None,
#  'country': {'id': 68, 'name': 'England'}}

# %%
# See the away team name for the first match in the dataset
json_sb_match_data_wsl_1920[0]['away_team']['away_team_name']
# Out:
# 'Liverpool WFC'

# %% [markdown]
# Print out the result list for the FA Women's Super League

# %%
# Print all the match results
for match in json_sb_match_data_wsl_1920:
    home_team_name = match['home_team']['home_team_name']
    away_team_name = match['away_team']['away_team_name']
    home_score = match['home_score']
    away_score = match['away_score']
    describe_text = f"The match between {home_team_name} and {away_team_name}"
    result_text = f" finished {home_score} : {away_score}"
    print(describe_text + result_text)
# Out:
# The match between Brighton & Hove Albion WFC and Liverpool WFC finished 1 : 0
# The match between Chelsea FCW and Reading WFC finished 3 : 1
# The match between Tottenham Hotspur Women and Manchester City WFC finished 1 : 4
# The match between West Ham United LFC and Brighton & Hove Albion WFC finished 2 : 1
# The match between Manchester United and Bristol City WFC finished 0 : 1
# The match between Liverpool WFC and Reading WFC finished 0 : 1
# The match between Chelsea FCW and West Ham United LFC finished 8 : 0
# The match between Reading WFC and Tottenham Hotspur Women finished 3 : 1
# The match between Birmingham City WFC and Manchester City WFC finished 0 : 2
# The match between Tottenham Hotspur Women and West Ham United LFC finished 2 : 1
# The match between Everton LFC and Reading WFC finished 3 : 1
# The match between Everton LFC and Arsenal WFC finished 1 : 3
# The match between Brighton & Hove Albion WFC and West Ham United LFC finished 1 : 3
# The match between Liverpool WFC and Chelsea FCW finished 1 : 1
# The match between Birmingham City WFC and Chelsea FCW finished 0 : 6
# The match between Reading WFC and Manchester United finished 1 : 1
# The match between Manchester City WFC and Brighton & Hove Albion WFC finished 5 : 0
# The match between Reading WFC and Bristol City WFC finished 3 : 3
# The match between West Ham United LFC and Chelsea FCW finished 1 : 3
# The match between Arsenal WFC and Birmingham City WFC finished 2 : 0
# The match between Manchester City WFC and Liverpool WFC finished 1 : 0
# The match between Reading WFC and Everton LFC finished 3 : 2
# The match between Arsenal WFC and Bristol City WFC finished 11 : 1
# The match between Brighton & Hove Albion WFC and Chelsea FCW finished 1 : 1
# The match between Manchester City WFC and Arsenal WFC finished 2 : 1
# The match between Brighton & Hove Albion WFC and Everton LFC finished 1 : 0
# The match between Manchester City WFC and Everton LFC finished 3 : 1
# The match between Chelsea FCW and Bristol City WFC finished 6 : 1
# The match between Brighton & Hove Albion WFC and Arsenal WFC finished 0 : 4
# The match between Manchester United and Arsenal WFC finished 0 : 1
# The match between Manchester City WFC and Birmingham City WFC finished 3 : 0
# The match between Birmingham City WFC and Everton LFC finished 0 : 1
# The match between West Ham United LFC and Manchester United finished 3 : 2
# The match between Tottenham Hotspur Women and Manchester United finished 0 : 3
# The match between Liverpool WFC and Bristol City WFC finished 1 : 1
# The match between Everton LFC and Brighton & Hove Albion WFC finished 2 : 0
# The match between Chelsea FCW and Arsenal WFC finished 2 : 1
# The match between Reading WFC and Birmingham City WFC finished 1 : 0
# The match between Bristol City WFC and Liverpool WFC finished 0 : 1
# The match between Arsenal WFC and Chelsea FCW finished 1 : 4
# The match between Manchester City WFC and West Ham United LFC finished 5 : 0
# The match between Bristol City WFC and Chelsea FCW finished 0 : 4
# The match between Tottenham Hotspur Women and Arsenal WFC finished 0 : 2
# The match between Manchester United and Liverpool WFC finished 2 : 0
# The match between West Ham United LFC and Reading WFC finished 2 : 3
# The match between Chelsea FCW and Tottenham Hotspur Women finished 1 : 0
# The match between Manchester United and Everton LFC finished 3 : 1
# The match between Bristol City WFC and Brighton & Hove Albion WFC finished 0 : 0
# The match between Manchester City WFC and Manchester United finished 1 : 0
# The match between Arsenal WFC and West Ham United LFC finished 2 : 1
# The match between Bristol City WFC and Tottenham Hotspur Women finished 1 : 2
# The match between Reading WFC and Manchester City WFC finished 0 : 2
# The match between Chelsea FCW and Manchester City WFC finished 2 : 1
# The match between Tottenham Hotspur Women and Liverpool WFC finished 1 : 0
# The match between Bristol City WFC and Manchester City WFC finished 0 : 5
# The match between West Ham United LFC and Birmingham City WFC finished 1 : 0
# The match between Everton LFC and Bristol City WFC finished 2 : 0
# The match between Arsenal WFC and Manchester City WFC finished 1 : 0
# The match between Manchester United and Reading WFC finished 2 : 0
# The match between Manchester City WFC and Bristol City WFC finished 1 : 0
# The match between Everton LFC and Manchester United finished 2 : 3
# The match between Manchester City WFC and Chelsea FCW finished 3 : 3
# The match between Tottenham Hotspur Women and Everton LFC finished 2 : 2
# The match between Reading WFC and West Ham United LFC finished 2 : 0
# The match between Birmingham City WFC and Liverpool WFC finished 2 : 0
# The match between Everton LFC and Manchester City WFC finished 0 : 1
# The match between Liverpool WFC and Arsenal WFC finished 2 : 3
# The match between West Ham United LFC and Tottenham Hotspur Women finished 0 : 2
# The match between Arsenal WFC and Brighton & Hove Albion WFC finished 4 : 0
# The match between Brighton & Hove Albion WFC and Manchester United finished 1 : 1
# The match between Chelsea FCW and Manchester United finished 1 : 0
# The match between Brighton & Hove Albion WFC and Birmingham City WFC finished 3 : 0
# The match between Arsenal WFC and Liverpool WFC finished 1 : 0
# The match between Manchester United and Brighton & Hove Albion WFC finished 4 : 0
# The match between Liverpool WFC and West Ham United LFC finished 1 : 1
# The match between Everton LFC and Tottenham Hotspur Women finished 3 : 1
# The match between Brighton & Hove Albion WFC and Reading WFC finished 2 : 2
# The match between Birmingham City WFC and Tottenham Hotspur Women finished 1 : 1
# The match between Bristol City WFC and Birmingham City WFC finished 0 : 2
# The match between Tottenham Hotspur Women and Brighton & Hove Albion WFC finished 1 : 0
# The match between Brighton & Hove Albion WFC and Tottenham Hotspur Women finished 0 : 1
# The match between West Ham United LFC and Liverpool WFC finished 4 : 2
# The match between Birmingham City WFC and Bristol City WFC finished 0 : 1
# The match between Reading WFC and Arsenal WFC finished 0 : 3
# The match between Manchester United and Tottenham Hotspur Women finished 3 : 0
# The match between Liverpool WFC and Everton LFC finished 0 : 1
# The match between Chelsea FCW and Birmingham City WFC finished 2 : 0

# %% [markdown]
# Code to show just Manchester City WFC's results in the World Cup

# %%
# Print match results involving Manchester City WFC
for match in json_sb_match_data_wsl_1920:
    home_team_name = match['home_team']['home_team_name']
    away_team_name = match['away_team']['away_team_name']
    if home_team_name == 'Manchester City WFC' or away_team_name == 'Manchester City WFC':
        home_score = match['home_score']
        away_score = match['away_score']
        describe_text = 'The match between ' + home_team_name + ' and ' + away_team_name
        result_text = ' finished ' + str(home_score) +  ' : ' + str(away_score)
        print(describe_text + result_text)
# Out:
# The match between Tottenham Hotspur Women and Manchester City WFC finished 1 : 4
# The match between Birmingham City WFC and Manchester City WFC finished 0 : 2
# The match between Manchester City WFC and Brighton & Hove Albion WFC finished 5 : 0
# The match between Manchester City WFC and Liverpool WFC finished 1 : 0
# The match between Manchester City WFC and Arsenal WFC finished 2 : 1
# The match between Manchester City WFC and Everton LFC finished 3 : 1
# The match between Manchester City WFC and Birmingham City WFC finished 3 : 0
# The match between Manchester City WFC and West Ham United LFC finished 5 : 0
# The match between Manchester City WFC and Manchester United finished 1 : 0
# The match between Reading WFC and Manchester City WFC finished 0 : 2
# The match between Chelsea FCW and Manchester City WFC finished 2 : 1
# The match between Bristol City WFC and Manchester City WFC finished 0 : 5
# The match between Arsenal WFC and Manchester City WFC finished 1 : 0
# The match between Manchester City WFC and Bristol City WFC finished 1 : 0
# The match between Manchester City WFC and Chelsea FCW finished 3 : 3
# The match between Everton LFC and Manchester City WFC finished 0 : 1

# %% [markdown]
# Find the match ID for the game we are interested in - Manchester City WFC vs. Manchester United

# %%
# Now lets find the match we are interested in - Manchester City WFC vs. Manchester United
home_team_required = 'Manchester City WFC'
away_team_required = 'Manchester United'

# %%
# Find ID for the match we are interested in - Manchester City WFC vs. Manchester United
for match in json_sb_match_data_wsl_1920:
    home_team_name = match['home_team']['home_team_name']
    away_team_name = match['away_team']['away_team_name']
    if (home_team_name == home_team_required) and (away_team_name == away_team_required):
        match_id_required = match['match_id']
print(home_team_required + ' vs ' + away_team_required + ' has id: ' + str(match_id_required))
# Out:
# Manchester City WFC vs Manchester United has id: 2275136

# %% [markdown]
# ##### Flatten Matches data

# %%
# Flatten the JSON Events data for each of the Big 5 European leagues and export each DataFrame as a CSV file

## WSL - 18/19
df_sb_match_data_wsl_1819_flat = json_normalize(json_sb_match_data_wsl_1819)
df_sb_match_data_wsl_1819_flat.to_csv(data_dir_sb + '/matches/raw/csv/wsl/' + '/df_sb_match_data_wsl_1819_flat.csv', index=None, header=True)
    
## WSL - 19/20
df_sb_match_data_wsl_1920_flat = json_normalize(json_sb_match_data_wsl_1920)
df_sb_match_data_wsl_1920_flat.to_csv(data_dir_sb + '/matches/raw/csv/wsl/' + '/df_sb_match_data_wsl_1920_flat.csv', index=None, header=True)

## WSL - 18/19
df_sb_match_data_wsl_2021_flat = json_normalize(json_sb_match_data_wsl_2021)
df_sb_match_data_wsl_2021_flat.to_csv(data_dir_sb + '/matches/raw/csv/wsl/' + '/df_sb_match_data_wsl_2021_flat.csv', index=None, header=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':

# %%
df_sb_match_data_wsl_1819_flat
# Out:
#      match_id  match_date      kick_off  home_score  away_score match_status  \
# 0       19743  2018-10-21  13:30:00.000           0           0    available
# 1       19740  2018-10-21  16:00:00.000           0           1    available
# 2       19716  2018-09-09  15:00:00.000           4           0    available
# 3       19800  2019-03-14  20:30:00.000           4           0    available
# 4       19739  2018-10-21  15:00:00.000           0           6    available
# ..        ...         ...           ...         ...         ...          ...
# 102     19756  2019-04-17  20:00:00.000           1           3    available
# 103     19754  2019-03-24  13:30:00.000           1           5    available
# 104     19724  2018-09-23  15:00:00.000           4           3    available
# 105     19814  2019-04-28  16:00:00.000           1           2    available
# 106     19729  2019-03-24  16:00:00.000           1           0    available
#
#                    last_updated  match_week  competition.competition_id  \
# 0              2020-07-29T05:00           6                          37
# 1              2020-07-29T05:00           6                          37
# 2              2020-07-29T05:00           1                          37
# 3    2020-08-24T14:34:34.401523          18                          37
# 4              2020-07-29T05:00           6                          37
# ..                          ...         ...                         ...
# 102            2020-07-29T05:00          16                          37
# 103            2020-07-29T05:00          16                          37
# 104            2020-07-29T05:00           3                          37
# 105            2020-07-29T05:00          21                          37
# 106            2020-07-29T05:00           4                          37
#
#     competition.country_name competition.competition_name  season.season_id  \
# 0                    England      FA Women's Super League                 4
# 1                    England      FA Women's Super League                 4
# 2                    England      FA Women's Super League                 4
# 3                    England      FA Women's Super League                 4
# 4                    England      FA Women's Super League                 4
# ..                       ...                          ...               ...
# 102                  England      FA Women's Super League                 4
# 103                  England      FA Women's Super League                 4
# 104                  England      FA Women's Super League                 4
# 105                  England      FA Women's Super League                 4
# 106                  England      FA Women's Super League                 4
#
#     season.season_name  home_team.home_team_id    home_team.home_team_name  \
# 0            2018/2019                     969         Birmingham City WFC
# 1            2018/2019                     972         West Ham United LFC
# 2            2018/2019                     974                 Reading WFC
# 3            2018/2019                     968                 Arsenal WFC
# 4            2018/2019                     965  Brighton & Hove Albion WFC
# ..                 ...                     ...                         ...
# 102          2018/2019                     967                 Everton LFC
# 103          2018/2019                     966               Liverpool WFC
# 104          2018/2019                     968                 Arsenal WFC
# 105          2018/2019                     973            Bristol City WFC
# 106          2018/2019                     973            Bristol City WFC
#
#     home_team.home_team_gender home_team.home_team_group  \
# 0                       female                      None
# 1                       female                      None
# 2                       female                      None
# 3                       female                      None
# 4                       female                      None
# ..                         ...                       ...
# 102                     female                      None
# 103                     female                      None
# 104                     female                      None
# 105                     female                      None
# 106                     female                      None
#
#      home_team.country.id home_team.country.name  \
# 0                      68                England
# 1                      68                England
# 2                      68                England
# 3                      68                England
# 4                      68                England
# ..                    ...                    ...
# 102                    68                England
# 103                    68                England
# 104                    68                England
# 105                    68                England
# 106                    68                England
#
#                                     home_team.managers  \
# 0    [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1    [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 2    [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# 3    [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 4    [{'id': 149, 'name': 'Hope Patricia Powell', '...
# ..                                                 ...
# 102  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 103  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 104  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 105  [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...
# 106  [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...
#
#      away_team.away_team_id away_team.away_team_name  \
# 0                       971              Chelsea FCW
# 1                       966            Liverpool WFC
# 2                       970          Yeovil Town LFC
# 3                       973         Bristol City WFC
# 4                       746      Manchester City WFC
# ..                      ...                      ...
# 102                     969      Birmingham City WFC
# 103                     968              Arsenal WFC
# 104                     972      West Ham United LFC
# 105                     972      West Ham United LFC
# 106                     967              Everton LFC
#
#     away_team.away_team_gender away_team.away_team_group  \
# 0                       female                      None
# 1                       female                      None
# 2                       female                      None
# 3                       female                      None
# 4                       female                      None
# ..                         ...                       ...
# 102                     female                      None
# 103                     female                      None
# 104                     female                      None
# 105                     female                      None
# 106                     female                      None
#
#      away_team.country.id away_team.country.name  \
# 0                      68                England
# 1                      68                England
# 2                      68                England
# 3                      68                England
# 4                      68                England
# ..                    ...                    ...
# 102                    68                England
# 103                    68                England
# 104                    68                England
# 105                    68                England
# 106                    68                England
#
#                                     away_team.managers metadata.data_version  \
# 0    [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 1    [{'id': 153, 'name': 'Chris Kirkland', 'nickna...                 1.0.3
# 2    [{'id': 147, 'name': 'Lee Burch', 'nickname': ...                 1.0.3
# 3    [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...                 1.1.0
# 4    [{'id': 30, 'name': 'Nick Cushing', 'nickname'...                 1.0.3
# ..                                                 ...                   ...
# 102  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...                 1.1.0
# 103  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...                 1.1.0
# 104  [{'id': 139, 'name': 'Matt Beard', 'nickname':...                 1.0.3
# 105  [{'id': 139, 'name': 'Matt Beard', 'nickname':...                 1.1.0
# 106  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...                 1.1.0
#
#      competition_stage.id competition_stage.name  stadium.id  \
# 0                       1         Regular Season      5332.0
# 1                       1         Regular Season      4062.0
# 2                       1         Regular Season       577.0
# 3                       1         Regular Season       456.0
# 4                       1         Regular Season         NaN
# ..                    ...                    ...         ...
# 102                     1         Regular Season       111.0
# 103                     1         Regular Season       579.0
# 104                     1         Regular Season       456.0
# 105                     1         Regular Season      4055.0
# 106                     1         Regular Season      4055.0
#
#                 stadium.name  stadium.country.id stadium.country.name  \
# 0    SportNation.bet Stadium               255.0        International
# 1     The Rush Green Stadium                68.0              England
# 2                 Adams Park                68.0              England
# 3                Meadow Park                68.0              England
# 4                        NaN                 NaN                  NaN
# ..                       ...                 ...                  ...
# 102              Haig Avenue                68.0              England
# 103             Prenton Park                68.0              England
# 104              Meadow Park                68.0              England
# 105    Stoke Gifford Stadium                68.0              England
# 106    Stoke Gifford Stadium                68.0              England
#
#      referee.id referee.name  referee.country.id referee.country.name  \
# 0         898.0     A. Fearn                 NaN                  NaN
# 1         568.0   J. Packman                68.0              England
# 2         567.0    H. Conley                68.0              England
# 3         915.0   R. Whitton                 NaN                  NaN
# 4           NaN          NaN                 NaN                  NaN
# ..          ...          ...                 ...                  ...
# 102       978.0    P. Clarke                 NaN                  NaN
# 103       567.0    H. Conley                68.0              England
# 104       897.0    P. Howard                 NaN                  NaN
# 105       842.0     R. Hulme                 NaN                  NaN
# 106       893.0   S. Pearson                 NaN                  NaN
#
#     metadata.shot_fidelity_version
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 102                              2
# 103                            NaN
# 104                            NaN
# 105                              2
# 106                            NaN
#
# [107 rows x 39 columns]

# %%
df_sb_match_data_wsl_1920_flat
# Out:
#     match_id  match_date      kick_off  home_score  away_score match_status  \
# 0    2275054  2020-01-05  15:00:00.000           1           0    available
# 1    2275072  2020-01-05  13:30:00.000           3           1    available
# 2    2275085  2020-01-05  15:00:00.000           1           4    available
# 3    2275113  2020-01-19  16:00:00.000           2           1    available
# 4    2275142  2020-01-05  13:00:00.000           0           1    available
# ..       ...         ...           ...         ...         ...          ...
# 82   2275083  2020-02-23  15:00:00.000           0           1    available
# 83   2275086  2019-12-08  15:30:00.000           0           3    available
# 84   2275137  2020-01-19  13:00:00.000           3           0    available
# 85   2275056  2019-11-17  16:00:00.000           0           1    available
# 86   2275074  2020-02-12  20:00:00.000           2           0    available
#
#         last_updated  match_week  competition.competition_id  \
# 0   2020-07-29T05:00          11                          37
# 1   2020-07-29T05:00          11                          37
# 2   2020-07-29T05:00          11                          37
# 3   2020-07-29T05:00          13                          37
# 4   2020-07-29T05:00          11                          37
# ..               ...         ...                         ...
# 82  2020-07-29T05:00          17                          37
# 83  2020-07-29T05:00           9                          37
# 84  2020-07-29T05:00          13                          37
# 85  2020-07-29T05:00           6                          37
# 86  2020-07-29T05:00          16                          37
#
#    competition.country_name competition.competition_name  season.season_id  \
# 0                   England      FA Women's Super League                42
# 1                   England      FA Women's Super League                42
# 2                   England      FA Women's Super League                42
# 3                   England      FA Women's Super League                42
# 4                   England      FA Women's Super League                42
# ..                      ...                          ...               ...
# 82                  England      FA Women's Super League                42
# 83                  England      FA Women's Super League                42
# 84                  England      FA Women's Super League                42
# 85                  England      FA Women's Super League                42
# 86                  England      FA Women's Super League                42
#
#    season.season_name  home_team.home_team_id    home_team.home_team_name  \
# 0           2019/2020                     965  Brighton & Hove Albion WFC
# 1           2019/2020                     971                 Chelsea FCW
# 2           2019/2020                     749     Tottenham Hotspur Women
# 3           2019/2020                     972         West Ham United LFC
# 4           2019/2020                    1475           Manchester United
# ..                ...                     ...                         ...
# 82          2019/2020                     969         Birmingham City WFC
# 83          2019/2020                     974                 Reading WFC
# 84          2019/2020                    1475           Manchester United
# 85          2019/2020                     966               Liverpool WFC
# 86          2019/2020                     971                 Chelsea FCW
#
#    home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 0                      female                      None                    68
# 1                      female                      None                    68
# 2                      female                      None                    68
# 3                      female                      None                    68
# 4                      female                      None                    68
# ..                        ...                       ...                   ...
# 82                     female                      None                    68
# 83                     female                      None                    68
# 84                     female                      None                    68
# 85                     female                      None                    68
# 86                     female                      None                    68
#
#    home_team.country.name  away_team.away_team_id    away_team.away_team_name  \
# 0                 England                     966               Liverpool WFC
# 1                 England                     974                 Reading WFC
# 2                 England                     746         Manchester City WFC
# 3                 England                     965  Brighton & Hove Albion WFC
# 4                 England                     973            Bristol City WFC
# ..                    ...                     ...                         ...
# 82                England                     973            Bristol City WFC
# 83                England                     968                 Arsenal WFC
# 84                England                     749     Tottenham Hotspur Women
# 85                England                     967                 Everton LFC
# 86                England                     969         Birmingham City WFC
#
#    away_team.away_team_gender away_team.away_team_group  away_team.country.id  \
# 0                      female                      None                    68
# 1                      female                      None                    68
# 2                      female                      None                    68
# 3                      female                      None                    68
# 4                      female                      None                    68
# ..                        ...                       ...                   ...
# 82                     female                      None                    68
# 83                     female                      None                    68
# 84                     female                      None                    68
# 85                     female                      None                    68
# 86                     female                      None                    68
#
#    away_team.country.name metadata.data_version  \
# 0                 England                 1.1.0
# 1                 England                 1.1.0
# 2                 England                 1.1.0
# 3                 England                 1.1.0
# 4                 England                 1.1.0
# ..                    ...                   ...
# 82                England                 1.1.0
# 83                England                 1.1.0
# 84                England                 1.1.0
# 85                England                 1.1.0
# 86                England                 1.1.0
#
#    metadata.shot_fidelity_version metadata.xy_fidelity_version  \
# 0                               2                            2
# 1                               2                            2
# 2                               2                            2
# 3                               2                            2
# 4                               2                            2
# ..                            ...                          ...
# 82                              2                            2
# 83                              2                            2
# 84                              2                            2
# 85                              2                            2
# 86                              2                            2
#
#     competition_stage.id competition_stage.name  \
# 0                      1         Regular Season
# 1                      1         Regular Season
# 2                      1         Regular Season
# 3                      1         Regular Season
# 4                      1         Regular Season
# ..                   ...                    ...
# 82                     1         Regular Season
# 83                     1         Regular Season
# 84                     1         Regular Season
# 85                     1         Regular Season
# 86                     1         Regular Season
#
#                                    home_team.managers  \
# 0                                                 NaN
# 1   [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 2   [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 3   [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 4   [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# ..                                                ...
# 82  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 83  [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# 84  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 85  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 86  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
#
#                                    away_team.managers  stadium.id  \
# 0                                                 NaN         NaN
# 1   [{'id': 144, 'name': 'Kelly Chambers', 'nickna...      4279.0
# 2   [{'id': 30, 'name': 'Nick Cushing', 'nickname'...       122.0
# 3   [{'id': 149, 'name': 'Hope Patricia Powell', '...      4062.0
# 4   [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...      4979.0
# ..                                                ...         ...
# 82  [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...      5332.0
# 83  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...       577.0
# 84  [{'id': 791, 'name': 'Karen Hills', 'nickname'...      4979.0
# 85  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...         6.0
# 86  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...      4279.0
#
#                       stadium.name  stadium.country.id stadium.country.name  \
# 0                              NaN                 NaN                  NaN
# 1   The Cherry Red Records Stadium                68.0              England
# 2                 The Hive Stadium                68.0              England
# 3           The Rush Green Stadium                68.0              England
# 4     Leigh Sports Village Stadium               255.0        International
# ..                             ...                 ...                  ...
# 82         SportNation.bet Stadium               255.0        International
# 83                      Adams Park                68.0              England
# 84    Leigh Sports Village Stadium               255.0        International
# 85                         Anfield                68.0              England
# 86  The Cherry Red Records Stadium                68.0              England
#
#     referee.id  referee.name  referee.country.id referee.country.name
# 0          NaN           NaN                 NaN                  NaN
# 1        893.0    S. Pearson                 NaN                  NaN
# 2        567.0     H. Conley                68.0              England
# 3        912.0    Ryan Atkin                 NaN                  NaN
# 4        894.0     L. Oliver                 NaN                  NaN
# ..         ...           ...                 ...                  ...
# 82       893.0    S. Pearson                 NaN                  NaN
# 83       842.0      R. Hulme                 NaN                  NaN
# 84      1721.0  E. Duckworth                 NaN                  NaN
# 85       898.0      A. Fearn                 NaN                  NaN
# 86       915.0    R. Whitton                 NaN                  NaN
#
# [87 rows x 40 columns]

# %%
df_sb_match_data_wsl_2021_flat
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3764234  2020-09-05  15:30:00.000           0           2    available
#
#                  last_updated  match_week  competition.competition_id  \
# 0  2020-09-06T19:03:37.632953           1                          37
#
#   competition.country_name competition.competition_name  season.season_id  \
# 0                  England      FA Women's Super League                90
#
#   season.season_name  home_team.home_team_id home_team.home_team_name  \
# 0          2020/2021                    2647              Aston Villa
#
#   home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 0                     female                      None                    68
#
#   home_team.country.name  away_team.away_team_id away_team.away_team_name  \
# 0                England                     746      Manchester City WFC
#
#   away_team.away_team_gender away_team.away_team_group  away_team.country.id  \
# 0                     female                      None                    68
#
#   away_team.country.name metadata.data_version metadata.shot_fidelity_version  \
# 0                England                 1.1.0                              2
#
#   metadata.xy_fidelity_version  competition_stage.id competition_stage.name  \
# 0                            2                     1         Regular Season
#
#    stadium.id stadium.name  stadium.country.id stadium.country.name  \
# 0         211   Villa Park                  68              England
#
#    referee.id referee.name
# 0         937     A. Bryne

# %% [markdown]
# ##### Concatenate the flattened Matches data for the WSL

# %%
# Concatenate the flattened events data for the Big 5 European leagues

## List of the Big 5 DataFrames
lst_events_dataframes_wsl = [df_sb_match_data_wsl_1819_flat, df_sb_match_data_wsl_1920_flat, df_sb_match_data_wsl_2021_flat]

## Concatenate the individual Big 5 DataFrames to one unified DataFrame
df_sb_match_data_wsl_flat = pd.concat(lst_events_dataframes_wsl)

## Export unified DataFrame
df_sb_match_data_wsl_flat.to_csv(data_dir_sb + '/matches/raw/csv/wsl/' + '/df_sb_match_data_wsl.csv', index=None, header=True)

# %%
df_sb_match_data_wsl_flat
# Out:
#     match_id  match_date      kick_off  home_score  away_score match_status  \
# 0      19743  2018-10-21  13:30:00.000           0           0    available
# 1      19740  2018-10-21  16:00:00.000           0           1    available
# 2      19716  2018-09-09  15:00:00.000           4           0    available
# 3      19800  2019-03-14  20:30:00.000           4           0    available
# 4      19739  2018-10-21  15:00:00.000           0           6    available
# ..       ...         ...           ...         ...         ...          ...
# 83   2275086  2019-12-08  15:30:00.000           0           3    available
# 84   2275137  2020-01-19  13:00:00.000           3           0    available
# 85   2275056  2019-11-17  16:00:00.000           0           1    available
# 86   2275074  2020-02-12  20:00:00.000           2           0    available
# 0    3764234  2020-09-05  15:30:00.000           0           2    available
#
#                   last_updated  match_week  competition.competition_id  \
# 0             2020-07-29T05:00           6                          37
# 1             2020-07-29T05:00           6                          37
# 2             2020-07-29T05:00           1                          37
# 3   2020-08-24T14:34:34.401523          18                          37
# 4             2020-07-29T05:00           6                          37
# ..                         ...         ...                         ...
# 83            2020-07-29T05:00           9                          37
# 84            2020-07-29T05:00          13                          37
# 85            2020-07-29T05:00           6                          37
# 86            2020-07-29T05:00          16                          37
# 0   2020-09-06T19:03:37.632953           1                          37
#
#    competition.country_name competition.competition_name  season.season_id  \
# 0                   England      FA Women's Super League                 4
# 1                   England      FA Women's Super League                 4
# 2                   England      FA Women's Super League                 4
# 3                   England      FA Women's Super League                 4
# 4                   England      FA Women's Super League                 4
# ..                      ...                          ...               ...
# 83                  England      FA Women's Super League                42
# 84                  England      FA Women's Super League                42
# 85                  England      FA Women's Super League                42
# 86                  England      FA Women's Super League                42
# 0                   England      FA Women's Super League                90
#
#    season.season_name  home_team.home_team_id    home_team.home_team_name  \
# 0           2018/2019                     969         Birmingham City WFC
# 1           2018/2019                     972         West Ham United LFC
# 2           2018/2019                     974                 Reading WFC
# 3           2018/2019                     968                 Arsenal WFC
# 4           2018/2019                     965  Brighton & Hove Albion WFC
# ..                ...                     ...                         ...
# 83          2019/2020                     974                 Reading WFC
# 84          2019/2020                    1475           Manchester United
# 85          2019/2020                     966               Liverpool WFC
# 86          2019/2020                     971                 Chelsea FCW
# 0           2020/2021                    2647                 Aston Villa
#
#    home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 0                      female                      None                    68
# 1                      female                      None                    68
# 2                      female                      None                    68
# 3                      female                      None                    68
# 4                      female                      None                    68
# ..                        ...                       ...                   ...
# 83                     female                      None                    68
# 84                     female                      None                    68
# 85                     female                      None                    68
# 86                     female                      None                    68
# 0                      female                      None                    68
#
#    home_team.country.name                                 home_team.managers  \
# 0                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1                 England  [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 2                 England  [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# 3                 England  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 4                 England  [{'id': 149, 'name': 'Hope Patricia Powell', '...
# ..                    ...                                                ...
# 83                England  [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# 84                England  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 85                England  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 86                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 0                 England                                                NaN
#
#     away_team.away_team_id away_team.away_team_name  \
# 0                      971              Chelsea FCW
# 1                      966            Liverpool WFC
# 2                      970          Yeovil Town LFC
# 3                      973         Bristol City WFC
# 4                      746      Manchester City WFC
# ..                     ...                      ...
# 83                     968              Arsenal WFC
# 84                     749  Tottenham Hotspur Women
# 85                     967              Everton LFC
# 86                     969      Birmingham City WFC
# 0                      746      Manchester City WFC
#
#    away_team.away_team_gender away_team.away_team_group  away_team.country.id  \
# 0                      female                      None                    68
# 1                      female                      None                    68
# 2                      female                      None                    68
# 3                      female                      None                    68
# 4                      female                      None                    68
# ..                        ...                       ...                   ...
# 83                     female                      None                    68
# 84                     female                      None                    68
# 85                     female                      None                    68
# 86                     female                      None                    68
# 0                      female                      None                    68
#
#    away_team.country.name                                 away_team.managers  \
# 0                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 1                 England  [{'id': 153, 'name': 'Chris Kirkland', 'nickna...
# 2                 England  [{'id': 147, 'name': 'Lee Burch', 'nickname': ...
# 3                 England  [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...
# 4                 England  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# ..                    ...                                                ...
# 83                England  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 84                England  [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 85                England  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 86                England  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 0                 England                                                NaN
#
#    metadata.data_version  competition_stage.id competition_stage.name  \
# 0                  1.0.3                     1         Regular Season
# 1                  1.0.3                     1         Regular Season
# 2                  1.0.3                     1         Regular Season
# 3                  1.1.0                     1         Regular Season
# 4                  1.0.3                     1         Regular Season
# ..                   ...                   ...                    ...
# 83                 1.1.0                     1         Regular Season
# 84                 1.1.0                     1         Regular Season
# 85                 1.1.0                     1         Regular Season
# 86                 1.1.0                     1         Regular Season
# 0                  1.1.0                     1         Regular Season
#
#     stadium.id                    stadium.name  stadium.country.id  \
# 0       5332.0         SportNation.bet Stadium               255.0
# 1       4062.0          The Rush Green Stadium                68.0
# 2        577.0                      Adams Park                68.0
# 3        456.0                     Meadow Park                68.0
# 4          NaN                             NaN                 NaN
# ..         ...                             ...                 ...
# 83       577.0                      Adams Park                68.0
# 84      4979.0    Leigh Sports Village Stadium               255.0
# 85         6.0                         Anfield                68.0
# 86      4279.0  The Cherry Red Records Stadium                68.0
# 0        211.0                      Villa Park                68.0
#
#    stadium.country.name  referee.id  referee.name  referee.country.id  \
# 0         International       898.0      A. Fearn                 NaN
# 1               England       568.0    J. Packman                68.0
# 2               England       567.0     H. Conley                68.0
# 3               England       915.0    R. Whitton                 NaN
# 4                   NaN         NaN           NaN                 NaN
# ..                  ...         ...           ...                 ...
# 83              England       842.0      R. Hulme                 NaN
# 84        International      1721.0  E. Duckworth                 NaN
# 85              England       898.0      A. Fearn                 NaN
# 86              England       915.0    R. Whitton                 NaN
# 0               England       937.0      A. Bryne                 NaN
#
#    referee.country.name metadata.shot_fidelity_version  \
# 0                   NaN                            NaN
# 1               England                            NaN
# 2               England                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# ..                  ...                            ...
# 83                  NaN                              2
# 84                  NaN                              2
# 85                  NaN                              2
# 86                  NaN                              2
# 0                   NaN                              2
#
#    metadata.xy_fidelity_version
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 83                            2
# 84                            2
# 85                            2
# 86                            2
# 0                             2
#
# [195 rows x 40 columns]

# %%
df_sb_match_data_wsl_flat.shape
# Out:
# (195, 40)

# %% [markdown]
# ##### Convert `match_id` column to list

# %%
lst_sb_wsl_match_id = df_sb_match_data_wsl_flat['match_id'].tolist()

# %%
lst_sb_wsl_match_id
# Out:
# [19743,
#  19740,
#  19716,
#  19800,
#  19739,
#  19734,
#  19748,
#  19822,
#  19766,
#  19785,
#  19749,
#  19751,
#  19764,
#  19773,
#  19783,
#  19736,
#  19747,
#  19787,
#  19771,
#  19769,
#  19770,
#  19765,
#  19757,
#  19742,
#  19777,
#  19758,
#  19802,
#  19803,
#  19746,
#  19733,
#  19811,
#  19805,
#  19745,
#  19752,
#  19772,
#  19775,
#  19760,
#  19792,
#  19732,
#  19744,
#  19799,
#  19730,
#  19753,
#  19735,
#  19717,
#  19718,
#  19720,
#  19719,
#  19715,
#  19723,
#  19722,
#  19727,
#  19731,
#  19714,
#  19728,
#  19726,
#  19725,
#  19738,
#  19759,
#  19750,
#  19761,
#  19763,
#  19762,
#  19768,
#  19767,
#  19776,
#  19794,
#  19820,
#  19737,
#  19790,
#  19789,
#  19793,
#  19791,
#  19796,
#  19795,
#  19797,
#  19780,
#  19782,
#  19781,
#  19779,
#  19798,
#  19784,
#  19786,
#  19774,
#  19755,
#  19806,
#  19807,
#  19788,
#  19808,
#  19804,
#  19813,
#  19816,
#  19809,
#  19810,
#  19815,
#  19817,
#  19818,
#  19819,
#  19821,
#  19801,
#  19741,
#  19778,
#  19756,
#  19754,
#  19724,
#  19814,
#  19729,
#  2275054,
#  2275072,
#  2275085,
#  2275113,
#  2275142,
#  2275099,
#  2275057,
#  2275075,
#  2275092,
#  2275077,
#  2275036,
#  2275117,
#  2275040,
#  2275045,
#  2275093,
#  2275153,
#  2275097,
#  2275122,
#  2275084,
#  2275089,
#  2275116,
#  2275127,
#  2275104,
#  2275052,
#  2275037,
#  2275027,
#  2275078,
#  2275080,
#  2275098,
#  2275156,
#  2275028,
#  2275120,
#  2275150,
#  2275139,
#  2275070,
#  2275051,
#  2275063,
#  2275050,
#  2275029,
#  2275090,
#  2275042,
#  2275108,
#  2275082,
#  2275138,
#  2275049,
#  2275132,
#  2275146,
#  2275061,
#  2275136,
#  2275096,
#  2275033,
#  2275107,
#  2275130,
#  2275034,
#  2275026,
#  2275094,
#  2275041,
#  2275044,
#  2275157,
#  2275106,
#  2275144,
#  2275105,
#  2275073,
#  2275038,
#  2275110,
#  2275131,
#  2275062,
#  2275048,
#  2275121,
#  2275151,
#  2275154,
#  2275065,
#  2275079,
#  2275140,
#  2275103,
#  2275126,
#  2275102,
#  2275109,
#  2275088,
#  2275091,
#  2275030,
#  2275133,
#  2275083,
#  2275086,
#  2275137,
#  2275056,
#  2275074,
#  3764234]

# %%
len(lst_sb_wsl_match_id)
# Out:
# 195

# %% [markdown]
# #### <a id='#section3.3.3.'>3.3.3. Events</a>

# %% [markdown]
# ##### Data Dictionary

# %% [markdown]
# The [StatsBomb](https://statsbomb.com/) dataset has one hundred and fourteen features (columns) with the following definitions and data types:
#
# | Feature     | Data type    |
# |------|-----|
# | `id`    | `object`
# | `index`    | `object`
# | `period`    | `object`
# | `timestamp`    | `object`
# | `minute`    | `object`
# | `second`    | `object`
# | `possession`    | `object`
# | `duration`    | `object`
# | `type.id`    | `object`
# | `type.name`    | `object`
# | `possession_team.id`    | `object`
# | `possession_team.name`    | `object`
# | `play_pattern.id`    | `object`
# | `play_pattern.name`    | `object`
# | `team.id`    | `object`
# | `team.name`    | `object`
# | `tactics.formation`    | `object`
# | `tactics.lineup`    | `object`
# | `related_events`    | `object`
# | `location`    | `object`
# | `player.id`    | `object`
# | `player.name`    | `object`
# | `position.id`    | `object`
# | `position.name`    | `object`
# | `pass.recipient.id`    | `object`
# | `pass.recipient.name`    | `object`
# | `pass.length`    | `object`
# | `pass.angle`    | `object`
# | `pass.height.id`    | `object`
# | `pass.height.name`    | `object`
# | `pass.end_location`    | `object`
# | `pass.type.id`    | `object`
# | `pass.type.name`    | `object`
# | `pass.body_part.id`    | `object`
# | `pass.body_part.name`    | `object`
# | `carry.end_location`    | `object`
# | `under_pressure`    | `object`
# | `duel.type.id`    | `object`
# | `duel.type.name`    | `object`
# | `out`    | `object`
# | `miscontrol.aerial_won`    | `object`
# | `pass.outcome.id`    | `object`
# | `pass.outcome.name`    | `object`
# | `ball_receipt.outcome.id`    | `object`
# | `ball_receipt.outcome.name`    | `object`
# | `pass.aerial_won`    | `object`
# | `counterpress`    | `object`
# | `off_camera`    | `object`
# | `dribble.outcome.id`    | `object`
# | `dribble.outcome.name`    | `object`
# | `dribble.overrun`    | `object`
# | `ball_recovery.offensive`    | `object`
# | `shot.statsbomb_xg`    | `object`
# | `shot.end_location`    | `object`
# | `shot.outcome.id`    | `object`
# | `shot.outcome.name`    | `object`
# | `shot.type.id`    | `object`
# | `shot.type.name`    | `object`
# | `shot.body_part.id`    | `object`
# | `shot.body_part.name`    | `object`
# | `shot.technique.id`    | `object`
# | `shot.technique.name`    | `object`
# | `shot.freeze_frame`    | `object`
# | `goalkeeper.end_location`    | `object`
# | `goalkeeper.type.id`    | `object`
# | `goalkeeper.type.name`    | `object`
# | `goalkeeper.position.id`    | `object`
# | `goalkeeper.position.name`    | `object`
# | `pass.straight`    | `object`
# | `pass.technique.id`    | `object`
# | `pass.technique.name`    | `object`
# | `clearance.head`    | `object`
# | `clearance.body_part.id`    | `object`
# | `clearance.body_part.name`    | `object`
# | `pass.switch`    | `object`
# | `duel.outcome.id`    | `object`
# | `duel.outcome.name`    | `object`
# | `foul_committed.advantage`    | `object`
# | `foul_won.advantage`    | `object`
# | `pass.cross`    | `object`
# | `pass.assisted_shot_id`    | `object`
# | `pass.shot_assist`    | `object`
# | `shot.one_on_one`    | `object`
# | `shot.key_pass_id`    | `object`
# | `goalkeeper.body_part.id`    | `object`
# | `goalkeeper.body_part.name`    | `object`
# | `goalkeeper.technique.id`    | `object`
# | `goalkeeper.technique.name`    | `object`
# | `goalkeeper.outcome.id`    | `object`
# | `goalkeeper.outcome.name`    | `object`
# | `clearance.aerial_won`    | `object`
# | `foul_committed.card.id`    | `object`
# | `foul_committed.card.name`    | `object`
# | `foul_won.defensive`    | `object`
# | `clearance.right_foot`    | `object`
# | `shot.first_time`    | `object`
# | `pass.through_ball`    | `object`
# | `interception.outcome.id`    | `object`
# | `interception.outcome.name`    | `object`
# | `clearance.left_foot`    | `object`
# | `ball_recovery.recovery_failure`    | `object`
# | `shot.aerial_won`    | `object`
# | `pass.goal_assist`    | `object`
# | `pass.cut_back`    | `object`
# | `pass.deflected`    | `object`
# | `clearance.other`    | `object`
# | `pass.outswinging`    | `object`
# | `substitution.outcome.id`    | `object`
# | `substitution.outcome.name`    | `object`
# | `substitution.replacement.id`    | `object`
# | `substitution.replacement.name`    | `object`
# | `block.deflection`    | `object`
# | `block.offensive`    | `object`
# | `injury_stoppage.in_chain`    | `object`
#
# For a full list of definitions, see the official documentation [[link](https://statsbomb.com/stat-definitions/)].

# %% [markdown]
# ##### Import Data

# %%
# Show files in directory
print(glob.glob(data_dir_sb + '/events/raw/json/' + '/*json'))
# Out:
# ['../../data/sb/events/raw/json/2275050.json', '../../data/sb/events/raw/json/19795.json', '../../data/sb/events/raw/json/7298.json', '../../data/sb/events/raw/json/265958.json', '../../data/sb/events/raw/json/69182.json', '../../data/sb/events/raw/json/18242.json', '../../data/sb/events/raw/json/69301.json', '../../data/sb/events/raw/json/303696.json', '../../data/sb/events/raw/json/69244.json', '../../data/sb/events/raw/json/2275142.json', '../../data/sb/events/raw/json/266620.json', '../../data/sb/events/raw/json/7559.json', '../../data/sb/events/raw/json/69213.json', '../../data/sb/events/raw/json/2275154.json', '../../data/sb/events/raw/json/69340.json', '../../data/sb/events/raw/json/69205.json', '../../data/sb/events/raw/json/19804.json', '../../data/sb/events/raw/json/8655.json', '../../data/sb/events/raw/json/266724.json', '../../data/sb/events/raw/json/19783.json', '../../data/sb/events/raw/json/22980.json', '../../data/sb/events/raw/json/2275103.json', '../../data/sb/events/raw/json/303680.json', '../../data/sb/events/raw/json/9855.json', '../../data/sb/events/raw/json/69252.json', '../../data/sb/events/raw/json/70264.json', '../../data/sb/events/raw/json/19717.json', '../../data/sb/events/raw/json/68341.json', '../../data/sb/events/raw/json/9592.json', '../../data/sb/events/raw/json/69229.json', '../../data/sb/events/raw/json/16231.json', '../../data/sb/events/raw/json/7563.json', '../../data/sb/events/raw/json/19740.json', '../../data/sb/events/raw/json/22943.json', '../../data/sb/events/raw/json/2275085.json', '../../data/sb/events/raw/json/69157.json', '../../data/sb/events/raw/json/68316.json', '../../data/sb/events/raw/json/16289.json', '../../data/sb/events/raw/json/267660.json', '../../data/sb/events/raw/json/7471.json', '../../data/sb/events/raw/json/7534.json', '../../data/sb/events/raw/json/69291.json', '../../data/sb/events/raw/json/70225.json', '../../data/sb/events/raw/json/2275093.json', '../../data/sb/events/raw/json/22955.json', '../../data/sb/events/raw/json/19756.json', '../../data/sb/events/raw/json/2275139.json', '../../data/sb/events/raw/json/69141.json', '../../data/sb/events/raw/json/9880.json', '../../data/sb/events/raw/json/69268.json', '../../data/sb/events/raw/json/69287.json', '../../data/sb/events/raw/json/7522.json', '../../data/sb/events/raw/json/9642.json', '../../data/sb/events/raw/json/70272.json', '../../data/sb/events/raw/json/68357.json', '../../data/sb/events/raw/json/265866.json', '../../data/sb/events/raw/json/266933.json', '../../data/sb/events/raw/json/7430.json', '../../data/sb/events/raw/json/266525.json', '../../data/sb/events/raw/json/267343.json', '../../data/sb/events/raw/json/69248.json', '../../data/sb/events/raw/json/68320.json', '../../data/sb/events/raw/json/19799.json', '../../data/sb/events/raw/json/69161.json', '../../data/sb/events/raw/json/16196.json', '../../data/sb/events/raw/json/267085.json', '../../data/sb/events/raw/json/267590.json', '../../data/sb/events/raw/json/19776.json', '../../data/sb/events/raw/json/7555.json', '../../data/sb/events/raw/json/15978.json', '../../data/sb/events/raw/json/266440.json', '../../data/sb/events/raw/json/267197.json', '../../data/sb/events/raw/json/7543.json', '../../data/sb/events/raw/json/19808.json', '../../data/sb/events/raw/json/303634.json', '../../data/sb/events/raw/json/69209.json', '../../data/sb/events/raw/json/68361.json', '../../data/sb/events/raw/json/70301.json', '../../data/sb/events/raw/json/22934.json', '../../data/sb/events/raw/json/19737.json', '../../data/sb/events/raw/json/266952.json', '../../data/sb/events/raw/json/7451.json', '../../data/sb/events/raw/json/267569.json', '../../data/sb/events/raw/json/69177.json', '../../data/sb/events/raw/json/68336.json', '../../data/sb/events/raw/json/3749528.json', '../../data/sb/events/raw/json/19760.json', '../../data/sb/events/raw/json/22963.json', '../../data/sb/events/raw/json/266883.json', '../../data/sb/events/raw/json/69225.json', '../../data/sb/event ...

# %%
# Import all StatsBomb JSON Event data files for the WSL and combined to one pandas DataFrame

## Create a blank DataFrame to append loaded JSON files
df_events = pd.DataFrame()

## Loop through WSL event data using match ids, load JSONs, normalise JSONs, append 
for match_id in lst_sb_wsl_match_id:
    with open(data_dir_sb + '/events/raw/json/' + str(match_id) + '.json') as f:
        event = json.load(f)
       #match_id = str(match_id)
        event_flat = json_normalize(event)
        event_flat['match_id'] = match_id
        df_events = df_events.append(event_flat)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_events.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'type.id', 'type.name',
#        ...
#        'player_off.permanent', 'shot.saved_to_post',
#        'goalkeeper.shot_saved_to_post', 'goalkeeper.lost_in_play',
#        'goalkeeper.success_out', 'shot.follows_dribble',
#        'half_start.late_video_start', 'goalkeeper.success_in_play',
#        'half_end.early_video_end', 'goalkeeper.saved_to_post'],
#       dtype='object', length=148)

# %%
# Export unified DataFrame
df_events.to_csv(data_dir_sb + '/events/raw/csv/wsl/' + '/df_sb_event_data_wsl.csv', index=None, header=True)

# %%
lst_formation = df_events['tactics.formation'].unique().tolist()

# %%
lst_formation
# Out:
# [4231.0,
#  42211.0,
#  nan,
#  442.0,
#  4321.0,
#  4222.0,
#  41221.0,
#  433.0,
#  4411.0,
#  4141.0,
#  5221.0,
#  42121.0,
#  3232.0,
#  451.0,
#  31222.0,
#  4132.0,
#  343.0,
#  541.0,
#  32221.0,
#  3421.0,
#  41212.0,
#  3142.0,
#  3511.0,
#  3412.0,
#  41131.0,
#  4312.0,
#  352.0]

# %% [markdown]
# #### <a id='#section3.3.3.'>3.3.4. Lineups</a>

# %% [markdown]
# ##### Data Dictionary

# %% [markdown]
# ##### Import Data

# %%
# Show files in directory
print(glob.glob(data_dir_sb + '/lineups/raw/json/' + '/*json'))
# Out:
# ['../../data/sb/lineups/raw/json/2275050.json', '../../data/sb/lineups/raw/json/19795.json', '../../data/sb/lineups/raw/json/7298.json', '../../data/sb/lineups/raw/json/265958.json', '../../data/sb/lineups/raw/json/69182.json', '../../data/sb/lineups/raw/json/18242.json', '../../data/sb/lineups/raw/json/69301.json', '../../data/sb/lineups/raw/json/303696.json', '../../data/sb/lineups/raw/json/69244.json', '../../data/sb/lineups/raw/json/2275142.json', '../../data/sb/lineups/raw/json/266620.json', '../../data/sb/lineups/raw/json/7559.json', '../../data/sb/lineups/raw/json/69213.json', '../../data/sb/lineups/raw/json/2275154.json', '../../data/sb/lineups/raw/json/69340.json', '../../data/sb/lineups/raw/json/69205.json', '../../data/sb/lineups/raw/json/19804.json', '../../data/sb/lineups/raw/json/8655.json', '../../data/sb/lineups/raw/json/266724.json', '../../data/sb/lineups/raw/json/19783.json', '../../data/sb/lineups/raw/json/22980.json', '../../data/sb/lineups/raw/json/2275103.json', '../../data/sb/lineups/raw/json/303680.json', '../../data/sb/lineups/raw/json/9855.json', '../../data/sb/lineups/raw/json/69252.json', '../../data/sb/lineups/raw/json/70264.json', '../../data/sb/lineups/raw/json/19717.json', '../../data/sb/lineups/raw/json/68341.json', '../../data/sb/lineups/raw/json/9592.json', '../../data/sb/lineups/raw/json/69229.json', '../../data/sb/lineups/raw/json/16231.json', '../../data/sb/lineups/raw/json/7563.json', '../../data/sb/lineups/raw/json/19740.json', '../../data/sb/lineups/raw/json/22943.json', '../../data/sb/lineups/raw/json/2275085.json', '../../data/sb/lineups/raw/json/69157.json', '../../data/sb/lineups/raw/json/68316.json', '../../data/sb/lineups/raw/json/16289.json', '../../data/sb/lineups/raw/json/267660.json', '../../data/sb/lineups/raw/json/7471.json', '../../data/sb/lineups/raw/json/7534.json', '../../data/sb/lineups/raw/json/69291.json', '../../data/sb/lineups/raw/json/70225.json', '../../data/sb/lineups/raw/json/2275093.json', '../../data/sb/lineups/raw/json/22955.json', '../../data/sb/lineups/raw/json/19756.json', '../../data/sb/lineups/raw/json/2275139.json', '../../data/sb/lineups/raw/json/69141.json', '../../data/sb/lineups/raw/json/9880.json', '../../data/sb/lineups/raw/json/69268.json', '../../data/sb/lineups/raw/json/69287.json', '../../data/sb/lineups/raw/json/7522.json', '../../data/sb/lineups/raw/json/9642.json', '../../data/sb/lineups/raw/json/70272.json', '../../data/sb/lineups/raw/json/68357.json', '../../data/sb/lineups/raw/json/265866.json', '../../data/sb/lineups/raw/json/266933.json', '../../data/sb/lineups/raw/json/7430.json', '../../data/sb/lineups/raw/json/266525.json', '../../data/sb/lineups/raw/json/267343.json', '../../data/sb/lineups/raw/json/69248.json', '../../data/sb/lineups/raw/json/68320.json', '../../data/sb/lineups/raw/json/19799.json', '../../data/sb/lineups/raw/json/69161.json', '../../data/sb/lineups/raw/json/16196.json', '../../data/sb/lineups/raw/json/267085.json', '../../data/sb/lineups/raw/json/267590.json', '../../data/sb/lineups/raw/json/19776.json', '../../data/sb/lineups/raw/json/7555.json', '../../data/sb/lineups/raw/json/15978.json', '../../data/sb/lineups/raw/json/266440.json', '../../data/sb/lineups/raw/json/267197.json', '../../data/sb/lineups/raw/json/7543.json', '../../data/sb/lineups/raw/json/19808.json', '../../data/sb/lineups/raw/json/303634.json', '../../data/sb/lineups/raw/json/69209.json', '../../data/sb/lineups/raw/json/68361.json', '../../data/sb/lineups/raw/json/70301.json', '../../data/sb/lineups/raw/json/22934.json', '../../data/sb/lineups/raw/json/19737.json', '../../data/sb/lineups/raw/json/266952.json', '../../data/sb/lineups/raw/json/7451.json', '../../data/sb/lineups/raw/json/267569.json', '../../data/sb/lineups/raw/json/69177.json', '../../data/sb/lineups/raw/json/68336.json', '../../data/sb/lineups/raw/json/3749528.json', '../../data/sb/lineups/raw/json/19760.json', '../../data/sb/lineups/raw/json/22963.json', '../../data/sb/lineup ...

# %%
# Import all StatsBomb JSON lineup data files for the WSL and combined to one pandas DataFrame

## Create a blank DataFrame to append loaded JSON files
df_lineups = pd.DataFrame()

## Loop through WSL lineup data using match ids, load JSONs, normalise JSONs, append 
for lineup_id in lst_sb_wsl_match_id:
    with open(data_dir_sb + '/lineups/raw/json/' + str(lineup_id) + '.json') as f:
        lineup = json.load(f)
        lineup_flat = json_normalize(lineup)
        df_lineups = df_lineups.append(lineup_flat)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_lineups
# Out:
#     team_id            team_name  \
# 0       971          Chelsea FCW
# 1       969  Birmingham City WFC
# 0       972  West Ham United LFC
# 1       966        Liverpool WFC
# 0       974          Reading WFC
# ..      ...                  ...
# 1       966        Liverpool WFC
# 0       971          Chelsea FCW
# 1       969  Birmingham City WFC
# 0       746  Manchester City WFC
# 1      2647          Aston Villa
#
#                                                lineup
# 0   [{'player_id': 4633, 'player_name': 'Magdalena...
# 1   [{'player_id': 10193, 'player_name': 'Chloe Ar...
# 0   [{'player_id': 4653, 'player_name': 'Jane Ross...
# 1   [{'player_id': 15218, 'player_name': 'Jessica ...
# 0   [{'player_id': 10198, 'player_name': 'Josanne ...
# ..                                                ...
# 1   [{'player_id': 15547, 'player_name': 'Melissa ...
# 0   [{'player_id': 4633, 'player_name': 'Magdalena...
# 1   [{'player_id': 10193, 'player_name': 'Chloe Ar...
# 0   [{'player_id': 4637, 'player_name': 'Ellie Roe...
# 1   [{'player_id': 4657, 'player_name': 'Anita Amm...
#
# [390 rows x 3 columns]

# %%
# Export lineups DataFrame
df_lineups.to_csv(data_dir_sb + '/lineups/raw/csv/wsl/' + '/df_sb_lineup_data_wsl.csv', index=None, header=True)

# %% [markdown]
# ---

# %% [markdown]
# ## <a id='#section4'>4. Data Engineering</a>
# Before conducting an [Exploratory Data Analysis (EDA)](#section5) of the data, we'll first need to clean and wrangle the datasets to a form that meet our needs.

# %% [markdown]
# ### <a id='#section4.1'>4.1. Join Datasets</a>
# Next, we're required to join the `Matches` DataFrame and the `Players` DataFrame to the `Events` DatFrame. The `Events` data is the base DataFrame in which we join the other tables via `wyId`, `matchId`, `competitionId`, `playerId`, and `teamId`.

# %% [markdown]
# ##### Join Competitions Data to Match Data

# %%
# Join the Events DataFrame to the Matches DataFrame
df_sb_match_competitions = pd.merge(df_sb_match_data_wsl_flat, df_sb_competitions_data_flat_select, left_on=['competition.competition_id', 'season.season_id'], right_on=['competition_id', 'season_id'])

# %%
df_sb_match_competitions.head()
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0     19743  2018-10-21  13:30:00.000           0           0    available
# 1     19740  2018-10-21  16:00:00.000           0           1    available
# 2     19716  2018-09-09  15:00:00.000           4           0    available
# 3     19800  2019-03-14  20:30:00.000           4           0    available
# 4     19739  2018-10-21  15:00:00.000           0           6    available
#
#                  last_updated  match_week  competition.competition_id  \
# 0            2020-07-29T05:00           6                          37
# 1            2020-07-29T05:00           6                          37
# 2            2020-07-29T05:00           1                          37
# 3  2020-08-24T14:34:34.401523          18                          37
# 4            2020-07-29T05:00           6                          37
#
#   competition.country_name competition.competition_name  season.season_id  \
# 0                  England      FA Women's Super League                 4
# 1                  England      FA Women's Super League                 4
# 2                  England      FA Women's Super League                 4
# 3                  England      FA Women's Super League                 4
# 4                  England      FA Women's Super League                 4
#
#   season.season_name  home_team.home_team_id    home_team.home_team_name  \
# 0          2018/2019                     969         Birmingham City WFC
# 1          2018/2019                     972         West Ham United LFC
# 2          2018/2019                     974                 Reading WFC
# 3          2018/2019                     968                 Arsenal WFC
# 4          2018/2019                     965  Brighton & Hove Albion WFC
#
#   home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 0                     female                      None                    68
# 1                     female                      None                    68
# 2                     female                      None                    68
# 3                     female                      None                    68
# 4                     female                      None                    68
#
#   home_team.country.name                                 home_team.managers  \
# 0                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1                England  [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 2                England  [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# 3                England  [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 4                England  [{'id': 149, 'name': 'Hope Patricia Powell', '...
#
#    away_team.away_team_id away_team.away_team_name away_team.away_team_gender  \
# 0                     971              Chelsea FCW                     female
# 1                     966            Liverpool WFC                     female
# 2                     970          Yeovil Town LFC                     female
# 3                     973         Bristol City WFC                     female
# 4                     746      Manchester City WFC                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 0                      None                    68                England
# 1                      None                    68                England
# 2                      None                    68                England
# 3                      None                    68                England
# 4                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 0  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 1  [{'id': 153, 'name': 'Chris Kirkland', 'nickna...                 1.0.3
# 2  [{'id': 147, 'name': 'Lee Burch', 'nickname': ...                 1.0.3
# 3  [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...                 1.1.0
# 4  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 0                     1         Regular Season      5332.0
# 1                     1         Regular Season      4062.0
# 2                     1         Regular Season       577.0
# 3                     1         Regular Season       456.0
# 4                     1         Regular Season         NaN
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 0  SportNation.bet Stadium               255.0        International
# 1   The Rush Green Stadium                68.0              England
# 2               Adams Park                68.0              England
# 3              Meadow Park                68.0              England
# 4                      NaN                 NaN                  NaN
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 0       898.0     A. Fearn                 NaN                  NaN
# 1       568.0   J. Packman                68.0              England
# 2       567.0    H. Conley                68.0              England
# 3       915.0   R. Whitton                 NaN                  NaN
# 4         NaN          NaN                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 0                            NaN                          NaN              37
# 1                            NaN                          NaN              37
# 2                            NaN                          NaN              37
# 3                            NaN                          NaN              37
# 4                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 0          4      England  FA Women's Super League             female
# 1          4      England  FA Women's Super League             female
# 2          4      England  FA Women's Super League             female
# 3          4      England  FA Women's Super League             female
# 4          4      England  FA Women's Super League             female
#
#   season_name
# 0   2018/2019
# 1   2018/2019
# 2   2018/2019
# 3   2018/2019
# 4   2018/2019

# %% [markdown]
# ##### Join Events Data to Match Data

# %%
# Join the Events DataFrame to the Matches-Competitions DataFrame
df_sb_events_match_competitions = pd.merge(df_events, df_sb_match_competitions, left_on=['match_id'], right_on=['match_id'])

# %%
df_sb_events_match_competitions.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12      1       1  00:00:00.000       0
# 1  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7      2       1  00:00:00.000       0
# 2  c036ad64-e323-4c8d-b770-3b6e26e7d882      3       1  00:00:00.000       0
# 3  48ca911e-66d7-4ebc-8514-6728f94df8d2      4       1  00:00:00.000       0
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
#
#    second  possession  duration  type.id    type.name  possession_team.id  \
# 0       0           1  0.000000       35  Starting XI                 969
# 1       0           1  0.000000       35  Starting XI                 969
# 2       0           1  0.000000       18   Half Start                 969
# 3       0           1  0.000000       18   Half Start                 969
# 4       1           2  1.228695       30         Pass                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 0  Birmingham City WFC                1      Regular Play      969
# 1  Birmingham City WFC                1      Regular Play      971
# 2  Birmingham City WFC                1      Regular Play      971
# 3  Birmingham City WFC                1      Regular Play      969
# 4          Chelsea FCW                9     From Kick Off      971
#
#              team.name  tactics.formation  \
# 0  Birmingham City WFC             4231.0
# 1          Chelsea FCW            42211.0
# 2          Chelsea FCW                NaN
# 3  Birmingham City WFC                NaN
# 4          Chelsea FCW                NaN
#
#                                       tactics.lineup  \
# 0  [{'player': {'id': 15560, 'name': 'Ann-Katrin ...
# 1  [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            related_events      location  player.id  \
# 0                                     NaN           NaN        NaN
# 1                                     NaN           NaN        NaN
# 2  [48ca911e-66d7-4ebc-8514-6728f94df8d2]           NaN        NaN
# 3  [c036ad64-e323-4c8d-b770-3b6e26e7d882]           NaN        NaN
# 4  [89cf3d24-ba04-4269-9071-1dfabf468cd1]  [61.0, 41.0]     4641.0
#
#        player.name  position.id   position.name  pass.recipient.id  \
# 0              NaN          NaN             NaN                NaN
# 1              NaN          NaN             NaN                NaN
# 2              NaN          NaN             NaN                NaN
# 3              NaN          NaN             NaN                NaN
# 4  Francesca Kirby         23.0  Center Forward            15549.0
#
#   pass.recipient.name  pass.length  pass.angle  pass.height.id  \
# 0                 NaN          NaN         NaN             NaN
# 1                 NaN          NaN         NaN             NaN
# 2                 NaN          NaN         NaN             NaN
# 3                 NaN          NaN         NaN             NaN
# 4        Sophie Ingle     9.848858    2.723368             1.0
#
#   pass.height.name pass.end_location  pass.type.id pass.type.name  \
# 0              NaN               NaN           NaN            NaN
# 1              NaN               NaN           NaN            NaN
# 2              NaN               NaN           NaN            NaN
# 3              NaN               NaN           NaN            NaN
# 4      Ground Pass      [52.0, 45.0]          65.0       Kick Off
#
#    pass.body_part.id pass.body_part.name carry.end_location under_pressure  \
# 0                NaN                 NaN                NaN            NaN
# 1                NaN                 NaN                NaN            NaN
# 2                NaN                 NaN                NaN            NaN
# 3                NaN                 NaN                NaN            NaN
# 4               40.0          Right Foot                NaN            NaN
#
#    pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 0              NaN               NaN                      NaN
# 1              NaN               NaN                      NaN
# 2              NaN               NaN                      NaN
# 3              NaN               NaN                      NaN
# 4              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 0                       NaN          NaN           NaN            NaN
# 1                       NaN          NaN           NaN            NaN
# 2                       NaN          NaN           NaN            NaN
# 3                       NaN          NaN           NaN            NaN
# 4                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 0             NaN                      NaN                       NaN
# 1             NaN                      NaN                       NaN
# 2             NaN                      NaN                       NaN
# 3             NaN                      NaN                       NaN
# 4             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 0                 NaN                  NaN                   NaN
# 1                 NaN                  NaN                   NaN
# 2                 NaN                  NaN                   NaN
# 3                 NaN                  NaN                   NaN
# 4                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 0              NaN                NaN               NaN              NaN
# 1              NaN                NaN               NaN              NaN
# 2              NaN                NaN               NaN              NaN
# 3              NaN                NaN               NaN              NaN
# 4              NaN                NaN               NaN              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 0                NaN                 NaN           NaN            NaN
# 1                NaN                 NaN           NaN            NaN
# 2                NaN                 NaN           NaN            NaN
# 3                NaN                 NaN           NaN            NaN
# 4                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              NaN               NaN                NaN                 NaN
# 3              NaN               NaN                NaN                 NaN
# 4              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 0               NaN                     NaN                     NaN
# 1               NaN                     NaN                     NaN
# 2               NaN                     NaN                     NaN
# 3               NaN                     NaN                     NaN
# 4               NaN                     NaN                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 0        NaN              NaN               NaN         NaN
# 1        NaN              NaN               NaN         NaN
# 2        NaN              NaN               NaN         NaN
# 3        NaN              NaN               NaN         NaN
# 4        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 0                            NaN               NaN                NaN
# 1                            NaN               NaN                NaN
# 2                            NaN               NaN                NaN
# 3                            NaN               NaN                NaN
# 4                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 0                     NaN                      NaN             NaN
# 1                     NaN                      NaN             NaN
# 2                     NaN                      NaN             NaN
# 3                     NaN                      NaN             NaN
# 4                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 0             NaN               NaN                NaN                 NaN
# 1             NaN               NaN                NaN                 NaN
# 2             NaN               NaN                NaN                 NaN
# 3             NaN               NaN                NaN                 NaN
# 4             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 0                    NaN                     NaN                      NaN
# 1                    NaN                     NaN                      NaN
# 2                    NaN                     NaN                      NaN
# 3                    NaN                     NaN                      NaN
# 4                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 0                           NaN                NaN                  NaN
# 1                           NaN                NaN                  NaN
# 2                           NaN                NaN                  NaN
# 3                           NaN                NaN                  NaN
# 4                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 0           NaN        NaN                      NaN                      NaN
# 1           NaN        NaN                      NaN                      NaN
# 2           NaN        NaN                      NaN                      NaN
# 3           NaN        NaN                      NaN                      NaN
# 4           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 0                NaN             NaN                    NaN              NaN
# 1                NaN             NaN                    NaN              NaN
# 2                NaN             NaN                    NaN              NaN
# 3                NaN             NaN                    NaN              NaN
# 4                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 0                      NaN                   NaN             NaN     19743
# 1                      NaN                   NaN             NaN     19743
# 2                      NaN                   NaN             NaN     19743
# 3                      NaN                   NaN             NaN     19743
# 4                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 0            NaN             NaN            NaN           NaN            NaN
# 1            NaN             NaN            NaN           NaN            NaN
# 2            NaN             NaN            NaN           NaN            NaN
# 3            NaN             NaN            NaN           NaN            NaN
# 4            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 0                   NaN                     NaN              NaN
# 1                   NaN                     NaN              NaN
# 2                   NaN                     NaN              NaN
# 3                   NaN                     NaN              NaN
# 4                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 0              NaN            NaN                     NaN
# 1              NaN            NaN                     NaN
# 2              NaN            NaN                     NaN
# 3              NaN            NaN                     NaN
# 4              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 0                      NaN  NaN                 NaN                  NaN
# 1                      NaN  NaN                 NaN                  NaN
# 2                      NaN  NaN                 NaN                  NaN
# 3                      NaN  NaN                 NaN                  NaN
# 4                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 0             NaN           NaN             NaN              NaN
# 1             NaN           NaN             NaN              NaN
# 2             NaN           NaN             NaN              NaN
# 3             NaN           NaN             NaN              NaN
# 4             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 0           NaN            NaN                    NaN                     NaN
# 1           NaN            NaN                    NaN                     NaN
# 2           NaN            NaN                    NaN                     NaN
# 3           NaN            NaN                    NaN                     NaN
# 4           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 0           NaN              NaN                   NaN
# 1           NaN              NaN                   NaN
# 2           NaN              NaN                   NaN
# 3           NaN              NaN                   NaN
# 4           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 0                              NaN                 NaN                    NaN
# 1                              NaN                 NaN                    NaN
# 2                              NaN                 NaN                    NaN
# 3                              NaN                 NaN                    NaN
# 4                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 0                  NaN                NaN                           NaN
# 1                  NaN                NaN                           NaN
# 2                  NaN                NaN                           NaN
# 3                  NaN                NaN                           NaN
# 4                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 0                      NaN                      NaN  2018-10-21  13:30:00.000
# 1                      NaN                      NaN  2018-10-21  13:30:00.000
# 2                      NaN                      NaN  2018-10-21  13:30:00.000
# 3                      NaN                      NaN  2018-10-21  13:30:00.000
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 0           0           0    available  2020-07-29T05:00           6
# 1           0           0    available  2020-07-29T05:00           6
# 2           0           0    available  2020-07-29T05:00           6
# 3           0           0    available  2020-07-29T05:00           6
# 4           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 0                          37                  England
# 1                          37                  England
# 2                          37                  England
# 3                          37                  England
# 4                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 0      FA Women's Super League                 4          2018/2019
# 1      FA Women's Super League                 4          2018/2019
# 2      FA Women's Super League                 4          2018/2019
# 3      FA Women's Super League                 4          2018/2019
# 4      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 0                     969      Birmingham City WFC                     female
# 1                     969      Birmingham City WFC                     female
# 2                     969      Birmingham City WFC                     female
# 3                     969      Birmingham City WFC                     female
# 4                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 0                      None                    68                England
# 1                      None                    68                England
# 2                      None                    68                England
# 3                      None                    68                England
# 4                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 0  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 1  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 2  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 3  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 0              Chelsea FCW                     female
# 1              Chelsea FCW                     female
# 2              Chelsea FCW                     female
# 3              Chelsea FCW                     female
# 4              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 0                      None                    68                England
# 1                      None                    68                England
# 2                      None                    68                England
# 3                      None                    68                England
# 4                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 0  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 1  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 2  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 3  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 0                     1         Regular Season      5332.0
# 1                     1         Regular Season      5332.0
# 2                     1         Regular Season      5332.0
# 3                     1         Regular Season      5332.0
# 4                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 0  SportNation.bet Stadium               255.0        International
# 1  SportNation.bet Stadium               255.0        International
# 2  SportNation.bet Stadium               255.0        International
# 3  SportNation.bet Stadium               255.0        International
# 4  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 0       898.0     A. Fearn                 NaN                  NaN
# 1       898.0     A. Fearn                 NaN                  NaN
# 2       898.0     A. Fearn                 NaN                  NaN
# 3       898.0     A. Fearn                 NaN                  NaN
# 4       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 0                            NaN                          NaN              37
# 1                            NaN                          NaN              37
# 2                            NaN                          NaN              37
# 3                            NaN                          NaN              37
# 4                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 0          4      England  FA Women's Super League             female
# 1          4      England  FA Women's Super League             female
# 2          4      England  FA Women's Super League             female
# 3          4      England  FA Women's Super League             female
# 4          4      England  FA Women's Super League             female
#
#   season_name
# 0   2018/2019
# 1   2018/2019
# 2   2018/2019
# 3   2018/2019
# 4   2018/2019

# %%
df_sb_events_match_competitions.shape
# Out:
# (648877, 193)

# %% [markdown]
# ### <a id='#section4.2'>4.2. Create Engineered Attributes</a>

# %% [markdown]
# #### <a id='#section4.2.1'>4.2.1. Create `Team` and `Opponent` Attributes</a>

# %%
df_sb_events_match_competitions['Team'] = np.where(df_sb_events_match_competitions['team.name'] == df_sb_events_match_competitions['home_team.home_team_name'], df_sb_events_match_competitions['home_team.home_team_name'], df_sb_events_match_competitions['away_team.away_team_name'])
df_sb_events_match_competitions['Opponent'] = np.where(df_sb_events_match_competitions['team.name'] == df_sb_events_match_competitions['away_team.away_team_name'], df_sb_events_match_competitions['home_team.home_team_name'], df_sb_events_match_competitions['away_team.away_team_name'])

# %% [markdown]
# #### <a id='#section4.2.2'>4.2.2. Create `Full_Fixture_Date` Attribute</a>

# %%
df_sb_events_match_competitions['Full_Fixture_Date'] = df_sb_events_match_competitions['match_date'].astype(str) + ' ' + df_sb_events_match_competitions['home_team.home_team_name'].astype(str)  + ' ' + df_sb_events_match_competitions['home_score'].astype(str) + ' ' + ' vs. ' + ' ' + df_sb_events_match_competitions['away_score'].astype(str) + ' ' + df_sb_events_match_competitions['away_team.away_team_name'].astype(str)

# %%
df_sb_events_match_competitions.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12      1       1  00:00:00.000       0
# 1  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7      2       1  00:00:00.000       0
# 2  c036ad64-e323-4c8d-b770-3b6e26e7d882      3       1  00:00:00.000       0
# 3  48ca911e-66d7-4ebc-8514-6728f94df8d2      4       1  00:00:00.000       0
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
#
#    second  possession  duration  type.id    type.name  possession_team.id  \
# 0       0           1  0.000000       35  Starting XI                 969
# 1       0           1  0.000000       35  Starting XI                 969
# 2       0           1  0.000000       18   Half Start                 969
# 3       0           1  0.000000       18   Half Start                 969
# 4       1           2  1.228695       30         Pass                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 0  Birmingham City WFC                1      Regular Play      969
# 1  Birmingham City WFC                1      Regular Play      971
# 2  Birmingham City WFC                1      Regular Play      971
# 3  Birmingham City WFC                1      Regular Play      969
# 4          Chelsea FCW                9     From Kick Off      971
#
#              team.name  tactics.formation  \
# 0  Birmingham City WFC             4231.0
# 1          Chelsea FCW            42211.0
# 2          Chelsea FCW                NaN
# 3  Birmingham City WFC                NaN
# 4          Chelsea FCW                NaN
#
#                                       tactics.lineup  \
# 0  [{'player': {'id': 15560, 'name': 'Ann-Katrin ...
# 1  [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            related_events      location  player.id  \
# 0                                     NaN           NaN        NaN
# 1                                     NaN           NaN        NaN
# 2  [48ca911e-66d7-4ebc-8514-6728f94df8d2]           NaN        NaN
# 3  [c036ad64-e323-4c8d-b770-3b6e26e7d882]           NaN        NaN
# 4  [89cf3d24-ba04-4269-9071-1dfabf468cd1]  [61.0, 41.0]     4641.0
#
#        player.name  position.id   position.name  pass.recipient.id  \
# 0              NaN          NaN             NaN                NaN
# 1              NaN          NaN             NaN                NaN
# 2              NaN          NaN             NaN                NaN
# 3              NaN          NaN             NaN                NaN
# 4  Francesca Kirby         23.0  Center Forward            15549.0
#
#   pass.recipient.name  pass.length  pass.angle  pass.height.id  \
# 0                 NaN          NaN         NaN             NaN
# 1                 NaN          NaN         NaN             NaN
# 2                 NaN          NaN         NaN             NaN
# 3                 NaN          NaN         NaN             NaN
# 4        Sophie Ingle     9.848858    2.723368             1.0
#
#   pass.height.name pass.end_location  pass.type.id pass.type.name  \
# 0              NaN               NaN           NaN            NaN
# 1              NaN               NaN           NaN            NaN
# 2              NaN               NaN           NaN            NaN
# 3              NaN               NaN           NaN            NaN
# 4      Ground Pass      [52.0, 45.0]          65.0       Kick Off
#
#    pass.body_part.id pass.body_part.name carry.end_location under_pressure  \
# 0                NaN                 NaN                NaN            NaN
# 1                NaN                 NaN                NaN            NaN
# 2                NaN                 NaN                NaN            NaN
# 3                NaN                 NaN                NaN            NaN
# 4               40.0          Right Foot                NaN            NaN
#
#    pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 0              NaN               NaN                      NaN
# 1              NaN               NaN                      NaN
# 2              NaN               NaN                      NaN
# 3              NaN               NaN                      NaN
# 4              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 0                       NaN          NaN           NaN            NaN
# 1                       NaN          NaN           NaN            NaN
# 2                       NaN          NaN           NaN            NaN
# 3                       NaN          NaN           NaN            NaN
# 4                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 0             NaN                      NaN                       NaN
# 1             NaN                      NaN                       NaN
# 2             NaN                      NaN                       NaN
# 3             NaN                      NaN                       NaN
# 4             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 0                 NaN                  NaN                   NaN
# 1                 NaN                  NaN                   NaN
# 2                 NaN                  NaN                   NaN
# 3                 NaN                  NaN                   NaN
# 4                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 0              NaN                NaN               NaN              NaN
# 1              NaN                NaN               NaN              NaN
# 2              NaN                NaN               NaN              NaN
# 3              NaN                NaN               NaN              NaN
# 4              NaN                NaN               NaN              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 0                NaN                 NaN           NaN            NaN
# 1                NaN                 NaN           NaN            NaN
# 2                NaN                 NaN           NaN            NaN
# 3                NaN                 NaN           NaN            NaN
# 4                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              NaN               NaN                NaN                 NaN
# 3              NaN               NaN                NaN                 NaN
# 4              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 0               NaN                     NaN                     NaN
# 1               NaN                     NaN                     NaN
# 2               NaN                     NaN                     NaN
# 3               NaN                     NaN                     NaN
# 4               NaN                     NaN                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 0        NaN              NaN               NaN         NaN
# 1        NaN              NaN               NaN         NaN
# 2        NaN              NaN               NaN         NaN
# 3        NaN              NaN               NaN         NaN
# 4        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 0                            NaN               NaN                NaN
# 1                            NaN               NaN                NaN
# 2                            NaN               NaN                NaN
# 3                            NaN               NaN                NaN
# 4                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 0                     NaN                      NaN             NaN
# 1                     NaN                      NaN             NaN
# 2                     NaN                      NaN             NaN
# 3                     NaN                      NaN             NaN
# 4                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 0             NaN               NaN                NaN                 NaN
# 1             NaN               NaN                NaN                 NaN
# 2             NaN               NaN                NaN                 NaN
# 3             NaN               NaN                NaN                 NaN
# 4             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 0                    NaN                     NaN                      NaN
# 1                    NaN                     NaN                      NaN
# 2                    NaN                     NaN                      NaN
# 3                    NaN                     NaN                      NaN
# 4                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 0                           NaN                NaN                  NaN
# 1                           NaN                NaN                  NaN
# 2                           NaN                NaN                  NaN
# 3                           NaN                NaN                  NaN
# 4                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 0           NaN        NaN                      NaN                      NaN
# 1           NaN        NaN                      NaN                      NaN
# 2           NaN        NaN                      NaN                      NaN
# 3           NaN        NaN                      NaN                      NaN
# 4           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 0                NaN             NaN                    NaN              NaN
# 1                NaN             NaN                    NaN              NaN
# 2                NaN             NaN                    NaN              NaN
# 3                NaN             NaN                    NaN              NaN
# 4                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 0                      NaN                   NaN             NaN     19743
# 1                      NaN                   NaN             NaN     19743
# 2                      NaN                   NaN             NaN     19743
# 3                      NaN                   NaN             NaN     19743
# 4                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 0            NaN             NaN            NaN           NaN            NaN
# 1            NaN             NaN            NaN           NaN            NaN
# 2            NaN             NaN            NaN           NaN            NaN
# 3            NaN             NaN            NaN           NaN            NaN
# 4            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 0                   NaN                     NaN              NaN
# 1                   NaN                     NaN              NaN
# 2                   NaN                     NaN              NaN
# 3                   NaN                     NaN              NaN
# 4                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 0              NaN            NaN                     NaN
# 1              NaN            NaN                     NaN
# 2              NaN            NaN                     NaN
# 3              NaN            NaN                     NaN
# 4              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 0                      NaN  NaN                 NaN                  NaN
# 1                      NaN  NaN                 NaN                  NaN
# 2                      NaN  NaN                 NaN                  NaN
# 3                      NaN  NaN                 NaN                  NaN
# 4                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 0             NaN           NaN             NaN              NaN
# 1             NaN           NaN             NaN              NaN
# 2             NaN           NaN             NaN              NaN
# 3             NaN           NaN             NaN              NaN
# 4             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 0           NaN            NaN                    NaN                     NaN
# 1           NaN            NaN                    NaN                     NaN
# 2           NaN            NaN                    NaN                     NaN
# 3           NaN            NaN                    NaN                     NaN
# 4           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 0           NaN              NaN                   NaN
# 1           NaN              NaN                   NaN
# 2           NaN              NaN                   NaN
# 3           NaN              NaN                   NaN
# 4           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 0                              NaN                 NaN                    NaN
# 1                              NaN                 NaN                    NaN
# 2                              NaN                 NaN                    NaN
# 3                              NaN                 NaN                    NaN
# 4                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 0                  NaN                NaN                           NaN
# 1                  NaN                NaN                           NaN
# 2                  NaN                NaN                           NaN
# 3                  NaN                NaN                           NaN
# 4                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 0                      NaN                      NaN  2018-10-21  13:30:00.000
# 1                      NaN                      NaN  2018-10-21  13:30:00.000
# 2                      NaN                      NaN  2018-10-21  13:30:00.000
# 3                      NaN                      NaN  2018-10-21  13:30:00.000
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 0           0           0    available  2020-07-29T05:00           6
# 1           0           0    available  2020-07-29T05:00           6
# 2           0           0    available  2020-07-29T05:00           6
# 3           0           0    available  2020-07-29T05:00           6
# 4           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 0                          37                  England
# 1                          37                  England
# 2                          37                  England
# 3                          37                  England
# 4                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 0      FA Women's Super League                 4          2018/2019
# 1      FA Women's Super League                 4          2018/2019
# 2      FA Women's Super League                 4          2018/2019
# 3      FA Women's Super League                 4          2018/2019
# 4      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 0                     969      Birmingham City WFC                     female
# 1                     969      Birmingham City WFC                     female
# 2                     969      Birmingham City WFC                     female
# 3                     969      Birmingham City WFC                     female
# 4                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 0                      None                    68                England
# 1                      None                    68                England
# 2                      None                    68                England
# 3                      None                    68                England
# 4                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 0  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 1  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 2  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 3  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 0              Chelsea FCW                     female
# 1              Chelsea FCW                     female
# 2              Chelsea FCW                     female
# 3              Chelsea FCW                     female
# 4              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 0                      None                    68                England
# 1                      None                    68                England
# 2                      None                    68                England
# 3                      None                    68                England
# 4                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 0  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 1  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 2  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 3  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 0                     1         Regular Season      5332.0
# 1                     1         Regular Season      5332.0
# 2                     1         Regular Season      5332.0
# 3                     1         Regular Season      5332.0
# 4                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 0  SportNation.bet Stadium               255.0        International
# 1  SportNation.bet Stadium               255.0        International
# 2  SportNation.bet Stadium               255.0        International
# 3  SportNation.bet Stadium               255.0        International
# 4  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 0       898.0     A. Fearn                 NaN                  NaN
# 1       898.0     A. Fearn                 NaN                  NaN
# 2       898.0     A. Fearn                 NaN                  NaN
# 3       898.0     A. Fearn                 NaN                  NaN
# 4       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 0                            NaN                          NaN              37
# 1                            NaN                          NaN              37
# 2                            NaN                          NaN              37
# 3                            NaN                          NaN              37
# 4                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 0          4      England  FA Women's Super League             female
# 1          4      England  FA Women's Super League             female
# 2          4      England  FA Women's Super League             female
# 3          4      England  FA Women's Super League             female
# 4          4      England  FA Women's Super League             female
#
#   season_name                 Team             Opponent  \
# 0   2018/2019  Birmingham City WFC          Chelsea FCW
# 1   2018/2019          Chelsea FCW  Birmingham City WFC
# 2   2018/2019          Chelsea FCW  Birmingham City WFC
# 3   2018/2019  Birmingham City WFC          Chelsea FCW
# 4   2018/2019          Chelsea FCW  Birmingham City WFC
#
#                                    Full_Fixture_Date
# 0  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 1  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 2  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...

# %% [markdown]
# ### <a id='#section4.3'>4.3. Export Raw DataFrame</a>

# %%
# Export 
df_sb_events_match_competitions.to_csv(data_dir_sb + '/combined/raw/csv/wsl/' + '/df_sb_combined_data_wsl.csv', index=None, header=True)

# %% [markdown]
# ## <a id='#section5'>5. Data Engineering</a>

# %% [markdown]
# ### <a id='#section5.1'>5.1. Assign Raw DataFrame to Engineered DataFrame</a>

# %%
# Assign Raw DataFrame to Engineered DataFrame
df_sb = df_sb_events_match_competitions

# %% [markdown]
# ### <a id='#section5.2'>5.2. Extract Lineups from DataFrame</a>

# %%
# List unique values in the df_sb['type.name'] column
df_sb['type.name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Ball Recovery', 'Block', 'Duel', 'Interception',
#        'Dribbled Past', 'Dribble', 'Shot', 'Goal Keeper',
#        'Foul Committed', 'Foul Won', 'Dispossessed', 'Clearance',
#        'Miscontrol', '50/50', 'Injury Stoppage', 'Player Off',
#        'Player On', 'Substitution', 'Shield', 'Tactical Shift',
#        'Half End', 'Error', 'Referee Ball-Drop', 'Offside',
#        'Own Goal Against', 'Own Goal For', 'Bad Behaviour'], dtype=object)

# %% [markdown]
# The starting XI players and formation can be found in the rows where `type.name` is 'Starting XI'.

# %%
df_lineup = df_sb[df_sb['type.name'] == 'Starting XI']

# %%
df_lineup
# Out:
#                                           id  index  period     timestamp  \
# 0       1c6261d9-f0ae-4430-a087-30b4d1ef6e12      1       1  00:00:00.000
# 1       489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7      2       1  00:00:00.000
# 3527    58bb5658-80a5-4b17-86a0-20111ab91353      1       1  00:00:00.000
# 3528    bbad0c35-aef8-40bf-b213-226e86c5f2f7      2       1  00:00:00.000
# 6565    04c3b8ac-d7a9-490e-a167-334fb353c82a      1       1  00:00:00.000
# ...                                      ...    ...     ...           ...
# 638307  36de8f79-c32a-4163-8ad7-bf2da3db4f9e      2       1  00:00:00.000
# 641636  32898ea7-108b-4f9b-86ec-847f35aa2974      1       1  00:00:00.000
# 641637  33bbf774-d931-4e8e-bbaa-6ba618878f25      2       1  00:00:00.000
# 645124  d7b811ef-4156-4e3c-a357-aed72b7c53b7      1       1  00:00:00.000
# 645125  313dea2e-3071-48c3-875b-a8476a8339b4      2       1  00:00:00.000
#
#         minute  second  possession  duration  type.id    type.name  \
# 0            0       0           1       0.0       35  Starting XI
# 1            0       0           1       0.0       35  Starting XI
# 3527         0       0           1       0.0       35  Starting XI
# 3528         0       0           1       0.0       35  Starting XI
# 6565         0       0           1       0.0       35  Starting XI
# ...        ...     ...         ...       ...      ...          ...
# 638307       0       0           1       0.0       35  Starting XI
# 641636       0       0           1       0.0       35  Starting XI
# 641637       0       0           1       0.0       35  Starting XI
# 645124       0       0           1       0.0       35  Starting XI
# 645125       0       0           1       0.0       35  Starting XI
#
#         possession_team.id possession_team.name  play_pattern.id  \
# 0                      969  Birmingham City WFC                1
# 1                      969  Birmingham City WFC                1
# 3527                   972  West Ham United LFC                1
# 3528                   972  West Ham United LFC                1
# 6565                   974          Reading WFC                1
# ...                    ...                  ...              ...
# 638307                1475    Manchester United                1
# 641636                 966        Liverpool WFC                1
# 641637                 966        Liverpool WFC                1
# 645124                 971          Chelsea FCW                1
# 645125                 971          Chelsea FCW                1
#
#        play_pattern.name  team.id                team.name  tactics.formation  \
# 0           Regular Play      969      Birmingham City WFC             4231.0
# 1           Regular Play      971              Chelsea FCW            42211.0
# 3527        Regular Play      972      West Ham United LFC              442.0
# 3528        Regular Play      966            Liverpool WFC             4321.0
# 6565        Regular Play      974              Reading WFC             4222.0
# ...                  ...      ...                      ...                ...
# 638307      Regular Play      749  Tottenham Hotspur Women              442.0
# 641636      Regular Play      966            Liverpool WFC             4231.0
# 641637      Regular Play      967              Everton LFC              433.0
# 645124      Regular Play      971              Chelsea FCW              442.0
# 645125      Regular Play      969      Birmingham City WFC             4231.0
#
#                                            tactics.lineup related_events  \
# 0       [{'player': {'id': 15560, 'name': 'Ann-Katrin ...            NaN
# 1       [{'player': {'id': 4640, 'name': 'Rut Hedvig L...            NaN
# 3527    [{'player': {'id': 18158, 'name': 'Rebecca Lei...            NaN
# 3528    [{'player': {'id': 19778, 'name': 'Frances Kit...            NaN
# 6565    [{'player': {'id': 15719, 'name': 'Grace Molon...            NaN
# ...                                                   ...            ...
# 638307  [{'player': {'id': 33349, 'name': 'Chloe Morga...            NaN
# 641636  [{'player': {'id': 15626, 'name': 'Anke Preuß'...            NaN
# 641637  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...            NaN
# 645124  [{'player': {'id': 19421, 'name': 'Carly Mitch...            NaN
# 645125  [{'player': {'id': 22032, 'name': 'Hannah Hamp...            NaN
#
#        location  player.id player.name  position.id position.name  \
# 0           NaN        NaN         NaN          NaN           NaN
# 1           NaN        NaN         NaN          NaN           NaN
# 3527        NaN        NaN         NaN          NaN           NaN
# 3528        NaN        NaN         NaN          NaN           NaN
# 6565        NaN        NaN         NaN          NaN           NaN
# ...         ...        ...         ...          ...           ...
# 638307      NaN        NaN         NaN          NaN           NaN
# 641636      NaN        NaN         NaN          NaN           NaN
# 641637      NaN        NaN         NaN          NaN           NaN
# 645124      NaN        NaN         NaN          NaN           NaN
# 645125      NaN        NaN         NaN          NaN           NaN
#
#         pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 0                     NaN                 NaN          NaN         NaN
# 1                     NaN                 NaN          NaN         NaN
# 3527                  NaN                 NaN          NaN         NaN
# 3528                  NaN                 NaN          NaN         NaN
# 6565                  NaN                 NaN          NaN         NaN
# ...                   ...                 ...          ...         ...
# 638307                NaN                 NaN          NaN         NaN
# 641636                NaN                 NaN          NaN         NaN
# 641637                NaN                 NaN          NaN         NaN
# 645124                NaN                 NaN          NaN         NaN
# 645125                NaN                 NaN          NaN         NaN
#
#         pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 0                  NaN              NaN               NaN           NaN
# 1                  NaN              NaN               NaN           NaN
# 3527               NaN              NaN               NaN           NaN
# 3528               NaN              NaN               NaN           NaN
# 6565               NaN              NaN               NaN           NaN
# ...                ...              ...               ...           ...
# 638307             NaN              NaN               NaN           NaN
# 641636             NaN              NaN               NaN           NaN
# 641637             NaN              NaN               NaN           NaN
# 645124             NaN              NaN               NaN           NaN
# 645125             NaN              NaN               NaN           NaN
#
#        pass.type.name  pass.body_part.id pass.body_part.name  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 3527              NaN                NaN                 NaN
# 3528              NaN                NaN                 NaN
# 6565              NaN                NaN                 NaN
# ...               ...                ...                 ...
# 638307            NaN                NaN                 NaN
# 641636            NaN                NaN                 NaN
# 641637            NaN                NaN                 NaN
# 645124            NaN                NaN                 NaN
# 645125            NaN                NaN                 NaN
#
#        carry.end_location under_pressure  pass.outcome.id pass.outcome.name  \
# 0                     NaN            NaN              NaN               NaN
# 1                     NaN            NaN              NaN               NaN
# 3527                  NaN            NaN              NaN               NaN
# 3528                  NaN            NaN              NaN               NaN
# 6565                  NaN            NaN              NaN               NaN
# ...                   ...            ...              ...               ...
# 638307                NaN            NaN              NaN               NaN
# 641636                NaN            NaN              NaN               NaN
# 641637                NaN            NaN              NaN               NaN
# 645124                NaN            NaN              NaN               NaN
# 645125                NaN            NaN              NaN               NaN
#
#         ball_receipt.outcome.id ball_receipt.outcome.name counterpress  \
# 0                           NaN                       NaN          NaN
# 1                           NaN                       NaN          NaN
# 3527                        NaN                       NaN          NaN
# 3528                        NaN                       NaN          NaN
# 6565                        NaN                       NaN          NaN
# ...                         ...                       ...          ...
# 638307                      NaN                       NaN          NaN
# 641636                      NaN                       NaN          NaN
# 641637                      NaN                       NaN          NaN
# 645124                      NaN                       NaN          NaN
# 645125                      NaN                       NaN          NaN
#
#         duel.type.id duel.type.name pass.aerial_won  interception.outcome.id  \
# 0                NaN            NaN             NaN                      NaN
# 1                NaN            NaN             NaN                      NaN
# 3527             NaN            NaN             NaN                      NaN
# 3528             NaN            NaN             NaN                      NaN
# 6565             NaN            NaN             NaN                      NaN
# ...              ...            ...             ...                      ...
# 638307           NaN            NaN             NaN                      NaN
# 641636           NaN            NaN             NaN                      NaN
# 641637           NaN            NaN             NaN                      NaN
# 645124           NaN            NaN             NaN                      NaN
# 645125           NaN            NaN             NaN                      NaN
#
#        interception.outcome.name  dribble.outcome.id dribble.outcome.name  \
# 0                            NaN                 NaN                  NaN
# 1                            NaN                 NaN                  NaN
# 3527                         NaN                 NaN                  NaN
# 3528                         NaN                 NaN                  NaN
# 6565                         NaN                 NaN                  NaN
# ...                          ...                 ...                  ...
# 638307                       NaN                 NaN                  NaN
# 641636                       NaN                 NaN                  NaN
# 641637                       NaN                 NaN                  NaN
# 645124                       NaN                 NaN                  NaN
# 645125                       NaN                 NaN                  NaN
#
#        pass.assisted_shot_id pass.shot_assist  shot.statsbomb_xg  \
# 0                        NaN              NaN                NaN
# 1                        NaN              NaN                NaN
# 3527                     NaN              NaN                NaN
# 3528                     NaN              NaN                NaN
# 6565                     NaN              NaN                NaN
# ...                      ...              ...                ...
# 638307                   NaN              NaN                NaN
# 641636                   NaN              NaN                NaN
# 641637                   NaN              NaN                NaN
# 645124                   NaN              NaN                NaN
# 645125                   NaN              NaN                NaN
#
#        shot.end_location shot.key_pass_id  shot.body_part.id  \
# 0                    NaN              NaN                NaN
# 1                    NaN              NaN                NaN
# 3527                 NaN              NaN                NaN
# 3528                 NaN              NaN                NaN
# 6565                 NaN              NaN                NaN
# ...                  ...              ...                ...
# 638307               NaN              NaN                NaN
# 641636               NaN              NaN                NaN
# 641637               NaN              NaN                NaN
# 645124               NaN              NaN                NaN
# 645125               NaN              NaN                NaN
#
#        shot.body_part.name  shot.type.id shot.type.name  shot.outcome.id  \
# 0                      NaN           NaN            NaN              NaN
# 1                      NaN           NaN            NaN              NaN
# 3527                   NaN           NaN            NaN              NaN
# 3528                   NaN           NaN            NaN              NaN
# 6565                   NaN           NaN            NaN              NaN
# ...                    ...           ...            ...              ...
# 638307                 NaN           NaN            NaN              NaN
# 641636                 NaN           NaN            NaN              NaN
# 641637                 NaN           NaN            NaN              NaN
# 645124                 NaN           NaN            NaN              NaN
# 645125                 NaN           NaN            NaN              NaN
#
#        shot.outcome.name  shot.technique.id shot.technique.name  \
# 0                    NaN                NaN                 NaN
# 1                    NaN                NaN                 NaN
# 3527                 NaN                NaN                 NaN
# 3528                 NaN                NaN                 NaN
# 6565                 NaN                NaN                 NaN
# ...                  ...                ...                 ...
# 638307               NaN                NaN                 NaN
# 641636               NaN                NaN                 NaN
# 641637               NaN                NaN                 NaN
# 645124               NaN                NaN                 NaN
# 645125               NaN                NaN                 NaN
#
#        shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 3527                 NaN                     NaN                     NaN
# 3528                 NaN                     NaN                     NaN
# 6565                 NaN                     NaN                     NaN
# ...                  ...                     ...                     ...
# 638307               NaN                     NaN                     NaN
# 641636               NaN                     NaN                     NaN
# 641637               NaN                     NaN                     NaN
# 645124               NaN                     NaN                     NaN
# 645125               NaN                     NaN                     NaN
#
#        goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 0                           NaN                 NaN                  NaN
# 1                           NaN                 NaN                  NaN
# 3527                        NaN                 NaN                  NaN
# 3528                        NaN                 NaN                  NaN
# 6565                        NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 638307                      NaN                 NaN                  NaN
# 641636                      NaN                 NaN                  NaN
# 641637                      NaN                 NaN                  NaN
# 645124                      NaN                 NaN                  NaN
# 645125                      NaN                 NaN                  NaN
#
#        off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 0             NaN              NaN               NaN         NaN
# 1             NaN              NaN               NaN         NaN
# 3527          NaN              NaN               NaN         NaN
# 3528          NaN              NaN               NaN         NaN
# 6565          NaN              NaN               NaN         NaN
# ...           ...              ...               ...         ...
# 638307        NaN              NaN               NaN         NaN
# 641636        NaN              NaN               NaN         NaN
# 641637        NaN              NaN               NaN         NaN
# 645124        NaN              NaN               NaN         NaN
# 645125        NaN              NaN               NaN         NaN
#
#        ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 0                                 NaN               NaN                NaN
# 1                                 NaN               NaN                NaN
# 3527                              NaN               NaN                NaN
# 3528                              NaN               NaN                NaN
# 6565                              NaN               NaN                NaN
# ...                               ...               ...                ...
# 638307                            NaN               NaN                NaN
# 641636                            NaN               NaN                NaN
# 641637                            NaN               NaN                NaN
# 645124                            NaN               NaN                NaN
# 645125                            NaN               NaN                NaN
#
#         foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 0                          NaN                      NaN             NaN
# 1                          NaN                      NaN             NaN
# 3527                       NaN                      NaN             NaN
# 3528                       NaN                      NaN             NaN
# 6565                       NaN                      NaN             NaN
# ...                        ...                      ...             ...
# 638307                     NaN                      NaN             NaN
# 641636                     NaN                      NaN             NaN
# 641637                     NaN                      NaN             NaN
# 645124                     NaN                      NaN             NaN
# 645125                     NaN                      NaN             NaN
#
#        shot.aerial_won pass.through_ball  pass.technique.id  \
# 0                  NaN               NaN                NaN
# 1                  NaN               NaN                NaN
# 3527               NaN               NaN                NaN
# 3528               NaN               NaN                NaN
# 6565               NaN               NaN                NaN
# ...                ...               ...                ...
# 638307             NaN               NaN                NaN
# 641636             NaN               NaN                NaN
# 641637             NaN               NaN                NaN
# 645124             NaN               NaN                NaN
# 645125             NaN               NaN                NaN
#
#        pass.technique.name  goalkeeper.outcome.id goalkeeper.outcome.name  \
# 0                      NaN                    NaN                     NaN
# 1                      NaN                    NaN                     NaN
# 3527                   NaN                    NaN                     NaN
# 3528                   NaN                    NaN                     NaN
# 6565                   NaN                    NaN                     NaN
# ...                    ...                    ...                     ...
# 638307                 NaN                    NaN                     NaN
# 641636                 NaN                    NaN                     NaN
# 641637                 NaN                    NaN                     NaN
# 645124                 NaN                    NaN                     NaN
# 645125                 NaN                    NaN                     NaN
#
#         goalkeeper.technique.id goalkeeper.technique.name  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 3527                        NaN                       NaN
# 3528                        NaN                       NaN
# 6565                        NaN                       NaN
# ...                         ...                       ...
# 638307                      NaN                       NaN
# 641636                      NaN                       NaN
# 641637                      NaN                       NaN
# 645124                      NaN                       NaN
# 645125                      NaN                       NaN
#
#         goalkeeper.body_part.id goalkeeper.body_part.name  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 3527                        NaN                       NaN
# 3528                        NaN                       NaN
# 6565                        NaN                       NaN
# ...                         ...                       ...
# 638307                      NaN                       NaN
# 641636                      NaN                       NaN
# 641637                      NaN                       NaN
# 645124                      NaN                       NaN
# 645125                      NaN                       NaN
#
#         substitution.outcome.id substitution.outcome.name  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 3527                        NaN                       NaN
# 3528                        NaN                       NaN
# 6565                        NaN                       NaN
# ...                         ...                       ...
# 638307                      NaN                       NaN
# 641636                      NaN                       NaN
# 641637                      NaN                       NaN
# 645124                      NaN                       NaN
# 645125                      NaN                       NaN
#
#         substitution.replacement.id substitution.replacement.name  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 3527                            NaN                           NaN
# 3528                            NaN                           NaN
# 6565                            NaN                           NaN
# ...                             ...                           ...
# 638307                          NaN                           NaN
# 641636                          NaN                           NaN
# 641637                          NaN                           NaN
# 645124                          NaN                           NaN
# 645125                          NaN                           NaN
#
#        foul_won.defensive clearance.aerial_won pass.backheel pass.cross  \
# 0                     NaN                  NaN           NaN        NaN
# 1                     NaN                  NaN           NaN        NaN
# 3527                  NaN                  NaN           NaN        NaN
# 3528                  NaN                  NaN           NaN        NaN
# 6565                  NaN                  NaN           NaN        NaN
# ...                   ...                  ...           ...        ...
# 638307                NaN                  NaN           NaN        NaN
# 641636                NaN                  NaN           NaN        NaN
# 641637                NaN                  NaN           NaN        NaN
# 645124                NaN                  NaN           NaN        NaN
# 645125                NaN                  NaN           NaN        NaN
#
#        foul_committed.offensive foul_committed.advantage foul_won.advantage  \
# 0                           NaN                      NaN                NaN
# 1                           NaN                      NaN                NaN
# 3527                        NaN                      NaN                NaN
# 3528                        NaN                      NaN                NaN
# 6565                        NaN                      NaN                NaN
# ...                         ...                      ...                ...
# 638307                      NaN                      NaN                NaN
# 641636                      NaN                      NaN                NaN
# 641637                      NaN                      NaN                NaN
# 645124                      NaN                      NaN                NaN
# 645125                      NaN                      NaN                NaN
#
#        dribble.overrun foul_committed.penalty foul_won.penalty  \
# 0                  NaN                    NaN              NaN
# 1                  NaN                    NaN              NaN
# 3527               NaN                    NaN              NaN
# 3528               NaN                    NaN              NaN
# 6565               NaN                    NaN              NaN
# ...                ...                    ...              ...
# 638307             NaN                    NaN              NaN
# 641636             NaN                    NaN              NaN
# 641637             NaN                    NaN              NaN
# 645124             NaN                    NaN              NaN
# 645125             NaN                    NaN              NaN
#
#        injury_stoppage.in_chain miscontrol.aerial_won block.offensive  \
# 0                           NaN                   NaN             NaN
# 1                           NaN                   NaN             NaN
# 3527                        NaN                   NaN             NaN
# 3528                        NaN                   NaN             NaN
# 6565                        NaN                   NaN             NaN
# ...                         ...                   ...             ...
# 638307                      NaN                   NaN             NaN
# 641636                      NaN                   NaN             NaN
# 641637                      NaN                   NaN             NaN
# 645124                      NaN                   NaN             NaN
# 645125                      NaN                   NaN             NaN
#
#         match_id shot.open_goal shot.first_time dribble.nutmeg pass.cut_back  \
# 0          19743            NaN             NaN            NaN           NaN
# 1          19743            NaN             NaN            NaN           NaN
# 3527       19740            NaN             NaN            NaN           NaN
# 3528       19740            NaN             NaN            NaN           NaN
# 6565       19716            NaN             NaN            NaN           NaN
# ...          ...            ...             ...            ...           ...
# 638307   2275137            NaN             NaN            NaN           NaN
# 641636   2275056            NaN             NaN            NaN           NaN
# 641637   2275056            NaN             NaN            NaN           NaN
# 645124   2275074            NaN             NaN            NaN           NaN
# 645125   2275074            NaN             NaN            NaN           NaN
#
#        pass.deflected pass.goal_assist  foul_committed.type.id  \
# 0                 NaN              NaN                     NaN
# 1                 NaN              NaN                     NaN
# 3527              NaN              NaN                     NaN
# 3528              NaN              NaN                     NaN
# 6565              NaN              NaN                     NaN
# ...               ...              ...                     ...
# 638307            NaN              NaN                     NaN
# 641636            NaN              NaN                     NaN
# 641637            NaN              NaN                     NaN
# 645124            NaN              NaN                     NaN
# 645125            NaN              NaN                     NaN
#
#        foul_committed.type.name pass.miscommunication ball_recovery.offensive  \
# 0                           NaN                   NaN                     NaN
# 1                           NaN                   NaN                     NaN
# 3527                        NaN                   NaN                     NaN
# 3528                        NaN                   NaN                     NaN
# 6565                        NaN                   NaN                     NaN
# ...                         ...                   ...                     ...
# 638307                      NaN                   NaN                     NaN
# 641636                      NaN                   NaN                     NaN
# 641637                      NaN                   NaN                     NaN
# 645124                      NaN                   NaN                     NaN
# 645125                      NaN                   NaN                     NaN
#
#        block.save_block block.deflection clearance.head  \
# 0                   NaN              NaN            NaN
# 1                   NaN              NaN            NaN
# 3527                NaN              NaN            NaN
# 3528                NaN              NaN            NaN
# 6565                NaN              NaN            NaN
# ...                 ...              ...            ...
# 638307              NaN              NaN            NaN
# 641636              NaN              NaN            NaN
# 641637              NaN              NaN            NaN
# 645124              NaN              NaN            NaN
# 645125              NaN              NaN            NaN
#
#         clearance.body_part.id clearance.body_part.name  out  \
# 0                          NaN                      NaN  NaN
# 1                          NaN                      NaN  NaN
# 3527                       NaN                      NaN  NaN
# 3528                       NaN                      NaN  NaN
# 6565                       NaN                      NaN  NaN
# ...                        ...                      ...  ...
# 638307                     NaN                      NaN  NaN
# 641636                     NaN                      NaN  NaN
# 641637                     NaN                      NaN  NaN
# 645124                     NaN                      NaN  NaN
# 645125                     NaN                      NaN  NaN
#
#        clearance.left_foot clearance.right_foot pass.inswinging pass.straight  \
# 0                      NaN                  NaN             NaN           NaN
# 1                      NaN                  NaN             NaN           NaN
# 3527                   NaN                  NaN             NaN           NaN
# 3528                   NaN                  NaN             NaN           NaN
# 6565                   NaN                  NaN             NaN           NaN
# ...                    ...                  ...             ...           ...
# 638307                 NaN                  NaN             NaN           NaN
# 641636                 NaN                  NaN             NaN           NaN
# 641637                 NaN                  NaN             NaN           NaN
# 645124                 NaN                  NaN             NaN           NaN
# 645125                 NaN                  NaN             NaN           NaN
#
#        clearance.other pass.outswinging shot.redirect shot.deflected  \
# 0                  NaN              NaN           NaN            NaN
# 1                  NaN              NaN           NaN            NaN
# 3527               NaN              NaN           NaN            NaN
# 3528               NaN              NaN           NaN            NaN
# 6565               NaN              NaN           NaN            NaN
# ...                ...              ...           ...            ...
# 638307             NaN              NaN           NaN            NaN
# 641636             NaN              NaN           NaN            NaN
# 641637             NaN              NaN           NaN            NaN
# 645124             NaN              NaN           NaN            NaN
# 645125             NaN              NaN           NaN            NaN
#
#         bad_behaviour.card.id bad_behaviour.card.name pass.no_touch  \
# 0                         NaN                     NaN           NaN
# 1                         NaN                     NaN           NaN
# 3527                      NaN                     NaN           NaN
# 3528                      NaN                     NaN           NaN
# 6565                      NaN                     NaN           NaN
# ...                       ...                     ...           ...
# 638307                    NaN                     NaN           NaN
# 641636                    NaN                     NaN           NaN
# 641637                    NaN                     NaN           NaN
# 645124                    NaN                     NaN           NaN
# 645125                    NaN                     NaN           NaN
#
#        dribble.no_touch shot.saved_off_target  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 3527                NaN                   NaN
# 3528                NaN                   NaN
# 6565                NaN                   NaN
# ...                 ...                   ...
# 638307              NaN                   NaN
# 641636              NaN                   NaN
# 641637              NaN                   NaN
# 645124              NaN                   NaN
# 645125              NaN                   NaN
#
#        goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 3527                                NaN                 NaN
# 3528                                NaN                 NaN
# 6565                                NaN                 NaN
# ...                                 ...                 ...
# 638307                              NaN                 NaN
# 641636                              NaN                 NaN
# 641637                              NaN                 NaN
# 645124                              NaN                 NaN
# 645125                              NaN                 NaN
#
#        goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 0                         NaN                  NaN                NaN
# 1                         NaN                  NaN                NaN
# 3527                      NaN                  NaN                NaN
# 3528                      NaN                  NaN                NaN
# 6565                      NaN                  NaN                NaN
# ...                       ...                  ...                ...
# 638307                    NaN                  NaN                NaN
# 641636                    NaN                  NaN                NaN
# 641637                    NaN                  NaN                NaN
# 645124                    NaN                  NaN                NaN
# 645125                    NaN                  NaN                NaN
#
#        goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 3527                             NaN                     NaN
# 3528                             NaN                     NaN
# 6565                             NaN                     NaN
# ...                              ...                     ...
# 638307                           NaN                     NaN
# 641636                           NaN                     NaN
# 641637                           NaN                     NaN
# 645124                           NaN                     NaN
# 645125                           NaN                     NaN
#
#        goalkeeper.success_out shot.follows_dribble  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 3527                      NaN                  NaN
# 3528                      NaN                  NaN
# 6565                      NaN                  NaN
# ...                       ...                  ...
# 638307                    NaN                  NaN
# 641636                    NaN                  NaN
# 641637                    NaN                  NaN
# 645124                    NaN                  NaN
# 645125                    NaN                  NaN
#
#        half_start.late_video_start goalkeeper.success_in_play  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 3527                           NaN                        NaN
# 3528                           NaN                        NaN
# 6565                           NaN                        NaN
# ...                            ...                        ...
# 638307                         NaN                        NaN
# 641636                         NaN                        NaN
# 641637                         NaN                        NaN
# 645124                         NaN                        NaN
# 645125                         NaN                        NaN
#
#        half_end.early_video_end goalkeeper.saved_to_post  match_date  \
# 0                           NaN                      NaN  2018-10-21
# 1                           NaN                      NaN  2018-10-21
# 3527                        NaN                      NaN  2018-10-21
# 3528                        NaN                      NaN  2018-10-21
# 6565                        NaN                      NaN  2018-09-09
# ...                         ...                      ...         ...
# 638307                      NaN                      NaN  2020-01-19
# 641636                      NaN                      NaN  2019-11-17
# 641637                      NaN                      NaN  2019-11-17
# 645124                      NaN                      NaN  2020-02-12
# 645125                      NaN                      NaN  2020-02-12
#
#             kick_off  home_score  away_score match_status      last_updated  \
# 0       13:30:00.000           0           0    available  2020-07-29T05:00
# 1       13:30:00.000           0           0    available  2020-07-29T05:00
# 3527    16:00:00.000           0           1    available  2020-07-29T05:00
# 3528    16:00:00.000           0           1    available  2020-07-29T05:00
# 6565    15:00:00.000           4           0    available  2020-07-29T05:00
# ...              ...         ...         ...          ...               ...
# 638307  13:00:00.000           3           0    available  2020-07-29T05:00
# 641636  16:00:00.000           0           1    available  2020-07-29T05:00
# 641637  16:00:00.000           0           1    available  2020-07-29T05:00
# 645124  20:00:00.000           2           0    available  2020-07-29T05:00
# 645125  20:00:00.000           2           0    available  2020-07-29T05:00
#
#         match_week  competition.competition_id competition.country_name  \
# 0                6                          37                  England
# 1                6                          37                  England
# 3527             6                          37                  England
# 3528             6                          37                  England
# 6565             1                          37                  England
# ...            ...                         ...                      ...
# 638307          13                          37                  England
# 641636           6                          37                  England
# 641637           6                          37                  England
# 645124          16                          37                  England
# 645125          16                          37                  England
#
#        competition.competition_name  season.season_id season.season_name  \
# 0           FA Women's Super League                 4          2018/2019
# 1           FA Women's Super League                 4          2018/2019
# 3527        FA Women's Super League                 4          2018/2019
# 3528        FA Women's Super League                 4          2018/2019
# 6565        FA Women's Super League                 4          2018/2019
# ...                             ...               ...                ...
# 638307      FA Women's Super League                42          2019/2020
# 641636      FA Women's Super League                42          2019/2020
# 641637      FA Women's Super League                42          2019/2020
# 645124      FA Women's Super League                42          2019/2020
# 645125      FA Women's Super League                42          2019/2020
#
#         home_team.home_team_id home_team.home_team_name  \
# 0                          969      Birmingham City WFC
# 1                          969      Birmingham City WFC
# 3527                       972      West Ham United LFC
# 3528                       972      West Ham United LFC
# 6565                       974              Reading WFC
# ...                        ...                      ...
# 638307                    1475        Manchester United
# 641636                     966            Liverpool WFC
# 641637                     966            Liverpool WFC
# 645124                     971              Chelsea FCW
# 645125                     971              Chelsea FCW
#
#        home_team.home_team_gender home_team.home_team_group  \
# 0                          female                      None
# 1                          female                      None
# 3527                       female                      None
# 3528                       female                      None
# 6565                       female                      None
# ...                           ...                       ...
# 638307                     female                      None
# 641636                     female                      None
# 641637                     female                      None
# 645124                     female                      None
# 645125                     female                      None
#
#         home_team.country.id home_team.country.name  \
# 0                         68                England
# 1                         68                England
# 3527                      68                England
# 3528                      68                England
# 6565                      68                England
# ...                      ...                    ...
# 638307                    68                England
# 641636                    68                England
# 641637                    68                England
# 645124                    68                England
# 645125                    68                England
#
#                                        home_team.managers  \
# 0       [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1       [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 3527    [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 3528    [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# 6565    [{'id': 144, 'name': 'Kelly Chambers', 'nickna...
# ...                                                   ...
# 638307  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 641636  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 641637  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 645124  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 645125  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
#
#         away_team.away_team_id away_team.away_team_name  \
# 0                          971              Chelsea FCW
# 1                          971              Chelsea FCW
# 3527                       966            Liverpool WFC
# 3528                       966            Liverpool WFC
# 6565                       970          Yeovil Town LFC
# ...                        ...                      ...
# 638307                     749  Tottenham Hotspur Women
# 641636                     967              Everton LFC
# 641637                     967              Everton LFC
# 645124                     969      Birmingham City WFC
# 645125                     969      Birmingham City WFC
#
#        away_team.away_team_gender away_team.away_team_group  \
# 0                          female                      None
# 1                          female                      None
# 3527                       female                      None
# 3528                       female                      None
# 6565                       female                      None
# ...                           ...                       ...
# 638307                     female                      None
# 641636                     female                      None
# 641637                     female                      None
# 645124                     female                      None
# 645125                     female                      None
#
#         away_team.country.id away_team.country.name  \
# 0                         68                England
# 1                         68                England
# 3527                      68                England
# 3528                      68                England
# 6565                      68                England
# ...                      ...                    ...
# 638307                    68                England
# 641636                    68                England
# 641637                    68                England
# 645124                    68                England
# 645125                    68                England
#
#                                        away_team.managers  \
# 0       [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 1       [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 3527    [{'id': 153, 'name': 'Chris Kirkland', 'nickna...
# 3528    [{'id': 153, 'name': 'Chris Kirkland', 'nickna...
# 6565    [{'id': 147, 'name': 'Lee Burch', 'nickname': ...
# ...                                                   ...
# 638307  [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 641636  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 641637  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 645124  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 645125  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
#
#        metadata.data_version  competition_stage.id competition_stage.name  \
# 0                      1.0.3                     1         Regular Season
# 1                      1.0.3                     1         Regular Season
# 3527                   1.0.3                     1         Regular Season
# 3528                   1.0.3                     1         Regular Season
# 6565                   1.0.3                     1         Regular Season
# ...                      ...                   ...                    ...
# 638307                 1.1.0                     1         Regular Season
# 641636                 1.1.0                     1         Regular Season
# 641637                 1.1.0                     1         Regular Season
# 645124                 1.1.0                     1         Regular Season
# 645125                 1.1.0                     1         Regular Season
#
#         stadium.id                    stadium.name  stadium.country.id  \
# 0           5332.0         SportNation.bet Stadium               255.0
# 1           5332.0         SportNation.bet Stadium               255.0
# 3527        4062.0          The Rush Green Stadium                68.0
# 3528        4062.0          The Rush Green Stadium                68.0
# 6565         577.0                      Adams Park                68.0
# ...            ...                             ...                 ...
# 638307      4979.0    Leigh Sports Village Stadium               255.0
# 641636         6.0                         Anfield                68.0
# 641637         6.0                         Anfield                68.0
# 645124      4279.0  The Cherry Red Records Stadium                68.0
# 645125      4279.0  The Cherry Red Records Stadium                68.0
#
#        stadium.country.name  referee.id  referee.name  referee.country.id  \
# 0             International       898.0      A. Fearn                 NaN
# 1             International       898.0      A. Fearn                 NaN
# 3527                England       568.0    J. Packman                68.0
# 3528                England       568.0    J. Packman                68.0
# 6565                England       567.0     H. Conley                68.0
# ...                     ...         ...           ...                 ...
# 638307        International      1721.0  E. Duckworth                 NaN
# 641636              England       898.0      A. Fearn                 NaN
# 641637              England       898.0      A. Fearn                 NaN
# 645124              England       915.0    R. Whitton                 NaN
# 645125              England       915.0    R. Whitton                 NaN
#
#        referee.country.name metadata.shot_fidelity_version  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 3527                England                            NaN
# 3528                England                            NaN
# 6565                England                            NaN
# ...                     ...                            ...
# 638307                  NaN                              2
# 641636                  NaN                              2
# 641637                  NaN                              2
# 645124                  NaN                              2
# 645125                  NaN                              2
#
#        metadata.xy_fidelity_version  competition_id  season_id country_name  \
# 0                               NaN              37          4      England
# 1                               NaN              37          4      England
# 3527                            NaN              37          4      England
# 3528                            NaN              37          4      England
# 6565                            NaN              37          4      England
# ...                             ...             ...        ...          ...
# 638307                            2              37         42      England
# 641636                            2              37         42      England
# 641637                            2              37         42      England
# 645124                            2              37         42      England
# 645125                            2              37         42      England
#
#                competition_name competition_gender season_name  \
# 0       FA Women's Super League             female   2018/2019
# 1       FA Women's Super League             female   2018/2019
# 3527    FA Women's Super League             female   2018/2019
# 3528    FA Women's Super League             female   2018/2019
# 6565    FA Women's Super League             female   2018/2019
# ...                         ...                ...         ...
# 638307  FA Women's Super League             female   2019/2020
# 641636  FA Women's Super League             female   2019/2020
# 641637  FA Women's Super League             female   2019/2020
# 645124  FA Women's Super League             female   2019/2020
# 645125  FA Women's Super League             female   2019/2020
#
#                            Team             Opponent  \
# 0           Birmingham City WFC          Chelsea FCW
# 1                   Chelsea FCW  Birmingham City WFC
# 3527        West Ham United LFC        Liverpool WFC
# 3528              Liverpool WFC  West Ham United LFC
# 6565                Reading WFC      Yeovil Town LFC
# ...                         ...                  ...
# 638307  Tottenham Hotspur Women    Manchester United
# 641636            Liverpool WFC          Everton LFC
# 641637              Everton LFC        Liverpool WFC
# 645124              Chelsea FCW  Birmingham City WFC
# 645125      Birmingham City WFC          Chelsea FCW
#
#                                         Full_Fixture_Date
# 0       2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 1       2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3527    2018-10-21 West Ham United LFC 0  vs.  1 Liver...
# 3528    2018-10-21 West Ham United LFC 0  vs.  1 Liver...
# 6565     2018-09-09 Reading WFC 4  vs.  0 Yeovil Town LFC
# ...                                                   ...
# 638307  2020-01-19 Manchester United 3  vs.  0 Tottenh...
# 641636     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 641637     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 645124  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
# 645125  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
#
# [388 rows x 196 columns]

# %%
# Streamline DataFrame to include just the columns of interest

## Define columns
cols = ['id', 'type.name', 'match_date', 'kick_off', 'Full_Fixture_Date', 'team.id', 'team.name', 'tactics.formation', 'tactics.lineup', 'competition_name', 'season_name', 'home_team.home_team_name', 'away_team.away_team_name', 'Team', 'Opponent', 'home_score', 'away_score']

## Select only columns of interest
df_lineup_select = df_lineup[cols]

# %%
df_lineup_select
# Out:
#                                           id    type.name  match_date  \
# 0       1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 1       489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 3527    58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 3528    bbad0c35-aef8-40bf-b213-226e86c5f2f7  Starting XI  2018-10-21
# 6565    04c3b8ac-d7a9-490e-a167-334fb353c82a  Starting XI  2018-09-09
# ...                                      ...          ...         ...
# 638307  36de8f79-c32a-4163-8ad7-bf2da3db4f9e  Starting XI  2020-01-19
# 641636  32898ea7-108b-4f9b-86ec-847f35aa2974  Starting XI  2019-11-17
# 641637  33bbf774-d931-4e8e-bbaa-6ba618878f25  Starting XI  2019-11-17
# 645124  d7b811ef-4156-4e3c-a357-aed72b7c53b7  Starting XI  2020-02-12
# 645125  313dea2e-3071-48c3-875b-a8476a8339b4  Starting XI  2020-02-12
#
#             kick_off                                  Full_Fixture_Date  \
# 0       13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 1       13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3527    16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...
# 3528    16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...
# 6565    15:00:00.000   2018-09-09 Reading WFC 4  vs.  0 Yeovil Town LFC
# ...              ...                                                ...
# 638307  13:00:00.000  2020-01-19 Manchester United 3  vs.  0 Tottenh...
# 641636  16:00:00.000     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 641637  16:00:00.000     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 645124  20:00:00.000  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
# 645125  20:00:00.000  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
#
#         team.id                team.name  tactics.formation  \
# 0           969      Birmingham City WFC             4231.0
# 1           971              Chelsea FCW            42211.0
# 3527        972      West Ham United LFC              442.0
# 3528        966            Liverpool WFC             4321.0
# 6565        974              Reading WFC             4222.0
# ...         ...                      ...                ...
# 638307      749  Tottenham Hotspur Women              442.0
# 641636      966            Liverpool WFC             4231.0
# 641637      967              Everton LFC              433.0
# 645124      971              Chelsea FCW              442.0
# 645125      969      Birmingham City WFC             4231.0
#
#                                            tactics.lineup  \
# 0       [{'player': {'id': 15560, 'name': 'Ann-Katrin ...
# 1       [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 3527    [{'player': {'id': 18158, 'name': 'Rebecca Lei...
# 3528    [{'player': {'id': 19778, 'name': 'Frances Kit...
# 6565    [{'player': {'id': 15719, 'name': 'Grace Molon...
# ...                                                   ...
# 638307  [{'player': {'id': 33349, 'name': 'Chloe Morga...
# 641636  [{'player': {'id': 15626, 'name': 'Anke Preuß'...
# 641637  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...
# 645124  [{'player': {'id': 19421, 'name': 'Carly Mitch...
# 645125  [{'player': {'id': 22032, 'name': 'Hannah Hamp...
#
#                competition_name season_name home_team.home_team_name  \
# 0       FA Women's Super League   2018/2019      Birmingham City WFC
# 1       FA Women's Super League   2018/2019      Birmingham City WFC
# 3527    FA Women's Super League   2018/2019      West Ham United LFC
# 3528    FA Women's Super League   2018/2019      West Ham United LFC
# 6565    FA Women's Super League   2018/2019              Reading WFC
# ...                         ...         ...                      ...
# 638307  FA Women's Super League   2019/2020        Manchester United
# 641636  FA Women's Super League   2019/2020            Liverpool WFC
# 641637  FA Women's Super League   2019/2020            Liverpool WFC
# 645124  FA Women's Super League   2019/2020              Chelsea FCW
# 645125  FA Women's Super League   2019/2020              Chelsea FCW
#
#        away_team.away_team_name                     Team             Opponent  \
# 0                   Chelsea FCW      Birmingham City WFC          Chelsea FCW
# 1                   Chelsea FCW              Chelsea FCW  Birmingham City WFC
# 3527              Liverpool WFC      West Ham United LFC        Liverpool WFC
# 3528              Liverpool WFC            Liverpool WFC  West Ham United LFC
# 6565            Yeovil Town LFC              Reading WFC      Yeovil Town LFC
# ...                         ...                      ...                  ...
# 638307  Tottenham Hotspur Women  Tottenham Hotspur Women    Manchester United
# 641636              Everton LFC            Liverpool WFC          Everton LFC
# 641637              Everton LFC              Everton LFC        Liverpool WFC
# 645124      Birmingham City WFC              Chelsea FCW  Birmingham City WFC
# 645125      Birmingham City WFC      Birmingham City WFC          Chelsea FCW
#
#         home_score  away_score
# 0                0           0
# 1                0           0
# 3527             0           1
# 3528             0           1
# 6565             4           0
# ...            ...         ...
# 638307           3           0
# 641636           0           1
# 641637           0           1
# 645124           2           0
# 645125           2           0
#
# [388 rows x 17 columns]

# %% [markdown]
# We can see from the extracted lineup data so far. To get the stating XI players, we need to breakdown the `tactics.lineup` attribute.

# %%
# Normalize tactics.lineup - see: https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame

## explode all columns with lists of dicts
df_lineup_select_normalize = df_lineup_select.apply(lambda x: x.explode()).reset_index(drop=True)

## list of columns with dicts
cols_to_normalize = ['tactics.lineup']

## if there are keys, which will become column names, overlap with excising column names. add the current column name as a prefix
normalized = list()

for col in cols_to_normalize:
    d = pd.json_normalize(df_lineup_select_normalize[col], sep='_')
    d.columns = [f'{col}_{v}' for v in d.columns]
    normalized.append(d.copy())

## combine df with the normalized columns
df_lineup_select_normalize = pd.concat([df_lineup_select_normalize] + normalized, axis=1).drop(columns=cols_to_normalize)

## display(df_lineup_select_normalize)
df_lineup_select_normalize.head(30)
# Out:
#                                       id    type.name  match_date  \
# 0   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 1   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 2   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 3   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 4   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 5   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 6   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 7   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 8   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 9   1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 10  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  Starting XI  2018-10-21
# 11  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 12  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 13  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 14  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 15  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 16  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 17  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 18  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 19  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 20  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 21  489dd844-2b2e-4b0c-90ef-7bbab5ab4bd7  Starting XI  2018-10-21
# 22  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 23  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 24  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 25  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 26  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 27  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 28  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
# 29  58bb5658-80a5-4b17-86a0-20111ab91353  Starting XI  2018-10-21
#
#         kick_off                                  Full_Fixture_Date  team.id  \
# 0   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 1   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 2   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 3   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 4   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 5   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 6   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 7   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 8   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 9   13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 10  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      969
# 11  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 12  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 13  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 14  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 15  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 16  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 17  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 18  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 19  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 20  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 21  13:30:00.000  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...      971
# 22  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 23  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 24  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 25  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 26  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 27  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 28  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
# 29  16:00:00.000  2018-10-21 West Ham United LFC 0  vs.  1 Liver...      972
#
#               team.name  tactics.formation         competition_name  \
# 0   Birmingham City WFC             4231.0  FA Women's Super League
# 1   Birmingham City WFC             4231.0  FA Women's Super League
# 2   Birmingham City WFC             4231.0  FA Women's Super League
# 3   Birmingham City WFC             4231.0  FA Women's Super League
# 4   Birmingham City WFC             4231.0  FA Women's Super League
# 5   Birmingham City WFC             4231.0  FA Women's Super League
# 6   Birmingham City WFC             4231.0  FA Women's Super League
# 7   Birmingham City WFC             4231.0  FA Women's Super League
# 8   Birmingham City WFC             4231.0  FA Women's Super League
# 9   Birmingham City WFC             4231.0  FA Women's Super League
# 10  Birmingham City WFC             4231.0  FA Women's Super League
# 11          Chelsea FCW            42211.0  FA Women's Super League
# 12          Chelsea FCW            42211.0  FA Women's Super League
# 13          Chelsea FCW            42211.0  FA Women's Super League
# 14          Chelsea FCW            42211.0  FA Women's Super League
# 15          Chelsea FCW            42211.0  FA Women's Super League
# 16          Chelsea FCW            42211.0  FA Women's Super League
# 17          Chelsea FCW            42211.0  FA Women's Super League
# 18          Chelsea FCW            42211.0  FA Women's Super League
# 19          Chelsea FCW            42211.0  FA Women's Super League
# 20          Chelsea FCW            42211.0  FA Women's Super League
# 21          Chelsea FCW            42211.0  FA Women's Super League
# 22  West Ham United LFC              442.0  FA Women's Super League
# 23  West Ham United LFC              442.0  FA Women's Super League
# 24  West Ham United LFC              442.0  FA Women's Super League
# 25  West Ham United LFC              442.0  FA Women's Super League
# 26  West Ham United LFC              442.0  FA Women's Super League
# 27  West Ham United LFC              442.0  FA Women's Super League
# 28  West Ham United LFC              442.0  FA Women's Super League
# 29  West Ham United LFC              442.0  FA Women's Super League
#
#    season_name home_team.home_team_name away_team.away_team_name  \
# 0    2018/2019      Birmingham City WFC              Chelsea FCW
# 1    2018/2019      Birmingham City WFC              Chelsea FCW
# 2    2018/2019      Birmingham City WFC              Chelsea FCW
# 3    2018/2019      Birmingham City WFC              Chelsea FCW
# 4    2018/2019      Birmingham City WFC              Chelsea FCW
# 5    2018/2019      Birmingham City WFC              Chelsea FCW
# 6    2018/2019      Birmingham City WFC              Chelsea FCW
# 7    2018/2019      Birmingham City WFC              Chelsea FCW
# 8    2018/2019      Birmingham City WFC              Chelsea FCW
# 9    2018/2019      Birmingham City WFC              Chelsea FCW
# 10   2018/2019      Birmingham City WFC              Chelsea FCW
# 11   2018/2019      Birmingham City WFC              Chelsea FCW
# 12   2018/2019      Birmingham City WFC              Chelsea FCW
# 13   2018/2019      Birmingham City WFC              Chelsea FCW
# 14   2018/2019      Birmingham City WFC              Chelsea FCW
# 15   2018/2019      Birmingham City WFC              Chelsea FCW
# 16   2018/2019      Birmingham City WFC              Chelsea FCW
# 17   2018/2019      Birmingham City WFC              Chelsea FCW
# 18   2018/2019      Birmingham City WFC              Chelsea FCW
# 19   2018/2019      Birmingham City WFC              Chelsea FCW
# 20   2018/2019      Birmingham City WFC              Chelsea FCW
# 21   2018/2019      Birmingham City WFC              Chelsea FCW
# 22   2018/2019      West Ham United LFC            Liverpool WFC
# 23   2018/2019      West Ham United LFC            Liverpool WFC
# 24   2018/2019      West Ham United LFC            Liverpool WFC
# 25   2018/2019      West Ham United LFC            Liverpool WFC
# 26   2018/2019      West Ham United LFC            Liverpool WFC
# 27   2018/2019      West Ham United LFC            Liverpool WFC
# 28   2018/2019      West Ham United LFC            Liverpool WFC
# 29   2018/2019      West Ham United LFC            Liverpool WFC
#
#                    Team             Opponent  home_score  away_score  \
# 0   Birmingham City WFC          Chelsea FCW           0           0
# 1   Birmingham City WFC          Chelsea FCW           0           0
# 2   Birmingham City WFC          Chelsea FCW           0           0
# 3   Birmingham City WFC          Chelsea FCW           0           0
# 4   Birmingham City WFC          Chelsea FCW           0           0
# 5   Birmingham City WFC          Chelsea FCW           0           0
# 6   Birmingham City WFC          Chelsea FCW           0           0
# 7   Birmingham City WFC          Chelsea FCW           0           0
# 8   Birmingham City WFC          Chelsea FCW           0           0
# 9   Birmingham City WFC          Chelsea FCW           0           0
# 10  Birmingham City WFC          Chelsea FCW           0           0
# 11          Chelsea FCW  Birmingham City WFC           0           0
# 12          Chelsea FCW  Birmingham City WFC           0           0
# 13          Chelsea FCW  Birmingham City WFC           0           0
# 14          Chelsea FCW  Birmingham City WFC           0           0
# 15          Chelsea FCW  Birmingham City WFC           0           0
# 16          Chelsea FCW  Birmingham City WFC           0           0
# 17          Chelsea FCW  Birmingham City WFC           0           0
# 18          Chelsea FCW  Birmingham City WFC           0           0
# 19          Chelsea FCW  Birmingham City WFC           0           0
# 20          Chelsea FCW  Birmingham City WFC           0           0
# 21          Chelsea FCW  Birmingham City WFC           0           0
# 22  West Ham United LFC        Liverpool WFC           0           1
# 23  West Ham United LFC        Liverpool WFC           0           1
# 24  West Ham United LFC        Liverpool WFC           0           1
# 25  West Ham United LFC        Liverpool WFC           0           1
# 26  West Ham United LFC        Liverpool WFC           0           1
# 27  West Ham United LFC        Liverpool WFC           0           1
# 28  West Ham United LFC        Liverpool WFC           0           1
# 29  West Ham United LFC        Liverpool WFC           0           1
#
#     tactics.lineup_jersey_number  tactics.lineup_player_id  \
# 0                           30.0                     15560
# 1                            7.0                     10193
# 2                            3.0                     19502
# 3                           25.0                     19503
# 4                            6.0                     15569
# 5                           13.0                     15565
# 6                            4.0                     19501
# 7                           15.0                     15563
# 8                           37.0                     15562
# 9                            8.0                     19500
# 10                          14.0                     15557
# 11                           1.0                      4640
# 12                           7.0                     19422
# 13                           4.0                      4642
# 14                          16.0                      4633
# 15                          20.0                     10222
# 16                           5.0                     15549
# 17                          24.0                      4638
# 18                          22.0                      4660
# 19                          15.0                     15550
# 20                          10.0                      4647
# 21                          14.0                      4641
# 22                           1.0                     18158
# 23                           2.0                     18145
# 24                          14.0                     21014
# 25                           5.0                     18151
# 26                           3.0                     18155
# 27                           7.0                     18153
# 28                          10.0                     18150
# 29                          12.0                     18147
#
#         tactics.lineup_player_name  tactics.lineup_position_id  \
# 0                Ann-Katrin Berger                           1
# 1                     Chloe Arthur                           2
# 2                 Meaghan Sargeant                           3
# 3                    Aoife Mannion                           5
# 4                     Kerys Harrop                           6
# 5                     Marisa Ewers                           9
# 6                      Hayley Ladd                          11
# 7                 Charlie Wellings                          17
# 8                  Lucy Staniforth                          19
# 9               Sarah Emma Mayling                          21
# 10                     Emma Follis                          23
# 11              Rut Hedvig Lindahl                           1
# 12                  Jessica Carter                           2
# 13                   Millie Bright                           3
# 14              Magdalena Ericsson                           5
# 15                 Jonna Andersson                           6
# 16                    Sophie Ingle                           9
# 17                     Drew Spence                          11
# 18                   Erin Cuthbert                          12
# 19                 Bethany England                          16
# 20                       So-yun Ji                          19
# 21                 Francesca Kirby                          23
# 22           Rebecca Leigh Spencer                           1
# 23                    Ria Percival                           2
# 24                    Vyan Sampson                           3
# 25  Gilly Louise Scarlett Flaherty                           5
# 26                      Erin Simon                           6
# 27                  Alisha Lehmann                          12
# 28                     Julia Simic                          13
# 29                  Kate Longhurst                          15
#
#    tactics.lineup_position_name
# 0                    Goalkeeper
# 1                    Right Back
# 2             Right Center Back
# 3              Left Center Back
# 4                     Left Back
# 5      Right Defensive Midfield
# 6       Left Defensive Midfield
# 7                    Right Wing
# 8     Center Attacking Midfield
# 9                     Left Wing
# 10               Center Forward
# 11                   Goalkeeper
# 12                   Right Back
# 13            Right Center Back
# 14             Left Center Back
# 15                    Left Back
# 16     Right Defensive Midfield
# 17      Left Defensive Midfield
# 18               Right Midfield
# 19                Left Midfield
# 20    Center Attacking Midfield
# 21               Center Forward
# 22                   Goalkeeper
# 23                   Right Back
# 24            Right Center Back
# 25             Left Center Back
# 26                    Left Back
# 27               Right Midfield
# 28        Right Center Midfield
# 29         Left Center Midfield

# %%
df_lineup_engineered = df_lineup_select_normalize

# %%
# Streamline DataFrame to include just the columns of interest

## Define columns
cols = ['id', 'match_date', 'kick_off', 'Full_Fixture_Date', 'type.name', 'season_name', 'competition_name', 'home_team.home_team_name', 'away_team.away_team_name', 'Team', 'Opponent', 'home_score', 'away_score', 'tactics.formation', 'tactics.lineup_jersey_number', 'tactics.lineup_position_id', 'tactics.lineup_player_name', 'tactics.lineup_position_name']

## Select only columns of interest
df_lineup_engineered_select = df_lineup_engineered[cols]

# %%
df_lineup_engineered_select['tactics.formation'] = df_lineup_engineered_select['tactics.formation'].astype('Int64')
df_lineup_engineered_select['tactics.lineup_jersey_number'] = df_lineup_engineered_select['tactics.lineup_jersey_number'].astype('Int64')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_lineup_engineered_select.head(5)
# Out:
#                                      id  match_date      kick_off  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 1  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 2  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 3  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 4  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
#
#                                    Full_Fixture_Date    type.name season_name  \
# 0  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI   2018/2019
# 1  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI   2018/2019
# 2  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI   2018/2019
# 3  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI   2018/2019
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI   2018/2019
#
#           competition_name home_team.home_team_name away_team.away_team_name  \
# 0  FA Women's Super League      Birmingham City WFC              Chelsea FCW
# 1  FA Women's Super League      Birmingham City WFC              Chelsea FCW
# 2  FA Women's Super League      Birmingham City WFC              Chelsea FCW
# 3  FA Women's Super League      Birmingham City WFC              Chelsea FCW
# 4  FA Women's Super League      Birmingham City WFC              Chelsea FCW
#
#                   Team     Opponent  home_score  away_score  \
# 0  Birmingham City WFC  Chelsea FCW           0           0
# 1  Birmingham City WFC  Chelsea FCW           0           0
# 2  Birmingham City WFC  Chelsea FCW           0           0
# 3  Birmingham City WFC  Chelsea FCW           0           0
# 4  Birmingham City WFC  Chelsea FCW           0           0
#
#    tactics.formation  tactics.lineup_jersey_number  \
# 0               4231                            30
# 1               4231                             7
# 2               4231                             3
# 3               4231                            25
# 4               4231                             6
#
#    tactics.lineup_position_id tactics.lineup_player_name  \
# 0                           1          Ann-Katrin Berger
# 1                           2               Chloe Arthur
# 2                           3           Meaghan Sargeant
# 3                           5              Aoife Mannion
# 4                           6               Kerys Harrop
#
#   tactics.lineup_position_name
# 0                   Goalkeeper
# 1                   Right Back
# 2            Right Center Back
# 3             Left Center Back
# 4                    Left Back

# %%
df_lineup_engineered_select.columns
# Out:
# Index(['id', 'match_date', 'kick_off', 'Full_Fixture_Date', 'type.name',
#        'season_name', 'competition_name', 'home_team.home_team_name',
#        'away_team.away_team_name', 'Team', 'Opponent', 'home_score',
#        'away_score', 'tactics.formation', 'tactics.lineup_jersey_number',
#        'tactics.lineup_position_id', 'tactics.lineup_player_name',
#        'tactics.lineup_position_name'],
#       dtype='object')

# %%
## Rename columns
df_lineup_engineered_select = df_lineup_engineered_select.rename(columns={'id': 'Match_Id',
                                                                          'match_date': 'Match_Date',
                                                                          'kick_off': 'Kick_Off',
                                                                          'type.name': 'Type_Name',
                                                                          'season_name': 'Season',
                                                                          'competition_name': 'Competition',
                                                                          'home_team.home_team_name': 'Home_Team',
                                                                          'away_team.away_team_name': 'Away_Team',
                                                                          'home_score': 'Home_Score',
                                                                          'away_score': 'Away_Score',
                                                                          'tactics.formation': 'Formation',
                                                                          'tactics.lineup_jersey_number': 'Shirt_Number',
                                                                          'tactics.lineup_position_id': 'Position_Number',
                                                                          'tactics.lineup_player_name': 'Player_Name',
                                                                          'tactics.lineup_position_name': 'Position_Name'
                                                                         }
                                                                         
                                                                )

## Display DataFrame
df_lineup_engineered_select.head()
# Out:
#                                Match_Id  Match_Date      Kick_Off  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 1  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 2  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 3  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
# 4  1c6261d9-f0ae-4430-a087-30b4d1ef6e12  2018-10-21  13:30:00.000
#
#                                    Full_Fixture_Date    Type_Name     Season  \
# 0  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 1  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 2  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 3  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
#
#                Competition            Home_Team    Away_Team  \
# 0  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 1  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 2  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 3  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 4  FA Women's Super League  Birmingham City WFC  Chelsea FCW
#
#                   Team     Opponent  Home_Score  Away_Score  Formation  \
# 0  Birmingham City WFC  Chelsea FCW           0           0       4231
# 1  Birmingham City WFC  Chelsea FCW           0           0       4231
# 2  Birmingham City WFC  Chelsea FCW           0           0       4231
# 3  Birmingham City WFC  Chelsea FCW           0           0       4231
# 4  Birmingham City WFC  Chelsea FCW           0           0       4231
#
#    Shirt_Number  Position_Number        Player_Name      Position_Name
# 0            30                1  Ann-Katrin Berger         Goalkeeper
# 1             7                2       Chloe Arthur         Right Back
# 2             3                3   Meaghan Sargeant  Right Center Back
# 3            25                5      Aoife Mannion   Left Center Back
# 4             6                6       Kerys Harrop          Left Back

# %%
# Convert Match_Date from string to datetime64[ns]
df_lineup_engineered_select['Match_Date']= pd.to_datetime(df_lineup_engineered_select['Match_Date'])

# %%
"""
# THIS IS NOT WORKING ATM

# Convert Kick_Off from string to datetime64[ns]
df_lineup_engineered_select['Kick_Off']= pd.to_datetime(df_lineup_engineered_select['Kick_Off'], format='%H:%M', errors='ignore')
df_lineup_engineered_select['Kick_Off'] = df_lineup_engineered_select['Kick_Off'].dt.time
"""
# Out:
# "\n# THIS IS NOT WORKING ATM\n\n# Convert Kick_Off from string to datetime64[ns]\ndf_lineup_engineered_select['Kick_Off']= pd.to_datetime(df_lineup_engineered_select['Kick_Off'], format='%H:%M', errors='ignore')\ndf_lineup_engineered_select['Kick_Off'] = df_lineup_engineered_select['Kick_Off'].dt.time\n"

# %%
df_lineup_engineered_select.dtypes
# Out:
# Match_Id                     object
# Match_Date           datetime64[ns]
# Kick_Off                     object
# Full_Fixture_Date            object
# Type_Name                    object
# Season                       object
# Competition                  object
# Home_Team                    object
# Away_Team                    object
# Team                         object
# Opponent                     object
# Home_Score                    int64
# Away_Score                    int64
# Formation                     Int64
# Shirt_Number                  Int64
# Position_Number               int64
# Player_Name                  object
# Position_Name                object
# dtype: object

# %%
# Put hyphens between numbers in Formation attribute

## Convert Formation attribute from Integer to String
df_lineup_engineered_select['Formation'] = df_lineup_engineered_select['Formation'].astype(str)

## Define custom function to add hyphen between letters: StackOverflow: https://stackoverflow.com/questions/29382285/python-making-a-function-that-would-add-between-letters
def f(s):
        m = s[0]
        for i in s[1:]:
             m += '-' + i
        return m
    
## Apply custom function
df_lineup_engineered_select['Formation'] = df_lineup_engineered_select.apply(lambda row: f(row['Formation']),axis=1)

# %%
lst_formation = df_lineup_engineered_select['Formation'].unique().tolist()

# %%
lst_formation
# Out:
# ['4-2-3-1',
#  '4-2-2-1-1',
#  '4-4-2',
#  '4-3-2-1',
#  '4-2-2-2',
#  '4-1-2-2-1',
#  '4-3-3',
#  '4-4-1-1',
#  '4-1-4-1',
#  '5-2-2-1',
#  '4-2-1-2-1',
#  '3-2-3-2',
#  '3-4-2-1',
#  '3-2-2-2-1',
#  '4-1-2-1-2',
#  '3-1-4-2',
#  '3-5-1-1',
#  '3-4-1-2',
#  '4-5-1',
#  '4-3-1-2',
#  '3-4-3',
#  '3-5-2']

# %% [markdown]
# ##### Add Position Coordinates

# %%
df_formations_coords = pd.read_csv(data_dir_sb + '/sb_formation_coordinates.csv')

# %%
#df_formations_coords['Id'] = df_formations_coords['Id'].astype('Int8')
#df_formations_coords['Player_Number'] = df_formations_coords['Player_Number'].astype('Int8')

# %%
df_lineup_engineered_select = pd.merge(df_lineup_engineered_select, df_formations_coords, how='left', left_on=['Formation', 'Position_Number'], right_on=['Formation', 'Player_Number'])

# %%
#df_lineup_engineered_select = df_lineup_engineered_select.drop(['Player_Number'], axis=1)
df_lineup_engineered_select = df_lineup_engineered_select.drop(['Id'], axis=1)
df_lineup_engineered_select = df_lineup_engineered_select.drop(['Player_Position'], axis=1)

# %%
df_lineup_engineered_select.head()
# Out:
#                                Match_Id Match_Date      Kick_Off  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 1  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 2  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 3  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 4  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
#
#                                    Full_Fixture_Date    Type_Name     Season  \
# 0  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 1  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 2  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 3  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
#
#                Competition            Home_Team    Away_Team  \
# 0  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 1  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 2  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 3  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 4  FA Women's Super League  Birmingham City WFC  Chelsea FCW
#
#                   Team     Opponent  Home_Score  Away_Score Formation  \
# 0  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 1  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 2  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 3  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 4  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
#
#    Shirt_Number  Position_Number        Player_Name      Position_Name  \
# 0            30                1  Ann-Katrin Berger         Goalkeeper
# 1             7                2       Chloe Arthur         Right Back
# 2             3                3   Meaghan Sargeant  Right Center Back
# 3            25                5      Aoife Mannion   Left Center Back
# 4             6                6       Kerys Harrop          Left Back
#
#    Player_Number Player_Position_Abv     X     Y
# 0            1.0                  GK  25.0   5.0
# 1            2.0                  RB  42.0  16.0
# 2            3.0                 RCB  30.0  12.0
# 3            5.0                 LCB  20.0  12.0
# 4            6.0                  LB   8.0  16.0

# %% [markdown]
# ##### Add Opponent Data to Each Row

# %%
# Select columns of interest

## Define columns
cols = ['Match_Date',
        'Competition',
        'Full_Fixture_Date',
        'Team',
        'Formation'
       ]

##
df_lineup_opponent = df_lineup_engineered_select[cols]

##
df_lineup_opponent = df_lineup_opponent.drop_duplicates()

##
df_lineup_opponent.head()
# Out:
#    Match_Date              Competition  \
# 0  2018-10-21  FA Women's Super League
# 11 2018-10-21  FA Women's Super League
# 22 2018-10-21  FA Women's Super League
# 33 2018-10-21  FA Women's Super League
# 44 2018-09-09  FA Women's Super League
#
#                                     Full_Fixture_Date                 Team  \
# 0   2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Birmingham City WFC
# 11  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...          Chelsea FCW
# 22  2018-10-21 West Ham United LFC 0  vs.  1 Liver...  West Ham United LFC
# 33  2018-10-21 West Ham United LFC 0  vs.  1 Liver...        Liverpool WFC
# 44   2018-09-09 Reading WFC 4  vs.  0 Yeovil Town LFC          Reading WFC
#
#     Formation
# 0     4-2-3-1
# 11  4-2-2-1-1
# 22      4-4-2
# 33    4-3-2-1
# 44    4-2-2-2

# %%
# Join DataFrame to itself on 'Date', 'Fixture', 'Team'/'Opponent', and 'Event', to join Team and Opponent together
df_lineup_engineered_opponent_select = pd.merge(df_lineup_engineered_select, df_lineup_opponent,  how='left', left_on=['Match_Date', 'Competition', 'Full_Fixture_Date', 'Opponent'], right_on = ['Match_Date', 'Competition', 'Full_Fixture_Date', 'Team'])

# %%
# Clean Data

## Drop columns
df_lineup_engineered_opponent_select = df_lineup_engineered_opponent_select.drop(columns=['Team_y'])


## Rename columns
df_lineup_engineered_opponent_select = df_lineup_engineered_opponent_select.rename(columns={'Team_x': 'Team',
                                                                                            'Formation_x': 'Formation',
                                                                                            'Formation_y': 'Opponent_Formation'
                                                                                           }
                                                                                      )

## Display DataFrame
df_lineup_engineered_opponent_select.head()
# Out:
#                                Match_Id Match_Date      Kick_Off  \
# 0  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 1  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 2  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 3  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
# 4  1c6261d9-f0ae-4430-a087-30b4d1ef6e12 2018-10-21  13:30:00.000
#
#                                    Full_Fixture_Date    Type_Name     Season  \
# 0  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 1  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 2  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 3  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...  Starting XI  2018/2019
#
#                Competition            Home_Team    Away_Team  \
# 0  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 1  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 2  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 3  FA Women's Super League  Birmingham City WFC  Chelsea FCW
# 4  FA Women's Super League  Birmingham City WFC  Chelsea FCW
#
#                   Team     Opponent  Home_Score  Away_Score Formation  \
# 0  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 1  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 2  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 3  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
# 4  Birmingham City WFC  Chelsea FCW           0           0   4-2-3-1
#
#    Shirt_Number  Position_Number        Player_Name      Position_Name  \
# 0            30                1  Ann-Katrin Berger         Goalkeeper
# 1             7                2       Chloe Arthur         Right Back
# 2             3                3   Meaghan Sargeant  Right Center Back
# 3            25                5      Aoife Mannion   Left Center Back
# 4             6                6       Kerys Harrop          Left Back
#
#    Player_Number Player_Position_Abv     X     Y Opponent_Formation
# 0            1.0                  GK  25.0   5.0          4-2-2-1-1
# 1            2.0                  RB  42.0  16.0          4-2-2-1-1
# 2            3.0                 RCB  30.0  12.0          4-2-2-1-1
# 3            5.0                 LCB  20.0  12.0          4-2-2-1-1
# 4            6.0                  LB   8.0  16.0          4-2-2-1-1

# %% [markdown]
# ##### Export DataFrame

# %%
# Export 
df_lineup_engineered_opponent_select.to_csv(data_dir_sb + '/lineups/engineered/' + '/sb_lineups_1819_2021_wsl.csv', index=None, header=True)

# %%
# Export 
df_lineup_engineered_opponent_select.to_csv(data_dir + '/export/' + '/sb_wsl_lineups.csv', index=None, header=True)

# %% [markdown]
# ### <a id='#section5.3'>5.3. Tactical Shifts</a>

# %%
df_tactics = df_sb[df_sb['type.name'] == 'Tactical Shift']

# %%
df_tactics
# Out:
#                                           id  index  period     timestamp  \
# 952     b671a141-5cf4-42f6-ae53-2a13bea26ed3    953       1  00:25:13.108
# 2648    7afb9d97-1f6f-4114-a6a5-ea9953192c44   2649       2  00:19:41.594
# 3329    2cbab546-69ac-4022-bc03-d03c0a6f4dcb   3330       2  00:44:44.734
# 11607   b93193ee-2953-4715-a63a-ee928145f2e1   1853       2  00:02:24.550
# 13768   e478f069-d318-4b53-8bc9-54c9b93538eb    532       1  00:13:46.960
# ...                                      ...    ...     ...           ...
# 640677  3e69faac-7e19-490a-b1c8-846365e91be5   2372       2  00:18:03.430
# 641466  13badfbc-4c5a-4398-a8f1-54b68ba3188c   3161       2  00:42:43.468
# 641480  0ffd3c35-d7cb-4109-a8e4-798213ba0b38   3175       2  00:43:28.282
# 642500  7c55b875-11a1-4db4-a0cf-b0156e178b5e    865       1  00:20:00.853
# 643968  1fc7c234-6ad0-458b-80b5-355b5f0714d4   2333       2  00:11:39.512
#
#         minute  second  possession  duration  type.id       type.name  \
# 952         25      13          46       0.0       36  Tactical Shift
# 2648        64      41         141       0.0       36  Tactical Shift
# 3329        89      44         185       0.0       36  Tactical Shift
# 11607       47      24          81       0.0       36  Tactical Shift
# 13768       13      46          27       0.0       36  Tactical Shift
# ...        ...     ...         ...       ...      ...             ...
# 640677      63       3         142       0.0       36  Tactical Shift
# 641466      87      43         186       0.0       36  Tactical Shift
# 641480      88      28         187       0.0       36  Tactical Shift
# 642500      20       0          52       0.0       36  Tactical Shift
# 643968      56      39         134       0.0       36  Tactical Shift
#
#         possession_team.id        possession_team.name  play_pattern.id  \
# 952                    971                 Chelsea FCW                1
# 2648                   969         Birmingham City WFC                4
# 3329                   971                 Chelsea FCW                4
# 11607                  973            Bristol City WFC                1
# 13768                  965  Brighton & Hove Albion WFC                4
# ...                    ...                         ...              ...
# 640677                 749     Tottenham Hotspur Women                1
# 641466                1475           Manchester United                1
# 641480                 749     Tottenham Hotspur Women                7
# 642500                 966               Liverpool WFC                4
# 643968                 966               Liverpool WFC                3
#
#        play_pattern.name  team.id                   team.name  \
# 952         Regular Play      969         Birmingham City WFC
# 2648       From Throw In      971                 Chelsea FCW
# 3329       From Throw In      971                 Chelsea FCW
# 11607       Regular Play      973            Bristol City WFC
# 13768      From Throw In      965  Brighton & Hove Albion WFC
# ...                  ...      ...                         ...
# 640677      Regular Play      749     Tottenham Hotspur Women
# 641466      Regular Play      749     Tottenham Hotspur Women
# 641480    From Goal Kick     1475           Manchester United
# 642500     From Throw In      967                 Everton LFC
# 643968    From Free Kick      967                 Everton LFC
#
#         tactics.formation                                     tactics.lineup  \
# 952                4231.0  [{'player': {'id': 15560, 'name': 'Ann-Katrin ...
# 2648              42211.0  [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 3329              42211.0  [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 11607              4411.0  [{'player': {'id': 16376, 'name': 'Sophie Bagg...
# 13768              4141.0  [{'player': {'id': 19419, 'name': 'Marie Houri...
# ...                   ...                                                ...
# 640677              442.0  [{'player': {'id': 33349, 'name': 'Chloe Morga...
# 641466              442.0  [{'player': {'id': 33349, 'name': 'Chloe Morga...
# 641480             4231.0  [{'player': {'id': 31538, 'name': 'Mary Alexan...
# 642500              433.0  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...
# 643968              433.0  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...
#
#                                 related_events location  player.id  \
# 952                                        NaN      NaN        NaN
# 2648                                       NaN      NaN        NaN
# 3329                                       NaN      NaN        NaN
# 11607                                      NaN      NaN        NaN
# 13768   [f64c4a50-57d1-49b1-8a04-f9b24845aff3]      NaN        NaN
# ...                                        ...      ...        ...
# 640677                                     NaN      NaN        NaN
# 641466                                     NaN      NaN        NaN
# 641480                                     NaN      NaN        NaN
# 642500                                     NaN      NaN        NaN
# 643968                                     NaN      NaN        NaN
#
#        player.name  position.id position.name  pass.recipient.id  \
# 952            NaN          NaN           NaN                NaN
# 2648           NaN          NaN           NaN                NaN
# 3329           NaN          NaN           NaN                NaN
# 11607          NaN          NaN           NaN                NaN
# 13768          NaN          NaN           NaN                NaN
# ...            ...          ...           ...                ...
# 640677         NaN          NaN           NaN                NaN
# 641466         NaN          NaN           NaN                NaN
# 641480         NaN          NaN           NaN                NaN
# 642500         NaN          NaN           NaN                NaN
# 643968         NaN          NaN           NaN                NaN
#
#        pass.recipient.name  pass.length  pass.angle  pass.height.id  \
# 952                    NaN          NaN         NaN             NaN
# 2648                   NaN          NaN         NaN             NaN
# 3329                   NaN          NaN         NaN             NaN
# 11607                  NaN          NaN         NaN             NaN
# 13768                  NaN          NaN         NaN             NaN
# ...                    ...          ...         ...             ...
# 640677                 NaN          NaN         NaN             NaN
# 641466                 NaN          NaN         NaN             NaN
# 641480                 NaN          NaN         NaN             NaN
# 642500                 NaN          NaN         NaN             NaN
# 643968                 NaN          NaN         NaN             NaN
#
#        pass.height.name pass.end_location  pass.type.id pass.type.name  \
# 952                 NaN               NaN           NaN            NaN
# 2648                NaN               NaN           NaN            NaN
# 3329                NaN               NaN           NaN            NaN
# 11607               NaN               NaN           NaN            NaN
# 13768               NaN               NaN           NaN            NaN
# ...                 ...               ...           ...            ...
# 640677              NaN               NaN           NaN            NaN
# 641466              NaN               NaN           NaN            NaN
# 641480              NaN               NaN           NaN            NaN
# 642500              NaN               NaN           NaN            NaN
# 643968              NaN               NaN           NaN            NaN
#
#         pass.body_part.id pass.body_part.name carry.end_location  \
# 952                   NaN                 NaN                NaN
# 2648                  NaN                 NaN                NaN
# 3329                  NaN                 NaN                NaN
# 11607                 NaN                 NaN                NaN
# 13768                 NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 640677                NaN                 NaN                NaN
# 641466                NaN                 NaN                NaN
# 641480                NaN                 NaN                NaN
# 642500                NaN                 NaN                NaN
# 643968                NaN                 NaN                NaN
#
#        under_pressure  pass.outcome.id pass.outcome.name  \
# 952               NaN              NaN               NaN
# 2648              NaN              NaN               NaN
# 3329              NaN              NaN               NaN
# 11607             NaN              NaN               NaN
# 13768            True              NaN               NaN
# ...               ...              ...               ...
# 640677            NaN              NaN               NaN
# 641466            NaN              NaN               NaN
# 641480            NaN              NaN               NaN
# 642500            NaN              NaN               NaN
# 643968            NaN              NaN               NaN
#
#         ball_receipt.outcome.id ball_receipt.outcome.name counterpress  \
# 952                         NaN                       NaN          NaN
# 2648                        NaN                       NaN          NaN
# 3329                        NaN                       NaN          NaN
# 11607                       NaN                       NaN          NaN
# 13768                       NaN                       NaN          NaN
# ...                         ...                       ...          ...
# 640677                      NaN                       NaN          NaN
# 641466                      NaN                       NaN          NaN
# 641480                      NaN                       NaN          NaN
# 642500                      NaN                       NaN          NaN
# 643968                      NaN                       NaN          NaN
#
#         duel.type.id duel.type.name pass.aerial_won  interception.outcome.id  \
# 952              NaN            NaN             NaN                      NaN
# 2648             NaN            NaN             NaN                      NaN
# 3329             NaN            NaN             NaN                      NaN
# 11607            NaN            NaN             NaN                      NaN
# 13768            NaN            NaN             NaN                      NaN
# ...              ...            ...             ...                      ...
# 640677           NaN            NaN             NaN                      NaN
# 641466           NaN            NaN             NaN                      NaN
# 641480           NaN            NaN             NaN                      NaN
# 642500           NaN            NaN             NaN                      NaN
# 643968           NaN            NaN             NaN                      NaN
#
#        interception.outcome.name  dribble.outcome.id dribble.outcome.name  \
# 952                          NaN                 NaN                  NaN
# 2648                         NaN                 NaN                  NaN
# 3329                         NaN                 NaN                  NaN
# 11607                        NaN                 NaN                  NaN
# 13768                        NaN                 NaN                  NaN
# ...                          ...                 ...                  ...
# 640677                       NaN                 NaN                  NaN
# 641466                       NaN                 NaN                  NaN
# 641480                       NaN                 NaN                  NaN
# 642500                       NaN                 NaN                  NaN
# 643968                       NaN                 NaN                  NaN
#
#        pass.assisted_shot_id pass.shot_assist  shot.statsbomb_xg  \
# 952                      NaN              NaN                NaN
# 2648                     NaN              NaN                NaN
# 3329                     NaN              NaN                NaN
# 11607                    NaN              NaN                NaN
# 13768                    NaN              NaN                NaN
# ...                      ...              ...                ...
# 640677                   NaN              NaN                NaN
# 641466                   NaN              NaN                NaN
# 641480                   NaN              NaN                NaN
# 642500                   NaN              NaN                NaN
# 643968                   NaN              NaN                NaN
#
#        shot.end_location shot.key_pass_id  shot.body_part.id  \
# 952                  NaN              NaN                NaN
# 2648                 NaN              NaN                NaN
# 3329                 NaN              NaN                NaN
# 11607                NaN              NaN                NaN
# 13768                NaN              NaN                NaN
# ...                  ...              ...                ...
# 640677               NaN              NaN                NaN
# 641466               NaN              NaN                NaN
# 641480               NaN              NaN                NaN
# 642500               NaN              NaN                NaN
# 643968               NaN              NaN                NaN
#
#        shot.body_part.name  shot.type.id shot.type.name  shot.outcome.id  \
# 952                    NaN           NaN            NaN              NaN
# 2648                   NaN           NaN            NaN              NaN
# 3329                   NaN           NaN            NaN              NaN
# 11607                  NaN           NaN            NaN              NaN
# 13768                  NaN           NaN            NaN              NaN
# ...                    ...           ...            ...              ...
# 640677                 NaN           NaN            NaN              NaN
# 641466                 NaN           NaN            NaN              NaN
# 641480                 NaN           NaN            NaN              NaN
# 642500                 NaN           NaN            NaN              NaN
# 643968                 NaN           NaN            NaN              NaN
#
#        shot.outcome.name  shot.technique.id shot.technique.name  \
# 952                  NaN                NaN                 NaN
# 2648                 NaN                NaN                 NaN
# 3329                 NaN                NaN                 NaN
# 11607                NaN                NaN                 NaN
# 13768                NaN                NaN                 NaN
# ...                  ...                ...                 ...
# 640677               NaN                NaN                 NaN
# 641466               NaN                NaN                 NaN
# 641480               NaN                NaN                 NaN
# 642500               NaN                NaN                 NaN
# 643968               NaN                NaN                 NaN
#
#        shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 952                  NaN                     NaN                     NaN
# 2648                 NaN                     NaN                     NaN
# 3329                 NaN                     NaN                     NaN
# 11607                NaN                     NaN                     NaN
# 13768                NaN                     NaN                     NaN
# ...                  ...                     ...                     ...
# 640677               NaN                     NaN                     NaN
# 641466               NaN                     NaN                     NaN
# 641480               NaN                     NaN                     NaN
# 642500               NaN                     NaN                     NaN
# 643968               NaN                     NaN                     NaN
#
#        goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 952                         NaN                 NaN                  NaN
# 2648                        NaN                 NaN                  NaN
# 3329                        NaN                 NaN                  NaN
# 11607                       NaN                 NaN                  NaN
# 13768                       NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 640677                      NaN                 NaN                  NaN
# 641466                      NaN                 NaN                  NaN
# 641480                      NaN                 NaN                  NaN
# 642500                      NaN                 NaN                  NaN
# 643968                      NaN                 NaN                  NaN
#
#        off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 952           NaN              NaN               NaN         NaN
# 2648          NaN              NaN               NaN         NaN
# 3329          NaN              NaN               NaN         NaN
# 11607         NaN              NaN               NaN         NaN
# 13768         NaN              NaN               NaN         NaN
# ...           ...              ...               ...         ...
# 640677        NaN              NaN               NaN         NaN
# 641466        NaN              NaN               NaN         NaN
# 641480        NaN              NaN               NaN         NaN
# 642500        NaN              NaN               NaN         NaN
# 643968        NaN              NaN               NaN         NaN
#
#        ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 952                               NaN               NaN                NaN
# 2648                              NaN               NaN                NaN
# 3329                              NaN               NaN                NaN
# 11607                             NaN               NaN                NaN
# 13768                             NaN               NaN                NaN
# ...                               ...               ...                ...
# 640677                            NaN               NaN                NaN
# 641466                            NaN               NaN                NaN
# 641480                            NaN               NaN                NaN
# 642500                            NaN               NaN                NaN
# 643968                            NaN               NaN                NaN
#
#         foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 952                        NaN                      NaN             NaN
# 2648                       NaN                      NaN             NaN
# 3329                       NaN                      NaN             NaN
# 11607                      NaN                      NaN             NaN
# 13768                      NaN                      NaN             NaN
# ...                        ...                      ...             ...
# 640677                     NaN                      NaN             NaN
# 641466                     NaN                      NaN             NaN
# 641480                     NaN                      NaN             NaN
# 642500                     NaN                      NaN             NaN
# 643968                     NaN                      NaN             NaN
#
#        shot.aerial_won pass.through_ball  pass.technique.id  \
# 952                NaN               NaN                NaN
# 2648               NaN               NaN                NaN
# 3329               NaN               NaN                NaN
# 11607              NaN               NaN                NaN
# 13768              NaN               NaN                NaN
# ...                ...               ...                ...
# 640677             NaN               NaN                NaN
# 641466             NaN               NaN                NaN
# 641480             NaN               NaN                NaN
# 642500             NaN               NaN                NaN
# 643968             NaN               NaN                NaN
#
#        pass.technique.name  goalkeeper.outcome.id goalkeeper.outcome.name  \
# 952                    NaN                    NaN                     NaN
# 2648                   NaN                    NaN                     NaN
# 3329                   NaN                    NaN                     NaN
# 11607                  NaN                    NaN                     NaN
# 13768                  NaN                    NaN                     NaN
# ...                    ...                    ...                     ...
# 640677                 NaN                    NaN                     NaN
# 641466                 NaN                    NaN                     NaN
# 641480                 NaN                    NaN                     NaN
# 642500                 NaN                    NaN                     NaN
# 643968                 NaN                    NaN                     NaN
#
#         goalkeeper.technique.id goalkeeper.technique.name  \
# 952                         NaN                       NaN
# 2648                        NaN                       NaN
# 3329                        NaN                       NaN
# 11607                       NaN                       NaN
# 13768                       NaN                       NaN
# ...                         ...                       ...
# 640677                      NaN                       NaN
# 641466                      NaN                       NaN
# 641480                      NaN                       NaN
# 642500                      NaN                       NaN
# 643968                      NaN                       NaN
#
#         goalkeeper.body_part.id goalkeeper.body_part.name  \
# 952                         NaN                       NaN
# 2648                        NaN                       NaN
# 3329                        NaN                       NaN
# 11607                       NaN                       NaN
# 13768                       NaN                       NaN
# ...                         ...                       ...
# 640677                      NaN                       NaN
# 641466                      NaN                       NaN
# 641480                      NaN                       NaN
# 642500                      NaN                       NaN
# 643968                      NaN                       NaN
#
#         substitution.outcome.id substitution.outcome.name  \
# 952                         NaN                       NaN
# 2648                        NaN                       NaN
# 3329                        NaN                       NaN
# 11607                       NaN                       NaN
# 13768                       NaN                       NaN
# ...                         ...                       ...
# 640677                      NaN                       NaN
# 641466                      NaN                       NaN
# 641480                      NaN                       NaN
# 642500                      NaN                       NaN
# 643968                      NaN                       NaN
#
#         substitution.replacement.id substitution.replacement.name  \
# 952                             NaN                           NaN
# 2648                            NaN                           NaN
# 3329                            NaN                           NaN
# 11607                           NaN                           NaN
# 13768                           NaN                           NaN
# ...                             ...                           ...
# 640677                          NaN                           NaN
# 641466                          NaN                           NaN
# 641480                          NaN                           NaN
# 642500                          NaN                           NaN
# 643968                          NaN                           NaN
#
#        foul_won.defensive clearance.aerial_won pass.backheel pass.cross  \
# 952                   NaN                  NaN           NaN        NaN
# 2648                  NaN                  NaN           NaN        NaN
# 3329                  NaN                  NaN           NaN        NaN
# 11607                 NaN                  NaN           NaN        NaN
# 13768                 NaN                  NaN           NaN        NaN
# ...                   ...                  ...           ...        ...
# 640677                NaN                  NaN           NaN        NaN
# 641466                NaN                  NaN           NaN        NaN
# 641480                NaN                  NaN           NaN        NaN
# 642500                NaN                  NaN           NaN        NaN
# 643968                NaN                  NaN           NaN        NaN
#
#        foul_committed.offensive foul_committed.advantage foul_won.advantage  \
# 952                         NaN                      NaN                NaN
# 2648                        NaN                      NaN                NaN
# 3329                        NaN                      NaN                NaN
# 11607                       NaN                      NaN                NaN
# 13768                       NaN                      NaN                NaN
# ...                         ...                      ...                ...
# 640677                      NaN                      NaN                NaN
# 641466                      NaN                      NaN                NaN
# 641480                      NaN                      NaN                NaN
# 642500                      NaN                      NaN                NaN
# 643968                      NaN                      NaN                NaN
#
#        dribble.overrun foul_committed.penalty foul_won.penalty  \
# 952                NaN                    NaN              NaN
# 2648               NaN                    NaN              NaN
# 3329               NaN                    NaN              NaN
# 11607              NaN                    NaN              NaN
# 13768              NaN                    NaN              NaN
# ...                ...                    ...              ...
# 640677             NaN                    NaN              NaN
# 641466             NaN                    NaN              NaN
# 641480             NaN                    NaN              NaN
# 642500             NaN                    NaN              NaN
# 643968             NaN                    NaN              NaN
#
#        injury_stoppage.in_chain miscontrol.aerial_won block.offensive  \
# 952                         NaN                   NaN             NaN
# 2648                        NaN                   NaN             NaN
# 3329                        NaN                   NaN             NaN
# 11607                       NaN                   NaN             NaN
# 13768                       NaN                   NaN             NaN
# ...                         ...                   ...             ...
# 640677                      NaN                   NaN             NaN
# 641466                      NaN                   NaN             NaN
# 641480                      NaN                   NaN             NaN
# 642500                      NaN                   NaN             NaN
# 643968                      NaN                   NaN             NaN
#
#         match_id shot.open_goal shot.first_time dribble.nutmeg pass.cut_back  \
# 952        19743            NaN             NaN            NaN           NaN
# 2648       19743            NaN             NaN            NaN           NaN
# 3329       19743            NaN             NaN            NaN           NaN
# 11607      19800            NaN             NaN            NaN           NaN
# 13768      19739            NaN             NaN            NaN           NaN
# ...          ...            ...             ...            ...           ...
# 640677   2275137            NaN             NaN            NaN           NaN
# 641466   2275137            NaN             NaN            NaN           NaN
# 641480   2275137            NaN             NaN            NaN           NaN
# 642500   2275056            NaN             NaN            NaN           NaN
# 643968   2275056            NaN             NaN            NaN           NaN
#
#        pass.deflected pass.goal_assist  foul_committed.type.id  \
# 952               NaN              NaN                     NaN
# 2648              NaN              NaN                     NaN
# 3329              NaN              NaN                     NaN
# 11607             NaN              NaN                     NaN
# 13768             NaN              NaN                     NaN
# ...               ...              ...                     ...
# 640677            NaN              NaN                     NaN
# 641466            NaN              NaN                     NaN
# 641480            NaN              NaN                     NaN
# 642500            NaN              NaN                     NaN
# 643968            NaN              NaN                     NaN
#
#        foul_committed.type.name pass.miscommunication ball_recovery.offensive  \
# 952                         NaN                   NaN                     NaN
# 2648                        NaN                   NaN                     NaN
# 3329                        NaN                   NaN                     NaN
# 11607                       NaN                   NaN                     NaN
# 13768                       NaN                   NaN                     NaN
# ...                         ...                   ...                     ...
# 640677                      NaN                   NaN                     NaN
# 641466                      NaN                   NaN                     NaN
# 641480                      NaN                   NaN                     NaN
# 642500                      NaN                   NaN                     NaN
# 643968                      NaN                   NaN                     NaN
#
#        block.save_block block.deflection clearance.head  \
# 952                 NaN              NaN            NaN
# 2648                NaN              NaN            NaN
# 3329                NaN              NaN            NaN
# 11607               NaN              NaN            NaN
# 13768               NaN              NaN            NaN
# ...                 ...              ...            ...
# 640677              NaN              NaN            NaN
# 641466              NaN              NaN            NaN
# 641480              NaN              NaN            NaN
# 642500              NaN              NaN            NaN
# 643968              NaN              NaN            NaN
#
#         clearance.body_part.id clearance.body_part.name  out  \
# 952                        NaN                      NaN  NaN
# 2648                       NaN                      NaN  NaN
# 3329                       NaN                      NaN  NaN
# 11607                      NaN                      NaN  NaN
# 13768                      NaN                      NaN  NaN
# ...                        ...                      ...  ...
# 640677                     NaN                      NaN  NaN
# 641466                     NaN                      NaN  NaN
# 641480                     NaN                      NaN  NaN
# 642500                     NaN                      NaN  NaN
# 643968                     NaN                      NaN  NaN
#
#        clearance.left_foot clearance.right_foot pass.inswinging pass.straight  \
# 952                    NaN                  NaN             NaN           NaN
# 2648                   NaN                  NaN             NaN           NaN
# 3329                   NaN                  NaN             NaN           NaN
# 11607                  NaN                  NaN             NaN           NaN
# 13768                  NaN                  NaN             NaN           NaN
# ...                    ...                  ...             ...           ...
# 640677                 NaN                  NaN             NaN           NaN
# 641466                 NaN                  NaN             NaN           NaN
# 641480                 NaN                  NaN             NaN           NaN
# 642500                 NaN                  NaN             NaN           NaN
# 643968                 NaN                  NaN             NaN           NaN
#
#        clearance.other pass.outswinging shot.redirect shot.deflected  \
# 952                NaN              NaN           NaN            NaN
# 2648               NaN              NaN           NaN            NaN
# 3329               NaN              NaN           NaN            NaN
# 11607              NaN              NaN           NaN            NaN
# 13768              NaN              NaN           NaN            NaN
# ...                ...              ...           ...            ...
# 640677             NaN              NaN           NaN            NaN
# 641466             NaN              NaN           NaN            NaN
# 641480             NaN              NaN           NaN            NaN
# 642500             NaN              NaN           NaN            NaN
# 643968             NaN              NaN           NaN            NaN
#
#         bad_behaviour.card.id bad_behaviour.card.name pass.no_touch  \
# 952                       NaN                     NaN           NaN
# 2648                      NaN                     NaN           NaN
# 3329                      NaN                     NaN           NaN
# 11607                     NaN                     NaN           NaN
# 13768                     NaN                     NaN           NaN
# ...                       ...                     ...           ...
# 640677                    NaN                     NaN           NaN
# 641466                    NaN                     NaN           NaN
# 641480                    NaN                     NaN           NaN
# 642500                    NaN                     NaN           NaN
# 643968                    NaN                     NaN           NaN
#
#        dribble.no_touch shot.saved_off_target  \
# 952                 NaN                   NaN
# 2648                NaN                   NaN
# 3329                NaN                   NaN
# 11607               NaN                   NaN
# 13768               NaN                   NaN
# ...                 ...                   ...
# 640677              NaN                   NaN
# 641466              NaN                   NaN
# 641480              NaN                   NaN
# 642500              NaN                   NaN
# 643968              NaN                   NaN
#
#        goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 952                                 NaN                 NaN
# 2648                                NaN                 NaN
# 3329                                NaN                 NaN
# 11607                               NaN                 NaN
# 13768                               NaN                 NaN
# ...                                 ...                 ...
# 640677                              NaN                 NaN
# 641466                              NaN                 NaN
# 641480                              NaN                 NaN
# 642500                              NaN                 NaN
# 643968                              NaN                 NaN
#
#        goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 952                       NaN                  NaN                NaN
# 2648                      NaN                  NaN                NaN
# 3329                      NaN                  NaN                NaN
# 11607                     NaN                  NaN                NaN
# 13768                     NaN                  NaN                NaN
# ...                       ...                  ...                ...
# 640677                    NaN                  NaN                NaN
# 641466                    NaN                  NaN                NaN
# 641480                    NaN                  NaN                NaN
# 642500                    NaN                  NaN                NaN
# 643968                    NaN                  NaN                NaN
#
#        goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 952                              NaN                     NaN
# 2648                             NaN                     NaN
# 3329                             NaN                     NaN
# 11607                            NaN                     NaN
# 13768                            NaN                     NaN
# ...                              ...                     ...
# 640677                           NaN                     NaN
# 641466                           NaN                     NaN
# 641480                           NaN                     NaN
# 642500                           NaN                     NaN
# 643968                           NaN                     NaN
#
#        goalkeeper.success_out shot.follows_dribble  \
# 952                       NaN                  NaN
# 2648                      NaN                  NaN
# 3329                      NaN                  NaN
# 11607                     NaN                  NaN
# 13768                     NaN                  NaN
# ...                       ...                  ...
# 640677                    NaN                  NaN
# 641466                    NaN                  NaN
# 641480                    NaN                  NaN
# 642500                    NaN                  NaN
# 643968                    NaN                  NaN
#
#        half_start.late_video_start goalkeeper.success_in_play  \
# 952                            NaN                        NaN
# 2648                           NaN                        NaN
# 3329                           NaN                        NaN
# 11607                          NaN                        NaN
# 13768                          NaN                        NaN
# ...                            ...                        ...
# 640677                         NaN                        NaN
# 641466                         NaN                        NaN
# 641480                         NaN                        NaN
# 642500                         NaN                        NaN
# 643968                         NaN                        NaN
#
#        half_end.early_video_end goalkeeper.saved_to_post  match_date  \
# 952                         NaN                      NaN  2018-10-21
# 2648                        NaN                      NaN  2018-10-21
# 3329                        NaN                      NaN  2018-10-21
# 11607                       NaN                      NaN  2019-03-14
# 13768                       NaN                      NaN  2018-10-21
# ...                         ...                      ...         ...
# 640677                      NaN                      NaN  2020-01-19
# 641466                      NaN                      NaN  2020-01-19
# 641480                      NaN                      NaN  2020-01-19
# 642500                      NaN                      NaN  2019-11-17
# 643968                      NaN                      NaN  2019-11-17
#
#             kick_off  home_score  away_score match_status  \
# 952     13:30:00.000           0           0    available
# 2648    13:30:00.000           0           0    available
# 3329    13:30:00.000           0           0    available
# 11607   20:30:00.000           4           0    available
# 13768   15:00:00.000           0           6    available
# ...              ...         ...         ...          ...
# 640677  13:00:00.000           3           0    available
# 641466  13:00:00.000           3           0    available
# 641480  13:00:00.000           3           0    available
# 642500  16:00:00.000           0           1    available
# 643968  16:00:00.000           0           1    available
#
#                       last_updated  match_week  competition.competition_id  \
# 952               2020-07-29T05:00           6                          37
# 2648              2020-07-29T05:00           6                          37
# 3329              2020-07-29T05:00           6                          37
# 11607   2020-08-24T14:34:34.401523          18                          37
# 13768             2020-07-29T05:00           6                          37
# ...                            ...         ...                         ...
# 640677            2020-07-29T05:00          13                          37
# 641466            2020-07-29T05:00          13                          37
# 641480            2020-07-29T05:00          13                          37
# 642500            2020-07-29T05:00           6                          37
# 643968            2020-07-29T05:00           6                          37
#
#        competition.country_name competition.competition_name  \
# 952                     England      FA Women's Super League
# 2648                    England      FA Women's Super League
# 3329                    England      FA Women's Super League
# 11607                   England      FA Women's Super League
# 13768                   England      FA Women's Super League
# ...                         ...                          ...
# 640677                  England      FA Women's Super League
# 641466                  England      FA Women's Super League
# 641480                  England      FA Women's Super League
# 642500                  England      FA Women's Super League
# 643968                  England      FA Women's Super League
#
#         season.season_id season.season_name  home_team.home_team_id  \
# 952                    4          2018/2019                     969
# 2648                   4          2018/2019                     969
# 3329                   4          2018/2019                     969
# 11607                  4          2018/2019                     968
# 13768                  4          2018/2019                     965
# ...                  ...                ...                     ...
# 640677                42          2019/2020                    1475
# 641466                42          2019/2020                    1475
# 641480                42          2019/2020                    1475
# 642500                42          2019/2020                     966
# 643968                42          2019/2020                     966
#
#           home_team.home_team_name home_team.home_team_gender  \
# 952            Birmingham City WFC                     female
# 2648           Birmingham City WFC                     female
# 3329           Birmingham City WFC                     female
# 11607                  Arsenal WFC                     female
# 13768   Brighton & Hove Albion WFC                     female
# ...                            ...                        ...
# 640677           Manchester United                     female
# 641466           Manchester United                     female
# 641480           Manchester United                     female
# 642500               Liverpool WFC                     female
# 643968               Liverpool WFC                     female
#
#        home_team.home_team_group  home_team.country.id home_team.country.name  \
# 952                         None                    68                England
# 2648                        None                    68                England
# 3329                        None                    68                England
# 11607                       None                    68                England
# 13768                       None                    68                England
# ...                          ...                   ...                    ...
# 640677                      None                    68                England
# 641466                      None                    68                England
# 641480                      None                    68                England
# 642500                      None                    68                England
# 643968                      None                    68                England
#
#                                        home_team.managers  \
# 952     [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 2648    [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 3329    [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 11607   [{'id': 31, 'name': 'Joseph Montemurro', 'nick...
# 13768   [{'id': 149, 'name': 'Hope Patricia Powell', '...
# ...                                                   ...
# 640677  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 641466  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 641480  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 642500  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 643968  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
#
#         away_team.away_team_id away_team.away_team_name  \
# 952                        971              Chelsea FCW
# 2648                       971              Chelsea FCW
# 3329                       971              Chelsea FCW
# 11607                      973         Bristol City WFC
# 13768                      746      Manchester City WFC
# ...                        ...                      ...
# 640677                     749  Tottenham Hotspur Women
# 641466                     749  Tottenham Hotspur Women
# 641480                     749  Tottenham Hotspur Women
# 642500                     967              Everton LFC
# 643968                     967              Everton LFC
#
#        away_team.away_team_gender away_team.away_team_group  \
# 952                        female                      None
# 2648                       female                      None
# 3329                       female                      None
# 11607                      female                      None
# 13768                      female                      None
# ...                           ...                       ...
# 640677                     female                      None
# 641466                     female                      None
# 641480                     female                      None
# 642500                     female                      None
# 643968                     female                      None
#
#         away_team.country.id away_team.country.name  \
# 952                       68                England
# 2648                      68                England
# 3329                      68                England
# 11607                     68                England
# 13768                     68                England
# ...                      ...                    ...
# 640677                    68                England
# 641466                    68                England
# 641480                    68                England
# 642500                    68                England
# 643968                    68                England
#
#                                        away_team.managers  \
# 952     [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 2648    [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 3329    [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 11607   [{'id': 143, 'name': 'Tanya Oxtoby', 'nickname...
# 13768   [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# ...                                                   ...
# 640677  [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 641466  [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 641480  [{'id': 791, 'name': 'Karen Hills', 'nickname'...
# 642500  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 643968  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
#
#        metadata.data_version  competition_stage.id competition_stage.name  \
# 952                    1.0.3                     1         Regular Season
# 2648                   1.0.3                     1         Regular Season
# 3329                   1.0.3                     1         Regular Season
# 11607                  1.1.0                     1         Regular Season
# 13768                  1.0.3                     1         Regular Season
# ...                      ...                   ...                    ...
# 640677                 1.1.0                     1         Regular Season
# 641466                 1.1.0                     1         Regular Season
# 641480                 1.1.0                     1         Regular Season
# 642500                 1.1.0                     1         Regular Season
# 643968                 1.1.0                     1         Regular Season
#
#         stadium.id                  stadium.name  stadium.country.id  \
# 952         5332.0       SportNation.bet Stadium               255.0
# 2648        5332.0       SportNation.bet Stadium               255.0
# 3329        5332.0       SportNation.bet Stadium               255.0
# 11607        456.0                   Meadow Park                68.0
# 13768          NaN                           NaN                 NaN
# ...            ...                           ...                 ...
# 640677      4979.0  Leigh Sports Village Stadium               255.0
# 641466      4979.0  Leigh Sports Village Stadium               255.0
# 641480      4979.0  Leigh Sports Village Stadium               255.0
# 642500         6.0                       Anfield                68.0
# 643968         6.0                       Anfield                68.0
#
#        stadium.country.name  referee.id  referee.name  referee.country.id  \
# 952           International       898.0      A. Fearn                 NaN
# 2648          International       898.0      A. Fearn                 NaN
# 3329          International       898.0      A. Fearn                 NaN
# 11607               England       915.0    R. Whitton                 NaN
# 13768                   NaN         NaN           NaN                 NaN
# ...                     ...         ...           ...                 ...
# 640677        International      1721.0  E. Duckworth                 NaN
# 641466        International      1721.0  E. Duckworth                 NaN
# 641480        International      1721.0  E. Duckworth                 NaN
# 642500              England       898.0      A. Fearn                 NaN
# 643968              England       898.0      A. Fearn                 NaN
#
#        referee.country.name metadata.shot_fidelity_version  \
# 952                     NaN                            NaN
# 2648                    NaN                            NaN
# 3329                    NaN                            NaN
# 11607                   NaN                            NaN
# 13768                   NaN                            NaN
# ...                     ...                            ...
# 640677                  NaN                              2
# 641466                  NaN                              2
# 641480                  NaN                              2
# 642500                  NaN                              2
# 643968                  NaN                              2
#
#        metadata.xy_fidelity_version  competition_id  season_id country_name  \
# 952                             NaN              37          4      England
# 2648                            NaN              37          4      England
# 3329                            NaN              37          4      England
# 11607                           NaN              37          4      England
# 13768                           NaN              37          4      England
# ...                             ...             ...        ...          ...
# 640677                            2              37         42      England
# 641466                            2              37         42      England
# 641480                            2              37         42      England
# 642500                            2              37         42      England
# 643968                            2              37         42      England
#
#                competition_name competition_gender season_name  \
# 952     FA Women's Super League             female   2018/2019
# 2648    FA Women's Super League             female   2018/2019
# 3329    FA Women's Super League             female   2018/2019
# 11607   FA Women's Super League             female   2018/2019
# 13768   FA Women's Super League             female   2018/2019
# ...                         ...                ...         ...
# 640677  FA Women's Super League             female   2019/2020
# 641466  FA Women's Super League             female   2019/2020
# 641480  FA Women's Super League             female   2019/2020
# 642500  FA Women's Super League             female   2019/2020
# 643968  FA Women's Super League             female   2019/2020
#
#                               Team                 Opponent  \
# 952            Birmingham City WFC              Chelsea FCW
# 2648                   Chelsea FCW      Birmingham City WFC
# 3329                   Chelsea FCW      Birmingham City WFC
# 11607             Bristol City WFC              Arsenal WFC
# 13768   Brighton & Hove Albion WFC      Manchester City WFC
# ...                            ...                      ...
# 640677     Tottenham Hotspur Women        Manchester United
# 641466     Tottenham Hotspur Women        Manchester United
# 641480           Manchester United  Tottenham Hotspur Women
# 642500                 Everton LFC            Liverpool WFC
# 643968                 Everton LFC            Liverpool WFC
#
#                                         Full_Fixture_Date
# 952     2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 2648    2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3329    2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 11607   2019-03-14 Arsenal WFC 4  vs.  0 Bristol City WFC
# 13768   2018-10-21 Brighton & Hove Albion WFC 0  vs.  ...
# ...                                                   ...
# 640677  2020-01-19 Manchester United 3  vs.  0 Tottenh...
# 641466  2020-01-19 Manchester United 3  vs.  0 Tottenh...
# 641480  2020-01-19 Manchester United 3  vs.  0 Tottenh...
# 642500     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 643968     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
#
# [345 rows x 196 columns]

# %%
# Select columns of interest

##
cols = ['id', 'type.name', 'team.id', 'team.name', 'tactics.formation', 'tactics.lineup']

##
df_tactics_select = df_tactics[cols]

# %%
df_tactics_select
# Out:
#                                           id       type.name  team.id  \
# 952     b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 2648    7afb9d97-1f6f-4114-a6a5-ea9953192c44  Tactical Shift      971
# 3329    2cbab546-69ac-4022-bc03-d03c0a6f4dcb  Tactical Shift      971
# 11607   b93193ee-2953-4715-a63a-ee928145f2e1  Tactical Shift      973
# 13768   e478f069-d318-4b53-8bc9-54c9b93538eb  Tactical Shift      965
# ...                                      ...             ...      ...
# 640677  3e69faac-7e19-490a-b1c8-846365e91be5  Tactical Shift      749
# 641466  13badfbc-4c5a-4398-a8f1-54b68ba3188c  Tactical Shift      749
# 641480  0ffd3c35-d7cb-4109-a8e4-798213ba0b38  Tactical Shift     1475
# 642500  7c55b875-11a1-4db4-a0cf-b0156e178b5e  Tactical Shift      967
# 643968  1fc7c234-6ad0-458b-80b5-355b5f0714d4  Tactical Shift      967
#
#                          team.name  tactics.formation  \
# 952            Birmingham City WFC             4231.0
# 2648                   Chelsea FCW            42211.0
# 3329                   Chelsea FCW            42211.0
# 11607             Bristol City WFC             4411.0
# 13768   Brighton & Hove Albion WFC             4141.0
# ...                            ...                ...
# 640677     Tottenham Hotspur Women              442.0
# 641466     Tottenham Hotspur Women              442.0
# 641480           Manchester United             4231.0
# 642500                 Everton LFC              433.0
# 643968                 Everton LFC              433.0
#
#                                            tactics.lineup
# 952     [{'player': {'id': 15560, 'name': 'Ann-Katrin ...
# 2648    [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 3329    [{'player': {'id': 4640, 'name': 'Rut Hedvig L...
# 11607   [{'player': {'id': 16376, 'name': 'Sophie Bagg...
# 13768   [{'player': {'id': 19419, 'name': 'Marie Houri...
# ...                                                   ...
# 640677  [{'player': {'id': 33349, 'name': 'Chloe Morga...
# 641466  [{'player': {'id': 33349, 'name': 'Chloe Morga...
# 641480  [{'player': {'id': 31538, 'name': 'Mary Alexan...
# 642500  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...
# 643968  [{'player': {'id': 13857, 'name': 'Tinja-Riikk...
#
# [345 rows x 6 columns]

# %%
# Normalize tactics.lineup - see: https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame

## explode all columns with lists of dicts
df_tactics_select_normalize = df_tactics_select.apply(lambda x: x.explode()).reset_index(drop=True)

## list of columns with dicts
cols_to_normalize = ['tactics.lineup']

## if there are keys, which will become column names, overlap with excising column names. add the current column name as a prefix
normalized = list()
for col in cols_to_normalize:
    
    d = pd.json_normalize(df_tactics_select_normalize[col], sep='_')
    d.columns = [f'{col}_{v}' for v in d.columns]
    normalized.append(d.copy())

## combine df with the normalized columns
df_tactics_select_normalize = pd.concat([df_tactics_select_normalize] + normalized, axis=1).drop(columns=cols_to_normalize)

## display(df_lineup_select_normalize)
df_tactics_select_normalize.head(10)
# Out:
#                                      id       type.name  team.id  \
# 0  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 1  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 2  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 3  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 4  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 5  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 6  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 7  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 8  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
# 9  b671a141-5cf4-42f6-ae53-2a13bea26ed3  Tactical Shift      969
#
#              team.name  tactics.formation  tactics.lineup_jersey_number  \
# 0  Birmingham City WFC             4231.0                            30
# 1  Birmingham City WFC             4231.0                            23
# 2  Birmingham City WFC             4231.0                             3
# 3  Birmingham City WFC             4231.0                            25
# 4  Birmingham City WFC             4231.0                             6
# 5  Birmingham City WFC             4231.0                             7
# 6  Birmingham City WFC             4231.0                             4
# 7  Birmingham City WFC             4231.0                            15
# 8  Birmingham City WFC             4231.0                            37
# 9  Birmingham City WFC             4231.0                             8
#
#    tactics.lineup_player_id tactics.lineup_player_name  \
# 0                     15560          Ann-Katrin Berger
# 1                     19592              Harriet Scott
# 2                     19502           Meaghan Sargeant
# 3                     19503              Aoife Mannion
# 4                     15569               Kerys Harrop
# 5                     10193               Chloe Arthur
# 6                     19501                Hayley Ladd
# 7                     15563           Charlie Wellings
# 8                     15562            Lucy Staniforth
# 9                     19500         Sarah Emma Mayling
#
#    tactics.lineup_position_id tactics.lineup_position_name
# 0                           1                   Goalkeeper
# 1                           2                   Right Back
# 2                           3            Right Center Back
# 3                           5             Left Center Back
# 4                           6                    Left Back
# 5                           9     Right Defensive Midfield
# 6                          11      Left Defensive Midfield
# 7                          17                   Right Wing
# 8                          19    Center Attacking Midfield
# 9                          21                    Left Wing

# %% [markdown]
# ### <a id='#section5.4'>5.4. Halves</a>

# %%
df_half = df_sb[df_sb['type.name'] == 'Half Start']

# %%
df_half
# Out:
#                                           id  index  period     timestamp  \
# 2       c036ad64-e323-4c8d-b770-3b6e26e7d882      3       1  00:00:00.000
# 3       48ca911e-66d7-4ebc-8514-6728f94df8d2      4       1  00:00:00.000
# 1929    c30d35de-f34d-4e02-a58b-e86f981e1f1f   1930       2  00:00:00.000
# 1930    7005c1ff-bd6a-4d47-9897-eb79b926d479   1931       2  00:00:00.000
# 3529    74511f98-3f74-4691-bcc9-6bc7100bc0aa      3       1  00:00:00.000
# ...                                      ...    ...     ...           ...
# 643559  e7c7ac72-7ad8-4910-8c40-44ba1377ddec   1924       2  00:00:00.000
# 645126  2d821933-278c-454d-8ad4-3c18ed37f9a6      3       1  00:00:00.000
# 645127  8ee9248c-24df-4ba2-879e-550998582f44      4       1  00:00:00.000
# 646975  540daf54-e771-4379-bcee-2cc9667f2546   1852       2  00:00:00.000
# 646976  9c2195ac-53fc-4ae8-8bfc-7bcd2838db49   1853       2  00:00:00.000
#
#         minute  second  possession  duration  type.id   type.name  \
# 2            0       0           1       0.0       18  Half Start
# 3            0       0           1       0.0       18  Half Start
# 1929        45       0          91       0.0       18  Half Start
# 1930        45       0          91       0.0       18  Half Start
# 3529         0       0           1       0.0       18  Half Start
# ...        ...     ...         ...       ...      ...         ...
# 643559      45       0         107       0.0       18  Half Start
# 645126       0       0           1       0.0       18  Half Start
# 645127       0       0           1       0.0       18  Half Start
# 646975      45       0          95       0.0       18  Half Start
# 646976      45       0          95       0.0       18  Half Start
#
#         possession_team.id possession_team.name  play_pattern.id  \
# 2                      969  Birmingham City WFC                1
# 3                      969  Birmingham City WFC                1
# 1929                   971          Chelsea FCW                4
# 1930                   971          Chelsea FCW                4
# 3529                   972  West Ham United LFC                1
# ...                    ...                  ...              ...
# 643559                 966        Liverpool WFC                9
# 645126                 971          Chelsea FCW                1
# 645127                 971          Chelsea FCW                1
# 646975                 971          Chelsea FCW                1
# 646976                 971          Chelsea FCW                1
#
#        play_pattern.name  team.id            team.name  tactics.formation  \
# 2           Regular Play      971          Chelsea FCW                NaN
# 3           Regular Play      969  Birmingham City WFC                NaN
# 1929       From Throw In      971          Chelsea FCW                NaN
# 1930       From Throw In      969  Birmingham City WFC                NaN
# 3529        Regular Play      966        Liverpool WFC                NaN
# ...                  ...      ...                  ...                ...
# 643559     From Kick Off      967          Everton LFC                NaN
# 645126      Regular Play      969  Birmingham City WFC                NaN
# 645127      Regular Play      971          Chelsea FCW                NaN
# 646975      Regular Play      969  Birmingham City WFC                NaN
# 646976      Regular Play      971          Chelsea FCW                NaN
#
#        tactics.lineup                          related_events location  \
# 2                 NaN  [48ca911e-66d7-4ebc-8514-6728f94df8d2]      NaN
# 3                 NaN  [c036ad64-e323-4c8d-b770-3b6e26e7d882]      NaN
# 1929              NaN  [7005c1ff-bd6a-4d47-9897-eb79b926d479]      NaN
# 1930              NaN  [c30d35de-f34d-4e02-a58b-e86f981e1f1f]      NaN
# 3529              NaN  [604d7a26-34c1-4542-91b6-1ba1daf9b619]      NaN
# ...               ...                                     ...      ...
# 643559            NaN  [72890b42-968b-4d79-a568-1037fbaf6697]      NaN
# 645126            NaN  [8ee9248c-24df-4ba2-879e-550998582f44]      NaN
# 645127            NaN  [2d821933-278c-454d-8ad4-3c18ed37f9a6]      NaN
# 646975            NaN  [9c2195ac-53fc-4ae8-8bfc-7bcd2838db49]      NaN
# 646976            NaN  [540daf54-e771-4379-bcee-2cc9667f2546]      NaN
#
#         player.id player.name  position.id position.name  pass.recipient.id  \
# 2             NaN         NaN          NaN           NaN                NaN
# 3             NaN         NaN          NaN           NaN                NaN
# 1929          NaN         NaN          NaN           NaN                NaN
# 1930          NaN         NaN          NaN           NaN                NaN
# 3529          NaN         NaN          NaN           NaN                NaN
# ...           ...         ...          ...           ...                ...
# 643559        NaN         NaN          NaN           NaN                NaN
# 645126        NaN         NaN          NaN           NaN                NaN
# 645127        NaN         NaN          NaN           NaN                NaN
# 646975        NaN         NaN          NaN           NaN                NaN
# 646976        NaN         NaN          NaN           NaN                NaN
#
#        pass.recipient.name  pass.length  pass.angle  pass.height.id  \
# 2                      NaN          NaN         NaN             NaN
# 3                      NaN          NaN         NaN             NaN
# 1929                   NaN          NaN         NaN             NaN
# 1930                   NaN          NaN         NaN             NaN
# 3529                   NaN          NaN         NaN             NaN
# ...                    ...          ...         ...             ...
# 643559                 NaN          NaN         NaN             NaN
# 645126                 NaN          NaN         NaN             NaN
# 645127                 NaN          NaN         NaN             NaN
# 646975                 NaN          NaN         NaN             NaN
# 646976                 NaN          NaN         NaN             NaN
#
#        pass.height.name pass.end_location  pass.type.id pass.type.name  \
# 2                   NaN               NaN           NaN            NaN
# 3                   NaN               NaN           NaN            NaN
# 1929                NaN               NaN           NaN            NaN
# 1930                NaN               NaN           NaN            NaN
# 3529                NaN               NaN           NaN            NaN
# ...                 ...               ...           ...            ...
# 643559              NaN               NaN           NaN            NaN
# 645126              NaN               NaN           NaN            NaN
# 645127              NaN               NaN           NaN            NaN
# 646975              NaN               NaN           NaN            NaN
# 646976              NaN               NaN           NaN            NaN
#
#         pass.body_part.id pass.body_part.name carry.end_location  \
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 1929                  NaN                 NaN                NaN
# 1930                  NaN                 NaN                NaN
# 3529                  NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 643559                NaN                 NaN                NaN
# 645126                NaN                 NaN                NaN
# 645127                NaN                 NaN                NaN
# 646975                NaN                 NaN                NaN
# 646976                NaN                 NaN                NaN
#
#        under_pressure  pass.outcome.id pass.outcome.name  \
# 2                 NaN              NaN               NaN
# 3                 NaN              NaN               NaN
# 1929              NaN              NaN               NaN
# 1930              NaN              NaN               NaN
# 3529              NaN              NaN               NaN
# ...               ...              ...               ...
# 643559            NaN              NaN               NaN
# 645126            NaN              NaN               NaN
# 645127            NaN              NaN               NaN
# 646975            NaN              NaN               NaN
# 646976            NaN              NaN               NaN
#
#         ball_receipt.outcome.id ball_receipt.outcome.name counterpress  \
# 2                           NaN                       NaN          NaN
# 3                           NaN                       NaN          NaN
# 1929                        NaN                       NaN          NaN
# 1930                        NaN                       NaN          NaN
# 3529                        NaN                       NaN          NaN
# ...                         ...                       ...          ...
# 643559                      NaN                       NaN          NaN
# 645126                      NaN                       NaN          NaN
# 645127                      NaN                       NaN          NaN
# 646975                      NaN                       NaN          NaN
# 646976                      NaN                       NaN          NaN
#
#         duel.type.id duel.type.name pass.aerial_won  interception.outcome.id  \
# 2                NaN            NaN             NaN                      NaN
# 3                NaN            NaN             NaN                      NaN
# 1929             NaN            NaN             NaN                      NaN
# 1930             NaN            NaN             NaN                      NaN
# 3529             NaN            NaN             NaN                      NaN
# ...              ...            ...             ...                      ...
# 643559           NaN            NaN             NaN                      NaN
# 645126           NaN            NaN             NaN                      NaN
# 645127           NaN            NaN             NaN                      NaN
# 646975           NaN            NaN             NaN                      NaN
# 646976           NaN            NaN             NaN                      NaN
#
#        interception.outcome.name  dribble.outcome.id dribble.outcome.name  \
# 2                            NaN                 NaN                  NaN
# 3                            NaN                 NaN                  NaN
# 1929                         NaN                 NaN                  NaN
# 1930                         NaN                 NaN                  NaN
# 3529                         NaN                 NaN                  NaN
# ...                          ...                 ...                  ...
# 643559                       NaN                 NaN                  NaN
# 645126                       NaN                 NaN                  NaN
# 645127                       NaN                 NaN                  NaN
# 646975                       NaN                 NaN                  NaN
# 646976                       NaN                 NaN                  NaN
#
#        pass.assisted_shot_id pass.shot_assist  shot.statsbomb_xg  \
# 2                        NaN              NaN                NaN
# 3                        NaN              NaN                NaN
# 1929                     NaN              NaN                NaN
# 1930                     NaN              NaN                NaN
# 3529                     NaN              NaN                NaN
# ...                      ...              ...                ...
# 643559                   NaN              NaN                NaN
# 645126                   NaN              NaN                NaN
# 645127                   NaN              NaN                NaN
# 646975                   NaN              NaN                NaN
# 646976                   NaN              NaN                NaN
#
#        shot.end_location shot.key_pass_id  shot.body_part.id  \
# 2                    NaN              NaN                NaN
# 3                    NaN              NaN                NaN
# 1929                 NaN              NaN                NaN
# 1930                 NaN              NaN                NaN
# 3529                 NaN              NaN                NaN
# ...                  ...              ...                ...
# 643559               NaN              NaN                NaN
# 645126               NaN              NaN                NaN
# 645127               NaN              NaN                NaN
# 646975               NaN              NaN                NaN
# 646976               NaN              NaN                NaN
#
#        shot.body_part.name  shot.type.id shot.type.name  shot.outcome.id  \
# 2                      NaN           NaN            NaN              NaN
# 3                      NaN           NaN            NaN              NaN
# 1929                   NaN           NaN            NaN              NaN
# 1930                   NaN           NaN            NaN              NaN
# 3529                   NaN           NaN            NaN              NaN
# ...                    ...           ...            ...              ...
# 643559                 NaN           NaN            NaN              NaN
# 645126                 NaN           NaN            NaN              NaN
# 645127                 NaN           NaN            NaN              NaN
# 646975                 NaN           NaN            NaN              NaN
# 646976                 NaN           NaN            NaN              NaN
#
#        shot.outcome.name  shot.technique.id shot.technique.name  \
# 2                    NaN                NaN                 NaN
# 3                    NaN                NaN                 NaN
# 1929                 NaN                NaN                 NaN
# 1930                 NaN                NaN                 NaN
# 3529                 NaN                NaN                 NaN
# ...                  ...                ...                 ...
# 643559               NaN                NaN                 NaN
# 645126               NaN                NaN                 NaN
# 645127               NaN                NaN                 NaN
# 646975               NaN                NaN                 NaN
# 646976               NaN                NaN                 NaN
#
#        shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 1929                 NaN                     NaN                     NaN
# 1930                 NaN                     NaN                     NaN
# 3529                 NaN                     NaN                     NaN
# ...                  ...                     ...                     ...
# 643559               NaN                     NaN                     NaN
# 645126               NaN                     NaN                     NaN
# 645127               NaN                     NaN                     NaN
# 646975               NaN                     NaN                     NaN
# 646976               NaN                     NaN                     NaN
#
#        goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 2                           NaN                 NaN                  NaN
# 3                           NaN                 NaN                  NaN
# 1929                        NaN                 NaN                  NaN
# 1930                        NaN                 NaN                  NaN
# 3529                        NaN                 NaN                  NaN
# ...                         ...                 ...                  ...
# 643559                      NaN                 NaN                  NaN
# 645126                      NaN                 NaN                  NaN
# 645127                      NaN                 NaN                  NaN
# 646975                      NaN                 NaN                  NaN
# 646976                      NaN                 NaN                  NaN
#
#        off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 2             NaN              NaN               NaN         NaN
# 3             NaN              NaN               NaN         NaN
# 1929          NaN              NaN               NaN         NaN
# 1930          NaN              NaN               NaN         NaN
# 3529          NaN              NaN               NaN         NaN
# ...           ...              ...               ...         ...
# 643559        NaN              NaN               NaN         NaN
# 645126        NaN              NaN               NaN         NaN
# 645127        NaN              NaN               NaN         NaN
# 646975        NaN              NaN               NaN         NaN
# 646976        NaN              NaN               NaN         NaN
#
#        ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 2                                 NaN               NaN                NaN
# 3                                 NaN               NaN                NaN
# 1929                              NaN               NaN                NaN
# 1930                              NaN               NaN                NaN
# 3529                              NaN               NaN                NaN
# ...                               ...               ...                ...
# 643559                            NaN               NaN                NaN
# 645126                            NaN               NaN                NaN
# 645127                            NaN               NaN                NaN
# 646975                            NaN               NaN                NaN
# 646976                            NaN               NaN                NaN
#
#         foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 2                          NaN                      NaN             NaN
# 3                          NaN                      NaN             NaN
# 1929                       NaN                      NaN             NaN
# 1930                       NaN                      NaN             NaN
# 3529                       NaN                      NaN             NaN
# ...                        ...                      ...             ...
# 643559                     NaN                      NaN             NaN
# 645126                     NaN                      NaN             NaN
# 645127                     NaN                      NaN             NaN
# 646975                     NaN                      NaN             NaN
# 646976                     NaN                      NaN             NaN
#
#        shot.aerial_won pass.through_ball  pass.technique.id  \
# 2                  NaN               NaN                NaN
# 3                  NaN               NaN                NaN
# 1929               NaN               NaN                NaN
# 1930               NaN               NaN                NaN
# 3529               NaN               NaN                NaN
# ...                ...               ...                ...
# 643559             NaN               NaN                NaN
# 645126             NaN               NaN                NaN
# 645127             NaN               NaN                NaN
# 646975             NaN               NaN                NaN
# 646976             NaN               NaN                NaN
#
#        pass.technique.name  goalkeeper.outcome.id goalkeeper.outcome.name  \
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 1929                   NaN                    NaN                     NaN
# 1930                   NaN                    NaN                     NaN
# 3529                   NaN                    NaN                     NaN
# ...                    ...                    ...                     ...
# 643559                 NaN                    NaN                     NaN
# 645126                 NaN                    NaN                     NaN
# 645127                 NaN                    NaN                     NaN
# 646975                 NaN                    NaN                     NaN
# 646976                 NaN                    NaN                     NaN
#
#         goalkeeper.technique.id goalkeeper.technique.name  \
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 1929                        NaN                       NaN
# 1930                        NaN                       NaN
# 3529                        NaN                       NaN
# ...                         ...                       ...
# 643559                      NaN                       NaN
# 645126                      NaN                       NaN
# 645127                      NaN                       NaN
# 646975                      NaN                       NaN
# 646976                      NaN                       NaN
#
#         goalkeeper.body_part.id goalkeeper.body_part.name  \
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 1929                        NaN                       NaN
# 1930                        NaN                       NaN
# 3529                        NaN                       NaN
# ...                         ...                       ...
# 643559                      NaN                       NaN
# 645126                      NaN                       NaN
# 645127                      NaN                       NaN
# 646975                      NaN                       NaN
# 646976                      NaN                       NaN
#
#         substitution.outcome.id substitution.outcome.name  \
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 1929                        NaN                       NaN
# 1930                        NaN                       NaN
# 3529                        NaN                       NaN
# ...                         ...                       ...
# 643559                      NaN                       NaN
# 645126                      NaN                       NaN
# 645127                      NaN                       NaN
# 646975                      NaN                       NaN
# 646976                      NaN                       NaN
#
#         substitution.replacement.id substitution.replacement.name  \
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 1929                            NaN                           NaN
# 1930                            NaN                           NaN
# 3529                            NaN                           NaN
# ...                             ...                           ...
# 643559                          NaN                           NaN
# 645126                          NaN                           NaN
# 645127                          NaN                           NaN
# 646975                          NaN                           NaN
# 646976                          NaN                           NaN
#
#        foul_won.defensive clearance.aerial_won pass.backheel pass.cross  \
# 2                     NaN                  NaN           NaN        NaN
# 3                     NaN                  NaN           NaN        NaN
# 1929                  NaN                  NaN           NaN        NaN
# 1930                  NaN                  NaN           NaN        NaN
# 3529                  NaN                  NaN           NaN        NaN
# ...                   ...                  ...           ...        ...
# 643559                NaN                  NaN           NaN        NaN
# 645126                NaN                  NaN           NaN        NaN
# 645127                NaN                  NaN           NaN        NaN
# 646975                NaN                  NaN           NaN        NaN
# 646976                NaN                  NaN           NaN        NaN
#
#        foul_committed.offensive foul_committed.advantage foul_won.advantage  \
# 2                           NaN                      NaN                NaN
# 3                           NaN                      NaN                NaN
# 1929                        NaN                      NaN                NaN
# 1930                        NaN                      NaN                NaN
# 3529                        NaN                      NaN                NaN
# ...                         ...                      ...                ...
# 643559                      NaN                      NaN                NaN
# 645126                      NaN                      NaN                NaN
# 645127                      NaN                      NaN                NaN
# 646975                      NaN                      NaN                NaN
# 646976                      NaN                      NaN                NaN
#
#        dribble.overrun foul_committed.penalty foul_won.penalty  \
# 2                  NaN                    NaN              NaN
# 3                  NaN                    NaN              NaN
# 1929               NaN                    NaN              NaN
# 1930               NaN                    NaN              NaN
# 3529               NaN                    NaN              NaN
# ...                ...                    ...              ...
# 643559             NaN                    NaN              NaN
# 645126             NaN                    NaN              NaN
# 645127             NaN                    NaN              NaN
# 646975             NaN                    NaN              NaN
# 646976             NaN                    NaN              NaN
#
#        injury_stoppage.in_chain miscontrol.aerial_won block.offensive  \
# 2                           NaN                   NaN             NaN
# 3                           NaN                   NaN             NaN
# 1929                        NaN                   NaN             NaN
# 1930                        NaN                   NaN             NaN
# 3529                        NaN                   NaN             NaN
# ...                         ...                   ...             ...
# 643559                      NaN                   NaN             NaN
# 645126                      NaN                   NaN             NaN
# 645127                      NaN                   NaN             NaN
# 646975                      NaN                   NaN             NaN
# 646976                      NaN                   NaN             NaN
#
#         match_id shot.open_goal shot.first_time dribble.nutmeg pass.cut_back  \
# 2          19743            NaN             NaN            NaN           NaN
# 3          19743            NaN             NaN            NaN           NaN
# 1929       19743            NaN             NaN            NaN           NaN
# 1930       19743            NaN             NaN            NaN           NaN
# 3529       19740            NaN             NaN            NaN           NaN
# ...          ...            ...             ...            ...           ...
# 643559   2275056            NaN             NaN            NaN           NaN
# 645126   2275074            NaN             NaN            NaN           NaN
# 645127   2275074            NaN             NaN            NaN           NaN
# 646975   2275074            NaN             NaN            NaN           NaN
# 646976   2275074            NaN             NaN            NaN           NaN
#
#        pass.deflected pass.goal_assist  foul_committed.type.id  \
# 2                 NaN              NaN                     NaN
# 3                 NaN              NaN                     NaN
# 1929              NaN              NaN                     NaN
# 1930              NaN              NaN                     NaN
# 3529              NaN              NaN                     NaN
# ...               ...              ...                     ...
# 643559            NaN              NaN                     NaN
# 645126            NaN              NaN                     NaN
# 645127            NaN              NaN                     NaN
# 646975            NaN              NaN                     NaN
# 646976            NaN              NaN                     NaN
#
#        foul_committed.type.name pass.miscommunication ball_recovery.offensive  \
# 2                           NaN                   NaN                     NaN
# 3                           NaN                   NaN                     NaN
# 1929                        NaN                   NaN                     NaN
# 1930                        NaN                   NaN                     NaN
# 3529                        NaN                   NaN                     NaN
# ...                         ...                   ...                     ...
# 643559                      NaN                   NaN                     NaN
# 645126                      NaN                   NaN                     NaN
# 645127                      NaN                   NaN                     NaN
# 646975                      NaN                   NaN                     NaN
# 646976                      NaN                   NaN                     NaN
#
#        block.save_block block.deflection clearance.head  \
# 2                   NaN              NaN            NaN
# 3                   NaN              NaN            NaN
# 1929                NaN              NaN            NaN
# 1930                NaN              NaN            NaN
# 3529                NaN              NaN            NaN
# ...                 ...              ...            ...
# 643559              NaN              NaN            NaN
# 645126              NaN              NaN            NaN
# 645127              NaN              NaN            NaN
# 646975              NaN              NaN            NaN
# 646976              NaN              NaN            NaN
#
#         clearance.body_part.id clearance.body_part.name  out  \
# 2                          NaN                      NaN  NaN
# 3                          NaN                      NaN  NaN
# 1929                       NaN                      NaN  NaN
# 1930                       NaN                      NaN  NaN
# 3529                       NaN                      NaN  NaN
# ...                        ...                      ...  ...
# 643559                     NaN                      NaN  NaN
# 645126                     NaN                      NaN  NaN
# 645127                     NaN                      NaN  NaN
# 646975                     NaN                      NaN  NaN
# 646976                     NaN                      NaN  NaN
#
#        clearance.left_foot clearance.right_foot pass.inswinging pass.straight  \
# 2                      NaN                  NaN             NaN           NaN
# 3                      NaN                  NaN             NaN           NaN
# 1929                   NaN                  NaN             NaN           NaN
# 1930                   NaN                  NaN             NaN           NaN
# 3529                   NaN                  NaN             NaN           NaN
# ...                    ...                  ...             ...           ...
# 643559                 NaN                  NaN             NaN           NaN
# 645126                 NaN                  NaN             NaN           NaN
# 645127                 NaN                  NaN             NaN           NaN
# 646975                 NaN                  NaN             NaN           NaN
# 646976                 NaN                  NaN             NaN           NaN
#
#        clearance.other pass.outswinging shot.redirect shot.deflected  \
# 2                  NaN              NaN           NaN            NaN
# 3                  NaN              NaN           NaN            NaN
# 1929               NaN              NaN           NaN            NaN
# 1930               NaN              NaN           NaN            NaN
# 3529               NaN              NaN           NaN            NaN
# ...                ...              ...           ...            ...
# 643559             NaN              NaN           NaN            NaN
# 645126             NaN              NaN           NaN            NaN
# 645127             NaN              NaN           NaN            NaN
# 646975             NaN              NaN           NaN            NaN
# 646976             NaN              NaN           NaN            NaN
#
#         bad_behaviour.card.id bad_behaviour.card.name pass.no_touch  \
# 2                         NaN                     NaN           NaN
# 3                         NaN                     NaN           NaN
# 1929                      NaN                     NaN           NaN
# 1930                      NaN                     NaN           NaN
# 3529                      NaN                     NaN           NaN
# ...                       ...                     ...           ...
# 643559                    NaN                     NaN           NaN
# 645126                    NaN                     NaN           NaN
# 645127                    NaN                     NaN           NaN
# 646975                    NaN                     NaN           NaN
# 646976                    NaN                     NaN           NaN
#
#        dribble.no_touch shot.saved_off_target  \
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 1929                NaN                   NaN
# 1930                NaN                   NaN
# 3529                NaN                   NaN
# ...                 ...                   ...
# 643559              NaN                   NaN
# 645126              NaN                   NaN
# 645127              NaN                   NaN
# 646975              NaN                   NaN
# 646976              NaN                   NaN
#
#        goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 2                                   NaN                 NaN
# 3                                   NaN                 NaN
# 1929                                NaN                 NaN
# 1930                                NaN                 NaN
# 3529                                NaN                 NaN
# ...                                 ...                 ...
# 643559                              NaN                 NaN
# 645126                              NaN                 NaN
# 645127                              NaN                 NaN
# 646975                              NaN                 NaN
# 646976                              NaN                 NaN
#
#        goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 2                         NaN                  NaN                NaN
# 3                         NaN                  NaN                NaN
# 1929                      NaN                  NaN                NaN
# 1930                      NaN                  NaN                NaN
# 3529                      NaN                  NaN                NaN
# ...                       ...                  ...                ...
# 643559                    NaN                  NaN                NaN
# 645126                    NaN                  NaN                NaN
# 645127                    NaN                  NaN                NaN
# 646975                    NaN                  NaN                NaN
# 646976                    NaN                  NaN                NaN
#
#        goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 1929                             NaN                     NaN
# 1930                             NaN                     NaN
# 3529                             NaN                     NaN
# ...                              ...                     ...
# 643559                           NaN                     NaN
# 645126                           NaN                     NaN
# 645127                           NaN                     NaN
# 646975                           NaN                     NaN
# 646976                           NaN                     NaN
#
#        goalkeeper.success_out shot.follows_dribble  \
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 1929                      NaN                  NaN
# 1930                      NaN                  NaN
# 3529                      NaN                  NaN
# ...                       ...                  ...
# 643559                    NaN                  NaN
# 645126                    NaN                  NaN
# 645127                    NaN                  NaN
# 646975                    NaN                  NaN
# 646976                    NaN                  NaN
#
#        half_start.late_video_start goalkeeper.success_in_play  \
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 1929                           NaN                        NaN
# 1930                           NaN                        NaN
# 3529                           NaN                        NaN
# ...                            ...                        ...
# 643559                         NaN                        NaN
# 645126                         NaN                        NaN
# 645127                         NaN                        NaN
# 646975                         NaN                        NaN
# 646976                         NaN                        NaN
#
#        half_end.early_video_end goalkeeper.saved_to_post  match_date  \
# 2                           NaN                      NaN  2018-10-21
# 3                           NaN                      NaN  2018-10-21
# 1929                        NaN                      NaN  2018-10-21
# 1930                        NaN                      NaN  2018-10-21
# 3529                        NaN                      NaN  2018-10-21
# ...                         ...                      ...         ...
# 643559                      NaN                      NaN  2019-11-17
# 645126                      NaN                      NaN  2020-02-12
# 645127                      NaN                      NaN  2020-02-12
# 646975                      NaN                      NaN  2020-02-12
# 646976                      NaN                      NaN  2020-02-12
#
#             kick_off  home_score  away_score match_status      last_updated  \
# 2       13:30:00.000           0           0    available  2020-07-29T05:00
# 3       13:30:00.000           0           0    available  2020-07-29T05:00
# 1929    13:30:00.000           0           0    available  2020-07-29T05:00
# 1930    13:30:00.000           0           0    available  2020-07-29T05:00
# 3529    16:00:00.000           0           1    available  2020-07-29T05:00
# ...              ...         ...         ...          ...               ...
# 643559  16:00:00.000           0           1    available  2020-07-29T05:00
# 645126  20:00:00.000           2           0    available  2020-07-29T05:00
# 645127  20:00:00.000           2           0    available  2020-07-29T05:00
# 646975  20:00:00.000           2           0    available  2020-07-29T05:00
# 646976  20:00:00.000           2           0    available  2020-07-29T05:00
#
#         match_week  competition.competition_id competition.country_name  \
# 2                6                          37                  England
# 3                6                          37                  England
# 1929             6                          37                  England
# 1930             6                          37                  England
# 3529             6                          37                  England
# ...            ...                         ...                      ...
# 643559           6                          37                  England
# 645126          16                          37                  England
# 645127          16                          37                  England
# 646975          16                          37                  England
# 646976          16                          37                  England
#
#        competition.competition_name  season.season_id season.season_name  \
# 2           FA Women's Super League                 4          2018/2019
# 3           FA Women's Super League                 4          2018/2019
# 1929        FA Women's Super League                 4          2018/2019
# 1930        FA Women's Super League                 4          2018/2019
# 3529        FA Women's Super League                 4          2018/2019
# ...                             ...               ...                ...
# 643559      FA Women's Super League                42          2019/2020
# 645126      FA Women's Super League                42          2019/2020
# 645127      FA Women's Super League                42          2019/2020
# 646975      FA Women's Super League                42          2019/2020
# 646976      FA Women's Super League                42          2019/2020
#
#         home_team.home_team_id home_team.home_team_name  \
# 2                          969      Birmingham City WFC
# 3                          969      Birmingham City WFC
# 1929                       969      Birmingham City WFC
# 1930                       969      Birmingham City WFC
# 3529                       972      West Ham United LFC
# ...                        ...                      ...
# 643559                     966            Liverpool WFC
# 645126                     971              Chelsea FCW
# 645127                     971              Chelsea FCW
# 646975                     971              Chelsea FCW
# 646976                     971              Chelsea FCW
#
#        home_team.home_team_gender home_team.home_team_group  \
# 2                          female                      None
# 3                          female                      None
# 1929                       female                      None
# 1930                       female                      None
# 3529                       female                      None
# ...                           ...                       ...
# 643559                     female                      None
# 645126                     female                      None
# 645127                     female                      None
# 646975                     female                      None
# 646976                     female                      None
#
#         home_team.country.id home_team.country.name  \
# 2                         68                England
# 3                         68                England
# 1929                      68                England
# 1930                      68                England
# 3529                      68                England
# ...                      ...                    ...
# 643559                    68                England
# 645126                    68                England
# 645127                    68                England
# 646975                    68                England
# 646976                    68                England
#
#                                        home_team.managers  \
# 2       [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 3       [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1929    [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 1930    [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 3529    [{'id': 139, 'name': 'Matt Beard', 'nickname':...
# ...                                                   ...
# 643559  [{'id': 623, 'name': 'Victoria Jepson', 'nickn...
# 645126  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 645127  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 646975  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 646976  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
#
#         away_team.away_team_id away_team.away_team_name  \
# 2                          971              Chelsea FCW
# 3                          971              Chelsea FCW
# 1929                       971              Chelsea FCW
# 1930                       971              Chelsea FCW
# 3529                       966            Liverpool WFC
# ...                        ...                      ...
# 643559                     967              Everton LFC
# 645126                     969      Birmingham City WFC
# 645127                     969      Birmingham City WFC
# 646975                     969      Birmingham City WFC
# 646976                     969      Birmingham City WFC
#
#        away_team.away_team_gender away_team.away_team_group  \
# 2                          female                      None
# 3                          female                      None
# 1929                       female                      None
# 1930                       female                      None
# 3529                       female                      None
# ...                           ...                       ...
# 643559                     female                      None
# 645126                     female                      None
# 645127                     female                      None
# 646975                     female                      None
# 646976                     female                      None
#
#         away_team.country.id away_team.country.name  \
# 2                         68                England
# 3                         68                England
# 1929                      68                England
# 1930                      68                England
# 3529                      68                England
# ...                      ...                    ...
# 643559                    68                England
# 645126                    68                England
# 645127                    68                England
# 646975                    68                England
# 646976                    68                England
#
#                                        away_team.managers  \
# 2       [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 3       [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 1929    [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 1930    [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 3529    [{'id': 153, 'name': 'Chris Kirkland', 'nickna...
# ...                                                   ...
# 643559  [{'id': 639, 'name': 'Willie Kirk', 'nickname'...
# 645126  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 645127  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 646975  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
# 646976  [{'id': 1817, 'name': 'Marta Tejedor', 'nickna...
#
#        metadata.data_version  competition_stage.id competition_stage.name  \
# 2                      1.0.3                     1         Regular Season
# 3                      1.0.3                     1         Regular Season
# 1929                   1.0.3                     1         Regular Season
# 1930                   1.0.3                     1         Regular Season
# 3529                   1.0.3                     1         Regular Season
# ...                      ...                   ...                    ...
# 643559                 1.1.0                     1         Regular Season
# 645126                 1.1.0                     1         Regular Season
# 645127                 1.1.0                     1         Regular Season
# 646975                 1.1.0                     1         Regular Season
# 646976                 1.1.0                     1         Regular Season
#
#         stadium.id                    stadium.name  stadium.country.id  \
# 2           5332.0         SportNation.bet Stadium               255.0
# 3           5332.0         SportNation.bet Stadium               255.0
# 1929        5332.0         SportNation.bet Stadium               255.0
# 1930        5332.0         SportNation.bet Stadium               255.0
# 3529        4062.0          The Rush Green Stadium                68.0
# ...            ...                             ...                 ...
# 643559         6.0                         Anfield                68.0
# 645126      4279.0  The Cherry Red Records Stadium                68.0
# 645127      4279.0  The Cherry Red Records Stadium                68.0
# 646975      4279.0  The Cherry Red Records Stadium                68.0
# 646976      4279.0  The Cherry Red Records Stadium                68.0
#
#        stadium.country.name  referee.id referee.name  referee.country.id  \
# 2             International       898.0     A. Fearn                 NaN
# 3             International       898.0     A. Fearn                 NaN
# 1929          International       898.0     A. Fearn                 NaN
# 1930          International       898.0     A. Fearn                 NaN
# 3529                England       568.0   J. Packman                68.0
# ...                     ...         ...          ...                 ...
# 643559              England       898.0     A. Fearn                 NaN
# 645126              England       915.0   R. Whitton                 NaN
# 645127              England       915.0   R. Whitton                 NaN
# 646975              England       915.0   R. Whitton                 NaN
# 646976              England       915.0   R. Whitton                 NaN
#
#        referee.country.name metadata.shot_fidelity_version  \
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 1929                    NaN                            NaN
# 1930                    NaN                            NaN
# 3529                England                            NaN
# ...                     ...                            ...
# 643559                  NaN                              2
# 645126                  NaN                              2
# 645127                  NaN                              2
# 646975                  NaN                              2
# 646976                  NaN                              2
#
#        metadata.xy_fidelity_version  competition_id  season_id country_name  \
# 2                               NaN              37          4      England
# 3                               NaN              37          4      England
# 1929                            NaN              37          4      England
# 1930                            NaN              37          4      England
# 3529                            NaN              37          4      England
# ...                             ...             ...        ...          ...
# 643559                            2              37         42      England
# 645126                            2              37         42      England
# 645127                            2              37         42      England
# 646975                            2              37         42      England
# 646976                            2              37         42      England
#
#                competition_name competition_gender season_name  \
# 2       FA Women's Super League             female   2018/2019
# 3       FA Women's Super League             female   2018/2019
# 1929    FA Women's Super League             female   2018/2019
# 1930    FA Women's Super League             female   2018/2019
# 3529    FA Women's Super League             female   2018/2019
# ...                         ...                ...         ...
# 643559  FA Women's Super League             female   2019/2020
# 645126  FA Women's Super League             female   2019/2020
# 645127  FA Women's Super League             female   2019/2020
# 646975  FA Women's Super League             female   2019/2020
# 646976  FA Women's Super League             female   2019/2020
#
#                        Team             Opponent  \
# 2               Chelsea FCW  Birmingham City WFC
# 3       Birmingham City WFC          Chelsea FCW
# 1929            Chelsea FCW  Birmingham City WFC
# 1930    Birmingham City WFC          Chelsea FCW
# 3529          Liverpool WFC  West Ham United LFC
# ...                     ...                  ...
# 643559          Everton LFC        Liverpool WFC
# 645126  Birmingham City WFC          Chelsea FCW
# 645127          Chelsea FCW  Birmingham City WFC
# 646975  Birmingham City WFC          Chelsea FCW
# 646976          Chelsea FCW  Birmingham City WFC
#
#                                         Full_Fixture_Date
# 2       2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3       2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 1929    2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 1930    2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 3529    2018-10-21 West Ham United LFC 0  vs.  1 Liver...
# ...                                                   ...
# 643559     2019-11-17 Liverpool WFC 0  vs.  1 Everton LFC
# 645126  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
# 645127  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
# 646975  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
# 646976  2020-02-12 Chelsea FCW 2  vs.  0 Birmingham Ci...
#
# [776 rows x 196 columns]

# %% [markdown]
# ### <a id='#section5.5'>5.5. Isolate In-Play Events</a>
# DataFrame of only player's actions i.e. removing line ups, halves, etc.

# %% [markdown]
# #### <a id='#section5.5.1'>5.5.1. Remove Non-Event rows</a>

# %%
# List unique values in the df_sb['type.name'] column
df_sb['type.name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Ball Recovery', 'Block', 'Duel', 'Interception',
#        'Dribbled Past', 'Dribble', 'Shot', 'Goal Keeper',
#        'Foul Committed', 'Foul Won', 'Dispossessed', 'Clearance',
#        'Miscontrol', '50/50', 'Injury Stoppage', 'Player Off',
#        'Player On', 'Substitution', 'Shield', 'Tactical Shift',
#        'Half End', 'Error', 'Referee Ball-Drop', 'Offside',
#        'Own Goal Against', 'Own Goal For', 'Bad Behaviour'], dtype=object)

# %%
lst_events = ['Pass', 'Ball Receipt*', 'Carry', 'Duel', 'Miscontrol', 'Pressure', 'Ball Recovery', 'Dribbled Past', 'Dribble', 'Shot', 'Block', 'Goal Keeper', 'Clearance', 'Dispossessed', 'Foul Committed', 'Foul Won', 'Interception', 'Shield', 'Half End', 'Substitution', 'Tactical Shift', 'Injury Stoppage', 'Player Off', 'Player On', 'Offside', 'Referee Ball-Drop', 'Error']

# %%
df_sb_events = df_sb[df_sb['type.name'].isin(lst_events)]

# %%
df_sb_events.shape
# Out:
# (647281, 196)

# %% [markdown]
# #### <a id='#section5.5.2'>5.5.2. Break down all `location` attributes into seperate attribute for X, Y (and sometimes Z) coordinates</a>

# %%
# Display all location columns
for col in df_sb_events.columns:
    if 'location' in col:
        print(col)
# Out:
# location
# pass.end_location
# carry.end_location
# shot.end_location
# goalkeeper.end_location

# %% [markdown]
# There are the following five 'location' attributes:
# - `location`
# - `pass.end_location`
# - `carry.end_location`
# - `shot.end_location`
# - `goalkeeper.end_location`
#
# From reviewing the official documentation [[link](https://statsbomb.com/stat-definitions/)], the five attributes have the following dimensionality:
# - `location` [x, y]
# - `pass.end_location` [x, y]
# - `carry.end_location` [x, y]
# - `shot.end_location` [x, y, z]
# - `goalkeeper.end_location` [x, y]

# %%
"""
# CURRENTLY NOT WORKING, NEED TO FIX

# Normalize 'shot.freeze_frame' avvtribute - see: https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame

## explode all columns with lists of dicts
df_sb_events_normalize = df_sb_events.apply(lambda x: x.explode()).reset_index(drop=True)

## list of columns with dicts
cols_to_normalize = ['shot.freeze_frame']

## if there are keys, which will become column names, overlap with excising column names. add the current column name as a prefix
normalized = list()

for col in cols_to_normalize:
    d = pd.json_normalize(df_sb_events_normalize[col], sep='_')
    d.columns = [f'{col}_{v}' for v in d.columns]
    normalized.append(d.copy())

## combine df with the normalized columns
df_sb_events_normalize = pd.concat([df_sb_events_normalize] + normalized, axis=1).drop(columns=cols_to_normalize)

## display(df_lineup_select_normalize)
df_sb_events_normalize.head(30)
"""
# Out:
# "\n# CURRENTLY NOT WORKING, NEED TO FIX\n\n# Normalize 'shot.freeze_frame' avvtribute - see: https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame\n\n## explode all columns with lists of dicts\ndf_sb_events_normalize = df_sb_events.apply(lambda x: x.explode()).reset_index(drop=True)\n\n## list of columns with dicts\ncols_to_normalize = ['shot.freeze_frame']\n\n## if there are keys, which will become column names, overlap with excising column names. add the current column name as a prefix\nnormalized = list()\n\nfor col in cols_to_normalize:\n    d = pd.json_normalize(df_sb_events_normalize[col], sep='_')\n    d.columns = [f'{col}_{v}' for v in d.columns]\n    normalized.append(d.copy())\n\n## combine df with the normalized columns\ndf_sb_events_normalize = pd.concat([df_sb_events_normalize] + normalized, axis=1).drop(columns=cols_to_normalize)\n\n## display(df_lineup_select_normalize)\ndf_sb_events_normalize.head(30)\n"

# %%
#

##
df_sb_events['location'] = df_sb_events['location'].astype(str)
df_sb_events['pass.end_location'] = df_sb_events['pass.end_location'].astype(str)
df_sb_events['carry.end_location'] = df_sb_events['carry.end_location'].astype(str)
df_sb_events['shot.end_location'] = df_sb_events['shot.end_location'].astype(str)
df_sb_events['goalkeeper.end_location'] = df_sb_events['goalkeeper.end_location'].astype(str)
df_sb_events['shot.end_location'] = df_sb_events['shot.end_location'].astype(str)
#df_sb_events['shot.freeze_frame'] = df_sb_events['shot.freeze_frame'].astype(str)


##

###
df_sb_events['location'] = df_sb_events['location'].str.replace('[','')
df_sb_events['pass.end_location'] = df_sb_events['pass.end_location'].str.replace('[','')
df_sb_events['carry.end_location'] = df_sb_events['carry.end_location'].str.replace('[','')
df_sb_events['shot.end_location'] = df_sb_events['shot.end_location'].str.replace('[','')
df_sb_events['goalkeeper.end_location'] = df_sb_events['goalkeeper.end_location'].str.replace('[','')
#df_sb_events['shot.freeze_frame'] = df_sb_events['shot.freeze_frame'].str.replace('[','')

###
df_sb_events['location'] = df_sb_events['location'].str.replace(']','')
df_sb_events['pass.end_location'] = df_sb_events['pass.end_location'].str.replace(']','')
df_sb_events['carry.end_location'] = df_sb_events['carry.end_location'].str.replace(']','')
df_sb_events['shot.end_location'] = df_sb_events['shot.end_location'].str.replace(']','')
df_sb_events['goalkeeper.end_location'] = df_sb_events['goalkeeper.end_location'].str.replace(']','')
#df_sb_events['shot.freeze_frame'] = df_sb_events['shot.freeze_frame'].str.replace(']','')


## Break down each location attributes
df_sb_events['location_x'], df_sb_events['location_y'] = df_sb_events['location'].str.split(',', 1).str
df_sb_events['pass.end_location_x'], df_sb_events['pass.end_location_y'] = df_sb_events['pass.end_location'].str.split(',', 1).str
df_sb_events['carry.end_location_x'], df_sb_events['carry.end_location_y'] = df_sb_events['carry.end_location'].str.split(',', 1).str
df_sb_events['shot.end_location_x'], df_sb_events['shot.end_location_y'], df_sb_events['shot.end_location_z'] = df_sb_events['shot.end_location'].str.split(',', 3).str[0:3].str
df_sb_events['goalkeeper.end_location_x'], df_sb_events['goalkeeper.end_location_y'] = df_sb_events['goalkeeper.end_location'].str.split(',', 1).str
#df_sb_events['shot.freeze_frame_x'], df_sb_events['shot.freeze_frame_y'] = df_sb_events['shot.freeze_frame'].str.split(',', 1).str


## Display DataFrame
df_sb_events.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       id  index  period     timestamp  minute  \
# 4   ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 5   89cf3d24-ba04-4269-9071-1dfabf468cd1      6       1  00:00:02.553       0
# 6   59972a9e-3362-43e1-96fd-883b2e3fbba4      7       1  00:00:02.553       0
# 7   88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 8   9f0af77c-93cc-49d5-8d16-b7a640a0b59f      9       1  00:00:05.082       0
# 9   0dcfde6b-5909-4af4-bf4e-2e0f240c5d8c     10       1  00:00:05.082       0
# 10  68374d6d-a178-4ffc-b4c7-236736c61ab0     11       1  00:00:05.122       0
# 11  c54c86a3-4bdd-47e1-87b7-67101a95ecc3     12       1  00:00:06.379       0
# 12  cc54dc47-7b90-4f99-b619-bb3986a0be0d     13       1  00:00:06.379       0
# 13  62187430-8a2c-4a84-a0e0-5b84a19b6d6d     14       1  00:00:09.208       0
#
#     second  possession  duration  type.id      type.name  possession_team.id  \
# 4        1           2  1.228695       30           Pass                 971
# 5        2           2       NaN       42  Ball Receipt*                 971
# 6        2           2  0.835305       43          Carry                 971
# 7        3           2  1.693583       30           Pass                 971
# 8        5           2       NaN       42  Ball Receipt*                 971
# 9        5           2  0.040017       43          Carry                 971
# 10       5           2  1.257417       30           Pass                 971
# 11       6           2       NaN       42  Ball Receipt*                 971
# 12       6           2  2.829083       43          Carry                 971
# 13       9           2  1.585060       30           Pass                 971
#
#    possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4           Chelsea FCW                9     From Kick Off      971
# 5           Chelsea FCW                9     From Kick Off      971
# 6           Chelsea FCW                9     From Kick Off      971
# 7           Chelsea FCW                9     From Kick Off      971
# 8           Chelsea FCW                9     From Kick Off      971
# 9           Chelsea FCW                9     From Kick Off      971
# 10          Chelsea FCW                9     From Kick Off      971
# 11          Chelsea FCW                9     From Kick Off      971
# 12          Chelsea FCW                9     From Kick Off      971
# 13          Chelsea FCW                9     From Kick Off      971
#
#       team.name  tactics.formation tactics.lineup  \
# 4   Chelsea FCW                NaN            NaN
# 5   Chelsea FCW                NaN            NaN
# 6   Chelsea FCW                NaN            NaN
# 7   Chelsea FCW                NaN            NaN
# 8   Chelsea FCW                NaN            NaN
# 9   Chelsea FCW                NaN            NaN
# 10  Chelsea FCW                NaN            NaN
# 11  Chelsea FCW                NaN            NaN
# 12  Chelsea FCW                NaN            NaN
# 13  Chelsea FCW                NaN            NaN
#
#                                        related_events    location  player.id  \
# 4              [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 5              [ac80414e-cec3-4c56-8e57-ac04149efbe2]  52.0, 45.0    15549.0
# 6   [88d1ce50-3a00-4c88-90ba-a25e658c0deb, 89cf3d2...  52.0, 45.0    15549.0
# 7              [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 8              [88d1ce50-3a00-4c88-90ba-a25e658c0deb]  38.0, 30.0     4633.0
# 9   [68374d6d-a178-4ffc-b4c7-236736c61ab0, 9f0af77...  38.0, 30.0     4633.0
# 10             [c54c86a3-4bdd-47e1-87b7-67101a95ecc3]  38.0, 30.0     4633.0
# 11             [68374d6d-a178-4ffc-b4c7-236736c61ab0]  33.0, 52.0     4642.0
# 12  [62187430-8a2c-4a84-a0e0-5b84a19b6d6d, c54c86a...  33.0, 52.0     4642.0
# 13             [bed1875f-5f95-426e-a9d2-d97073ae7184]  36.0, 57.0     4642.0
#
#            player.name  position.id             position.name  \
# 4      Francesca Kirby         23.0            Center Forward
# 5         Sophie Ingle          9.0  Right Defensive Midfield
# 6         Sophie Ingle          9.0  Right Defensive Midfield
# 7         Sophie Ingle          9.0  Right Defensive Midfield
# 8   Magdalena Ericsson          5.0          Left Center Back
# 9   Magdalena Ericsson          5.0          Left Center Back
# 10  Magdalena Ericsson          5.0          Left Center Back
# 11       Millie Bright          3.0         Right Center Back
# 12       Millie Bright          3.0         Right Center Back
# 13       Millie Bright          3.0         Right Center Back
#
#     pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4             15549.0        Sophie Ingle     9.848858    2.723368
# 5                 NaN                 NaN          NaN         NaN
# 6                 NaN                 NaN          NaN         NaN
# 7              4633.0  Magdalena Ericsson    21.213203   -2.356194
# 8                 NaN                 NaN          NaN         NaN
# 9                 NaN                 NaN          NaN         NaN
# 10             4642.0       Millie Bright    22.561028    1.794273
# 11                NaN                 NaN          NaN         NaN
# 12                NaN                 NaN          NaN         NaN
# 13            19422.0      Jessica Carter    21.540659    1.190290
#
#     pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4              1.0      Ground Pass        52.0, 45.0          65.0
# 5              NaN              NaN               nan           NaN
# 6              NaN              NaN               nan           NaN
# 7              1.0      Ground Pass        38.0, 30.0           NaN
# 8              NaN              NaN               nan           NaN
# 9              NaN              NaN               nan           NaN
# 10             1.0      Ground Pass        33.0, 52.0           NaN
# 11             NaN              NaN               nan           NaN
# 12             NaN              NaN               nan           NaN
# 13             1.0      Ground Pass        44.0, 77.0           NaN
#
#    pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4        Kick Off               40.0          Right Foot                nan
# 5             NaN                NaN                 NaN                nan
# 6             NaN                NaN                 NaN         53.0, 45.0
# 7             NaN               40.0          Right Foot                nan
# 8             NaN                NaN                 NaN                nan
# 9             NaN                NaN                 NaN         38.0, 30.0
# 10            NaN               38.0           Left Foot                nan
# 11            NaN                NaN                 NaN                nan
# 12            NaN                NaN                 NaN         36.0, 57.0
# 13            NaN               40.0          Right Foot                nan
#
#    under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4             NaN              NaN               NaN                      NaN
# 5             NaN              NaN               NaN                      NaN
# 6             NaN              NaN               NaN                      NaN
# 7             NaN              NaN               NaN                      NaN
# 8             NaN              NaN               NaN                      NaN
# 9             NaN              NaN               NaN                      NaN
# 10            NaN              NaN               NaN                      NaN
# 11            NaN              NaN               NaN                      NaN
# 12            NaN              NaN               NaN                      NaN
# 13            NaN              NaN               NaN                      NaN
#
#    ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                        NaN          NaN           NaN            NaN
# 5                        NaN          NaN           NaN            NaN
# 6                        NaN          NaN           NaN            NaN
# 7                        NaN          NaN           NaN            NaN
# 8                        NaN          NaN           NaN            NaN
# 9                        NaN          NaN           NaN            NaN
# 10                       NaN          NaN           NaN            NaN
# 11                       NaN          NaN           NaN            NaN
# 12                       NaN          NaN           NaN            NaN
# 13                       NaN          NaN           NaN            NaN
#
#    pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4              NaN                      NaN                       NaN
# 5              NaN                      NaN                       NaN
# 6              NaN                      NaN                       NaN
# 7              NaN                      NaN                       NaN
# 8              NaN                      NaN                       NaN
# 9              NaN                      NaN                       NaN
# 10             NaN                      NaN                       NaN
# 11             NaN                      NaN                       NaN
# 12             NaN                      NaN                       NaN
# 13             NaN                      NaN                       NaN
#
#     dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                  NaN                  NaN                   NaN
# 5                  NaN                  NaN                   NaN
# 6                  NaN                  NaN                   NaN
# 7                  NaN                  NaN                   NaN
# 8                  NaN                  NaN                   NaN
# 9                  NaN                  NaN                   NaN
# 10                 NaN                  NaN                   NaN
# 11                 NaN                  NaN                   NaN
# 12                 NaN                  NaN                   NaN
# 13                 NaN                  NaN                   NaN
#
#    pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4               NaN                NaN               nan              NaN
# 5               NaN                NaN               nan              NaN
# 6               NaN                NaN               nan              NaN
# 7               NaN                NaN               nan              NaN
# 8               NaN                NaN               nan              NaN
# 9               NaN                NaN               nan              NaN
# 10              NaN                NaN               nan              NaN
# 11              NaN                NaN               nan              NaN
# 12              NaN                NaN               nan              NaN
# 13              NaN                NaN               nan              NaN
#
#     shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                 NaN                 NaN           NaN            NaN
# 5                 NaN                 NaN           NaN            NaN
# 6                 NaN                 NaN           NaN            NaN
# 7                 NaN                 NaN           NaN            NaN
# 8                 NaN                 NaN           NaN            NaN
# 9                 NaN                 NaN           NaN            NaN
# 10                NaN                 NaN           NaN            NaN
# 11                NaN                 NaN           NaN            NaN
# 12                NaN                 NaN           NaN            NaN
# 13                NaN                 NaN           NaN            NaN
#
#     shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4               NaN               NaN                NaN                 NaN
# 5               NaN               NaN                NaN                 NaN
# 6               NaN               NaN                NaN                 NaN
# 7               NaN               NaN                NaN                 NaN
# 8               NaN               NaN                NaN                 NaN
# 9               NaN               NaN                NaN                 NaN
# 10              NaN               NaN                NaN                 NaN
# 11              NaN               NaN                NaN                 NaN
# 12              NaN               NaN                NaN                 NaN
# 13              NaN               NaN                NaN                 NaN
#
#    shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4                NaN                     nan                     NaN
# 5                NaN                     nan                     NaN
# 6                NaN                     nan                     NaN
# 7                NaN                     nan                     NaN
# 8                NaN                     nan                     NaN
# 9                NaN                     nan                     NaN
# 10               NaN                     nan                     NaN
# 11               NaN                     nan                     NaN
# 12               NaN                     nan                     NaN
# 13               NaN                     nan                     NaN
#
#    goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                       NaN                 NaN                  NaN
# 5                       NaN                 NaN                  NaN
# 6                       NaN                 NaN                  NaN
# 7                       NaN                 NaN                  NaN
# 8                       NaN                 NaN                  NaN
# 9                       NaN                 NaN                  NaN
# 10                      NaN                 NaN                  NaN
# 11                      NaN                 NaN                  NaN
# 12                      NaN                 NaN                  NaN
# 13                      NaN                 NaN                  NaN
#
#    off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4         NaN              NaN               NaN         NaN
# 5         NaN              NaN               NaN         NaN
# 6         NaN              NaN               NaN         NaN
# 7         NaN              NaN               NaN         NaN
# 8         NaN              NaN               NaN         NaN
# 9         NaN              NaN               NaN         NaN
# 10        NaN              NaN               NaN         NaN
# 11        NaN              NaN               NaN         NaN
# 12        NaN              NaN               NaN         NaN
# 13        NaN              NaN               NaN         NaN
#
#    ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                             NaN               NaN                NaN
# 5                             NaN               NaN                NaN
# 6                             NaN               NaN                NaN
# 7                             NaN               NaN                NaN
# 8                             NaN               NaN                NaN
# 9                             NaN               NaN                NaN
# 10                            NaN               NaN                NaN
# 11                            NaN               NaN                NaN
# 12                            NaN               NaN                NaN
# 13                            NaN               NaN                NaN
#
#     foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                      NaN                      NaN             NaN
# 5                      NaN                      NaN             NaN
# 6                      NaN                      NaN             NaN
# 7                      NaN                      NaN             NaN
# 8                      NaN                      NaN             NaN
# 9                      NaN                      NaN             NaN
# 10                     NaN                      NaN             NaN
# 11                     NaN                      NaN             NaN
# 12                     NaN                      NaN             NaN
# 13                     NaN                      NaN             NaN
#
#    shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 5              NaN               NaN                NaN                 NaN
# 6              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 8              NaN               NaN                NaN                 NaN
# 9              NaN               NaN                NaN                 NaN
# 10             NaN               NaN                NaN                 NaN
# 11             NaN               NaN                NaN                 NaN
# 12             NaN               NaN                NaN                 NaN
# 13             NaN               NaN                NaN                 NaN
#
#     goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                     NaN                     NaN                      NaN
# 5                     NaN                     NaN                      NaN
# 6                     NaN                     NaN                      NaN
# 7                     NaN                     NaN                      NaN
# 8                     NaN                     NaN                      NaN
# 9                     NaN                     NaN                      NaN
# 10                    NaN                     NaN                      NaN
# 11                    NaN                     NaN                      NaN
# 12                    NaN                     NaN                      NaN
# 13                    NaN                     NaN                      NaN
#
#    goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                        NaN                      NaN
# 5                        NaN                      NaN
# 6                        NaN                      NaN
# 7                        NaN                      NaN
# 8                        NaN                      NaN
# 9                        NaN                      NaN
# 10                       NaN                      NaN
# 11                       NaN                      NaN
# 12                       NaN                      NaN
# 13                       NaN                      NaN
#
#    goalkeeper.body_part.name  substitution.outcome.id  \
# 4                        NaN                      NaN
# 5                        NaN                      NaN
# 6                        NaN                      NaN
# 7                        NaN                      NaN
# 8                        NaN                      NaN
# 9                        NaN                      NaN
# 10                       NaN                      NaN
# 11                       NaN                      NaN
# 12                       NaN                      NaN
# 13                       NaN                      NaN
#
#    substitution.outcome.name  substitution.replacement.id  \
# 4                        NaN                          NaN
# 5                        NaN                          NaN
# 6                        NaN                          NaN
# 7                        NaN                          NaN
# 8                        NaN                          NaN
# 9                        NaN                          NaN
# 10                       NaN                          NaN
# 11                       NaN                          NaN
# 12                       NaN                          NaN
# 13                       NaN                          NaN
#
#    substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                            NaN                NaN                  NaN
# 5                            NaN                NaN                  NaN
# 6                            NaN                NaN                  NaN
# 7                            NaN                NaN                  NaN
# 8                            NaN                NaN                  NaN
# 9                            NaN                NaN                  NaN
# 10                           NaN                NaN                  NaN
# 11                           NaN                NaN                  NaN
# 12                           NaN                NaN                  NaN
# 13                           NaN                NaN                  NaN
#
#    pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4            NaN        NaN                      NaN                      NaN
# 5            NaN        NaN                      NaN                      NaN
# 6            NaN        NaN                      NaN                      NaN
# 7            NaN        NaN                      NaN                      NaN
# 8            NaN        NaN                      NaN                      NaN
# 9            NaN        NaN                      NaN                      NaN
# 10           NaN        NaN                      NaN                      NaN
# 11           NaN        NaN                      NaN                      NaN
# 12           NaN        NaN                      NaN                      NaN
# 13           NaN        NaN                      NaN                      NaN
#
#    foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                 NaN             NaN                    NaN              NaN
# 5                 NaN             NaN                    NaN              NaN
# 6                 NaN             NaN                    NaN              NaN
# 7                 NaN             NaN                    NaN              NaN
# 8                 NaN             NaN                    NaN              NaN
# 9                 NaN             NaN                    NaN              NaN
# 10                NaN             NaN                    NaN              NaN
# 11                NaN             NaN                    NaN              NaN
# 12                NaN             NaN                    NaN              NaN
# 13                NaN             NaN                    NaN              NaN
#
#    injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                       NaN                   NaN             NaN     19743
# 5                       NaN                   NaN             NaN     19743
# 6                       NaN                   NaN             NaN     19743
# 7                       NaN                   NaN             NaN     19743
# 8                       NaN                   NaN             NaN     19743
# 9                       NaN                   NaN             NaN     19743
# 10                      NaN                   NaN             NaN     19743
# 11                      NaN                   NaN             NaN     19743
# 12                      NaN                   NaN             NaN     19743
# 13                      NaN                   NaN             NaN     19743
#
#    shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4             NaN             NaN            NaN           NaN            NaN
# 5             NaN             NaN            NaN           NaN            NaN
# 6             NaN             NaN            NaN           NaN            NaN
# 7             NaN             NaN            NaN           NaN            NaN
# 8             NaN             NaN            NaN           NaN            NaN
# 9             NaN             NaN            NaN           NaN            NaN
# 10            NaN             NaN            NaN           NaN            NaN
# 11            NaN             NaN            NaN           NaN            NaN
# 12            NaN             NaN            NaN           NaN            NaN
# 13            NaN             NaN            NaN           NaN            NaN
#
#    pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4               NaN                     NaN                      NaN
# 5               NaN                     NaN                      NaN
# 6               NaN                     NaN                      NaN
# 7               NaN                     NaN                      NaN
# 8               NaN                     NaN                      NaN
# 9               NaN                     NaN                      NaN
# 10              NaN                     NaN                      NaN
# 11              NaN                     NaN                      NaN
# 12              NaN                     NaN                      NaN
# 13              NaN                     NaN                      NaN
#
#    pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                    NaN                     NaN              NaN
# 5                    NaN                     NaN              NaN
# 6                    NaN                     NaN              NaN
# 7                    NaN                     NaN              NaN
# 8                    NaN                     NaN              NaN
# 9                    NaN                     NaN              NaN
# 10                   NaN                     NaN              NaN
# 11                   NaN                     NaN              NaN
# 12                   NaN                     NaN              NaN
# 13                   NaN                     NaN              NaN
#
#    block.deflection clearance.head  clearance.body_part.id  \
# 4               NaN            NaN                     NaN
# 5               NaN            NaN                     NaN
# 6               NaN            NaN                     NaN
# 7               NaN            NaN                     NaN
# 8               NaN            NaN                     NaN
# 9               NaN            NaN                     NaN
# 10              NaN            NaN                     NaN
# 11              NaN            NaN                     NaN
# 12              NaN            NaN                     NaN
# 13              NaN            NaN                     NaN
#
#    clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                       NaN  NaN                 NaN                  NaN
# 5                       NaN  NaN                 NaN                  NaN
# 6                       NaN  NaN                 NaN                  NaN
# 7                       NaN  NaN                 NaN                  NaN
# 8                       NaN  NaN                 NaN                  NaN
# 9                       NaN  NaN                 NaN                  NaN
# 10                      NaN  NaN                 NaN                  NaN
# 11                      NaN  NaN                 NaN                  NaN
# 12                      NaN  NaN                 NaN                  NaN
# 13                      NaN  NaN                 NaN                  NaN
#
#    pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4              NaN           NaN             NaN              NaN
# 5              NaN           NaN             NaN              NaN
# 6              NaN           NaN             NaN              NaN
# 7              NaN           NaN             NaN              NaN
# 8              NaN           NaN             NaN              NaN
# 9              NaN           NaN             NaN              NaN
# 10             NaN           NaN             NaN              NaN
# 11             NaN           NaN             NaN              NaN
# 12             NaN           NaN             NaN              NaN
# 13             NaN           NaN             NaN              NaN
#
#    shot.redirect shot.deflected  bad_behaviour.card.id  \
# 4            NaN            NaN                    NaN
# 5            NaN            NaN                    NaN
# 6            NaN            NaN                    NaN
# 7            NaN            NaN                    NaN
# 8            NaN            NaN                    NaN
# 9            NaN            NaN                    NaN
# 10           NaN            NaN                    NaN
# 11           NaN            NaN                    NaN
# 12           NaN            NaN                    NaN
# 13           NaN            NaN                    NaN
#
#    bad_behaviour.card.name pass.no_touch dribble.no_touch  \
# 4                      NaN           NaN              NaN
# 5                      NaN           NaN              NaN
# 6                      NaN           NaN              NaN
# 7                      NaN           NaN              NaN
# 8                      NaN           NaN              NaN
# 9                      NaN           NaN              NaN
# 10                     NaN           NaN              NaN
# 11                     NaN           NaN              NaN
# 12                     NaN           NaN              NaN
# 13                     NaN           NaN              NaN
#
#    shot.saved_off_target goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 4                    NaN                              NaN                 NaN
# 5                    NaN                              NaN                 NaN
# 6                    NaN                              NaN                 NaN
# 7                    NaN                              NaN                 NaN
# 8                    NaN                              NaN                 NaN
# 9                    NaN                              NaN                 NaN
# 10                   NaN                              NaN                 NaN
# 11                   NaN                              NaN                 NaN
# 12                   NaN                              NaN                 NaN
# 13                   NaN                              NaN                 NaN
#
#    goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 4                     NaN                  NaN                NaN
# 5                     NaN                  NaN                NaN
# 6                     NaN                  NaN                NaN
# 7                     NaN                  NaN                NaN
# 8                     NaN                  NaN                NaN
# 9                     NaN                  NaN                NaN
# 10                    NaN                  NaN                NaN
# 11                    NaN                  NaN                NaN
# 12                    NaN                  NaN                NaN
# 13                    NaN                  NaN                NaN
#
#    goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 4                            NaN                     NaN
# 5                            NaN                     NaN
# 6                            NaN                     NaN
# 7                            NaN                     NaN
# 8                            NaN                     NaN
# 9                            NaN                     NaN
# 10                           NaN                     NaN
# 11                           NaN                     NaN
# 12                           NaN                     NaN
# 13                           NaN                     NaN
#
#    goalkeeper.success_out shot.follows_dribble half_start.late_video_start  \
# 4                     NaN                  NaN                         NaN
# 5                     NaN                  NaN                         NaN
# 6                     NaN                  NaN                         NaN
# 7                     NaN                  NaN                         NaN
# 8                     NaN                  NaN                         NaN
# 9                     NaN                  NaN                         NaN
# 10                    NaN                  NaN                         NaN
# 11                    NaN                  NaN                         NaN
# 12                    NaN                  NaN                         NaN
# 13                    NaN                  NaN                         NaN
#
#    goalkeeper.success_in_play half_end.early_video_end  \
# 4                         NaN                      NaN
# 5                         NaN                      NaN
# 6                         NaN                      NaN
# 7                         NaN                      NaN
# 8                         NaN                      NaN
# 9                         NaN                      NaN
# 10                        NaN                      NaN
# 11                        NaN                      NaN
# 12                        NaN                      NaN
# 13                        NaN                      NaN
#
#    goalkeeper.saved_to_post  match_date      kick_off  home_score  away_score  \
# 4                       NaN  2018-10-21  13:30:00.000           0           0
# 5                       NaN  2018-10-21  13:30:00.000           0           0
# 6                       NaN  2018-10-21  13:30:00.000           0           0
# 7                       NaN  2018-10-21  13:30:00.000           0           0
# 8                       NaN  2018-10-21  13:30:00.000           0           0
# 9                       NaN  2018-10-21  13:30:00.000           0           0
# 10                      NaN  2018-10-21  13:30:00.000           0           0
# 11                      NaN  2018-10-21  13:30:00.000           0           0
# 12                      NaN  2018-10-21  13:30:00.000           0           0
# 13                      NaN  2018-10-21  13:30:00.000           0           0
#
#    match_status      last_updated  match_week  competition.competition_id  \
# 4     available  2020-07-29T05:00           6                          37
# 5     available  2020-07-29T05:00           6                          37
# 6     available  2020-07-29T05:00           6                          37
# 7     available  2020-07-29T05:00           6                          37
# 8     available  2020-07-29T05:00           6                          37
# 9     available  2020-07-29T05:00           6                          37
# 10    available  2020-07-29T05:00           6                          37
# 11    available  2020-07-29T05:00           6                          37
# 12    available  2020-07-29T05:00           6                          37
# 13    available  2020-07-29T05:00           6                          37
#
#    competition.country_name competition.competition_name  season.season_id  \
# 4                   England      FA Women's Super League                 4
# 5                   England      FA Women's Super League                 4
# 6                   England      FA Women's Super League                 4
# 7                   England      FA Women's Super League                 4
# 8                   England      FA Women's Super League                 4
# 9                   England      FA Women's Super League                 4
# 10                  England      FA Women's Super League                 4
# 11                  England      FA Women's Super League                 4
# 12                  England      FA Women's Super League                 4
# 13                  England      FA Women's Super League                 4
#
#    season.season_name  home_team.home_team_id home_team.home_team_name  \
# 4           2018/2019                     969      Birmingham City WFC
# 5           2018/2019                     969      Birmingham City WFC
# 6           2018/2019                     969      Birmingham City WFC
# 7           2018/2019                     969      Birmingham City WFC
# 8           2018/2019                     969      Birmingham City WFC
# 9           2018/2019                     969      Birmingham City WFC
# 10          2018/2019                     969      Birmingham City WFC
# 11          2018/2019                     969      Birmingham City WFC
# 12          2018/2019                     969      Birmingham City WFC
# 13          2018/2019                     969      Birmingham City WFC
#
#    home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 4                      female                      None                    68
# 5                      female                      None                    68
# 6                      female                      None                    68
# 7                      female                      None                    68
# 8                      female                      None                    68
# 9                      female                      None                    68
# 10                     female                      None                    68
# 11                     female                      None                    68
# 12                     female                      None                    68
# 13                     female                      None                    68
#
#    home_team.country.name                                 home_team.managers  \
# 4                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 5                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 6                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 7                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 8                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 9                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 10                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 11                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 12                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 13                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
#
#     away_team.away_team_id away_team.away_team_name  \
# 4                      971              Chelsea FCW
# 5                      971              Chelsea FCW
# 6                      971              Chelsea FCW
# 7                      971              Chelsea FCW
# 8                      971              Chelsea FCW
# 9                      971              Chelsea FCW
# 10                     971              Chelsea FCW
# 11                     971              Chelsea FCW
# 12                     971              Chelsea FCW
# 13                     971              Chelsea FCW
#
#    away_team.away_team_gender away_team.away_team_group  away_team.country.id  \
# 4                      female                      None                    68
# 5                      female                      None                    68
# 6                      female                      None                    68
# 7                      female                      None                    68
# 8                      female                      None                    68
# 9                      female                      None                    68
# 10                     female                      None                    68
# 11                     female                      None                    68
# 12                     female                      None                    68
# 13                     female                      None                    68
#
#    away_team.country.name                                 away_team.managers  \
# 4                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 5                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 6                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 7                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 8                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 9                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 10                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 11                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 12                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 13                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
#
#    metadata.data_version  competition_stage.id competition_stage.name  \
# 4                  1.0.3                     1         Regular Season
# 5                  1.0.3                     1         Regular Season
# 6                  1.0.3                     1         Regular Season
# 7                  1.0.3                     1         Regular Season
# 8                  1.0.3                     1         Regular Season
# 9                  1.0.3                     1         Regular Season
# 10                 1.0.3                     1         Regular Season
# 11                 1.0.3                     1         Regular Season
# 12                 1.0.3                     1         Regular Season
# 13                 1.0.3                     1         Regular Season
#
#     stadium.id             stadium.name  stadium.country.id  \
# 4       5332.0  SportNation.bet Stadium               255.0
# 5       5332.0  SportNation.bet Stadium               255.0
# 6       5332.0  SportNation.bet Stadium               255.0
# 7       5332.0  SportNation.bet Stadium               255.0
# 8       5332.0  SportNation.bet Stadium               255.0
# 9       5332.0  SportNation.bet Stadium               255.0
# 10      5332.0  SportNation.bet Stadium               255.0
# 11      5332.0  SportNation.bet Stadium               255.0
# 12      5332.0  SportNation.bet Stadium               255.0
# 13      5332.0  SportNation.bet Stadium               255.0
#
#    stadium.country.name  referee.id referee.name  referee.country.id  \
# 4         International       898.0     A. Fearn                 NaN
# 5         International       898.0     A. Fearn                 NaN
# 6         International       898.0     A. Fearn                 NaN
# 7         International       898.0     A. Fearn                 NaN
# 8         International       898.0     A. Fearn                 NaN
# 9         International       898.0     A. Fearn                 NaN
# 10        International       898.0     A. Fearn                 NaN
# 11        International       898.0     A. Fearn                 NaN
# 12        International       898.0     A. Fearn                 NaN
# 13        International       898.0     A. Fearn                 NaN
#
#    referee.country.name metadata.shot_fidelity_version  \
# 4                   NaN                            NaN
# 5                   NaN                            NaN
# 6                   NaN                            NaN
# 7                   NaN                            NaN
# 8                   NaN                            NaN
# 9                   NaN                            NaN
# 10                  NaN                            NaN
# 11                  NaN                            NaN
# 12                  NaN                            NaN
# 13                  NaN                            NaN
#
#    metadata.xy_fidelity_version  competition_id  season_id country_name  \
# 4                           NaN              37          4      England
# 5                           NaN              37          4      England
# 6                           NaN              37          4      England
# 7                           NaN              37          4      England
# 8                           NaN              37          4      England
# 9                           NaN              37          4      England
# 10                          NaN              37          4      England
# 11                          NaN              37          4      England
# 12                          NaN              37          4      England
# 13                          NaN              37          4      England
#
#            competition_name competition_gender season_name         Team  \
# 4   FA Women's Super League             female   2018/2019  Chelsea FCW
# 5   FA Women's Super League             female   2018/2019  Chelsea FCW
# 6   FA Women's Super League             female   2018/2019  Chelsea FCW
# 7   FA Women's Super League             female   2018/2019  Chelsea FCW
# 8   FA Women's Super League             female   2018/2019  Chelsea FCW
# 9   FA Women's Super League             female   2018/2019  Chelsea FCW
# 10  FA Women's Super League             female   2018/2019  Chelsea FCW
# 11  FA Women's Super League             female   2018/2019  Chelsea FCW
# 12  FA Women's Super League             female   2018/2019  Chelsea FCW
# 13  FA Women's Super League             female   2018/2019  Chelsea FCW
#
#                Opponent                                  Full_Fixture_Date  \
# 4   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 5   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 6   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 7   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 8   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 9   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 10  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 11  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 12  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 13  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
#
#    location_x location_y pass.end_location_x pass.end_location_y  \
# 4        61.0       41.0                52.0                45.0
# 5        52.0       45.0                 nan                 NaN
# 6        52.0       45.0                 nan                 NaN
# 7        53.0       45.0                38.0                30.0
# 8        38.0       30.0                 nan                 NaN
# 9        38.0       30.0                 nan                 NaN
# 10       38.0       30.0                33.0                52.0
# 11       33.0       52.0                 nan                 NaN
# 12       33.0       52.0                 nan                 NaN
# 13       36.0       57.0                44.0                77.0
#
#    carry.end_location_x carry.end_location_y shot.end_location_x  \
# 4                   nan                  NaN                 nan
# 5                   nan                  NaN                 nan
# 6                  53.0                 45.0                 nan
# 7                   nan                  NaN                 nan
# 8                   nan                  NaN                 nan
# 9                  38.0                 30.0                 nan
# 10                  nan                  NaN                 nan
# 11                  nan                  NaN                 nan
# 12                 36.0                 57.0                 nan
# 13                  nan                  NaN                 nan
#
#    shot.end_location_y shot.end_location_z goalkeeper.end_location_x  \
# 4                  NaN                 NaN                       nan
# 5                  NaN                 NaN                       nan
# 6                  NaN                 NaN                       nan
# 7                  NaN                 NaN                       nan
# 8                  NaN                 NaN                       nan
# 9                  NaN                 NaN                       nan
# 10                 NaN                 NaN                       nan
# 11                 NaN                 NaN                       nan
# 12                 NaN                 NaN                       nan
# 13                 NaN                 NaN                       nan
#
#    goalkeeper.end_location_y
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN

# %%
df_sb_events.shape
# Out:
# (647281, 207)

# %% [markdown]
# ##### Export Dataset

# %%
# Export 
df_sb_events.to_csv(data_dir_sb + '/events/engineered/' + '/sb_events_1819_2021_wsl.csv', index=None, header=True)

# Export 
df_sb_events.to_csv(data_dir + '/export/' + '/sb_wsl_events.csv', index=None, header=True)

# %% [markdown]
# #### <a id='#section5.5.3'>5.5.3. Create Passing Matrix Data</a>

# %%
df1 = df_sb_events.copy()

# %%
df1['df_name'] = 'df1'

# %%
df1.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 5  89cf3d24-ba04-4269-9071-1dfabf468cd1      6       1  00:00:02.553       0
# 6  59972a9e-3362-43e1-96fd-883b2e3fbba4      7       1  00:00:02.553       0
# 7  88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 8  9f0af77c-93cc-49d5-8d16-b7a640a0b59f      9       1  00:00:05.082       0
#
#    second  possession  duration  type.id      type.name  possession_team.id  \
# 4       1           2  1.228695       30           Pass                 971
# 5       2           2       NaN       42  Ball Receipt*                 971
# 6       2           2  0.835305       43          Carry                 971
# 7       3           2  1.693583       30           Pass                 971
# 8       5           2       NaN       42  Ball Receipt*                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4          Chelsea FCW                9     From Kick Off      971
# 5          Chelsea FCW                9     From Kick Off      971
# 6          Chelsea FCW                9     From Kick Off      971
# 7          Chelsea FCW                9     From Kick Off      971
# 8          Chelsea FCW                9     From Kick Off      971
#
#      team.name  tactics.formation tactics.lineup  \
# 4  Chelsea FCW                NaN            NaN
# 5  Chelsea FCW                NaN            NaN
# 6  Chelsea FCW                NaN            NaN
# 7  Chelsea FCW                NaN            NaN
# 8  Chelsea FCW                NaN            NaN
#
#                                       related_events    location  player.id  \
# 4             [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 5             [ac80414e-cec3-4c56-8e57-ac04149efbe2]  52.0, 45.0    15549.0
# 6  [88d1ce50-3a00-4c88-90ba-a25e658c0deb, 89cf3d2...  52.0, 45.0    15549.0
# 7             [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 8             [88d1ce50-3a00-4c88-90ba-a25e658c0deb]  38.0, 30.0     4633.0
#
#           player.name  position.id             position.name  \
# 4     Francesca Kirby         23.0            Center Forward
# 5        Sophie Ingle          9.0  Right Defensive Midfield
# 6        Sophie Ingle          9.0  Right Defensive Midfield
# 7        Sophie Ingle          9.0  Right Defensive Midfield
# 8  Magdalena Ericsson          5.0          Left Center Back
#
#    pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4            15549.0        Sophie Ingle     9.848858    2.723368
# 5                NaN                 NaN          NaN         NaN
# 6                NaN                 NaN          NaN         NaN
# 7             4633.0  Magdalena Ericsson    21.213203   -2.356194
# 8                NaN                 NaN          NaN         NaN
#
#    pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4             1.0      Ground Pass        52.0, 45.0          65.0
# 5             NaN              NaN               nan           NaN
# 6             NaN              NaN               nan           NaN
# 7             1.0      Ground Pass        38.0, 30.0           NaN
# 8             NaN              NaN               nan           NaN
#
#   pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4       Kick Off               40.0          Right Foot                nan
# 5            NaN                NaN                 NaN                nan
# 6            NaN                NaN                 NaN         53.0, 45.0
# 7            NaN               40.0          Right Foot                nan
# 8            NaN                NaN                 NaN                nan
#
#   under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4            NaN              NaN               NaN                      NaN
# 5            NaN              NaN               NaN                      NaN
# 6            NaN              NaN               NaN                      NaN
# 7            NaN              NaN               NaN                      NaN
# 8            NaN              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                       NaN          NaN           NaN            NaN
# 5                       NaN          NaN           NaN            NaN
# 6                       NaN          NaN           NaN            NaN
# 7                       NaN          NaN           NaN            NaN
# 8                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4             NaN                      NaN                       NaN
# 5             NaN                      NaN                       NaN
# 6             NaN                      NaN                       NaN
# 7             NaN                      NaN                       NaN
# 8             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                 NaN                  NaN                   NaN
# 5                 NaN                  NaN                   NaN
# 6                 NaN                  NaN                   NaN
# 7                 NaN                  NaN                   NaN
# 8                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4              NaN                NaN               nan              NaN
# 5              NaN                NaN               nan              NaN
# 6              NaN                NaN               nan              NaN
# 7              NaN                NaN               nan              NaN
# 8              NaN                NaN               nan              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                NaN                 NaN           NaN            NaN
# 5                NaN                 NaN           NaN            NaN
# 6                NaN                 NaN           NaN            NaN
# 7                NaN                 NaN           NaN            NaN
# 8                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 5              NaN               NaN                NaN                 NaN
# 6              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 8              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4               NaN                     nan                     NaN
# 5               NaN                     nan                     NaN
# 6               NaN                     nan                     NaN
# 7               NaN                     nan                     NaN
# 8               NaN                     nan                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                      NaN                 NaN                  NaN
# 5                      NaN                 NaN                  NaN
# 6                      NaN                 NaN                  NaN
# 7                      NaN                 NaN                  NaN
# 8                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4        NaN              NaN               NaN         NaN
# 5        NaN              NaN               NaN         NaN
# 6        NaN              NaN               NaN         NaN
# 7        NaN              NaN               NaN         NaN
# 8        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                            NaN               NaN                NaN
# 5                            NaN               NaN                NaN
# 6                            NaN               NaN                NaN
# 7                            NaN               NaN                NaN
# 8                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                     NaN                      NaN             NaN
# 5                     NaN                      NaN             NaN
# 6                     NaN                      NaN             NaN
# 7                     NaN                      NaN             NaN
# 8                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4             NaN               NaN                NaN                 NaN
# 5             NaN               NaN                NaN                 NaN
# 6             NaN               NaN                NaN                 NaN
# 7             NaN               NaN                NaN                 NaN
# 8             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                    NaN                     NaN                      NaN
# 5                    NaN                     NaN                      NaN
# 6                    NaN                     NaN                      NaN
# 7                    NaN                     NaN                      NaN
# 8                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                           NaN                NaN                  NaN
# 5                           NaN                NaN                  NaN
# 6                           NaN                NaN                  NaN
# 7                           NaN                NaN                  NaN
# 8                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4           NaN        NaN                      NaN                      NaN
# 5           NaN        NaN                      NaN                      NaN
# 6           NaN        NaN                      NaN                      NaN
# 7           NaN        NaN                      NaN                      NaN
# 8           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                NaN             NaN                    NaN              NaN
# 5                NaN             NaN                    NaN              NaN
# 6                NaN             NaN                    NaN              NaN
# 7                NaN             NaN                    NaN              NaN
# 8                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                      NaN                   NaN             NaN     19743
# 5                      NaN                   NaN             NaN     19743
# 6                      NaN                   NaN             NaN     19743
# 7                      NaN                   NaN             NaN     19743
# 8                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4            NaN             NaN            NaN           NaN            NaN
# 5            NaN             NaN            NaN           NaN            NaN
# 6            NaN             NaN            NaN           NaN            NaN
# 7            NaN             NaN            NaN           NaN            NaN
# 8            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4              NaN                     NaN                      NaN
# 5              NaN                     NaN                      NaN
# 6              NaN                     NaN                      NaN
# 7              NaN                     NaN                      NaN
# 8              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                   NaN                     NaN              NaN
# 5                   NaN                     NaN              NaN
# 6                   NaN                     NaN              NaN
# 7                   NaN                     NaN              NaN
# 8                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 4              NaN            NaN                     NaN
# 5              NaN            NaN                     NaN
# 6              NaN            NaN                     NaN
# 7              NaN            NaN                     NaN
# 8              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                      NaN  NaN                 NaN                  NaN
# 5                      NaN  NaN                 NaN                  NaN
# 6                      NaN  NaN                 NaN                  NaN
# 7                      NaN  NaN                 NaN                  NaN
# 8                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4             NaN           NaN             NaN              NaN
# 5             NaN           NaN             NaN              NaN
# 6             NaN           NaN             NaN              NaN
# 7             NaN           NaN             NaN              NaN
# 8             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 4           NaN            NaN                    NaN                     NaN
# 5           NaN            NaN                    NaN                     NaN
# 6           NaN            NaN                    NaN                     NaN
# 7           NaN            NaN                    NaN                     NaN
# 8           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 4           NaN              NaN                   NaN
# 5           NaN              NaN                   NaN
# 6           NaN              NaN                   NaN
# 7           NaN              NaN                   NaN
# 8           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 4                              NaN                 NaN                    NaN
# 5                              NaN                 NaN                    NaN
# 6                              NaN                 NaN                    NaN
# 7                              NaN                 NaN                    NaN
# 8                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 4                  NaN                NaN                           NaN
# 5                  NaN                NaN                           NaN
# 6                  NaN                NaN                           NaN
# 7                  NaN                NaN                           NaN
# 8                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 4                     NaN                    NaN                  NaN
# 5                     NaN                    NaN                  NaN
# 6                     NaN                    NaN                  NaN
# 7                     NaN                    NaN                  NaN
# 8                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
# 5                      NaN                      NaN  2018-10-21  13:30:00.000
# 6                      NaN                      NaN  2018-10-21  13:30:00.000
# 7                      NaN                      NaN  2018-10-21  13:30:00.000
# 8                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 4           0           0    available  2020-07-29T05:00           6
# 5           0           0    available  2020-07-29T05:00           6
# 6           0           0    available  2020-07-29T05:00           6
# 7           0           0    available  2020-07-29T05:00           6
# 8           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 4                          37                  England
# 5                          37                  England
# 6                          37                  England
# 7                          37                  England
# 8                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 4      FA Women's Super League                 4          2018/2019
# 5      FA Women's Super League                 4          2018/2019
# 6      FA Women's Super League                 4          2018/2019
# 7      FA Women's Super League                 4          2018/2019
# 8      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 4                     969      Birmingham City WFC                     female
# 5                     969      Birmingham City WFC                     female
# 6                     969      Birmingham City WFC                     female
# 7                     969      Birmingham City WFC                     female
# 8                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 5  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 6  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 7  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 8  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 4              Chelsea FCW                     female
# 5              Chelsea FCW                     female
# 6              Chelsea FCW                     female
# 7              Chelsea FCW                     female
# 8              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 5  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 6  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 7  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 8  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 4                     1         Regular Season      5332.0
# 5                     1         Regular Season      5332.0
# 6                     1         Regular Season      5332.0
# 7                     1         Regular Season      5332.0
# 8                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 4  SportNation.bet Stadium               255.0        International
# 5  SportNation.bet Stadium               255.0        International
# 6  SportNation.bet Stadium               255.0        International
# 7  SportNation.bet Stadium               255.0        International
# 8  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 4       898.0     A. Fearn                 NaN                  NaN
# 5       898.0     A. Fearn                 NaN                  NaN
# 6       898.0     A. Fearn                 NaN                  NaN
# 7       898.0     A. Fearn                 NaN                  NaN
# 8       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 4                            NaN                          NaN              37
# 5                            NaN                          NaN              37
# 6                            NaN                          NaN              37
# 7                            NaN                          NaN              37
# 8                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 4          4      England  FA Women's Super League             female
# 5          4      England  FA Women's Super League             female
# 6          4      England  FA Women's Super League             female
# 7          4      England  FA Women's Super League             female
# 8          4      England  FA Women's Super League             female
#
#   season_name         Team             Opponent  \
# 4   2018/2019  Chelsea FCW  Birmingham City WFC
# 5   2018/2019  Chelsea FCW  Birmingham City WFC
# 6   2018/2019  Chelsea FCW  Birmingham City WFC
# 7   2018/2019  Chelsea FCW  Birmingham City WFC
# 8   2018/2019  Chelsea FCW  Birmingham City WFC
#
#                                    Full_Fixture_Date location_x location_y  \
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       61.0       41.0
# 5  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 6  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 7  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       53.0       45.0
# 8  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       38.0       30.0
#
#   pass.end_location_x pass.end_location_y carry.end_location_x  \
# 4                52.0                45.0                  nan
# 5                 nan                 NaN                  nan
# 6                 nan                 NaN                 53.0
# 7                38.0                30.0                  nan
# 8                 nan                 NaN                  nan
#
#   carry.end_location_y shot.end_location_x shot.end_location_y  \
# 4                  NaN                 nan                 NaN
# 5                  NaN                 nan                 NaN
# 6                 45.0                 nan                 NaN
# 7                  NaN                 nan                 NaN
# 8                  NaN                 nan                 NaN
#
#   shot.end_location_z goalkeeper.end_location_x goalkeeper.end_location_y  \
# 4                 NaN                       nan                       NaN
# 5                 NaN                       nan                       NaN
# 6                 NaN                       nan                       NaN
# 7                 NaN                       nan                       NaN
# 8                 NaN                       nan                       NaN
#
#   df_name
# 4     df1
# 5     df1
# 6     df1
# 7     df1
# 8     df1

# %%
df2 = df_sb_events.copy()

# %%
df2['df_name'] = 'df2'

# %%
df2.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 5  89cf3d24-ba04-4269-9071-1dfabf468cd1      6       1  00:00:02.553       0
# 6  59972a9e-3362-43e1-96fd-883b2e3fbba4      7       1  00:00:02.553       0
# 7  88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 8  9f0af77c-93cc-49d5-8d16-b7a640a0b59f      9       1  00:00:05.082       0
#
#    second  possession  duration  type.id      type.name  possession_team.id  \
# 4       1           2  1.228695       30           Pass                 971
# 5       2           2       NaN       42  Ball Receipt*                 971
# 6       2           2  0.835305       43          Carry                 971
# 7       3           2  1.693583       30           Pass                 971
# 8       5           2       NaN       42  Ball Receipt*                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4          Chelsea FCW                9     From Kick Off      971
# 5          Chelsea FCW                9     From Kick Off      971
# 6          Chelsea FCW                9     From Kick Off      971
# 7          Chelsea FCW                9     From Kick Off      971
# 8          Chelsea FCW                9     From Kick Off      971
#
#      team.name  tactics.formation tactics.lineup  \
# 4  Chelsea FCW                NaN            NaN
# 5  Chelsea FCW                NaN            NaN
# 6  Chelsea FCW                NaN            NaN
# 7  Chelsea FCW                NaN            NaN
# 8  Chelsea FCW                NaN            NaN
#
#                                       related_events    location  player.id  \
# 4             [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 5             [ac80414e-cec3-4c56-8e57-ac04149efbe2]  52.0, 45.0    15549.0
# 6  [88d1ce50-3a00-4c88-90ba-a25e658c0deb, 89cf3d2...  52.0, 45.0    15549.0
# 7             [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 8             [88d1ce50-3a00-4c88-90ba-a25e658c0deb]  38.0, 30.0     4633.0
#
#           player.name  position.id             position.name  \
# 4     Francesca Kirby         23.0            Center Forward
# 5        Sophie Ingle          9.0  Right Defensive Midfield
# 6        Sophie Ingle          9.0  Right Defensive Midfield
# 7        Sophie Ingle          9.0  Right Defensive Midfield
# 8  Magdalena Ericsson          5.0          Left Center Back
#
#    pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4            15549.0        Sophie Ingle     9.848858    2.723368
# 5                NaN                 NaN          NaN         NaN
# 6                NaN                 NaN          NaN         NaN
# 7             4633.0  Magdalena Ericsson    21.213203   -2.356194
# 8                NaN                 NaN          NaN         NaN
#
#    pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4             1.0      Ground Pass        52.0, 45.0          65.0
# 5             NaN              NaN               nan           NaN
# 6             NaN              NaN               nan           NaN
# 7             1.0      Ground Pass        38.0, 30.0           NaN
# 8             NaN              NaN               nan           NaN
#
#   pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4       Kick Off               40.0          Right Foot                nan
# 5            NaN                NaN                 NaN                nan
# 6            NaN                NaN                 NaN         53.0, 45.0
# 7            NaN               40.0          Right Foot                nan
# 8            NaN                NaN                 NaN                nan
#
#   under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4            NaN              NaN               NaN                      NaN
# 5            NaN              NaN               NaN                      NaN
# 6            NaN              NaN               NaN                      NaN
# 7            NaN              NaN               NaN                      NaN
# 8            NaN              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                       NaN          NaN           NaN            NaN
# 5                       NaN          NaN           NaN            NaN
# 6                       NaN          NaN           NaN            NaN
# 7                       NaN          NaN           NaN            NaN
# 8                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4             NaN                      NaN                       NaN
# 5             NaN                      NaN                       NaN
# 6             NaN                      NaN                       NaN
# 7             NaN                      NaN                       NaN
# 8             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                 NaN                  NaN                   NaN
# 5                 NaN                  NaN                   NaN
# 6                 NaN                  NaN                   NaN
# 7                 NaN                  NaN                   NaN
# 8                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4              NaN                NaN               nan              NaN
# 5              NaN                NaN               nan              NaN
# 6              NaN                NaN               nan              NaN
# 7              NaN                NaN               nan              NaN
# 8              NaN                NaN               nan              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                NaN                 NaN           NaN            NaN
# 5                NaN                 NaN           NaN            NaN
# 6                NaN                 NaN           NaN            NaN
# 7                NaN                 NaN           NaN            NaN
# 8                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 5              NaN               NaN                NaN                 NaN
# 6              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 8              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4               NaN                     nan                     NaN
# 5               NaN                     nan                     NaN
# 6               NaN                     nan                     NaN
# 7               NaN                     nan                     NaN
# 8               NaN                     nan                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                      NaN                 NaN                  NaN
# 5                      NaN                 NaN                  NaN
# 6                      NaN                 NaN                  NaN
# 7                      NaN                 NaN                  NaN
# 8                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4        NaN              NaN               NaN         NaN
# 5        NaN              NaN               NaN         NaN
# 6        NaN              NaN               NaN         NaN
# 7        NaN              NaN               NaN         NaN
# 8        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                            NaN               NaN                NaN
# 5                            NaN               NaN                NaN
# 6                            NaN               NaN                NaN
# 7                            NaN               NaN                NaN
# 8                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                     NaN                      NaN             NaN
# 5                     NaN                      NaN             NaN
# 6                     NaN                      NaN             NaN
# 7                     NaN                      NaN             NaN
# 8                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4             NaN               NaN                NaN                 NaN
# 5             NaN               NaN                NaN                 NaN
# 6             NaN               NaN                NaN                 NaN
# 7             NaN               NaN                NaN                 NaN
# 8             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                    NaN                     NaN                      NaN
# 5                    NaN                     NaN                      NaN
# 6                    NaN                     NaN                      NaN
# 7                    NaN                     NaN                      NaN
# 8                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                           NaN                NaN                  NaN
# 5                           NaN                NaN                  NaN
# 6                           NaN                NaN                  NaN
# 7                           NaN                NaN                  NaN
# 8                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4           NaN        NaN                      NaN                      NaN
# 5           NaN        NaN                      NaN                      NaN
# 6           NaN        NaN                      NaN                      NaN
# 7           NaN        NaN                      NaN                      NaN
# 8           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                NaN             NaN                    NaN              NaN
# 5                NaN             NaN                    NaN              NaN
# 6                NaN             NaN                    NaN              NaN
# 7                NaN             NaN                    NaN              NaN
# 8                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                      NaN                   NaN             NaN     19743
# 5                      NaN                   NaN             NaN     19743
# 6                      NaN                   NaN             NaN     19743
# 7                      NaN                   NaN             NaN     19743
# 8                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4            NaN             NaN            NaN           NaN            NaN
# 5            NaN             NaN            NaN           NaN            NaN
# 6            NaN             NaN            NaN           NaN            NaN
# 7            NaN             NaN            NaN           NaN            NaN
# 8            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4              NaN                     NaN                      NaN
# 5              NaN                     NaN                      NaN
# 6              NaN                     NaN                      NaN
# 7              NaN                     NaN                      NaN
# 8              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                   NaN                     NaN              NaN
# 5                   NaN                     NaN              NaN
# 6                   NaN                     NaN              NaN
# 7                   NaN                     NaN              NaN
# 8                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 4              NaN            NaN                     NaN
# 5              NaN            NaN                     NaN
# 6              NaN            NaN                     NaN
# 7              NaN            NaN                     NaN
# 8              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                      NaN  NaN                 NaN                  NaN
# 5                      NaN  NaN                 NaN                  NaN
# 6                      NaN  NaN                 NaN                  NaN
# 7                      NaN  NaN                 NaN                  NaN
# 8                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4             NaN           NaN             NaN              NaN
# 5             NaN           NaN             NaN              NaN
# 6             NaN           NaN             NaN              NaN
# 7             NaN           NaN             NaN              NaN
# 8             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 4           NaN            NaN                    NaN                     NaN
# 5           NaN            NaN                    NaN                     NaN
# 6           NaN            NaN                    NaN                     NaN
# 7           NaN            NaN                    NaN                     NaN
# 8           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 4           NaN              NaN                   NaN
# 5           NaN              NaN                   NaN
# 6           NaN              NaN                   NaN
# 7           NaN              NaN                   NaN
# 8           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 4                              NaN                 NaN                    NaN
# 5                              NaN                 NaN                    NaN
# 6                              NaN                 NaN                    NaN
# 7                              NaN                 NaN                    NaN
# 8                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 4                  NaN                NaN                           NaN
# 5                  NaN                NaN                           NaN
# 6                  NaN                NaN                           NaN
# 7                  NaN                NaN                           NaN
# 8                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 4                     NaN                    NaN                  NaN
# 5                     NaN                    NaN                  NaN
# 6                     NaN                    NaN                  NaN
# 7                     NaN                    NaN                  NaN
# 8                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
# 5                      NaN                      NaN  2018-10-21  13:30:00.000
# 6                      NaN                      NaN  2018-10-21  13:30:00.000
# 7                      NaN                      NaN  2018-10-21  13:30:00.000
# 8                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 4           0           0    available  2020-07-29T05:00           6
# 5           0           0    available  2020-07-29T05:00           6
# 6           0           0    available  2020-07-29T05:00           6
# 7           0           0    available  2020-07-29T05:00           6
# 8           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 4                          37                  England
# 5                          37                  England
# 6                          37                  England
# 7                          37                  England
# 8                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 4      FA Women's Super League                 4          2018/2019
# 5      FA Women's Super League                 4          2018/2019
# 6      FA Women's Super League                 4          2018/2019
# 7      FA Women's Super League                 4          2018/2019
# 8      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 4                     969      Birmingham City WFC                     female
# 5                     969      Birmingham City WFC                     female
# 6                     969      Birmingham City WFC                     female
# 7                     969      Birmingham City WFC                     female
# 8                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 5  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 6  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 7  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 8  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 4              Chelsea FCW                     female
# 5              Chelsea FCW                     female
# 6              Chelsea FCW                     female
# 7              Chelsea FCW                     female
# 8              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 5  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 6  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 7  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 8  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 4                     1         Regular Season      5332.0
# 5                     1         Regular Season      5332.0
# 6                     1         Regular Season      5332.0
# 7                     1         Regular Season      5332.0
# 8                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 4  SportNation.bet Stadium               255.0        International
# 5  SportNation.bet Stadium               255.0        International
# 6  SportNation.bet Stadium               255.0        International
# 7  SportNation.bet Stadium               255.0        International
# 8  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 4       898.0     A. Fearn                 NaN                  NaN
# 5       898.0     A. Fearn                 NaN                  NaN
# 6       898.0     A. Fearn                 NaN                  NaN
# 7       898.0     A. Fearn                 NaN                  NaN
# 8       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 4                            NaN                          NaN              37
# 5                            NaN                          NaN              37
# 6                            NaN                          NaN              37
# 7                            NaN                          NaN              37
# 8                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 4          4      England  FA Women's Super League             female
# 5          4      England  FA Women's Super League             female
# 6          4      England  FA Women's Super League             female
# 7          4      England  FA Women's Super League             female
# 8          4      England  FA Women's Super League             female
#
#   season_name         Team             Opponent  \
# 4   2018/2019  Chelsea FCW  Birmingham City WFC
# 5   2018/2019  Chelsea FCW  Birmingham City WFC
# 6   2018/2019  Chelsea FCW  Birmingham City WFC
# 7   2018/2019  Chelsea FCW  Birmingham City WFC
# 8   2018/2019  Chelsea FCW  Birmingham City WFC
#
#                                    Full_Fixture_Date location_x location_y  \
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       61.0       41.0
# 5  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 6  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 7  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       53.0       45.0
# 8  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       38.0       30.0
#
#   pass.end_location_x pass.end_location_y carry.end_location_x  \
# 4                52.0                45.0                  nan
# 5                 nan                 NaN                  nan
# 6                 nan                 NaN                 53.0
# 7                38.0                30.0                  nan
# 8                 nan                 NaN                  nan
#
#   carry.end_location_y shot.end_location_x shot.end_location_y  \
# 4                  NaN                 nan                 NaN
# 5                  NaN                 nan                 NaN
# 6                 45.0                 nan                 NaN
# 7                  NaN                 nan                 NaN
# 8                  NaN                 nan                 NaN
#
#   shot.end_location_z goalkeeper.end_location_x goalkeeper.end_location_y  \
# 4                 NaN                       nan                       NaN
# 5                 NaN                       nan                       NaN
# 6                 NaN                       nan                       NaN
# 7                 NaN                       nan                       NaN
# 8                 NaN                       nan                       NaN
#
#   df_name
# 4     df2
# 5     df2
# 6     df2
# 7     df2
# 8     df2

# %%
df1.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 5  89cf3d24-ba04-4269-9071-1dfabf468cd1      6       1  00:00:02.553       0
# 6  59972a9e-3362-43e1-96fd-883b2e3fbba4      7       1  00:00:02.553       0
# 7  88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 8  9f0af77c-93cc-49d5-8d16-b7a640a0b59f      9       1  00:00:05.082       0
#
#    second  possession  duration  type.id      type.name  possession_team.id  \
# 4       1           2  1.228695       30           Pass                 971
# 5       2           2       NaN       42  Ball Receipt*                 971
# 6       2           2  0.835305       43          Carry                 971
# 7       3           2  1.693583       30           Pass                 971
# 8       5           2       NaN       42  Ball Receipt*                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4          Chelsea FCW                9     From Kick Off      971
# 5          Chelsea FCW                9     From Kick Off      971
# 6          Chelsea FCW                9     From Kick Off      971
# 7          Chelsea FCW                9     From Kick Off      971
# 8          Chelsea FCW                9     From Kick Off      971
#
#      team.name  tactics.formation tactics.lineup  \
# 4  Chelsea FCW                NaN            NaN
# 5  Chelsea FCW                NaN            NaN
# 6  Chelsea FCW                NaN            NaN
# 7  Chelsea FCW                NaN            NaN
# 8  Chelsea FCW                NaN            NaN
#
#                                       related_events    location  player.id  \
# 4             [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 5             [ac80414e-cec3-4c56-8e57-ac04149efbe2]  52.0, 45.0    15549.0
# 6  [88d1ce50-3a00-4c88-90ba-a25e658c0deb, 89cf3d2...  52.0, 45.0    15549.0
# 7             [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 8             [88d1ce50-3a00-4c88-90ba-a25e658c0deb]  38.0, 30.0     4633.0
#
#           player.name  position.id             position.name  \
# 4     Francesca Kirby         23.0            Center Forward
# 5        Sophie Ingle          9.0  Right Defensive Midfield
# 6        Sophie Ingle          9.0  Right Defensive Midfield
# 7        Sophie Ingle          9.0  Right Defensive Midfield
# 8  Magdalena Ericsson          5.0          Left Center Back
#
#    pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4            15549.0        Sophie Ingle     9.848858    2.723368
# 5                NaN                 NaN          NaN         NaN
# 6                NaN                 NaN          NaN         NaN
# 7             4633.0  Magdalena Ericsson    21.213203   -2.356194
# 8                NaN                 NaN          NaN         NaN
#
#    pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4             1.0      Ground Pass        52.0, 45.0          65.0
# 5             NaN              NaN               nan           NaN
# 6             NaN              NaN               nan           NaN
# 7             1.0      Ground Pass        38.0, 30.0           NaN
# 8             NaN              NaN               nan           NaN
#
#   pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4       Kick Off               40.0          Right Foot                nan
# 5            NaN                NaN                 NaN                nan
# 6            NaN                NaN                 NaN         53.0, 45.0
# 7            NaN               40.0          Right Foot                nan
# 8            NaN                NaN                 NaN                nan
#
#   under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4            NaN              NaN               NaN                      NaN
# 5            NaN              NaN               NaN                      NaN
# 6            NaN              NaN               NaN                      NaN
# 7            NaN              NaN               NaN                      NaN
# 8            NaN              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                       NaN          NaN           NaN            NaN
# 5                       NaN          NaN           NaN            NaN
# 6                       NaN          NaN           NaN            NaN
# 7                       NaN          NaN           NaN            NaN
# 8                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4             NaN                      NaN                       NaN
# 5             NaN                      NaN                       NaN
# 6             NaN                      NaN                       NaN
# 7             NaN                      NaN                       NaN
# 8             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                 NaN                  NaN                   NaN
# 5                 NaN                  NaN                   NaN
# 6                 NaN                  NaN                   NaN
# 7                 NaN                  NaN                   NaN
# 8                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4              NaN                NaN               nan              NaN
# 5              NaN                NaN               nan              NaN
# 6              NaN                NaN               nan              NaN
# 7              NaN                NaN               nan              NaN
# 8              NaN                NaN               nan              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                NaN                 NaN           NaN            NaN
# 5                NaN                 NaN           NaN            NaN
# 6                NaN                 NaN           NaN            NaN
# 7                NaN                 NaN           NaN            NaN
# 8                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 5              NaN               NaN                NaN                 NaN
# 6              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 8              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4               NaN                     nan                     NaN
# 5               NaN                     nan                     NaN
# 6               NaN                     nan                     NaN
# 7               NaN                     nan                     NaN
# 8               NaN                     nan                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                      NaN                 NaN                  NaN
# 5                      NaN                 NaN                  NaN
# 6                      NaN                 NaN                  NaN
# 7                      NaN                 NaN                  NaN
# 8                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4        NaN              NaN               NaN         NaN
# 5        NaN              NaN               NaN         NaN
# 6        NaN              NaN               NaN         NaN
# 7        NaN              NaN               NaN         NaN
# 8        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                            NaN               NaN                NaN
# 5                            NaN               NaN                NaN
# 6                            NaN               NaN                NaN
# 7                            NaN               NaN                NaN
# 8                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                     NaN                      NaN             NaN
# 5                     NaN                      NaN             NaN
# 6                     NaN                      NaN             NaN
# 7                     NaN                      NaN             NaN
# 8                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4             NaN               NaN                NaN                 NaN
# 5             NaN               NaN                NaN                 NaN
# 6             NaN               NaN                NaN                 NaN
# 7             NaN               NaN                NaN                 NaN
# 8             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                    NaN                     NaN                      NaN
# 5                    NaN                     NaN                      NaN
# 6                    NaN                     NaN                      NaN
# 7                    NaN                     NaN                      NaN
# 8                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                           NaN                NaN                  NaN
# 5                           NaN                NaN                  NaN
# 6                           NaN                NaN                  NaN
# 7                           NaN                NaN                  NaN
# 8                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4           NaN        NaN                      NaN                      NaN
# 5           NaN        NaN                      NaN                      NaN
# 6           NaN        NaN                      NaN                      NaN
# 7           NaN        NaN                      NaN                      NaN
# 8           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                NaN             NaN                    NaN              NaN
# 5                NaN             NaN                    NaN              NaN
# 6                NaN             NaN                    NaN              NaN
# 7                NaN             NaN                    NaN              NaN
# 8                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                      NaN                   NaN             NaN     19743
# 5                      NaN                   NaN             NaN     19743
# 6                      NaN                   NaN             NaN     19743
# 7                      NaN                   NaN             NaN     19743
# 8                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4            NaN             NaN            NaN           NaN            NaN
# 5            NaN             NaN            NaN           NaN            NaN
# 6            NaN             NaN            NaN           NaN            NaN
# 7            NaN             NaN            NaN           NaN            NaN
# 8            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4              NaN                     NaN                      NaN
# 5              NaN                     NaN                      NaN
# 6              NaN                     NaN                      NaN
# 7              NaN                     NaN                      NaN
# 8              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                   NaN                     NaN              NaN
# 5                   NaN                     NaN              NaN
# 6                   NaN                     NaN              NaN
# 7                   NaN                     NaN              NaN
# 8                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 4              NaN            NaN                     NaN
# 5              NaN            NaN                     NaN
# 6              NaN            NaN                     NaN
# 7              NaN            NaN                     NaN
# 8              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                      NaN  NaN                 NaN                  NaN
# 5                      NaN  NaN                 NaN                  NaN
# 6                      NaN  NaN                 NaN                  NaN
# 7                      NaN  NaN                 NaN                  NaN
# 8                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4             NaN           NaN             NaN              NaN
# 5             NaN           NaN             NaN              NaN
# 6             NaN           NaN             NaN              NaN
# 7             NaN           NaN             NaN              NaN
# 8             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 4           NaN            NaN                    NaN                     NaN
# 5           NaN            NaN                    NaN                     NaN
# 6           NaN            NaN                    NaN                     NaN
# 7           NaN            NaN                    NaN                     NaN
# 8           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 4           NaN              NaN                   NaN
# 5           NaN              NaN                   NaN
# 6           NaN              NaN                   NaN
# 7           NaN              NaN                   NaN
# 8           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 4                              NaN                 NaN                    NaN
# 5                              NaN                 NaN                    NaN
# 6                              NaN                 NaN                    NaN
# 7                              NaN                 NaN                    NaN
# 8                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 4                  NaN                NaN                           NaN
# 5                  NaN                NaN                           NaN
# 6                  NaN                NaN                           NaN
# 7                  NaN                NaN                           NaN
# 8                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 4                     NaN                    NaN                  NaN
# 5                     NaN                    NaN                  NaN
# 6                     NaN                    NaN                  NaN
# 7                     NaN                    NaN                  NaN
# 8                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
# 5                      NaN                      NaN  2018-10-21  13:30:00.000
# 6                      NaN                      NaN  2018-10-21  13:30:00.000
# 7                      NaN                      NaN  2018-10-21  13:30:00.000
# 8                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 4           0           0    available  2020-07-29T05:00           6
# 5           0           0    available  2020-07-29T05:00           6
# 6           0           0    available  2020-07-29T05:00           6
# 7           0           0    available  2020-07-29T05:00           6
# 8           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 4                          37                  England
# 5                          37                  England
# 6                          37                  England
# 7                          37                  England
# 8                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 4      FA Women's Super League                 4          2018/2019
# 5      FA Women's Super League                 4          2018/2019
# 6      FA Women's Super League                 4          2018/2019
# 7      FA Women's Super League                 4          2018/2019
# 8      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 4                     969      Birmingham City WFC                     female
# 5                     969      Birmingham City WFC                     female
# 6                     969      Birmingham City WFC                     female
# 7                     969      Birmingham City WFC                     female
# 8                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 5  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 6  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 7  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 8  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 4              Chelsea FCW                     female
# 5              Chelsea FCW                     female
# 6              Chelsea FCW                     female
# 7              Chelsea FCW                     female
# 8              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 5  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 6  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 7  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 8  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 4                     1         Regular Season      5332.0
# 5                     1         Regular Season      5332.0
# 6                     1         Regular Season      5332.0
# 7                     1         Regular Season      5332.0
# 8                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 4  SportNation.bet Stadium               255.0        International
# 5  SportNation.bet Stadium               255.0        International
# 6  SportNation.bet Stadium               255.0        International
# 7  SportNation.bet Stadium               255.0        International
# 8  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 4       898.0     A. Fearn                 NaN                  NaN
# 5       898.0     A. Fearn                 NaN                  NaN
# 6       898.0     A. Fearn                 NaN                  NaN
# 7       898.0     A. Fearn                 NaN                  NaN
# 8       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 4                            NaN                          NaN              37
# 5                            NaN                          NaN              37
# 6                            NaN                          NaN              37
# 7                            NaN                          NaN              37
# 8                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 4          4      England  FA Women's Super League             female
# 5          4      England  FA Women's Super League             female
# 6          4      England  FA Women's Super League             female
# 7          4      England  FA Women's Super League             female
# 8          4      England  FA Women's Super League             female
#
#   season_name         Team             Opponent  \
# 4   2018/2019  Chelsea FCW  Birmingham City WFC
# 5   2018/2019  Chelsea FCW  Birmingham City WFC
# 6   2018/2019  Chelsea FCW  Birmingham City WFC
# 7   2018/2019  Chelsea FCW  Birmingham City WFC
# 8   2018/2019  Chelsea FCW  Birmingham City WFC
#
#                                    Full_Fixture_Date location_x location_y  \
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       61.0       41.0
# 5  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 6  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 7  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       53.0       45.0
# 8  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       38.0       30.0
#
#   pass.end_location_x pass.end_location_y carry.end_location_x  \
# 4                52.0                45.0                  nan
# 5                 nan                 NaN                  nan
# 6                 nan                 NaN                 53.0
# 7                38.0                30.0                  nan
# 8                 nan                 NaN                  nan
#
#   carry.end_location_y shot.end_location_x shot.end_location_y  \
# 4                  NaN                 nan                 NaN
# 5                  NaN                 nan                 NaN
# 6                 45.0                 nan                 NaN
# 7                  NaN                 nan                 NaN
# 8                  NaN                 nan                 NaN
#
#   shot.end_location_z goalkeeper.end_location_x goalkeeper.end_location_y  \
# 4                 NaN                       nan                       NaN
# 5                 NaN                       nan                       NaN
# 6                 NaN                       nan                       NaN
# 7                 NaN                       nan                       NaN
# 8                 NaN                       nan                       NaN
#
#   df_name
# 4     df1
# 5     df1
# 6     df1
# 7     df1
# 8     df1

# %% [markdown]
# ##### Concatanate DataFrames

# %%
df_sb_events_passing = pd.concat([df1, df2])

# %%
df_sb_events_passing.shape
# Out:
# (1294562, 208)

# %% [markdown]
# ##### ...

# %%
df_sb_events_passing['Pass_X'] = np.where(df_sb_events_passing['df_name'] == 'df1', df_sb_events_passing['location_x'], df_sb_events_passing['pass.end_location_x'])
df_sb_events_passing['Pass_Y'] = np.where(df_sb_events_passing['df_name'] == 'df1', df_sb_events_passing['location_y'], df_sb_events_passing['pass.end_location_y'])

# %%
df_sb_events_passing.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 4  ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 5  89cf3d24-ba04-4269-9071-1dfabf468cd1      6       1  00:00:02.553       0
# 6  59972a9e-3362-43e1-96fd-883b2e3fbba4      7       1  00:00:02.553       0
# 7  88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 8  9f0af77c-93cc-49d5-8d16-b7a640a0b59f      9       1  00:00:05.082       0
#
#    second  possession  duration  type.id      type.name  possession_team.id  \
# 4       1           2  1.228695       30           Pass                 971
# 5       2           2       NaN       42  Ball Receipt*                 971
# 6       2           2  0.835305       43          Carry                 971
# 7       3           2  1.693583       30           Pass                 971
# 8       5           2       NaN       42  Ball Receipt*                 971
#
#   possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4          Chelsea FCW                9     From Kick Off      971
# 5          Chelsea FCW                9     From Kick Off      971
# 6          Chelsea FCW                9     From Kick Off      971
# 7          Chelsea FCW                9     From Kick Off      971
# 8          Chelsea FCW                9     From Kick Off      971
#
#      team.name  tactics.formation tactics.lineup  \
# 4  Chelsea FCW                NaN            NaN
# 5  Chelsea FCW                NaN            NaN
# 6  Chelsea FCW                NaN            NaN
# 7  Chelsea FCW                NaN            NaN
# 8  Chelsea FCW                NaN            NaN
#
#                                       related_events    location  player.id  \
# 4             [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 5             [ac80414e-cec3-4c56-8e57-ac04149efbe2]  52.0, 45.0    15549.0
# 6  [88d1ce50-3a00-4c88-90ba-a25e658c0deb, 89cf3d2...  52.0, 45.0    15549.0
# 7             [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 8             [88d1ce50-3a00-4c88-90ba-a25e658c0deb]  38.0, 30.0     4633.0
#
#           player.name  position.id             position.name  \
# 4     Francesca Kirby         23.0            Center Forward
# 5        Sophie Ingle          9.0  Right Defensive Midfield
# 6        Sophie Ingle          9.0  Right Defensive Midfield
# 7        Sophie Ingle          9.0  Right Defensive Midfield
# 8  Magdalena Ericsson          5.0          Left Center Back
#
#    pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4            15549.0        Sophie Ingle     9.848858    2.723368
# 5                NaN                 NaN          NaN         NaN
# 6                NaN                 NaN          NaN         NaN
# 7             4633.0  Magdalena Ericsson    21.213203   -2.356194
# 8                NaN                 NaN          NaN         NaN
#
#    pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4             1.0      Ground Pass        52.0, 45.0          65.0
# 5             NaN              NaN               nan           NaN
# 6             NaN              NaN               nan           NaN
# 7             1.0      Ground Pass        38.0, 30.0           NaN
# 8             NaN              NaN               nan           NaN
#
#   pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4       Kick Off               40.0          Right Foot                nan
# 5            NaN                NaN                 NaN                nan
# 6            NaN                NaN                 NaN         53.0, 45.0
# 7            NaN               40.0          Right Foot                nan
# 8            NaN                NaN                 NaN                nan
#
#   under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4            NaN              NaN               NaN                      NaN
# 5            NaN              NaN               NaN                      NaN
# 6            NaN              NaN               NaN                      NaN
# 7            NaN              NaN               NaN                      NaN
# 8            NaN              NaN               NaN                      NaN
#
#   ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                       NaN          NaN           NaN            NaN
# 5                       NaN          NaN           NaN            NaN
# 6                       NaN          NaN           NaN            NaN
# 7                       NaN          NaN           NaN            NaN
# 8                       NaN          NaN           NaN            NaN
#
#   pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4             NaN                      NaN                       NaN
# 5             NaN                      NaN                       NaN
# 6             NaN                      NaN                       NaN
# 7             NaN                      NaN                       NaN
# 8             NaN                      NaN                       NaN
#
#    dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                 NaN                  NaN                   NaN
# 5                 NaN                  NaN                   NaN
# 6                 NaN                  NaN                   NaN
# 7                 NaN                  NaN                   NaN
# 8                 NaN                  NaN                   NaN
#
#   pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4              NaN                NaN               nan              NaN
# 5              NaN                NaN               nan              NaN
# 6              NaN                NaN               nan              NaN
# 7              NaN                NaN               nan              NaN
# 8              NaN                NaN               nan              NaN
#
#    shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                NaN                 NaN           NaN            NaN
# 5                NaN                 NaN           NaN            NaN
# 6                NaN                 NaN           NaN            NaN
# 7                NaN                 NaN           NaN            NaN
# 8                NaN                 NaN           NaN            NaN
#
#    shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 5              NaN               NaN                NaN                 NaN
# 6              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 8              NaN               NaN                NaN                 NaN
#
#   shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4               NaN                     nan                     NaN
# 5               NaN                     nan                     NaN
# 6               NaN                     nan                     NaN
# 7               NaN                     nan                     NaN
# 8               NaN                     nan                     NaN
#
#   goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                      NaN                 NaN                  NaN
# 5                      NaN                 NaN                  NaN
# 6                      NaN                 NaN                  NaN
# 7                      NaN                 NaN                  NaN
# 8                      NaN                 NaN                  NaN
#
#   off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4        NaN              NaN               NaN         NaN
# 5        NaN              NaN               NaN         NaN
# 6        NaN              NaN               NaN         NaN
# 7        NaN              NaN               NaN         NaN
# 8        NaN              NaN               NaN         NaN
#
#   ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                            NaN               NaN                NaN
# 5                            NaN               NaN                NaN
# 6                            NaN               NaN                NaN
# 7                            NaN               NaN                NaN
# 8                            NaN               NaN                NaN
#
#    foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                     NaN                      NaN             NaN
# 5                     NaN                      NaN             NaN
# 6                     NaN                      NaN             NaN
# 7                     NaN                      NaN             NaN
# 8                     NaN                      NaN             NaN
#
#   shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4             NaN               NaN                NaN                 NaN
# 5             NaN               NaN                NaN                 NaN
# 6             NaN               NaN                NaN                 NaN
# 7             NaN               NaN                NaN                 NaN
# 8             NaN               NaN                NaN                 NaN
#
#    goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                    NaN                     NaN                      NaN
# 5                    NaN                     NaN                      NaN
# 6                    NaN                     NaN                      NaN
# 7                    NaN                     NaN                      NaN
# 8                    NaN                     NaN                      NaN
#
#   goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   goalkeeper.body_part.name  substitution.outcome.id  \
# 4                       NaN                      NaN
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                       NaN                      NaN
#
#   substitution.outcome.name  substitution.replacement.id  \
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
#
#   substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                           NaN                NaN                  NaN
# 5                           NaN                NaN                  NaN
# 6                           NaN                NaN                  NaN
# 7                           NaN                NaN                  NaN
# 8                           NaN                NaN                  NaN
#
#   pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4           NaN        NaN                      NaN                      NaN
# 5           NaN        NaN                      NaN                      NaN
# 6           NaN        NaN                      NaN                      NaN
# 7           NaN        NaN                      NaN                      NaN
# 8           NaN        NaN                      NaN                      NaN
#
#   foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                NaN             NaN                    NaN              NaN
# 5                NaN             NaN                    NaN              NaN
# 6                NaN             NaN                    NaN              NaN
# 7                NaN             NaN                    NaN              NaN
# 8                NaN             NaN                    NaN              NaN
#
#   injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                      NaN                   NaN             NaN     19743
# 5                      NaN                   NaN             NaN     19743
# 6                      NaN                   NaN             NaN     19743
# 7                      NaN                   NaN             NaN     19743
# 8                      NaN                   NaN             NaN     19743
#
#   shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4            NaN             NaN            NaN           NaN            NaN
# 5            NaN             NaN            NaN           NaN            NaN
# 6            NaN             NaN            NaN           NaN            NaN
# 7            NaN             NaN            NaN           NaN            NaN
# 8            NaN             NaN            NaN           NaN            NaN
#
#   pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4              NaN                     NaN                      NaN
# 5              NaN                     NaN                      NaN
# 6              NaN                     NaN                      NaN
# 7              NaN                     NaN                      NaN
# 8              NaN                     NaN                      NaN
#
#   pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                   NaN                     NaN              NaN
# 5                   NaN                     NaN              NaN
# 6                   NaN                     NaN              NaN
# 7                   NaN                     NaN              NaN
# 8                   NaN                     NaN              NaN
#
#   block.deflection clearance.head  clearance.body_part.id  \
# 4              NaN            NaN                     NaN
# 5              NaN            NaN                     NaN
# 6              NaN            NaN                     NaN
# 7              NaN            NaN                     NaN
# 8              NaN            NaN                     NaN
#
#   clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                      NaN  NaN                 NaN                  NaN
# 5                      NaN  NaN                 NaN                  NaN
# 6                      NaN  NaN                 NaN                  NaN
# 7                      NaN  NaN                 NaN                  NaN
# 8                      NaN  NaN                 NaN                  NaN
#
#   pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4             NaN           NaN             NaN              NaN
# 5             NaN           NaN             NaN              NaN
# 6             NaN           NaN             NaN              NaN
# 7             NaN           NaN             NaN              NaN
# 8             NaN           NaN             NaN              NaN
#
#   shot.redirect shot.deflected  bad_behaviour.card.id bad_behaviour.card.name  \
# 4           NaN            NaN                    NaN                     NaN
# 5           NaN            NaN                    NaN                     NaN
# 6           NaN            NaN                    NaN                     NaN
# 7           NaN            NaN                    NaN                     NaN
# 8           NaN            NaN                    NaN                     NaN
#
#   pass.no_touch dribble.no_touch shot.saved_off_target  \
# 4           NaN              NaN                   NaN
# 5           NaN              NaN                   NaN
# 6           NaN              NaN                   NaN
# 7           NaN              NaN                   NaN
# 8           NaN              NaN                   NaN
#
#   goalkeeper.shot_saved_off_target goalkeeper.lost_out goalkeeper.punched_out  \
# 4                              NaN                 NaN                    NaN
# 5                              NaN                 NaN                    NaN
# 6                              NaN                 NaN                    NaN
# 7                              NaN                 NaN                    NaN
# 8                              NaN                 NaN                    NaN
#
#   player_off.permanent shot.saved_to_post goalkeeper.shot_saved_to_post  \
# 4                  NaN                NaN                           NaN
# 5                  NaN                NaN                           NaN
# 6                  NaN                NaN                           NaN
# 7                  NaN                NaN                           NaN
# 8                  NaN                NaN                           NaN
#
#   goalkeeper.lost_in_play goalkeeper.success_out shot.follows_dribble  \
# 4                     NaN                    NaN                  NaN
# 5                     NaN                    NaN                  NaN
# 6                     NaN                    NaN                  NaN
# 7                     NaN                    NaN                  NaN
# 8                     NaN                    NaN                  NaN
#
#   half_start.late_video_start goalkeeper.success_in_play  \
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
#
#   half_end.early_video_end goalkeeper.saved_to_post  match_date      kick_off  \
# 4                      NaN                      NaN  2018-10-21  13:30:00.000
# 5                      NaN                      NaN  2018-10-21  13:30:00.000
# 6                      NaN                      NaN  2018-10-21  13:30:00.000
# 7                      NaN                      NaN  2018-10-21  13:30:00.000
# 8                      NaN                      NaN  2018-10-21  13:30:00.000
#
#    home_score  away_score match_status      last_updated  match_week  \
# 4           0           0    available  2020-07-29T05:00           6
# 5           0           0    available  2020-07-29T05:00           6
# 6           0           0    available  2020-07-29T05:00           6
# 7           0           0    available  2020-07-29T05:00           6
# 8           0           0    available  2020-07-29T05:00           6
#
#    competition.competition_id competition.country_name  \
# 4                          37                  England
# 5                          37                  England
# 6                          37                  England
# 7                          37                  England
# 8                          37                  England
#
#   competition.competition_name  season.season_id season.season_name  \
# 4      FA Women's Super League                 4          2018/2019
# 5      FA Women's Super League                 4          2018/2019
# 6      FA Women's Super League                 4          2018/2019
# 7      FA Women's Super League                 4          2018/2019
# 8      FA Women's Super League                 4          2018/2019
#
#    home_team.home_team_id home_team.home_team_name home_team.home_team_gender  \
# 4                     969      Birmingham City WFC                     female
# 5                     969      Birmingham City WFC                     female
# 6                     969      Birmingham City WFC                     female
# 7                     969      Birmingham City WFC                     female
# 8                     969      Birmingham City WFC                     female
#
#   home_team.home_team_group  home_team.country.id home_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   home_team.managers  away_team.away_team_id  \
# 4  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 5  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 6  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 7  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
# 8  [{'id': 128, 'name': 'Marc Skinner', 'nickname...                     971
#
#   away_team.away_team_name away_team.away_team_gender  \
# 4              Chelsea FCW                     female
# 5              Chelsea FCW                     female
# 6              Chelsea FCW                     female
# 7              Chelsea FCW                     female
# 8              Chelsea FCW                     female
#
#   away_team.away_team_group  away_team.country.id away_team.country.name  \
# 4                      None                    68                England
# 5                      None                    68                England
# 6                      None                    68                England
# 7                      None                    68                England
# 8                      None                    68                England
#
#                                   away_team.managers metadata.data_version  \
# 4  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 5  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 6  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 7  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
# 8  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...                 1.0.3
#
#    competition_stage.id competition_stage.name  stadium.id  \
# 4                     1         Regular Season      5332.0
# 5                     1         Regular Season      5332.0
# 6                     1         Regular Season      5332.0
# 7                     1         Regular Season      5332.0
# 8                     1         Regular Season      5332.0
#
#               stadium.name  stadium.country.id stadium.country.name  \
# 4  SportNation.bet Stadium               255.0        International
# 5  SportNation.bet Stadium               255.0        International
# 6  SportNation.bet Stadium               255.0        International
# 7  SportNation.bet Stadium               255.0        International
# 8  SportNation.bet Stadium               255.0        International
#
#    referee.id referee.name  referee.country.id referee.country.name  \
# 4       898.0     A. Fearn                 NaN                  NaN
# 5       898.0     A. Fearn                 NaN                  NaN
# 6       898.0     A. Fearn                 NaN                  NaN
# 7       898.0     A. Fearn                 NaN                  NaN
# 8       898.0     A. Fearn                 NaN                  NaN
#
#   metadata.shot_fidelity_version metadata.xy_fidelity_version  competition_id  \
# 4                            NaN                          NaN              37
# 5                            NaN                          NaN              37
# 6                            NaN                          NaN              37
# 7                            NaN                          NaN              37
# 8                            NaN                          NaN              37
#
#    season_id country_name         competition_name competition_gender  \
# 4          4      England  FA Women's Super League             female
# 5          4      England  FA Women's Super League             female
# 6          4      England  FA Women's Super League             female
# 7          4      England  FA Women's Super League             female
# 8          4      England  FA Women's Super League             female
#
#   season_name         Team             Opponent  \
# 4   2018/2019  Chelsea FCW  Birmingham City WFC
# 5   2018/2019  Chelsea FCW  Birmingham City WFC
# 6   2018/2019  Chelsea FCW  Birmingham City WFC
# 7   2018/2019  Chelsea FCW  Birmingham City WFC
# 8   2018/2019  Chelsea FCW  Birmingham City WFC
#
#                                    Full_Fixture_Date location_x location_y  \
# 4  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       61.0       41.0
# 5  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 6  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       52.0       45.0
# 7  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       53.0       45.0
# 8  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...       38.0       30.0
#
#   pass.end_location_x pass.end_location_y carry.end_location_x  \
# 4                52.0                45.0                  nan
# 5                 nan                 NaN                  nan
# 6                 nan                 NaN                 53.0
# 7                38.0                30.0                  nan
# 8                 nan                 NaN                  nan
#
#   carry.end_location_y shot.end_location_x shot.end_location_y  \
# 4                  NaN                 nan                 NaN
# 5                  NaN                 nan                 NaN
# 6                 45.0                 nan                 NaN
# 7                  NaN                 nan                 NaN
# 8                  NaN                 nan                 NaN
#
#   shot.end_location_z goalkeeper.end_location_x goalkeeper.end_location_y  \
# 4                 NaN                       nan                       NaN
# 5                 NaN                       nan                       NaN
# 6                 NaN                       nan                       NaN
# 7                 NaN                       nan                       NaN
# 8                 NaN                       nan                       NaN
#
#   df_name Pass_X Pass_Y
# 4     df1   61.0   41.0
# 5     df1   52.0   45.0
# 6     df1   52.0   45.0
# 7     df1   53.0   45.0
# 8     df1   38.0   30.0

# %%
sorted(df_sb_events_passing.columns)
# Out:
# ['50_50.outcome.id',
#  '50_50.outcome.name',
#  'Full_Fixture_Date',
#  'Opponent',
#  'Pass_X',
#  'Pass_Y',
#  'Team',
#  'away_score',
#  'away_team.away_team_gender',
#  'away_team.away_team_group',
#  'away_team.away_team_id',
#  'away_team.away_team_name',
#  'away_team.country.id',
#  'away_team.country.name',
#  'away_team.managers',
#  'bad_behaviour.card.id',
#  'bad_behaviour.card.name',
#  'ball_receipt.outcome.id',
#  'ball_receipt.outcome.name',
#  'ball_recovery.offensive',
#  'ball_recovery.recovery_failure',
#  'block.deflection',
#  'block.offensive',
#  'block.save_block',
#  'carry.end_location',
#  'carry.end_location_x',
#  'carry.end_location_y',
#  'clearance.aerial_won',
#  'clearance.body_part.id',
#  'clearance.body_part.name',
#  'clearance.head',
#  'clearance.left_foot',
#  'clearance.other',
#  'clearance.right_foot',
#  'competition.competition_id',
#  'competition.competition_name',
#  'competition.country_name',
#  'competition_gender',
#  'competition_id',
#  'competition_name',
#  'competition_stage.id',
#  'competition_stage.name',
#  'counterpress',
#  'country_name',
#  'df_name',
#  'dribble.no_touch',
#  'dribble.nutmeg',
#  'dribble.outcome.id',
#  'dribble.outcome.name',
#  'dribble.overrun',
#  'duel.outcome.id',
#  'duel.outcome.name',
#  'duel.type.id',
#  'duel.type.name',
#  'duration',
#  'foul_committed.advantage',
#  'foul_committed.card.id',
#  'foul_committed.card.name',
#  'foul_committed.offensive',
#  'foul_committed.penalty',
#  'foul_committed.type.id',
#  'foul_committed.type.name',
#  'foul_won.advantage',
#  'foul_won.defensive',
#  'foul_won.penalty',
#  'goalkeeper.body_part.id',
#  'goalkeeper.body_part.name',
#  'goalkeeper.end_location',
#  'goalkeeper.end_location_x',
#  'goalkeeper.end_location_y',
#  'goalkeeper.lost_in_play',
#  'goalkeeper.lost_out',
#  'goalkeeper.outcome.id',
#  'goalkeeper.outcome.name',
#  'goalkeeper.position.id',
#  'goalkeeper.position.name',
#  'goalkeeper.punched_out',
#  'goalkeeper.saved_to_post',
#  'goalkeeper.shot_saved_off_target',
#  'goalkeeper.shot_saved_to_post',
#  'goalkeeper.success_in_play',
#  'goalkeeper.success_out',
#  'goalkeeper.technique.id',
#  'goalkeeper.technique.name',
#  'goalkeeper.type.id',
#  'goalkeeper.type.name',
#  'half_end.early_video_end',
#  'half_start.late_video_start',
#  'home_score',
#  'home_team.country.id',
#  'home_team.country.name',
#  'home_team.home_team_gender',
#  'home_team.home_team_group',
#  'home_team.home_team_id',
#  'home_team.home_team_name',
#  'home_team.managers',
#  'id',
#  'index',
#  'injury_stoppage.in_chain',
#  'interception.outcome.id',
#  'interception.outcome.name',
#  'kick_off',
#  'last_updated',
#  'location',
#  'location_x',
#  'location_y',
#  'match_date',
#  'match_id',
#  'match_status',
#  'match_week',
#  'metadata.data_version',
#  'metadata.shot_fidelity_version',
#  'metadata.xy_fidelity_version',
#  'minute',
#  'miscontrol.aerial_won',
#  'off_camera',
#  'out',
#  'pass.aerial_won',
#  'pass.angle',
#  'pass.assisted_shot_id',
#  'pass.backheel',
#  'pass.body_part.id',
#  'pass.body_part.name',
#  'pass.cross',
#  'pass.cut_back',
#  'pass.deflected',
#  'pass.end_location',
#  'pass.end_location_x',
#  'pass.end_location_y',
#  'pass.goal_assist',
#  'pass.height.id',
#  'pass.height.name',
#  'pass.inswinging',
#  'pass.length',
#  'pass.miscommunication',
#  'pass.no_touch',
#  'pass.outcome.id',
#  'pass.outcome.name',
#  'pass.outswinging',
#  'pass.recipient.id',
#  'pass.recipient.name',
#  'pass.shot_assist',
#  'pass.straight',
#  'pass.switch',
#  'pass.technique.id',
#  'pass.technique.name',
#  'pass.through_ball',
#  'pass.type.id',
#  'pass.type.name',
#  'period',
#  'play_pattern.id',
#  'play_pattern.name',
#  'player.id',
#  'player.name',
#  'player_off.permanent',
#  'position.id',
#  'position.name',
#  'possession',
#  'possession_team.id',
#  'possession_team.name',
#  'referee.country.id',
#  'referee.country.name',
#  'referee.id',
#  'referee.name',
#  'related_events',
#  'season.season_id',
#  'season.season_name',
#  'season_id',
#  'season_name',
#  'second',
#  'shot.aerial_won',
#  'shot.body_part.id',
#  'shot.body_part.name',
#  'shot.deflected',
#  'shot.end_location',
#  'shot.end_location_x',
#  'shot.end_location_y',
#  'shot.end_location_z',
#  'shot.first_time',
#  'shot.follows_dribble',
#  'shot.freeze_frame',
#  'shot.key_pass_id',
#  'shot.one_on_one',
#  'shot.open_goal',
#  'shot.outcome.id',
#  'shot.outcome.name',
#  'shot.redirect',
#  'shot.saved_off_target',
#  'shot.saved_to_post',
#  'shot.statsbomb_xg',
#  'shot.technique.id',
#  'shot.technique.name',
#  'shot.type.id',
#  'shot.type.name',
#  'stadium.country.id',
#  'stadium.country.name',
#  'stadium.id',
#  'stadium.name',
#  'substitution.outcome.id',
#  'substitution.outcome.name',
#  'substitution.replacement.id',
#  'substitution.replacement.name',
#  'tactics.formation',
#  'tactics.lineup',
#  'team.id',
#  'team.name',
#  'timestamp',
#  'type.id',
#  'type.name',
#  'under_pressure']

# %% [markdown]
# ##### Export Dataset

# %%
# Export 
#df_sb_events_passing.to_csv(data_dir_sb + '/events/engineered/' + '/sb_events_passing_matrix_1819_2021_wsl.csv', index=None, header=True)

# Export 
df_sb_events_passing.to_csv(data_dir + '/export/' + '/sb_wsl_events_passing_matrix.csv', index=None, header=True)

# %%
df_sb_events_passing_city_utd = df_sb_events_passing[df_sb_events_passing['Full_Fixture_Date'] == '2019-09-07 Manchester City WFC 1  vs.  0 Manchester United']

# %%
df_sb_events_passing_city_utd.head()
# Out:
#                                           id  index  period     timestamp  \
# 515710  ab619e0b-f5f2-4e1a-af5b-8762f47caa5d      5       1  00:00:01.041
# 515711  aed540cb-c9a9-4887-ace7-cc1b7bf00671      6       1  00:00:01.808
# 515712  a3cb5d58-4271-41ef-8127-744db21b2a15      7       1  00:00:01.808
# 515713  3b086c48-160e-4585-aab0-9a7be6405fdb      8       1  00:00:02.326
# 515714  5245e6e0-cde6-4041-b1a1-328c73277ebf      9       1  00:00:02.579
#
#         minute  second  possession  duration  type.id      type.name  \
# 515710       0       1           2  0.766714       30           Pass
# 515711       0       1           2       NaN       42  Ball Receipt*
# 515712       0       1           2  0.771229       43          Carry
# 515713       0       2           2  0.552478       17       Pressure
# 515714       0       2           2  1.774316       30           Pass
#
#         possession_team.id possession_team.name  play_pattern.id  \
# 515710                1475    Manchester United                9
# 515711                1475    Manchester United                9
# 515712                1475    Manchester United                9
# 515713                1475    Manchester United                9
# 515714                1475    Manchester United                9
#
#        play_pattern.name  team.id            team.name  tactics.formation  \
# 515710     From Kick Off     1475    Manchester United                NaN
# 515711     From Kick Off     1475    Manchester United                NaN
# 515712     From Kick Off     1475    Manchester United                NaN
# 515713     From Kick Off      746  Manchester City WFC                NaN
# 515714     From Kick Off     1475    Manchester United                NaN
#
#        tactics.lineup                                     related_events  \
# 515710            NaN             [aed540cb-c9a9-4887-ace7-cc1b7bf00671]
# 515711            NaN             [ab619e0b-f5f2-4e1a-af5b-8762f47caa5d]
# 515712            NaN  [3b086c48-160e-4585-aab0-9a7be6405fdb, 5245e6e...
# 515713            NaN  [5245e6e0-cde6-4041-b1a1-328c73277ebf, a3cb5d5...
# 515714            NaN  [3b086c48-160e-4585-aab0-9a7be6405fdb, 49a2740...
#
#           location  player.id    player.name  position.id  \
# 515710  60.0, 40.0     4653.0      Jane Ross         23.0
# 515711  51.3, 40.0    31540.0    Katie Zelem         10.0
# 515712  51.3, 40.0    31540.0    Katie Zelem         10.0
# 515713  64.3, 44.0     4992.0  Janine Beckie         23.0
# 515714  53.9, 37.8    31540.0    Katie Zelem         10.0
#
#                     position.name  pass.recipient.id pass.recipient.name  \
# 515710             Center Forward            31540.0         Katie Zelem
# 515711  Center Defensive Midfield                NaN                 NaN
# 515712  Center Defensive Midfield                NaN                 NaN
# 515713             Center Forward                NaN                 NaN
# 515714  Center Defensive Midfield            31539.0         Leah Galton
#
#         pass.length  pass.angle  pass.height.id pass.height.name  \
# 515710     8.700000    3.141593             1.0      Ground Pass
# 515711          NaN         NaN             NaN              NaN
# 515712          NaN         NaN             NaN              NaN
# 515713          NaN         NaN             NaN              NaN
# 515714    25.881653   -0.774470             3.0        High Pass
#
#        pass.end_location  pass.type.id pass.type.name  pass.body_part.id  \
# 515710        51.3, 40.0          65.0       Kick Off               40.0
# 515711               nan           NaN            NaN                NaN
# 515712               nan           NaN            NaN                NaN
# 515713               nan           NaN            NaN                NaN
# 515714        72.4, 19.7           NaN            NaN               40.0
#
#        pass.body_part.name carry.end_location under_pressure  pass.outcome.id  \
# 515710          Right Foot                nan            NaN              NaN
# 515711                 NaN                nan            NaN              NaN
# 515712                 NaN         53.9, 37.8           True              NaN
# 515713                 NaN                nan            NaN              NaN
# 515714          Right Foot                nan           True              9.0
#
#        pass.outcome.name  ball_receipt.outcome.id ball_receipt.outcome.name  \
# 515710               NaN                      NaN                       NaN
# 515711               NaN                      NaN                       NaN
# 515712               NaN                      NaN                       NaN
# 515713               NaN                      NaN                       NaN
# 515714        Incomplete                      NaN                       NaN
#
#        counterpress  duel.type.id duel.type.name pass.aerial_won  \
# 515710          NaN           NaN            NaN             NaN
# 515711          NaN           NaN            NaN             NaN
# 515712          NaN           NaN            NaN             NaN
# 515713          NaN           NaN            NaN             NaN
# 515714          NaN           NaN            NaN             NaN
#
#         interception.outcome.id interception.outcome.name  dribble.outcome.id  \
# 515710                      NaN                       NaN                 NaN
# 515711                      NaN                       NaN                 NaN
# 515712                      NaN                       NaN                 NaN
# 515713                      NaN                       NaN                 NaN
# 515714                      NaN                       NaN                 NaN
#
#        dribble.outcome.name pass.assisted_shot_id pass.shot_assist  \
# 515710                  NaN                   NaN              NaN
# 515711                  NaN                   NaN              NaN
# 515712                  NaN                   NaN              NaN
# 515713                  NaN                   NaN              NaN
# 515714                  NaN                   NaN              NaN
#
#         shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 515710                NaN               nan              NaN
# 515711                NaN               nan              NaN
# 515712                NaN               nan              NaN
# 515713                NaN               nan              NaN
# 515714                NaN               nan              NaN
#
#         shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 515710                NaN                 NaN           NaN            NaN
# 515711                NaN                 NaN           NaN            NaN
# 515712                NaN                 NaN           NaN            NaN
# 515713                NaN                 NaN           NaN            NaN
# 515714                NaN                 NaN           NaN            NaN
#
#         shot.outcome.id shot.outcome.name  shot.technique.id  \
# 515710              NaN               NaN                NaN
# 515711              NaN               NaN                NaN
# 515712              NaN               NaN                NaN
# 515713              NaN               NaN                NaN
# 515714              NaN               NaN                NaN
#
#        shot.technique.name shot.freeze_frame goalkeeper.end_location  \
# 515710                 NaN               NaN                     nan
# 515711                 NaN               NaN                     nan
# 515712                 NaN               NaN                     nan
# 515713                 NaN               NaN                     nan
# 515714                 NaN               NaN                     nan
#
#         goalkeeper.position.id goalkeeper.position.name  goalkeeper.type.id  \
# 515710                     NaN                      NaN                 NaN
# 515711                     NaN                      NaN                 NaN
# 515712                     NaN                      NaN                 NaN
# 515713                     NaN                      NaN                 NaN
# 515714                     NaN                      NaN                 NaN
#
#        goalkeeper.type.name off_camera  duel.outcome.id duel.outcome.name  \
# 515710                  NaN        NaN              NaN               NaN
# 515711                  NaN        NaN              NaN               NaN
# 515712                  NaN        NaN              NaN               NaN
# 515713                  NaN        NaN              NaN               NaN
# 515714                  NaN        NaN              NaN               NaN
#
#        pass.switch ball_recovery.recovery_failure  50_50.outcome.id  \
# 515710         NaN                            NaN               NaN
# 515711         NaN                            NaN               NaN
# 515712         NaN                            NaN               NaN
# 515713         NaN                            NaN               NaN
# 515714         NaN                            NaN               NaN
#
#        50_50.outcome.name  foul_committed.card.id foul_committed.card.name  \
# 515710                NaN                     NaN                      NaN
# 515711                NaN                     NaN                      NaN
# 515712                NaN                     NaN                      NaN
# 515713                NaN                     NaN                      NaN
# 515714                NaN                     NaN                      NaN
#
#        shot.one_on_one shot.aerial_won pass.through_ball  pass.technique.id  \
# 515710             NaN             NaN               NaN                NaN
# 515711             NaN             NaN               NaN                NaN
# 515712             NaN             NaN               NaN                NaN
# 515713             NaN             NaN               NaN                NaN
# 515714             NaN             NaN               NaN                NaN
#
#        pass.technique.name  goalkeeper.outcome.id goalkeeper.outcome.name  \
# 515710                 NaN                    NaN                     NaN
# 515711                 NaN                    NaN                     NaN
# 515712                 NaN                    NaN                     NaN
# 515713                 NaN                    NaN                     NaN
# 515714                 NaN                    NaN                     NaN
#
#         goalkeeper.technique.id goalkeeper.technique.name  \
# 515710                      NaN                       NaN
# 515711                      NaN                       NaN
# 515712                      NaN                       NaN
# 515713                      NaN                       NaN
# 515714                      NaN                       NaN
#
#         goalkeeper.body_part.id goalkeeper.body_part.name  \
# 515710                      NaN                       NaN
# 515711                      NaN                       NaN
# 515712                      NaN                       NaN
# 515713                      NaN                       NaN
# 515714                      NaN                       NaN
#
#         substitution.outcome.id substitution.outcome.name  \
# 515710                      NaN                       NaN
# 515711                      NaN                       NaN
# 515712                      NaN                       NaN
# 515713                      NaN                       NaN
# 515714                      NaN                       NaN
#
#         substitution.replacement.id substitution.replacement.name  \
# 515710                          NaN                           NaN
# 515711                          NaN                           NaN
# 515712                          NaN                           NaN
# 515713                          NaN                           NaN
# 515714                          NaN                           NaN
#
#        foul_won.defensive clearance.aerial_won pass.backheel pass.cross  \
# 515710                NaN                  NaN           NaN        NaN
# 515711                NaN                  NaN           NaN        NaN
# 515712                NaN                  NaN           NaN        NaN
# 515713                NaN                  NaN           NaN        NaN
# 515714                NaN                  NaN           NaN        NaN
#
#        foul_committed.offensive foul_committed.advantage foul_won.advantage  \
# 515710                      NaN                      NaN                NaN
# 515711                      NaN                      NaN                NaN
# 515712                      NaN                      NaN                NaN
# 515713                      NaN                      NaN                NaN
# 515714                      NaN                      NaN                NaN
#
#        dribble.overrun foul_committed.penalty foul_won.penalty  \
# 515710             NaN                    NaN              NaN
# 515711             NaN                    NaN              NaN
# 515712             NaN                    NaN              NaN
# 515713             NaN                    NaN              NaN
# 515714             NaN                    NaN              NaN
#
#        injury_stoppage.in_chain miscontrol.aerial_won block.offensive  \
# 515710                      NaN                   NaN             NaN
# 515711                      NaN                   NaN             NaN
# 515712                      NaN                   NaN             NaN
# 515713                      NaN                   NaN             NaN
# 515714                      NaN                   NaN             NaN
#
#         match_id shot.open_goal shot.first_time dribble.nutmeg pass.cut_back  \
# 515710   2275136            NaN             NaN            NaN           NaN
# 515711   2275136            NaN             NaN            NaN           NaN
# 515712   2275136            NaN             NaN            NaN           NaN
# 515713   2275136            NaN             NaN            NaN           NaN
# 515714   2275136            NaN             NaN            NaN           NaN
#
#        pass.deflected pass.goal_assist  foul_committed.type.id  \
# 515710            NaN              NaN                     NaN
# 515711            NaN              NaN                     NaN
# 515712            NaN              NaN                     NaN
# 515713            NaN              NaN                     NaN
# 515714            NaN              NaN                     NaN
#
#        foul_committed.type.name pass.miscommunication ball_recovery.offensive  \
# 515710                      NaN                   NaN                     NaN
# 515711                      NaN                   NaN                     NaN
# 515712                      NaN                   NaN                     NaN
# 515713                      NaN                   NaN                     NaN
# 515714                      NaN                   NaN                     NaN
#
#        block.save_block block.deflection clearance.head  \
# 515710              NaN              NaN            NaN
# 515711              NaN              NaN            NaN
# 515712              NaN              NaN            NaN
# 515713              NaN              NaN            NaN
# 515714              NaN              NaN            NaN
#
#         clearance.body_part.id clearance.body_part.name  out  \
# 515710                     NaN                      NaN  NaN
# 515711                     NaN                      NaN  NaN
# 515712                     NaN                      NaN  NaN
# 515713                     NaN                      NaN  NaN
# 515714                     NaN                      NaN  NaN
#
#        clearance.left_foot clearance.right_foot pass.inswinging pass.straight  \
# 515710                 NaN                  NaN             NaN           NaN
# 515711                 NaN                  NaN             NaN           NaN
# 515712                 NaN                  NaN             NaN           NaN
# 515713                 NaN                  NaN             NaN           NaN
# 515714                 NaN                  NaN             NaN           NaN
#
#        clearance.other pass.outswinging shot.redirect shot.deflected  \
# 515710             NaN              NaN           NaN            NaN
# 515711             NaN              NaN           NaN            NaN
# 515712             NaN              NaN           NaN            NaN
# 515713             NaN              NaN           NaN            NaN
# 515714             NaN              NaN           NaN            NaN
#
#         bad_behaviour.card.id bad_behaviour.card.name pass.no_touch  \
# 515710                    NaN                     NaN           NaN
# 515711                    NaN                     NaN           NaN
# 515712                    NaN                     NaN           NaN
# 515713                    NaN                     NaN           NaN
# 515714                    NaN                     NaN           NaN
#
#        dribble.no_touch shot.saved_off_target  \
# 515710              NaN                   NaN
# 515711              NaN                   NaN
# 515712              NaN                   NaN
# 515713              NaN                   NaN
# 515714              NaN                   NaN
#
#        goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 515710                              NaN                 NaN
# 515711                              NaN                 NaN
# 515712                              NaN                 NaN
# 515713                              NaN                 NaN
# 515714                              NaN                 NaN
#
#        goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 515710                    NaN                  NaN                NaN
# 515711                    NaN                  NaN                NaN
# 515712                    NaN                  NaN                NaN
# 515713                    NaN                  NaN                NaN
# 515714                    NaN                  NaN                NaN
#
#        goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 515710                           NaN                     NaN
# 515711                           NaN                     NaN
# 515712                           NaN                     NaN
# 515713                           NaN                     NaN
# 515714                           NaN                     NaN
#
#        goalkeeper.success_out shot.follows_dribble  \
# 515710                    NaN                  NaN
# 515711                    NaN                  NaN
# 515712                    NaN                  NaN
# 515713                    NaN                  NaN
# 515714                    NaN                  NaN
#
#        half_start.late_video_start goalkeeper.success_in_play  \
# 515710                         NaN                        NaN
# 515711                         NaN                        NaN
# 515712                         NaN                        NaN
# 515713                         NaN                        NaN
# 515714                         NaN                        NaN
#
#        half_end.early_video_end goalkeeper.saved_to_post  match_date  \
# 515710                      NaN                      NaN  2019-09-07
# 515711                      NaN                      NaN  2019-09-07
# 515712                      NaN                      NaN  2019-09-07
# 515713                      NaN                      NaN  2019-09-07
# 515714                      NaN                      NaN  2019-09-07
#
#             kick_off  home_score  away_score match_status      last_updated  \
# 515710  16:00:00.000           1           0    available  2020-07-29T05:00
# 515711  16:00:00.000           1           0    available  2020-07-29T05:00
# 515712  16:00:00.000           1           0    available  2020-07-29T05:00
# 515713  16:00:00.000           1           0    available  2020-07-29T05:00
# 515714  16:00:00.000           1           0    available  2020-07-29T05:00
#
#         match_week  competition.competition_id competition.country_name  \
# 515710           1                          37                  England
# 515711           1                          37                  England
# 515712           1                          37                  England
# 515713           1                          37                  England
# 515714           1                          37                  England
#
#        competition.competition_name  season.season_id season.season_name  \
# 515710      FA Women's Super League                42          2019/2020
# 515711      FA Women's Super League                42          2019/2020
# 515712      FA Women's Super League                42          2019/2020
# 515713      FA Women's Super League                42          2019/2020
# 515714      FA Women's Super League                42          2019/2020
#
#         home_team.home_team_id home_team.home_team_name  \
# 515710                     746      Manchester City WFC
# 515711                     746      Manchester City WFC
# 515712                     746      Manchester City WFC
# 515713                     746      Manchester City WFC
# 515714                     746      Manchester City WFC
#
#        home_team.home_team_gender home_team.home_team_group  \
# 515710                     female                      None
# 515711                     female                      None
# 515712                     female                      None
# 515713                     female                      None
# 515714                     female                      None
#
#         home_team.country.id home_team.country.name  \
# 515710                    68                England
# 515711                    68                England
# 515712                    68                England
# 515713                    68                England
# 515714                    68                England
#
#                                        home_team.managers  \
# 515710  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# 515711  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# 515712  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# 515713  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
# 515714  [{'id': 30, 'name': 'Nick Cushing', 'nickname'...
#
#         away_team.away_team_id away_team.away_team_name  \
# 515710                    1475        Manchester United
# 515711                    1475        Manchester United
# 515712                    1475        Manchester United
# 515713                    1475        Manchester United
# 515714                    1475        Manchester United
#
#        away_team.away_team_gender away_team.away_team_group  \
# 515710                     female                      None
# 515711                     female                      None
# 515712                     female                      None
# 515713                     female                      None
# 515714                     female                      None
#
#         away_team.country.id away_team.country.name  \
# 515710                    68                England
# 515711                    68                England
# 515712                    68                England
# 515713                    68                England
# 515714                    68                England
#
#                                        away_team.managers  \
# 515710  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 515711  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 515712  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 515713  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
# 515714  [{'id': 2926, 'name': 'Casey Stoney', 'nicknam...
#
#        metadata.data_version  competition_stage.id competition_stage.name  \
# 515710                 1.1.0                     1         Regular Season
# 515711                 1.1.0                     1         Regular Season
# 515712                 1.1.0                     1         Regular Season
# 515713                 1.1.0                     1         Regular Season
# 515714                 1.1.0                     1         Regular Season
#
#         stadium.id    stadium.name  stadium.country.id stadium.country.name  \
# 515710      4715.0  Etihad Stadium                68.0              England
# 515711      4715.0  Etihad Stadium                68.0              England
# 515712      4715.0  Etihad Stadium                68.0              England
# 515713      4715.0  Etihad Stadium                68.0              England
# 515714      4715.0  Etihad Stadium                68.0              England
#
#         referee.id referee.name  referee.country.id referee.country.name  \
# 515710       977.0    R. Welch                  NaN                  NaN
# 515711       977.0    R. Welch                  NaN                  NaN
# 515712       977.0    R. Welch                  NaN                  NaN
# 515713       977.0    R. Welch                  NaN                  NaN
# 515714       977.0    R. Welch                  NaN                  NaN
#
#        metadata.shot_fidelity_version metadata.xy_fidelity_version  \
# 515710                              2                            2
# 515711                              2                            2
# 515712                              2                            2
# 515713                              2                            2
# 515714                              2                            2
#
#         competition_id  season_id country_name         competition_name  \
# 515710              37         42      England  FA Women's Super League
# 515711              37         42      England  FA Women's Super League
# 515712              37         42      England  FA Women's Super League
# 515713              37         42      England  FA Women's Super League
# 515714              37         42      England  FA Women's Super League
#
#        competition_gender season_name                 Team  \
# 515710             female   2019/2020    Manchester United
# 515711             female   2019/2020    Manchester United
# 515712             female   2019/2020    Manchester United
# 515713             female   2019/2020  Manchester City WFC
# 515714             female   2019/2020    Manchester United
#
#                    Opponent  \
# 515710  Manchester City WFC
# 515711  Manchester City WFC
# 515712  Manchester City WFC
# 515713    Manchester United
# 515714  Manchester City WFC
#
#                                         Full_Fixture_Date location_x  \
# 515710  2019-09-07 Manchester City WFC 1  vs.  0 Manch...       60.0
# 515711  2019-09-07 Manchester City WFC 1  vs.  0 Manch...       51.3
# 515712  2019-09-07 Manchester City WFC 1  vs.  0 Manch...       51.3
# 515713  2019-09-07 Manchester City WFC 1  vs.  0 Manch...       64.3
# 515714  2019-09-07 Manchester City WFC 1  vs.  0 Manch...       53.9
#
#        location_y pass.end_location_x pass.end_location_y  \
# 515710       40.0                51.3                40.0
# 515711       40.0                 nan                 NaN
# 515712       40.0                 nan                 NaN
# 515713       44.0                 nan                 NaN
# 515714       37.8                72.4                19.7
#
#        carry.end_location_x carry.end_location_y shot.end_location_x  \
# 515710                  nan                  NaN                 nan
# 515711                  nan                  NaN                 nan
# 515712                 53.9                 37.8                 nan
# 515713                  nan                  NaN                 nan
# 515714                  nan                  NaN                 nan
#
#        shot.end_location_y shot.end_location_z goalkeeper.end_location_x  \
# 515710                 NaN                 NaN                       nan
# 515711                 NaN                 NaN                       nan
# 515712                 NaN                 NaN                       nan
# 515713                 NaN                 NaN                       nan
# 515714                 NaN                 NaN                       nan
#
#        goalkeeper.end_location_y df_name Pass_X Pass_Y
# 515710                       NaN     df1   60.0   40.0
# 515711                       NaN     df1   51.3   40.0
# 515712                       NaN     df1   51.3   40.0
# 515713                       NaN     df1   64.3   44.0
# 515714                       NaN     df1   53.9   37.8

# %%
df_sb_events_passing_city_utd.shape
# Out:
# (7192, 210)

# %%
df_sb_events_passing_city_utd.to_csv(data_dir + '/passing_network_test.csv', index=None, header=True)

# %% [markdown]
# #### <a id='#section5.5.4'>5.5.4. Create Passing Network Data</a>
#
# See: https://community.tableau.com/s/question/0D54T00000C6YbE/football-passing-network

# %%
df_sb_pass_network = df_sb_events_passing.copy()

# %%
df_sb_pass_network = df_sb_pass_network[df_sb_pass_network['type.name'] == 'Pass']

# %%
df_sb_pass_network['player_recipient'] = np.where(df_sb_pass_network['df_name'] == 'df1', df_sb_pass_network['player.name'], df_sb_pass_network['pass.recipient.name'])

# %%
df_sb_pass_network.head()
# Out:
#                                       id  index  period     timestamp  minute  \
# 4   ac80414e-cec3-4c56-8e57-ac04149efbe2      5       1  00:00:01.324       0
# 7   88d1ce50-3a00-4c88-90ba-a25e658c0deb      8       1  00:00:03.388       0
# 10  68374d6d-a178-4ffc-b4c7-236736c61ab0     11       1  00:00:05.122       0
# 13  62187430-8a2c-4a84-a0e0-5b84a19b6d6d     14       1  00:00:09.208       0
# 17  c8ffae01-8549-4ca5-8e42-6037f2e1f944     18       1  00:00:12.945       0
#
#     second  possession  duration  type.id type.name  possession_team.id  \
# 4        1           2  1.228695       30      Pass                 971
# 7        3           2  1.693583       30      Pass                 971
# 10       5           2  1.257417       30      Pass                 971
# 13       9           2  1.585060       30      Pass                 971
# 17      12           2  2.457301       30      Pass                 971
#
#    possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4           Chelsea FCW                9     From Kick Off      971
# 7           Chelsea FCW                9     From Kick Off      971
# 10          Chelsea FCW                9     From Kick Off      971
# 13          Chelsea FCW                9     From Kick Off      971
# 17          Chelsea FCW                9     From Kick Off      971
#
#       team.name  tactics.formation tactics.lineup  \
# 4   Chelsea FCW                NaN            NaN
# 7   Chelsea FCW                NaN            NaN
# 10  Chelsea FCW                NaN            NaN
# 13  Chelsea FCW                NaN            NaN
# 17  Chelsea FCW                NaN            NaN
#
#                                        related_events    location  player.id  \
# 4              [89cf3d24-ba04-4269-9071-1dfabf468cd1]  61.0, 41.0     4641.0
# 7              [9f0af77c-93cc-49d5-8d16-b7a640a0b59f]  53.0, 45.0    15549.0
# 10             [c54c86a3-4bdd-47e1-87b7-67101a95ecc3]  38.0, 30.0     4633.0
# 13             [bed1875f-5f95-426e-a9d2-d97073ae7184]  36.0, 57.0     4642.0
# 17  [14dae490-08c9-4239-be0a-4715f99f9e2d, c9d2527...  38.0, 74.0    19422.0
#
#            player.name  position.id             position.name  \
# 4      Francesca Kirby         23.0            Center Forward
# 7         Sophie Ingle          9.0  Right Defensive Midfield
# 10  Magdalena Ericsson          5.0          Left Center Back
# 13       Millie Bright          3.0         Right Center Back
# 17      Jessica Carter          2.0                Right Back
#
#     pass.recipient.id pass.recipient.name  pass.length  pass.angle  \
# 4             15549.0        Sophie Ingle     9.848858    2.723368
# 7              4633.0  Magdalena Ericsson    21.213203   -2.356194
# 10             4642.0       Millie Bright    22.561028    1.794273
# 13            19422.0      Jessica Carter    21.540659    1.190290
# 17             4640.0  Rut Hedvig Lindahl    36.055510   -2.553590
#
#     pass.height.id pass.height.name pass.end_location  pass.type.id  \
# 4              1.0      Ground Pass        52.0, 45.0          65.0
# 7              1.0      Ground Pass        38.0, 30.0           NaN
# 10             1.0      Ground Pass        33.0, 52.0           NaN
# 13             1.0      Ground Pass        44.0, 77.0           NaN
# 17             1.0      Ground Pass         8.0, 54.0           NaN
#
#    pass.type.name  pass.body_part.id pass.body_part.name carry.end_location  \
# 4        Kick Off               40.0          Right Foot                nan
# 7             NaN               40.0          Right Foot                nan
# 10            NaN               38.0           Left Foot                nan
# 13            NaN               40.0          Right Foot                nan
# 17            NaN               40.0          Right Foot                nan
#
#    under_pressure  pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4             NaN              NaN               NaN                      NaN
# 7             NaN              NaN               NaN                      NaN
# 10            NaN              NaN               NaN                      NaN
# 13            NaN              NaN               NaN                      NaN
# 17           True              NaN               NaN                      NaN
#
#    ball_receipt.outcome.name counterpress  duel.type.id duel.type.name  \
# 4                        NaN          NaN           NaN            NaN
# 7                        NaN          NaN           NaN            NaN
# 10                       NaN          NaN           NaN            NaN
# 13                       NaN          NaN           NaN            NaN
# 17                       NaN          NaN           NaN            NaN
#
#    pass.aerial_won  interception.outcome.id interception.outcome.name  \
# 4              NaN                      NaN                       NaN
# 7              NaN                      NaN                       NaN
# 10             NaN                      NaN                       NaN
# 13             NaN                      NaN                       NaN
# 17             NaN                      NaN                       NaN
#
#     dribble.outcome.id dribble.outcome.name pass.assisted_shot_id  \
# 4                  NaN                  NaN                   NaN
# 7                  NaN                  NaN                   NaN
# 10                 NaN                  NaN                   NaN
# 13                 NaN                  NaN                   NaN
# 17                 NaN                  NaN                   NaN
#
#    pass.shot_assist  shot.statsbomb_xg shot.end_location shot.key_pass_id  \
# 4               NaN                NaN               nan              NaN
# 7               NaN                NaN               nan              NaN
# 10              NaN                NaN               nan              NaN
# 13              NaN                NaN               nan              NaN
# 17              NaN                NaN               nan              NaN
#
#     shot.body_part.id shot.body_part.name  shot.type.id shot.type.name  \
# 4                 NaN                 NaN           NaN            NaN
# 7                 NaN                 NaN           NaN            NaN
# 10                NaN                 NaN           NaN            NaN
# 13                NaN                 NaN           NaN            NaN
# 17                NaN                 NaN           NaN            NaN
#
#     shot.outcome.id shot.outcome.name  shot.technique.id shot.technique.name  \
# 4               NaN               NaN                NaN                 NaN
# 7               NaN               NaN                NaN                 NaN
# 10              NaN               NaN                NaN                 NaN
# 13              NaN               NaN                NaN                 NaN
# 17              NaN               NaN                NaN                 NaN
#
#    shot.freeze_frame goalkeeper.end_location  goalkeeper.position.id  \
# 4                NaN                     nan                     NaN
# 7                NaN                     nan                     NaN
# 10               NaN                     nan                     NaN
# 13               NaN                     nan                     NaN
# 17               NaN                     nan                     NaN
#
#    goalkeeper.position.name  goalkeeper.type.id goalkeeper.type.name  \
# 4                       NaN                 NaN                  NaN
# 7                       NaN                 NaN                  NaN
# 10                      NaN                 NaN                  NaN
# 13                      NaN                 NaN                  NaN
# 17                      NaN                 NaN                  NaN
#
#    off_camera  duel.outcome.id duel.outcome.name pass.switch  \
# 4         NaN              NaN               NaN         NaN
# 7         NaN              NaN               NaN         NaN
# 10        NaN              NaN               NaN         NaN
# 13        NaN              NaN               NaN         NaN
# 17        NaN              NaN               NaN         NaN
#
#    ball_recovery.recovery_failure  50_50.outcome.id 50_50.outcome.name  \
# 4                             NaN               NaN                NaN
# 7                             NaN               NaN                NaN
# 10                            NaN               NaN                NaN
# 13                            NaN               NaN                NaN
# 17                            NaN               NaN                NaN
#
#     foul_committed.card.id foul_committed.card.name shot.one_on_one  \
# 4                      NaN                      NaN             NaN
# 7                      NaN                      NaN             NaN
# 10                     NaN                      NaN             NaN
# 13                     NaN                      NaN             NaN
# 17                     NaN                      NaN             NaN
#
#    shot.aerial_won pass.through_ball  pass.technique.id pass.technique.name  \
# 4              NaN               NaN                NaN                 NaN
# 7              NaN               NaN                NaN                 NaN
# 10             NaN               NaN                NaN                 NaN
# 13             NaN               NaN                NaN                 NaN
# 17             NaN               NaN                NaN                 NaN
#
#     goalkeeper.outcome.id goalkeeper.outcome.name  goalkeeper.technique.id  \
# 4                     NaN                     NaN                      NaN
# 7                     NaN                     NaN                      NaN
# 10                    NaN                     NaN                      NaN
# 13                    NaN                     NaN                      NaN
# 17                    NaN                     NaN                      NaN
#
#    goalkeeper.technique.name  goalkeeper.body_part.id  \
# 4                        NaN                      NaN
# 7                        NaN                      NaN
# 10                       NaN                      NaN
# 13                       NaN                      NaN
# 17                       NaN                      NaN
#
#    goalkeeper.body_part.name  substitution.outcome.id  \
# 4                        NaN                      NaN
# 7                        NaN                      NaN
# 10                       NaN                      NaN
# 13                       NaN                      NaN
# 17                       NaN                      NaN
#
#    substitution.outcome.name  substitution.replacement.id  \
# 4                        NaN                          NaN
# 7                        NaN                          NaN
# 10                       NaN                          NaN
# 13                       NaN                          NaN
# 17                       NaN                          NaN
#
#    substitution.replacement.name foul_won.defensive clearance.aerial_won  \
# 4                            NaN                NaN                  NaN
# 7                            NaN                NaN                  NaN
# 10                           NaN                NaN                  NaN
# 13                           NaN                NaN                  NaN
# 17                           NaN                NaN                  NaN
#
#    pass.backheel pass.cross foul_committed.offensive foul_committed.advantage  \
# 4            NaN        NaN                      NaN                      NaN
# 7            NaN        NaN                      NaN                      NaN
# 10           NaN        NaN                      NaN                      NaN
# 13           NaN        NaN                      NaN                      NaN
# 17           NaN        NaN                      NaN                      NaN
#
#    foul_won.advantage dribble.overrun foul_committed.penalty foul_won.penalty  \
# 4                 NaN             NaN                    NaN              NaN
# 7                 NaN             NaN                    NaN              NaN
# 10                NaN             NaN                    NaN              NaN
# 13                NaN             NaN                    NaN              NaN
# 17                NaN             NaN                    NaN              NaN
#
#    injury_stoppage.in_chain miscontrol.aerial_won block.offensive  match_id  \
# 4                       NaN                   NaN             NaN     19743
# 7                       NaN                   NaN             NaN     19743
# 10                      NaN                   NaN             NaN     19743
# 13                      NaN                   NaN             NaN     19743
# 17                      NaN                   NaN             NaN     19743
#
#    shot.open_goal shot.first_time dribble.nutmeg pass.cut_back pass.deflected  \
# 4             NaN             NaN            NaN           NaN            NaN
# 7             NaN             NaN            NaN           NaN            NaN
# 10            NaN             NaN            NaN           NaN            NaN
# 13            NaN             NaN            NaN           NaN            NaN
# 17            NaN             NaN            NaN           NaN            NaN
#
#    pass.goal_assist  foul_committed.type.id foul_committed.type.name  \
# 4               NaN                     NaN                      NaN
# 7               NaN                     NaN                      NaN
# 10              NaN                     NaN                      NaN
# 13              NaN                     NaN                      NaN
# 17              NaN                     NaN                      NaN
#
#    pass.miscommunication ball_recovery.offensive block.save_block  \
# 4                    NaN                     NaN              NaN
# 7                    NaN                     NaN              NaN
# 10                   NaN                     NaN              NaN
# 13                   NaN                     NaN              NaN
# 17                   NaN                     NaN              NaN
#
#    block.deflection clearance.head  clearance.body_part.id  \
# 4               NaN            NaN                     NaN
# 7               NaN            NaN                     NaN
# 10              NaN            NaN                     NaN
# 13              NaN            NaN                     NaN
# 17              NaN            NaN                     NaN
#
#    clearance.body_part.name  out clearance.left_foot clearance.right_foot  \
# 4                       NaN  NaN                 NaN                  NaN
# 7                       NaN  NaN                 NaN                  NaN
# 10                      NaN  NaN                 NaN                  NaN
# 13                      NaN  NaN                 NaN                  NaN
# 17                      NaN  NaN                 NaN                  NaN
#
#    pass.inswinging pass.straight clearance.other pass.outswinging  \
# 4              NaN           NaN             NaN              NaN
# 7              NaN           NaN             NaN              NaN
# 10             NaN           NaN             NaN              NaN
# 13             NaN           NaN             NaN              NaN
# 17             NaN           NaN             NaN              NaN
#
#    shot.redirect shot.deflected  bad_behaviour.card.id  \
# 4            NaN            NaN                    NaN
# 7            NaN            NaN                    NaN
# 10           NaN            NaN                    NaN
# 13           NaN            NaN                    NaN
# 17           NaN            NaN                    NaN
#
#    bad_behaviour.card.name pass.no_touch dribble.no_touch  \
# 4                      NaN           NaN              NaN
# 7                      NaN           NaN              NaN
# 10                     NaN           NaN              NaN
# 13                     NaN           NaN              NaN
# 17                     NaN           NaN              NaN
#
#    shot.saved_off_target goalkeeper.shot_saved_off_target goalkeeper.lost_out  \
# 4                    NaN                              NaN                 NaN
# 7                    NaN                              NaN                 NaN
# 10                   NaN                              NaN                 NaN
# 13                   NaN                              NaN                 NaN
# 17                   NaN                              NaN                 NaN
#
#    goalkeeper.punched_out player_off.permanent shot.saved_to_post  \
# 4                     NaN                  NaN                NaN
# 7                     NaN                  NaN                NaN
# 10                    NaN                  NaN                NaN
# 13                    NaN                  NaN                NaN
# 17                    NaN                  NaN                NaN
#
#    goalkeeper.shot_saved_to_post goalkeeper.lost_in_play  \
# 4                            NaN                     NaN
# 7                            NaN                     NaN
# 10                           NaN                     NaN
# 13                           NaN                     NaN
# 17                           NaN                     NaN
#
#    goalkeeper.success_out shot.follows_dribble half_start.late_video_start  \
# 4                     NaN                  NaN                         NaN
# 7                     NaN                  NaN                         NaN
# 10                    NaN                  NaN                         NaN
# 13                    NaN                  NaN                         NaN
# 17                    NaN                  NaN                         NaN
#
#    goalkeeper.success_in_play half_end.early_video_end  \
# 4                         NaN                      NaN
# 7                         NaN                      NaN
# 10                        NaN                      NaN
# 13                        NaN                      NaN
# 17                        NaN                      NaN
#
#    goalkeeper.saved_to_post  match_date      kick_off  home_score  away_score  \
# 4                       NaN  2018-10-21  13:30:00.000           0           0
# 7                       NaN  2018-10-21  13:30:00.000           0           0
# 10                      NaN  2018-10-21  13:30:00.000           0           0
# 13                      NaN  2018-10-21  13:30:00.000           0           0
# 17                      NaN  2018-10-21  13:30:00.000           0           0
#
#    match_status      last_updated  match_week  competition.competition_id  \
# 4     available  2020-07-29T05:00           6                          37
# 7     available  2020-07-29T05:00           6                          37
# 10    available  2020-07-29T05:00           6                          37
# 13    available  2020-07-29T05:00           6                          37
# 17    available  2020-07-29T05:00           6                          37
#
#    competition.country_name competition.competition_name  season.season_id  \
# 4                   England      FA Women's Super League                 4
# 7                   England      FA Women's Super League                 4
# 10                  England      FA Women's Super League                 4
# 13                  England      FA Women's Super League                 4
# 17                  England      FA Women's Super League                 4
#
#    season.season_name  home_team.home_team_id home_team.home_team_name  \
# 4           2018/2019                     969      Birmingham City WFC
# 7           2018/2019                     969      Birmingham City WFC
# 10          2018/2019                     969      Birmingham City WFC
# 13          2018/2019                     969      Birmingham City WFC
# 17          2018/2019                     969      Birmingham City WFC
#
#    home_team.home_team_gender home_team.home_team_group  home_team.country.id  \
# 4                      female                      None                    68
# 7                      female                      None                    68
# 10                     female                      None                    68
# 13                     female                      None                    68
# 17                     female                      None                    68
#
#    home_team.country.name                                 home_team.managers  \
# 4                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 7                 England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 10                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 13                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
# 17                England  [{'id': 128, 'name': 'Marc Skinner', 'nickname...
#
#     away_team.away_team_id away_team.away_team_name  \
# 4                      971              Chelsea FCW
# 7                      971              Chelsea FCW
# 10                     971              Chelsea FCW
# 13                     971              Chelsea FCW
# 17                     971              Chelsea FCW
#
#    away_team.away_team_gender away_team.away_team_group  away_team.country.id  \
# 4                      female                      None                    68
# 7                      female                      None                    68
# 10                     female                      None                    68
# 13                     female                      None                    68
# 17                     female                      None                    68
#
#    away_team.country.name                                 away_team.managers  \
# 4                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 7                 England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 10                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 13                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
# 17                England  [{'id': 152, 'name': 'Emma Hayes', 'nickname':...
#
#    metadata.data_version  competition_stage.id competition_stage.name  \
# 4                  1.0.3                     1         Regular Season
# 7                  1.0.3                     1         Regular Season
# 10                 1.0.3                     1         Regular Season
# 13                 1.0.3                     1         Regular Season
# 17                 1.0.3                     1         Regular Season
#
#     stadium.id             stadium.name  stadium.country.id  \
# 4       5332.0  SportNation.bet Stadium               255.0
# 7       5332.0  SportNation.bet Stadium               255.0
# 10      5332.0  SportNation.bet Stadium               255.0
# 13      5332.0  SportNation.bet Stadium               255.0
# 17      5332.0  SportNation.bet Stadium               255.0
#
#    stadium.country.name  referee.id referee.name  referee.country.id  \
# 4         International       898.0     A. Fearn                 NaN
# 7         International       898.0     A. Fearn                 NaN
# 10        International       898.0     A. Fearn                 NaN
# 13        International       898.0     A. Fearn                 NaN
# 17        International       898.0     A. Fearn                 NaN
#
#    referee.country.name metadata.shot_fidelity_version  \
# 4                   NaN                            NaN
# 7                   NaN                            NaN
# 10                  NaN                            NaN
# 13                  NaN                            NaN
# 17                  NaN                            NaN
#
#    metadata.xy_fidelity_version  competition_id  season_id country_name  \
# 4                           NaN              37          4      England
# 7                           NaN              37          4      England
# 10                          NaN              37          4      England
# 13                          NaN              37          4      England
# 17                          NaN              37          4      England
#
#            competition_name competition_gender season_name         Team  \
# 4   FA Women's Super League             female   2018/2019  Chelsea FCW
# 7   FA Women's Super League             female   2018/2019  Chelsea FCW
# 10  FA Women's Super League             female   2018/2019  Chelsea FCW
# 13  FA Women's Super League             female   2018/2019  Chelsea FCW
# 17  FA Women's Super League             female   2018/2019  Chelsea FCW
#
#                Opponent                                  Full_Fixture_Date  \
# 4   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 7   Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 10  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 13  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
# 17  Birmingham City WFC  2018-10-21 Birmingham City WFC 0  vs.  0 Chels...
#
#    location_x location_y pass.end_location_x pass.end_location_y  \
# 4        61.0       41.0                52.0                45.0
# 7        53.0       45.0                38.0                30.0
# 10       38.0       30.0                33.0                52.0
# 13       36.0       57.0                44.0                77.0
# 17       38.0       74.0                 8.0                54.0
#
#    carry.end_location_x carry.end_location_y shot.end_location_x  \
# 4                   nan                  NaN                 nan
# 7                   nan                  NaN                 nan
# 10                  nan                  NaN                 nan
# 13                  nan                  NaN                 nan
# 17                  nan                  NaN                 nan
#
#    shot.end_location_y shot.end_location_z goalkeeper.end_location_x  \
# 4                  NaN                 NaN                       nan
# 7                  NaN                 NaN                       nan
# 10                 NaN                 NaN                       nan
# 13                 NaN                 NaN                       nan
# 17                 NaN                 NaN                       nan
#
#    goalkeeper.end_location_y df_name Pass_X Pass_Y    player_recipient
# 4                        NaN     df1   61.0   41.0     Francesca Kirby
# 7                        NaN     df1   53.0   45.0        Sophie Ingle
# 10                       NaN     df1   38.0   30.0  Magdalena Ericsson
# 13                       NaN     df1   36.0   57.0       Millie Bright
# 17                       NaN     df1   38.0   74.0      Jessica Carter

# %%
sorted(df_sb_pass_network.columns)
# Out:
# ['50_50.outcome.id',
#  '50_50.outcome.name',
#  'Full_Fixture_Date',
#  'Opponent',
#  'Pass_X',
#  'Pass_Y',
#  'Team',
#  'away_score',
#  'away_team.away_team_gender',
#  'away_team.away_team_group',
#  'away_team.away_team_id',
#  'away_team.away_team_name',
#  'away_team.country.id',
#  'away_team.country.name',
#  'away_team.managers',
#  'bad_behaviour.card.id',
#  'bad_behaviour.card.name',
#  'ball_receipt.outcome.id',
#  'ball_receipt.outcome.name',
#  'ball_recovery.offensive',
#  'ball_recovery.recovery_failure',
#  'block.deflection',
#  'block.offensive',
#  'block.save_block',
#  'carry.end_location',
#  'carry.end_location_x',
#  'carry.end_location_y',
#  'clearance.aerial_won',
#  'clearance.body_part.id',
#  'clearance.body_part.name',
#  'clearance.head',
#  'clearance.left_foot',
#  'clearance.other',
#  'clearance.right_foot',
#  'competition.competition_id',
#  'competition.competition_name',
#  'competition.country_name',
#  'competition_gender',
#  'competition_id',
#  'competition_name',
#  'competition_stage.id',
#  'competition_stage.name',
#  'counterpress',
#  'country_name',
#  'df_name',
#  'dribble.no_touch',
#  'dribble.nutmeg',
#  'dribble.outcome.id',
#  'dribble.outcome.name',
#  'dribble.overrun',
#  'duel.outcome.id',
#  'duel.outcome.name',
#  'duel.type.id',
#  'duel.type.name',
#  'duration',
#  'foul_committed.advantage',
#  'foul_committed.card.id',
#  'foul_committed.card.name',
#  'foul_committed.offensive',
#  'foul_committed.penalty',
#  'foul_committed.type.id',
#  'foul_committed.type.name',
#  'foul_won.advantage',
#  'foul_won.defensive',
#  'foul_won.penalty',
#  'goalkeeper.body_part.id',
#  'goalkeeper.body_part.name',
#  'goalkeeper.end_location',
#  'goalkeeper.end_location_x',
#  'goalkeeper.end_location_y',
#  'goalkeeper.lost_in_play',
#  'goalkeeper.lost_out',
#  'goalkeeper.outcome.id',
#  'goalkeeper.outcome.name',
#  'goalkeeper.position.id',
#  'goalkeeper.position.name',
#  'goalkeeper.punched_out',
#  'goalkeeper.saved_to_post',
#  'goalkeeper.shot_saved_off_target',
#  'goalkeeper.shot_saved_to_post',
#  'goalkeeper.success_in_play',
#  'goalkeeper.success_out',
#  'goalkeeper.technique.id',
#  'goalkeeper.technique.name',
#  'goalkeeper.type.id',
#  'goalkeeper.type.name',
#  'half_end.early_video_end',
#  'half_start.late_video_start',
#  'home_score',
#  'home_team.country.id',
#  'home_team.country.name',
#  'home_team.home_team_gender',
#  'home_team.home_team_group',
#  'home_team.home_team_id',
#  'home_team.home_team_name',
#  'home_team.managers',
#  'id',
#  'index',
#  'injury_stoppage.in_chain',
#  'interception.outcome.id',
#  'interception.outcome.name',
#  'kick_off',
#  'last_updated',
#  'location',
#  'location_x',
#  'location_y',
#  'match_date',
#  'match_id',
#  'match_status',
#  'match_week',
#  'metadata.data_version',
#  'metadata.shot_fidelity_version',
#  'metadata.xy_fidelity_version',
#  'minute',
#  'miscontrol.aerial_won',
#  'off_camera',
#  'out',
#  'pass.aerial_won',
#  'pass.angle',
#  'pass.assisted_shot_id',
#  'pass.backheel',
#  'pass.body_part.id',
#  'pass.body_part.name',
#  'pass.cross',
#  'pass.cut_back',
#  'pass.deflected',
#  'pass.end_location',
#  'pass.end_location_x',
#  'pass.end_location_y',
#  'pass.goal_assist',
#  'pass.height.id',
#  'pass.height.name',
#  'pass.inswinging',
#  'pass.length',
#  'pass.miscommunication',
#  'pass.no_touch',
#  'pass.outcome.id',
#  'pass.outcome.name',
#  'pass.outswinging',
#  'pass.recipient.id',
#  'pass.recipient.name',
#  'pass.shot_assist',
#  'pass.straight',
#  'pass.switch',
#  'pass.technique.id',
#  'pass.technique.name',
#  'pass.through_ball',
#  'pass.type.id',
#  'pass.type.name',
#  'period',
#  'play_pattern.id',
#  'play_pattern.name',
#  'player.id',
#  'player.name',
#  'player_off.permanent',
#  'player_recipient',
#  'position.id',
#  'position.name',
#  'possession',
#  'possession_team.id',
#  'possession_team.name',
#  'referee.country.id',
#  'referee.country.name',
#  'referee.id',
#  'referee.name',
#  'related_events',
#  'season.season_id',
#  'season.season_name',
#  'season_id',
#  'season_name',
#  'second',
#  'shot.aerial_won',
#  'shot.body_part.id',
#  'shot.body_part.name',
#  'shot.deflected',
#  'shot.end_location',
#  'shot.end_location_x',
#  'shot.end_location_y',
#  'shot.end_location_z',
#  'shot.first_time',
#  'shot.follows_dribble',
#  'shot.freeze_frame',
#  'shot.key_pass_id',
#  'shot.one_on_one',
#  'shot.open_goal',
#  'shot.outcome.id',
#  'shot.outcome.name',
#  'shot.redirect',
#  'shot.saved_off_target',
#  'shot.saved_to_post',
#  'shot.statsbomb_xg',
#  'shot.technique.id',
#  'shot.technique.name',
#  'shot.type.id',
#  'shot.type.name',
#  'stadium.country.id',
#  'stadium.country.name',
#  'stadium.id',
#  'stadium.name',
#  'substitution.outcome.id',
#  'substitution.outcome.name',
#  'substitution.replacement.id',
#  'substitution.replacement.name',
#  'tactics.formation',
#  'tactics.lineup',
#  'team.id',
#  'team.name',
#  'timestamp',
#  'type.id',
#  'type.name',
#  'under_pressure']

# %%
df_sb_pass_network.shape
# Out:
# (352108, 211)

# %%
# Select columns of interest

## Define columns
cols = ['df_name',
        'id',
        'index',
        'competition_name',
        'season_name',
        'match_date',
        'kick_off',
        'Full_Fixture_Date',
        'Team',
        'Opponent',
        'home_team.home_team_name',
        'away_team.away_team_name',
        'home_score',
        'away_score',
        'player_recipient',
        'player.name',
        'pass.recipient.name',
        'position.id',
        'position.name',
        'type.name',
        'pass.type.name',
        'pass.outcome.name',
        'location_x',
        'location_y', 
        'pass.end_location_x',
        'pass.end_location_y',
        'Pass_X',
        'Pass_Y'
       ]

##
df_sb_pass_network_select = df_sb_pass_network[cols]

# %%
df_sb_pass_network_select['pass.to.from'] = df_sb_pass_network_select['player.name'] + ' - ' + df_sb_pass_network_select['pass.recipient.name']
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# List unique values in the df_sb_pass_network_select['pass.outcome.name'] column
df_sb_pass_network_select['pass.outcome.name'].unique()
# Out:
# array([nan, 'Incomplete', 'Out', 'Unknown', 'Injury Clearance',
#        'Pass Offside'], dtype=object)

# %%
df_sb_pass_network_select = df_sb_pass_network_select[df_sb_pass_network_select['pass.outcome.name'].isnull()]

# %%
df_sb_pass_network_select.shape
# Out:
# (256868, 29)

# %%
df_sb_pass_network_select = df_sb_pass_network_select.sort_values(['season_name', 'match_date', 'kick_off', 'Full_Fixture_Date', 'index', 'id', 'df_name'], ascending=[True, True, True, True, True, True, True])

# %%
df_sb_pass_network_select['Pass_X'] = df_sb_pass_network_select['Pass_X'].astype(str).astype(float)
df_sb_pass_network_select['Pass_Y'] = df_sb_pass_network_select['Pass_Y'].astype(str).astype(float)
df_sb_pass_network_select['location_x'] = df_sb_pass_network_select['location_x'].astype(str).astype(float)
df_sb_pass_network_select['location_y'] = df_sb_pass_network_select['location_y'].astype(str).astype(float)
df_sb_pass_network_select['pass.end_location_x'] = df_sb_pass_network_select['pass.end_location_x'].astype(str).astype(float)
df_sb_pass_network_select['pass.end_location_y'] = df_sb_pass_network_select['pass.end_location_y'].astype(str).astype(float)

# %%
df_sb_pass_network_select.dtypes
# Out:
# df_name                      object
# id                           object
# index                         int64
# competition_name             object
# season_name                  object
# match_date                   object
# kick_off                     object
# Full_Fixture_Date            object
# Team                         object
# Opponent                     object
# home_team.home_team_name     object
# away_team.away_team_name     object
# home_score                    int64
# away_score                    int64
# player_recipient             object
# player.name                  object
# pass.recipient.name          object
# position.id                 float64
# position.name                object
# type.name                    object
# pass.type.name               object
# pass.outcome.name            object
# location_x                  float64
# location_y                  float64
# pass.end_location_x         float64
# pass.end_location_y         float64
# Pass_X                      float64
# Pass_Y                      float64
# pass.to.from                 object
# dtype: object

# %%
df_sb_pass_network_select.head()
# Out:
#        df_name                                    id  index  \
# 148316     df1  1c8ebf3c-09af-4571-aeae-6afc0e5e6bf1      5
# 148316     df2  1c8ebf3c-09af-4571-aeae-6afc0e5e6bf1      5
# 148320     df1  7c77c968-d48d-41d3-b8ff-e78803ddb9d0      9
# 148320     df2  7c77c968-d48d-41d3-b8ff-e78803ddb9d0      9
# 148324     df1  0e3a80ea-6af5-40e5-af40-90f2cead6c3b     13
#
#                competition_name season_name  match_date      kick_off  \
# 148316  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 148316  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 148320  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 148320  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 148324  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
#
#                                      Full_Fixture_Date         Team  \
# 148316  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC
# 148316  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC
# 148320  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC
# 148320  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC
# 148324  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC
#
#              Opponent home_team.home_team_name away_team.away_team_name  \
# 148316  Liverpool WFC              Arsenal WFC            Liverpool WFC
# 148316  Liverpool WFC              Arsenal WFC            Liverpool WFC
# 148320  Liverpool WFC              Arsenal WFC            Liverpool WFC
# 148320  Liverpool WFC              Arsenal WFC            Liverpool WFC
# 148324  Liverpool WFC              Arsenal WFC            Liverpool WFC
#
#         home_score  away_score  player_recipient       player.name  \
# 148316           5           0  Vivianne Miedema  Vivianne Miedema
# 148316           5           0         Lia Wälti  Vivianne Miedema
# 148320           5           0         Lia Wälti         Lia Wälti
# 148320           5           0        Lisa Evans         Lia Wälti
# 148324           5           0        Lisa Evans        Lisa Evans
#
#          pass.recipient.name  position.id    position.name type.name  \
# 148316             Lia Wälti         23.0   Center Forward      Pass
# 148316             Lia Wälti         23.0   Center Forward      Pass
# 148320            Lisa Evans         14.0  Center Midfield      Pass
# 148320            Lisa Evans         14.0  Center Midfield      Pass
# 148324  Danielle van de Donk          2.0       Right Back      Pass
#
#        pass.type.name pass.outcome.name  location_x  location_y  \
# 148316       Kick Off               NaN        60.0        40.0
# 148316       Kick Off               NaN        60.0        40.0
# 148320            NaN               NaN        44.0        42.0
# 148320            NaN               NaN        44.0        42.0
# 148324            NaN               NaN        43.0        69.0
#
#         pass.end_location_x  pass.end_location_y  Pass_X  Pass_Y  \
# 148316                 48.0                 39.0    60.0    40.0
# 148316                 48.0                 39.0    48.0    39.0
# 148320                 45.0                 70.0    44.0    42.0
# 148320                 45.0                 70.0    45.0    70.0
# 148324                 69.0                 76.0    43.0    69.0
#
#                              pass.to.from
# 148316       Vivianne Miedema - Lia Wälti
# 148316       Vivianne Miedema - Lia Wälti
# 148320             Lia Wälti - Lisa Evans
# 148320             Lia Wälti - Lisa Evans
# 148324  Lisa Evans - Danielle van de Donk

# %%
#

##
df_sb_pass_network_grouped = (df_sb_pass_network_select
                                  .groupby(['competition_name',
                                            'season_name',
                                            'match_date',
                                            'kick_off',
                                            'Full_Fixture_Date',
                                            'Team',
                                            'Opponent',
                                            'home_team.home_team_name',
                                            'away_team.away_team_name',
                                            'home_score',
                                            'away_score',
                                            'pass.to.from',
                                            'player.name',
                                            'pass.recipient.name',
                                            'player_recipient'
                                           ])
                                  .agg({'pass.to.from': ['count']
                                       })
                             )

##
df_sb_pass_network_grouped.columns = df_sb_pass_network_grouped.columns.droplevel(level=0)

##
df_sb_pass_network_grouped = df_sb_pass_network_grouped.reset_index()

## 
df_sb_pass_network_grouped.columns = ['competition_name',
                                      'season_name',
                                      'match_date',
                                      'kick_off',
                                      'full_fixture_date',
                                      'team',
                                      'opponent',
                                      'home_team_name',
                                      'away_team_name',
                                      'home_score',
                                      'away_score',
                                      'pass_to_from',
                                      'player_name',
                                      'pass_recipient_name',
                                      'player_recipient',
                                      'count_passes',
                                     ]

##
#df_sb_pass_network_grouped['count_passes'] = df_sb_pass_network_grouped['count_passes'] / 2

##
df_sb_pass_network_grouped = df_sb_pass_network_grouped.sort_values(['season_name', 'match_date', 'kick_off', 'full_fixture_date', 'team', 'opponent', 'pass_to_from'], ascending=[True, True, True, True, True, True, True])

##
df_sb_pass_network_grouped.head()
# Out:
#           competition_name season_name  match_date      kick_off  \
# 0  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 1  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 2  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 3  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 4  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
#
#                                 full_fixture_date         team       opponent  \
# 0  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 1  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 2  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 3  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 4  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
#
#   home_team_name away_team_name  home_score  away_score  \
# 0    Arsenal WFC  Liverpool WFC           5           0
# 1    Arsenal WFC  Liverpool WFC           5           0
# 2    Arsenal WFC  Liverpool WFC           5           0
# 3    Arsenal WFC  Liverpool WFC           5           0
# 4    Arsenal WFC  Liverpool WFC           5           0
#
#                           pass_to_from   player_name   pass_recipient_name  \
# 0    Ava Kuyken - Danielle van de Donk    Ava Kuyken  Danielle van de Donk
# 1    Ava Kuyken - Danielle van de Donk    Ava Kuyken  Danielle van de Donk
# 2        Ava Kuyken - Vivianne Miedema    Ava Kuyken      Vivianne Miedema
# 3        Ava Kuyken - Vivianne Miedema    Ava Kuyken      Vivianne Miedema
# 4  Bethany Mead - Danielle van de Donk  Bethany Mead  Danielle van de Donk
#
#        player_recipient  count_passes
# 0            Ava Kuyken             2
# 1  Danielle van de Donk             2
# 2            Ava Kuyken             1
# 3      Vivianne Miedema             1
# 4          Bethany Mead             1

# %%
df_sb_pass_network_grouped.shape
# Out:
# (76920, 16)

# %%
# Select columns of interest

## Define columns
cols = ['Full_Fixture_Date',
        'player.name',
        'position.id',
        'position.name',
        'Pass_X',
        'Pass_Y'
       ]

##
df_sb_pass_network_avg_pass = df_sb_pass_network_select[cols]

# %%
df_sb_pass_network_avg_pass
# Out:
#                                         Full_Fixture_Date       player.name  \
# 148316     2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Vivianne Miedema
# 148316     2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Vivianne Miedema
# 148320     2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC         Lia Wälti
# 148320     2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC         Lia Wälti
# 148324     2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC        Lisa Evans
# ...                                                   ...               ...
# 631681  2020-02-23 West Ham United LFC 4  vs.  2 Liver...        Anke Preuß
# 631697  2020-02-23 West Ham United LFC 4  vs.  2 Liver...   Christie Murray
# 631697  2020-02-23 West Ham United LFC 4  vs.  2 Liver...   Christie Murray
# 631701  2020-02-23 West Ham United LFC 4  vs.  2 Liver...  Rhiannon Roberts
# 631701  2020-02-23 West Ham United LFC 4  vs.  2 Liver...  Rhiannon Roberts
#
#         position.id             position.name  Pass_X  Pass_Y
# 148316         23.0            Center Forward    60.0    40.0
# 148316         23.0            Center Forward    48.0    39.0
# 148320         14.0           Center Midfield    44.0    42.0
# 148320         14.0           Center Midfield    45.0    70.0
# 148324          2.0                Right Back    43.0    69.0
# ...             ...                       ...     ...     ...
# 631681          1.0                Goalkeeper    45.4    47.1
# 631697          9.0  Right Defensive Midfield    72.4    72.0
# 631697          9.0  Right Defensive Midfield    84.1    59.1
# 631701         11.0   Left Defensive Midfield    75.8    51.2
# 631701         11.0   Left Defensive Midfield    99.5     5.3
#
# [256868 rows x 6 columns]

# %%
#

##
df_sb_pass_network_avg_pass_grouped = (df_sb_pass_network_avg_pass 
                                          .groupby(['Full_Fixture_Date',
                                                    'player.name',
                                                    'position.id',
                                                    'position.name',
                                                   ])
                                          .agg({'Pass_X': ['mean'],
                                                'Pass_Y': ['mean']
                                               })
                                     )

##
df_sb_pass_network_avg_pass_grouped.columns = df_sb_pass_network_avg_pass_grouped .columns.droplevel(level=0)

##
df_sb_pass_network_avg_pass_grouped = df_sb_pass_network_avg_pass_grouped.reset_index()

## 
df_sb_pass_network_avg_pass_grouped.columns = ['full_fixture_date',
                                               'player_name',
                                               'position_id',
                                               'position_name',
                                               'avg_location_pass_x',
                                               'avg_location_pass_y'
                                     ]

##
df_sb_pass_network_avg_pass_grouped['avg_location_pass_x'] = df_sb_pass_network_avg_pass_grouped['avg_location_pass_x'].round(decimals=1)
df_sb_pass_network_avg_pass_grouped['avg_location_pass_y'] = df_sb_pass_network_avg_pass_grouped['avg_location_pass_y'].round(decimals=1)

##
df_sb_pass_network_avg_pass_grouped = df_sb_pass_network_avg_pass_grouped.sort_values(['full_fixture_date', 'player_name'], ascending=[True, True])

##
df_sb_pass_network_avg_pass_grouped.head()
# Out:
#                                 full_fixture_date   player_name  position_id  \
# 0  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC    Anke Preuß          1.0
# 1  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC    Ava Kuyken          9.0
# 2  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC    Ava Kuyken         21.0
# 3  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Bethany Mead         17.0
# 4  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Bethany Mead         21.0
#
#               position_name  avg_location_pass_x  avg_location_pass_y
# 0                Goalkeeper                 20.4                 47.9
# 1  Right Defensive Midfield                 55.8                 26.8
# 2                 Left Wing                 35.5                 13.0
# 3                Right Wing                111.0                 65.5
# 4                 Left Wing                 76.9                 46.2

# %%
# Join the Events DataFrame to the Matches DataFrame
df_sb_pass_network_final = pd.merge(df_sb_pass_network_grouped, df_sb_pass_network_avg_pass_grouped, left_on=['full_fixture_date', 'player_recipient'], right_on=['full_fixture_date', 'player_name'])

# %%
## Rename columns
df_sb_pass_network_final = df_sb_pass_network_final.rename(columns={'player_name_x': 'player_name',
                                                                   #'player_name_x': 'player_name'
                                                                   }
                                                          )

# %%
df_sb_pass_network_final.head()
# Out:
#           competition_name season_name  match_date      kick_off  \
# 0  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 1  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 2  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 3  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
# 4  FA Women's Super League   2018/2019  2018-09-09  13:30:00.000
#
#                                 full_fixture_date         team       opponent  \
# 0  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 1  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 2  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 3  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
# 4  2018-09-09 Arsenal WFC 5  vs.  0 Liverpool WFC  Arsenal WFC  Liverpool WFC
#
#   home_team_name away_team_name  home_score  away_score  \
# 0    Arsenal WFC  Liverpool WFC           5           0
# 1    Arsenal WFC  Liverpool WFC           5           0
# 2    Arsenal WFC  Liverpool WFC           5           0
# 3    Arsenal WFC  Liverpool WFC           5           0
# 4    Arsenal WFC  Liverpool WFC           5           0
#
#                         pass_to_from           player_name  \
# 0  Ava Kuyken - Danielle van de Donk            Ava Kuyken
# 1  Ava Kuyken - Danielle van de Donk            Ava Kuyken
# 2      Ava Kuyken - Vivianne Miedema            Ava Kuyken
# 3      Ava Kuyken - Vivianne Miedema            Ava Kuyken
# 4  Danielle van de Donk - Ava Kuyken  Danielle van de Donk
#
#     pass_recipient_name player_recipient  count_passes player_name_y  \
# 0  Danielle van de Donk       Ava Kuyken             2    Ava Kuyken
# 1  Danielle van de Donk       Ava Kuyken             2    Ava Kuyken
# 2      Vivianne Miedema       Ava Kuyken             1    Ava Kuyken
# 3      Vivianne Miedema       Ava Kuyken             1    Ava Kuyken
# 4            Ava Kuyken       Ava Kuyken             1    Ava Kuyken
#
#    position_id             position_name  avg_location_pass_x  \
# 0          9.0  Right Defensive Midfield                 55.8
# 1         21.0                 Left Wing                 35.5
# 2          9.0  Right Defensive Midfield                 55.8
# 3         21.0                 Left Wing                 35.5
# 4          9.0  Right Defensive Midfield                 55.8
#
#    avg_location_pass_y
# 0                 26.8
# 1                 13.0
# 2                 26.8
# 3                 13.0
# 4                 26.8

# %%
df_sb_pass_network_final.shape
# Out:
# (87862, 21)

# %% [markdown]
# ##### Export Dataset

# %%
# Export 
df_sb_pass_network_final.to_csv(data_dir_sb + '/events/engineered/' + '/sb_events_passing_network_1819_2021_wsl.csv', index=None, header=True)

# Export 
df_sb_pass_network_final.to_csv(data_dir + '/export/' + '/sb_wsl_events_passing_network.csv', index=None, header=True)

# %% [markdown]
# ## <a id='#section6'>6. Summary</a>
# This notebook engineers scraped [StatsBomb](https://statsbomb.com/) data using [pandas](http://pandas.pydata.org/).

# %% [markdown]
# ## <a id='#section7'>7. Next Steps</a>
# The next stage is to visualise this data in Tableau.

# %% [markdown]
# ## <a id='#section8'>8. References</a>
#
# #### Data
# *    [StatsBomb](https://statsbomb.com/) data
# *    [StatsBomb](https://github.com/statsbomb/open-data/tree/master/data) open data GitHub repository

# %% [markdown]
# ---
#
# ***Visit my website [EddWebster.com](https://www.eddwebster.com) or my [GitHub Repository](https://github.com/eddwebster) for more projects. If you'd like to get in contact, my Twitter handle is [@eddwebster](http://www.twitter.com/eddwebster) and my email is: edd.j.webster@gmail.com.***

# %% [markdown]
# [Back to the top](#top)
